# %% [markdown]
# # Analysis of DNA-MERFISH for CTP11
#
# by Pu Zheng
#
# 2022.02.15
#
# analysis for dataset:
#
# \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303
#
# This data is DNA of uncleared MERFISH RNA:
#     \\10.245.74.158\Chromatin_NAS_0\20220303-P_brain_M1_nonclear_adaptor

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 38616

# %% [markdown]
# # 0. fov parameters

# %%
reload(ia)
reload(classes)
reload(classes.batch_functions)
reload(classes.field_of_view)
reload(io_tools.load)
reload(get_img_info)
reload(visual_tools)
reload(ia.correction_tools)
reload(ia.correction_tools.alignment)
reload(ia.spot_tools.matching)
reload(ia.segmentation_tools.chromosome)
reload(ia.spot_tools.fitting)

fov_param = {'data_folder':r'\\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303',
             'save_folder':r'\\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303',
             'experiment_type': 'DNA',
             'num_threads': 32,
             'correction_folder':r'\\10.245.74.158\Chromatin_NAS_0\Corrections\20210621-Corrections_lumencor_from_60_to_50',
             'shared_parameters':{
                     'single_im_size':[50,2048,2048],
                     'distance_zxy': [250, 108, 108],
                     'corr_channels':['750','647','561'],
                     'num_empty_frames': 0, 
                     'num_buffer_frames':0,
                     'corr_hot_pixel':True,
                     'corr_Z_shift':False,
                     'corr_bleed':True,
                     'min_num_seeds':10,
                     'max_num_seeds': 20000,
                     'spot_seeding_th': 1000,
                     'normalize_intensity_local':False,
                     'normalize_intensity_background':False,
                     'corr_gaussian_highpass':False,
                 }, 
             }

# %% [markdown]
# # 1. Process Fov

# %%
_overwrite = False
_save_images = False
#sel_fov_ids = np.arange(50, 100) # batch2 in franklin

sel_fov_ids = np.arange(50, 158) # batch3 in franklin

for _fov_id in sel_fov_ids:
    
    if 'bad_fovs_ids' in locals() and  _fov_id in bad_fovs_ids:
        continue
    
    fov = classes.field_of_view.Field_of_View(fov_param, _fov_id=_fov_id,
                                              _color_info_kwargs={
                                                  '_color_filename':'Color_Usage',
                                              }, 
                                              _prioritize_saved_attrs=False,
                                              _save_info_to_file=False, # whether overwrite
                                              )
    
    # 2. Process image into candidate spots
    fov.parallel = True
    fov.combo_ref_id = 0
    fov._process_image_to_spots('combo', 
                                _load_common_reference=True, _load_with_multiple=False,
                                _save_images=_save_images,
                                _warp_images=False, 
                                _fit_spots=True,
                                _overwrite_drift=False, _overwrite_image=_overwrite,
                                _overwrite_spot=_overwrite,
                                _verbose=True)
    # 3. Process image into candidate spots
    fov.unique_ref_id = 0
    fov._process_image_to_spots('unique', 
                                _load_common_reference=True, _load_with_multiple=False,
                                _save_images=_save_images, _warp_images=False, _verbose=True)
    # 4. Process DAPI image
    fov._load_dapi_image()
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_050.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 6.781s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_050.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_050.hdf5
# ++ base attributes loaded:[] in 0.013s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.172s.
# -- checking combo, region:[ 3  4 68] in 0.016s.
# -- checking combo, region:[ 5  6 69] in 0.045s.
# -- checking combo, region:[ 7  8 70] in 0.066s.
# -- checking combo, region:[ 9 10 71] in 0.080s.
# -- checking combo, region:[11 12 72] in 0.027s.
# -- checking combo, region:[13 14 73] in 0.032s.
# -- checking combo, region:[15 16 74] in 0.041s.
# -- checking combo, region:[17 18 75] in 0.028s.
# -- checking combo, region:[19 20 76] in 0.026s.
# -- checking combo, region:[21 22 77] in 0.035s.
# -- checking combo, region:[23 24 78] in 0.029s.
# -- checking combo, region:[25 26 79] in 0.023s.
# -- checking combo, region:[27 28 80] in 0.019s.
# -- checking combo, region:[29 30 81] in 0.034s.
# -- checking combo, region:[31 32 82] in 0.014s.
# -- checking combo, region:[33 34 83] in 0.033s.
# -- checking combo, region:[35 36 84] in 0.032s.
# -- checking combo, region:[37 38 85] in 0.027s.
# -- checking combo, region:[39 40 86] in 0.026s.
# -- checking combo, region:[41 42 87] in 0.021s.
# -- checking combo, region:[43 44 88] in 0.037s.
# -- checking combo, region:[45 46 89] in 0.025s.
# -- checking combo, region:[47 48 90] in 0.034s.
# -- checking combo, region:[49 50 91] in 0.028s.
# -- checking combo, region:[51 52 92] in 0.039s.
# -- checking combo, region:[53 54 93] in 0.029s.
# -- checking combo, region:[55 56 94] in 0.027s.
# -- checking combo, region:[57 58 95] in 0.031s.
# -- checking combo, region:[59 60 96] in 0.033s.
# -- checking combo, region:[61 62 97] in 0.030s.
# -- checking combo, region:[63 64 98] in 0.042s.
# -- checking combo, region:[65 66 99] in 0.067s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.015s.
# -- checking unique, region:[3 4] in 0.022s.
# -- checking unique, region:[5 6] in 0.038s.
# -- checking unique, region:[7 8] in 0.020s.
# -- checking unique, region:[ 9 10] in 0.027s.
# -- checking unique, region:[11 12] in 0.024s.
# -- checking unique, region:[13 14] in 0.025s.
# -- checking unique, region:[15 16] in 0.021s.
# -- checking unique, region:[17 18] in 0.047s.
# -- checking unique, region:[19 20] in 0.040s.
# -- checking unique, region:[21 22] in 0.026s.
# -- checking unique, region:[23 24] in 0.035s.
# -- checking unique, region:[25 26] in 0.048s.
# -- checking unique, region:[27 28] in 0.046s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_051.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.406s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_051.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_051.hdf5
# ++ base attributes loaded:[] in 0.015s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.031s.
# -- checking combo, region:[ 3  4 68] in 0.037s.
# -- checking combo, region:[ 5  6 69] in 0.010s.
# -- checking combo, region:[ 7  8 70] in 0.047s.
# -- checking combo, region:[ 9 10 71] in 0.031s.
# -- checking combo, region:[11 12 72] in 0.016s.
# -- checking combo, region:[13 14 73] in 0.031s.
# -- checking combo, region:[15 16 74] in 0.047s.
# -- checking combo, region:[17 18 75] in 0.048s.
# -- checking combo, region:[19 20 76] in 0.052s.
# -- checking combo, region:[21 22 77] in 0.165s.
# -- checking combo, region:[23 24 78] in 0.129s.
# -- checking combo, region:[25 26 79] in 0.027s.
# -- checking combo, region:[27 28 80] in 0.047s.
# -- checking combo, region:[29 30 81] in 0.094s.
# -- checking combo, region:[31 32 82] in 0.048s.
# -- checking combo, region:[33 34 83] in 0.031s.
# -- checking combo, region:[35 36 84] in 0.048s.
# -- checking combo, region:[37 38 85] in 0.030s.
# -- checking combo, region:[39 40 86] in 0.031s.
# -- checking combo, region:[41 42 87] in 0.016s.
# -- checking combo, region:[43 44 88] in 0.047s.
# -- checking combo, region:[45 46 89] in 0.033s.
# -- checking combo, region:[47 48 90] in 0.030s.
# -- checking combo, region:[49 50 91] in 0.032s.
# -- checking combo, region:[51 52 92] in 0.045s.
# -- checking combo, region:[53 54 93] in 0.016s.
# -- checking combo, region:[55 56 94] in 0.032s.
# -- checking combo, region:[57 58 95] in 0.047s.
# -- checking combo, region:[59 60 96] in 0.032s.
# -- checking combo, region:[61 62 97] in 0.016s.
# -- checking combo, region:[63 64 98] in 0.047s.
# -- checking combo, region:[65 66 99] in 0.031s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.032s.
# -- checking unique, region:[3 4] in 0.016s.
# -- checking unique, region:[5 6] in 0.016s.
# -- checking unique, region:[7 8] in 0.025s.
# -- checking unique, region:[ 9 10] in 0.012s.
# -- checking unique, region:[11 12] in 0.014s.
# -- checking unique, region:[13 14] in 0.026s.
# -- checking unique, region:[15 16] in 0.032s.
# -- checking unique, region:[17 18] in 0.041s.
# -- checking unique, region:[19 20] in 0.046s.
# -- checking unique, region:[21 22] in 0.031s.
# -- checking unique, region:[23 24] in 0.037s.
# -- checking unique, region:[25 26] in 0.026s.
# -- checking unique, region:[27 28] in 0.047s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_052.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.501s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_052.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_052.hdf5
# ++ base attributes loaded:[] in 0.012s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.127s.
# -- checking combo, region:[ 3  4 68] in 0.029s.
# -- checking combo, region:[ 5  6 69] in 0.016s.
# -- checking combo, region:[ 7  8 70] in 0.031s.
# -- checking combo, region:[ 9 10 71] in 0.047s.
# -- checking combo, region:[11 12 72] in 0.031s.
# -- checking combo, region:[13 14 73] in 0.016s.
# -- checking combo, region:[15 16 74] in 0.050s.
# -- checking combo, region:[17 18 75] in 0.015s.
# -- checking combo, region:[19 20 76] in 0.038s.
# -- checking combo, region:[21 22 77] in 0.038s.
# -- checking combo, region:[23 24 78] in 0.031s.
# -- checking combo, region:[25 26 79] in 0.031s.
# -- checking combo, region:[27 28 80] in 0.016s.
# -- checking combo, region:[29 30 81] in 0.031s.
# -- checking combo, region:[31 32 82] in 0.042s.
# -- checking combo, region:[33 34 83] in 0.022s.
# -- checking combo, region:[35 36 84] in 0.045s.
# -- checking combo, region:[37 38 85] in 0.032s.
# -- checking combo, region:[39 40 86] in 0.016s.
# -- checking combo, region:[41 42 87] in 0.031s.
# -- checking combo, region:[43 44 88] in 0.046s.
# -- checking combo, region:[45 46 89] in 0.019s.
# -- checking combo, region:[47 48 90] in 0.034s.
# -- checking combo, region:[49 50 91] in 0.089s.
# -- checking combo, region:[51 52 92] in 0.078s.
# -- checking combo, region:[53 54 93] in 0.055s.
# -- checking combo, region:[55 56 94] in 0.043s.
# -- checking combo, region:[57 58 95] in 0.088s.
# -- checking combo, region:[59 60 96] in 0.047s.
# -- checking combo, region:[61 62 97] in 0.046s.
# -- checking combo, region:[63 64 98] in 0.017s.
# -- checking combo, region:[65 66 99] in 0.061s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.042s.
# -- checking unique, region:[3 4] in 0.019s.
# -- checking unique, region:[5 6] in 0.031s.
# -- checking unique, region:[7 8] in 0.038s.
# -- checking unique, region:[ 9 10] in 0.031s.
# -- checking unique, region:[11 12] in 0.031s.
# -- checking unique, region:[13 14] in 0.023s.
# -- checking unique, region:[15 16] in 0.031s.
# -- checking unique, region:[17 18] in 0.016s.
# -- checking unique, region:[19 20] in 0.030s.
# -- checking unique, region:[21 22] in 0.021s.
# -- checking unique, region:[23 24] in 0.016s.
# -- checking unique, region:[25 26] in 0.016s.
# -- checking unique, region:[27 28] in 0.015s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_053.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.563s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_053.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_053.hdf5
# ++ base attributes loaded:[] in 0.009s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.183s.
# -- checking combo, region:[ 3  4 68] in 0.021s.
# -- checking combo, region:[ 5  6 69] in 0.046s.
# -- checking combo, region:[ 7  8 70] in 0.078s.
# -- checking combo, region:[ 9 10 71] in 0.078s.
# -- checking combo, region:[11 12 72] in 0.031s.
# -- checking combo, region:[13 14 73] in 0.050s.
# -- checking combo, region:[15 16 74] in 0.075s.
# -- checking combo, region:[17 18 75] in 0.047s.
# -- checking combo, region:[19 20 76] in 0.042s.
# -- checking combo, region:[21 22 77] in 0.098s.
# -- checking combo, region:[23 24 78] in 0.094s.
# -- checking combo, region:[25 26 79] in 0.050s.
# -- checking combo, region:[27 28 80] in 0.041s.
# -- checking combo, region:[29 30 81] in 0.033s.
# -- checking combo, region:[31 32 82] in 0.031s.
# -- checking combo, region:[33 34 83] in 0.031s.
# -- checking combo, region:[35 36 84] in 0.031s.
# -- checking combo, region:[37 38 85] in 0.034s.
# -- checking combo, region:[39 40 86] in 0.016s.
# -- checking combo, region:[41 42 87] in 0.040s.
# -- checking combo, region:[43 44 88] in 0.036s.
# -- checking combo, region:[45 46 89] in 0.031s.
# -- checking combo, region:[47 48 90] in 0.016s.
# -- checking combo, region:[49 50 91] in 0.047s.
# -- checking combo, region:[51 52 92] in 0.063s.
# -- checking combo, region:[53 54 93] in 0.039s.
# -- checking combo, region:[55 56 94] in 0.029s.
# -- checking combo, region:[57 58 95] in 0.056s.
# -- checking combo, region:[59 60 96] in 0.031s.
# -- checking combo, region:[61 62 97] in 0.031s.
# -- checking combo, region:[63 64 98] in 0.028s.
# -- checking combo, region:[65 66 99] in 0.048s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.032s.
# -- checking unique, region:[3 4] in 0.016s.
# -- checking unique, region:[5 6] in 0.016s.
# -- checking unique, region:[7 8] in 0.063s.
# -- checking unique, region:[ 9 10] in 0.043s.
# -- checking unique, region:[11 12] in 0.046s.
# -- checking unique, region:[13 14] in 0.048s.
# -- checking unique, region:[15 16] in 0.047s.
# -- checking unique, region:[17 18] in 0.050s.
# -- checking unique, region:[19 20] in 0.030s.
# -- checking unique, region:[21 22] in 0.031s.
# -- checking unique, region:[23 24] in 0.041s.
# -- checking unique, region:[25 26] in 0.027s.
# -- checking unique, region:[27 28] in 0.062s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_054.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.453s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_054.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_054.hdf5
# ++ base attributes loaded:[] in 0.020s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.273s.
# -- checking combo, region:[ 3  4 68] in 0.024s.
# -- checking combo, region:[ 5  6 69] in 0.031s.
# -- checking combo, region:[ 7  8 70] in 0.047s.
# -- checking combo, region:[ 9 10 71] in 0.031s.
# -- checking combo, region:[11 12 72] in 0.031s.
# -- checking combo, region:[13 14 73] in 0.031s.
# -- checking combo, region:[15 16 74] in 0.045s.
# -- checking combo, region:[17 18 75] in 0.018s.
# -- checking combo, region:[19 20 76] in 0.048s.
# -- checking combo, region:[21 22 77] in 0.139s.
# -- checking combo, region:[23 24 78] in 0.119s.
# -- checking combo, region:[25 26 79] in 0.041s.
# -- checking combo, region:[27 28 80] in 0.028s.
# -- checking combo, region:[29 30 81] in 0.165s.
# -- checking combo, region:[31 32 82] in 0.040s.
# -- checking combo, region:[33 34 83] in 0.043s.
# -- checking combo, region:[35 36 84] in 0.141s.
# -- checking combo, region:[37 38 85] in 0.112s.
# -- checking combo, region:[39 40 86] in 0.045s.
# -- checking combo, region:[41 42 87] in 0.031s.
# -- checking combo, region:[43 44 88] in 0.134s.
# -- checking combo, region:[45 46 89] in 0.039s.
# -- checking combo, region:[47 48 90] in 0.031s.
# -- checking combo, region:[49 50 91] in 0.046s.
# -- checking combo, region:[51 52 92] in 0.047s.
# -- checking combo, region:[53 54 93] in 0.031s.
# -- checking combo, region:[55 56 94] in 0.030s.
# -- checking combo, region:[57 58 95] in 0.052s.
# -- checking combo, region:[59 60 96] in 0.027s.
# -- checking combo, region:[61 62 97] in 0.031s.
# -- checking combo, region:[63 64 98] in 0.047s.
# -- checking combo, region:[65 66 99] in 0.047s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.036s.
# -- checking unique, region:[3 4] in 0.039s.
# -- checking unique, region:[5 6] in 0.016s.
# -- checking unique, region:[7 8] in 0.029s.
# -- checking unique, region:[ 9 10] in 0.060s.
# -- checking unique, region:[11 12] in 0.060s.
# -- checking unique, region:[13 14] in 0.029s.
# -- checking unique, region:[15 16] in 0.031s.
# -- checking unique, region:[17 18] in 0.029s.
# -- checking unique, region:[19 20] in 0.031s.
# -- checking unique, region:[21 22] in 0.029s.
# -- checking unique, region:[23 24] in 0.039s.
# -- checking unique, region:[25 26] in 0.031s.
# -- checking unique, region:[27 28] in 0.031s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_055.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.406s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_055.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_055.hdf5
# ++ base attributes loaded:[] in 0.014s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.145s.
# -- checking combo, region:[ 3  4 68] in 0.016s.
# -- checking combo, region:[ 5  6 69] in 0.031s.
# -- checking combo, region:[ 7  8 70] in 0.031s.
# -- checking combo, region:[ 9 10 71] in 0.047s.
# -- checking combo, region:[11 12 72] in 0.034s.
# -- checking combo, region:[13 14 73] in 0.029s.
# -- checking combo, region:[15 16 74] in 0.038s.
# -- checking combo, region:[17 18 75] in 0.024s.
# -- checking combo, region:[19 20 76] in 0.016s.
# -- checking combo, region:[21 22 77] in 0.031s.
# -- checking combo, region:[23 24 78] in 0.031s.
# -- checking combo, region:[25 26 79] in 0.039s.
# -- checking combo, region:[27 28 80] in 0.009s.
# -- checking combo, region:[29 30 81] in 0.036s.
# -- checking combo, region:[31 32 82] in 0.023s.
# -- checking combo, region:[33 34 83] in 0.018s.
# -- checking combo, region:[35 36 84] in 0.031s.
# -- checking combo, region:[37 38 85] in 0.047s.
# -- checking combo, region:[39 40 86] in 0.033s.
# -- checking combo, region:[41 42 87] in 0.042s.
# -- checking combo, region:[43 44 88] in 0.128s.
# -- checking combo, region:[45 46 89] in 0.048s.
# -- checking combo, region:[47 48 90] in 0.046s.
# -- checking combo, region:[49 50 91] in 0.109s.
# -- checking combo, region:[51 52 92] in 0.121s.
# -- checking combo, region:[53 54 93] in 0.040s.
# -- checking combo, region:[55 56 94] in 0.042s.
# -- checking combo, region:[57 58 95] in 0.125s.
# -- checking combo, region:[59 60 96] in 0.049s.
# -- checking combo, region:[61 62 97] in 0.015s.
# -- checking combo, region:[63 64 98] in 0.036s.
# -- checking combo, region:[65 66 99] in 0.026s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.062s.
# -- checking unique, region:[3 4] in 0.044s.
# -- checking unique, region:[5 6] in 0.047s.
# -- checking unique, region:[7 8] in 0.063s.
# -- checking unique, region:[ 9 10] in 0.031s.
# -- checking unique, region:[11 12] in 0.031s.
# -- checking unique, region:[13 14] in 0.026s.
# -- checking unique, region:[15 16] in 0.016s.
# -- checking unique, region:[17 18] in 0.016s.
# -- checking unique, region:[19 20] in 0.016s.
# -- checking unique, region:[21 22] in 0.019s.
# -- checking unique, region:[23 24] in 0.016s.
# -- checking unique, region:[25 26] in 0.027s.
# -- checking unique, region:[27 28] in 0.037s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_056.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.359s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_056.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_056.hdf5
# ++ base attributes loaded:[] in 0.014s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.069s.
# -- checking combo, region:[ 3  4 68] in 0.034s.
# -- checking combo, region:[ 5  6 69] in 0.024s.
# -- checking combo, region:[ 7  8 70] in 0.045s.
# -- checking combo, region:[ 9 10 71] in 0.031s.
# -- checking combo, region:[11 12 72] in 0.031s.
# -- checking combo, region:[13 14 73] in 0.031s.
# -- checking combo, region:[15 16 74] in 0.036s.
# -- checking combo, region:[17 18 75] in 0.027s.
# -- checking combo, region:[19 20 76] in 0.036s.
# -- checking combo, region:[21 22 77] in 0.026s.
# -- checking combo, region:[23 24 78] in 0.031s.
# -- checking combo, region:[25 26 79] in 0.031s.
# -- checking combo, region:[27 28 80] in 0.031s.
# -- checking combo, region:[29 30 81] in 0.092s.
# -- checking combo, region:[31 32 82] in 0.018s.
# -- checking combo, region:[33 34 83] in 0.047s.
# -- checking combo, region:[35 36 84] in 0.078s.
# -- checking combo, region:[37 38 85] in 0.078s.
# -- checking combo, region:[39 40 86] in 0.031s.
# -- checking combo, region:[41 42 87] in 0.038s.
# -- checking combo, region:[43 44 88] in 0.086s.
# -- checking combo, region:[45 46 89] in 0.031s.
# -- checking combo, region:[47 48 90] in 0.031s.
# -- checking combo, region:[49 50 91] in 0.045s.
# -- checking combo, region:[51 52 92] in 0.032s.
# -- checking combo, region:[53 54 93] in 0.018s.
# -- checking combo, region:[55 56 94] in 0.030s.
# -- checking combo, region:[57 58 95] in 0.031s.
# -- checking combo, region:[59 60 96] in 0.031s.
# -- checking combo, region:[61 62 97] in 0.016s.
# -- checking combo, region:[63 64 98] in 0.033s.
# -- checking combo, region:[65 66 99] in 0.031s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.033s.
# -- checking unique, region:[3 4] in 0.031s.
# -- checking unique, region:[5 6] in 0.030s.
# -- checking unique, region:[7 8] in 0.012s.
# -- checking unique, region:[ 9 10] in 0.031s.
# -- checking unique, region:[11 12] in 0.031s.
# -- checking unique, region:[13 14] in 0.022s.
# -- checking unique, region:[15 16] in 0.016s.
# -- checking unique, region:[17 18] in 0.032s.
# -- checking unique, region:[19 20] in 0.021s.
# -- checking unique, region:[21 22] in 0.016s.
# -- checking unique, region:[23 24] in 0.016s.
# -- checking unique, region:[25 26] in 0.027s.
# -- checking unique, region:[27 28] in 0.029s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_057.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.485s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_057.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_057.hdf5
# ++ base attributes loaded:[] in 0.021s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.063s.
# -- checking combo, region:[ 3  4 68] in 0.030s.
# -- checking combo, region:[ 5  6 69] in 0.018s.
# -- checking combo, region:[ 7  8 70] in 0.045s.
# -- checking combo, region:[ 9 10 71] in 0.038s.
# -- checking combo, region:[11 12 72] in 0.024s.
# -- checking combo, region:[13 14 73] in 0.031s.
# -- checking combo, region:[15 16 74] in 0.064s.
# -- checking combo, region:[17 18 75] in 0.030s.
# -- checking combo, region:[19 20 76] in 0.016s.
# -- checking combo, region:[21 22 77] in 0.079s.
# -- checking combo, region:[23 24 78] in 0.077s.
# -- checking combo, region:[25 26 79] in 0.041s.
# -- checking combo, region:[27 28 80] in 0.022s.
# -- checking combo, region:[29 30 81] in 0.078s.
# -- checking combo, region:[31 32 82] in 0.031s.
# -- checking combo, region:[33 34 83] in 0.031s.
# -- checking combo, region:[35 36 84] in 0.112s.
# -- checking combo, region:[37 38 85] in 0.076s.
# -- checking combo, region:[39 40 86] in 0.031s.
# -- checking combo, region:[41 42 87] in 0.032s.
# -- checking combo, region:[43 44 88] in 0.046s.
# -- checking combo, region:[45 46 89] in 0.029s.
# -- checking combo, region:[47 48 90] in 0.020s.
# -- checking combo, region:[49 50 91] in 0.042s.
# -- checking combo, region:[51 52 92] in 0.034s.
# -- checking combo, region:[53 54 93] in 0.016s.
# -- checking combo, region:[55 56 94] in 0.031s.
# -- checking combo, region:[57 58 95] in 0.031s.
# -- checking combo, region:[59 60 96] in 0.016s.
# -- checking combo, region:[61 62 97] in 0.038s.
# -- checking combo, region:[63 64 98] in 0.025s.
# -- checking combo, region:[65 66 99] in 0.030s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.036s.
# -- checking unique, region:[3 4] in 0.036s.
# -- checking unique, region:[5 6] in 0.015s.
# -- checking unique, region:[7 8] in 0.031s.
# -- checking unique, region:[ 9 10] in 0.023s.
# -- checking unique, region:[11 12] in 0.031s.
# -- checking unique, region:[13 14] in 0.038s.
# -- checking unique, region:[15 16] in 0.014s.
# -- checking unique, region:[17 18] in 0.031s.
# -- checking unique, region:[19 20] in 0.046s.
# -- checking unique, region:[21 22] in 0.047s.
# -- checking unique, region:[23 24] in 0.047s.
# -- checking unique, region:[25 26] in 0.045s.
# -- checking unique, region:[27 28] in 0.047s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_058.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.647s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_058.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_058.hdf5
# ++ base attributes loaded:[] in 0.009s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.211s.
# -- checking combo, region:[ 3  4 68] in 0.043s.
# -- checking combo, region:[ 5  6 69] in 0.042s.
# -- checking combo, region:[ 7  8 70] in 0.062s.
# -- checking combo, region:[ 9 10 71] in 0.062s.
# -- checking combo, region:[11 12 72] in 0.033s.
# -- checking combo, region:[13 14 73] in 0.030s.
# -- checking combo, region:[15 16 74] in 0.031s.
# -- checking combo, region:[17 18 75] in 0.041s.
# -- checking combo, region:[19 20 76] in 0.021s.
# -- checking combo, region:[21 22 77] in 0.047s.
# -- checking combo, region:[23 24 78] in 0.047s.
# -- checking combo, region:[25 26 79] in 0.037s.
# -- checking combo, region:[27 28 80] in 0.025s.
# -- checking combo, region:[29 30 81] in 0.047s.
# -- checking combo, region:[31 32 82] in 0.030s.
# -- checking combo, region:[33 34 83] in 0.031s.
# -- checking combo, region:[35 36 84] in 0.031s.
# -- checking combo, region:[37 38 85] in 0.047s.
# -- checking combo, region:[39 40 86] in 0.031s.
# -- checking combo, region:[41 42 87] in 0.037s.
# -- checking combo, region:[43 44 88] in 0.024s.
# -- checking combo, region:[45 46 89] in 0.031s.
# -- checking combo, region:[47 48 90] in 0.031s.
# -- checking combo, region:[49 50 91] in 0.050s.
# -- checking combo, region:[51 52 92] in 0.044s.
# -- checking combo, region:[53 54 93] in 0.031s.
# -- checking combo, region:[55 56 94] in 0.031s.
# -- checking combo, region:[57 58 95] in 0.063s.
# -- checking combo, region:[59 60 96] in 0.031s.
# -- checking combo, region:[61 62 97] in 0.049s.
# -- checking combo, region:[63 64 98] in 0.035s.
# -- checking combo, region:[65 66 99] in 0.056s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.038s.
# -- checking unique, region:[3 4] in 0.025s.
# -- checking unique, region:[5 6] in 0.031s.
# -- checking unique, region:[7 8] in 0.040s.
# -- checking unique, region:[ 9 10] in 0.058s.
# -- checking unique, region:[11 12] in 0.066s.
# -- checking unique, region:[13 14] in 0.058s.
# -- checking unique, region:[15 16] in 0.063s.
# -- checking unique, region:[17 18] in 0.054s.
# -- checking unique, region:[19 20] in 0.047s.
# -- checking unique, region:[21 22] in 0.031s.
# -- checking unique, region:[23 24] in 0.031s.
# -- checking unique, region:[25 26] in 0.030s.
# -- checking unique, region:[27 28] in 0.031s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_059.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.487s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_059.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_059.hdf5
# ++ base attributes loaded:[] in 0.024s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.052s.
# -- checking combo, region:[ 3  4 68] in 0.011s.
# -- checking combo, region:[ 5  6 69] in 0.041s.
# -- checking combo, region:[ 7  8 70] in 0.019s.
# -- checking combo, region:[ 9 10 71] in 0.031s.
# -- checking combo, region:[11 12 72] in 0.031s.
# -- checking combo, region:[13 14 73] in 0.031s.
# -- checking combo, region:[15 16 74] in 0.016s.
# -- checking combo, region:[17 18 75] in 0.040s.
# -- checking combo, region:[19 20 76] in 0.023s.
# -- checking combo, region:[21 22 77] in 0.033s.
# -- checking combo, region:[23 24 78] in 0.059s.
# -- checking combo, region:[25 26 79] in 0.031s.
# -- checking combo, region:[27 28 80] in 0.031s.
# -- checking combo, region:[29 30 81] in 0.077s.
# -- checking combo, region:[31 32 82] in 0.018s.
# -- checking combo, region:[33 34 83] in 0.041s.
# -- checking combo, region:[35 36 84] in 0.051s.
# -- checking combo, region:[37 38 85] in 0.062s.
# -- checking combo, region:[39 40 86] in 0.036s.
# -- checking combo, region:[41 42 87] in 0.033s.
# -- checking combo, region:[43 44 88] in 0.056s.
# -- checking combo, region:[45 46 89] in 0.031s.
# -- checking combo, region:[47 48 90] in 0.031s.
# -- checking combo, region:[49 50 91] in 0.047s.
# -- checking combo, region:[51 52 92] in 0.062s.
# -- checking combo, region:[53 54 93] in 0.043s.
# -- checking combo, region:[55 56 94] in 0.020s.
# -- checking combo, region:[57 58 95] in 0.063s.
# -- checking combo, region:[59 60 96] in 0.016s.
# -- checking combo, region:[61 62 97] in 0.031s.
# -- checking combo, region:[63 64 98] in 0.016s.
# -- checking combo, region:[65 66 99] in 0.044s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.062s.
# -- checking unique, region:[3 4] in 0.039s.
# -- checking unique, region:[5 6] in 0.028s.
# -- checking unique, region:[7 8] in 0.055s.
# -- checking unique, region:[ 9 10] in 0.018s.
# -- checking unique, region:[11 12] in 0.023s.
# -- checking unique, region:[13 14] in 0.016s.
# -- checking unique, region:[15 16] in 0.015s.
# -- checking unique, region:[17 18] in 0.016s.
# -- checking unique, region:[19 20] in 0.033s.
# -- checking unique, region:[21 22] in 0.031s.
# -- checking unique, region:[23 24] in 0.082s.
# -- checking unique, region:[25 26] in 0.058s.
# -- checking unique, region:[27 28] in 0.078s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_060.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.858s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_060.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_060.hdf5
# ++ base attributes loaded:[] in 0.027s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.063s.
# -- checking combo, region:[ 3  4 68] in 0.034s.
# -- checking combo, region:[ 5  6 69] in 0.028s.
# -- checking combo, region:[ 7  8 70] in 0.031s.
# -- checking combo, region:[ 9 10 71] in 0.031s.
# -- checking combo, region:[11 12 72] in 0.016s.
# -- checking combo, region:[13 14 73] in 0.031s.
# -- checking combo, region:[15 16 74] in 0.016s.
# -- checking combo, region:[17 18 75] in 0.031s.
# -- checking combo, region:[19 20 76] in 0.028s.
# -- checking combo, region:[21 22 77] in 0.020s.
# -- checking combo, region:[23 24 78] in 0.031s.
# -- checking combo, region:[25 26 79] in 0.022s.
# -- checking combo, region:[27 28 80] in 0.023s.
# -- checking combo, region:[29 30 81] in 0.016s.
# -- checking combo, region:[31 32 82] in 0.031s.
# -- checking combo, region:[33 34 83] in 0.016s.
# -- checking combo, region:[35 36 84] in 0.042s.
# -- checking combo, region:[37 38 85] in 0.021s.
# -- checking combo, region:[39 40 86] in 0.032s.
# -- checking combo, region:[41 42 87] in 0.015s.
# -- checking combo, region:[43 44 88] in 0.030s.
# -- checking combo, region:[45 46 89] in 0.016s.
# -- checking combo, region:[47 48 90] in 0.016s.
# -- checking combo, region:[49 50 91] in 0.016s.
# -- checking combo, region:[51 52 92] in 0.031s.
# -- checking combo, region:[53 54 93] in 0.029s.
# -- checking combo, region:[55 56 94] in 0.018s.
# -- checking combo, region:[57 58 95] in 0.041s.
# -- checking combo, region:[59 60 96] in 0.020s.
# -- checking combo, region:[61 62 97] in 0.031s.
# -- checking combo, region:[63 64 98] in 0.031s.
# -- checking combo, region:[65 66 99] in 0.031s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.031s.
# -- checking unique, region:[3 4] in 0.018s.
# -- checking unique, region:[5 6] in 0.016s.
# -- checking unique, region:[7 8] in 0.025s.
# -- checking unique, region:[ 9 10] in 0.023s.
# -- checking unique, region:[11 12] in 0.047s.
# -- checking unique, region:[13 14] in 0.044s.
# -- checking unique, region:[15 16] in 0.047s.
# -- checking unique, region:[17 18] in 0.045s.
# -- checking unique, region:[19 20] in 0.019s.
# -- checking unique, region:[21 22] in 0.031s.
# -- checking unique, region:[23 24] in 0.031s.
# -- checking unique, region:[25 26] in 0.031s.
# -- checking unique, region:[27 28] in 0.031s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_061.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 4.873s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_061.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_061.hdf5
# ++ base attributes loaded:[] in 0.013s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.205s.
# -- checking combo, region:[ 3  4 68] in 0.060s.
# -- checking combo, region:[ 5  6 69] in 0.047s.
# -- checking combo, region:[ 7  8 70] in 0.109s.
# -- checking combo, region:[ 9 10 71] in 0.095s.
# -- checking combo, region:[11 12 72] in 0.044s.
# -- checking combo, region:[13 14 73] in 0.047s.
# -- checking combo, region:[15 16 74] in 0.078s.
# -- checking combo, region:[17 18 75] in 0.047s.
# -- checking combo, region:[19 20 76] in 0.045s.
# -- checking combo, region:[21 22 77] in 0.096s.
# -- checking combo, region:[23 24 78] in 0.062s.
# -- checking combo, region:[25 26 79] in 0.031s.
# -- checking combo, region:[27 28 80] in 0.034s.
# -- checking combo, region:[29 30 81] in 0.046s.
# -- checking combo, region:[31 32 82] in 0.016s.
# -- checking combo, region:[33 34 83] in 0.030s.
# -- checking combo, region:[35 36 84] in 0.031s.
# -- checking combo, region:[37 38 85] in 0.016s.
# -- checking combo, region:[39 40 86] in 0.031s.
# -- checking combo, region:[41 42 87] in 0.016s.
# -- checking combo, region:[43 44 88] in 0.048s.
# -- checking combo, region:[45 46 89] in 0.016s.
# -- checking combo, region:[47 48 90] in 0.032s.
# -- checking combo, region:[49 50 91] in 0.031s.
# -- checking combo, region:[51 52 92] in 0.029s.
# -- checking combo, region:[53 54 93] in 0.023s.
# -- checking combo, region:[55 56 94] in 0.040s.
# -- checking combo, region:[57 58 95] in 0.099s.
# -- checking combo, region:[59 60 96] in 0.036s.
# -- checking combo, region:[61 62 97] in 0.023s.
# -- checking combo, region:[63 64 98] in 0.044s.
# -- checking combo, region:[65 66 99] in 0.063s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.024s.
# -- checking unique, region:[3 4] in 0.031s.
# -- checking unique, region:[5 6] in 0.031s.
# -- checking unique, region:[7 8] in 0.066s.
# -- checking unique, region:[ 9 10] in 0.047s.
# -- checking unique, region:[11 12] in 0.063s.
# -- checking unique, region:[13 14] in 0.055s.
# -- checking unique, region:[15 16] in 0.077s.
# -- checking unique, region:[17 18] in 0.042s.
# -- checking unique, region:[19 20] in 0.032s.
# -- checking unique, region:[21 22] in 0.044s.
# -- checking unique, region:[23 24] in 0.045s.
# -- checking unique, region:[25 26] in 0.031s.
# -- checking unique, region:[27 28] in 0.027s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# ...
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_154.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 5.204s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_154.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_154.hdf5
# ++ base attributes loaded:[] in 0.030s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.078s.
# -- checking combo, region:[ 3  4 68] in 0.046s.
# -- checking combo, region:[ 5  6 69] in 0.043s.
# -- checking combo, region:[ 7  8 70] in 0.036s.
# -- checking combo, region:[ 9 10 71] in 0.048s.
# -- checking combo, region:[11 12 72] in 0.053s.
# -- checking combo, region:[13 14 73] in 0.039s.
# -- checking combo, region:[15 16 74] in 0.047s.
# -- checking combo, region:[17 18 75] in 0.047s.
# -- checking combo, region:[19 20 76] in 0.047s.
# -- checking combo, region:[21 22 77] in 0.055s.
# -- checking combo, region:[23 24 78] in 0.038s.
# -- checking combo, region:[25 26 79] in 0.042s.
# -- checking combo, region:[27 28 80] in 0.040s.
# -- checking combo, region:[29 30 81] in 0.044s.
# -- checking combo, region:[31 32 82] in 0.046s.
# -- checking combo, region:[33 34 83] in 0.031s.
# -- checking combo, region:[35 36 84] in 0.062s.
# -- checking combo, region:[37 38 85] in 0.047s.
# -- checking combo, region:[39 40 86] in 0.051s.
# -- checking combo, region:[41 42 87] in 0.044s.
# -- checking combo, region:[43 44 88] in 0.045s.
# -- checking combo, region:[45 46 89] in 0.053s.
# -- checking combo, region:[47 48 90] in 0.046s.
# -- checking combo, region:[49 50 91] in 0.055s.
# -- checking combo, region:[51 52 92] in 0.048s.
# -- checking combo, region:[53 54 93] in 0.046s.
# -- checking combo, region:[55 56 94] in 0.047s.
# -- checking combo, region:[57 58 95] in 0.047s.
# -- checking combo, region:[59 60 96] in 0.053s.
# -- checking combo, region:[61 62 97] in 0.046s.
# -- checking combo, region:[63 64 98] in 0.026s.
# -- checking combo, region:[65 66 99] in 0.046s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.047s.
# -- checking unique, region:[3 4] in 0.033s.
# -- checking unique, region:[5 6] in 0.027s.
# -- checking unique, region:[7 8] in 0.042s.
# -- checking unique, region:[ 9 10] in 0.023s.
# -- checking unique, region:[11 12] in 0.031s.
# -- checking unique, region:[13 14] in 0.030s.
# -- checking unique, region:[15 16] in 0.031s.
# -- checking unique, region:[17 18] in 0.026s.
# -- checking unique, region:[19 20] in 0.031s.
# -- checking unique, region:[21 22] in 0.038s.
# -- checking unique, region:[23 24] in 0.032s.
# -- checking unique, region:[25 26] in 0.031s.
# -- checking unique, region:[27 28] in 0.022s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_155.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 5.469s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_155.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_155.hdf5
# ++ base attributes loaded:[] in 0.022s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.078s.
# -- checking combo, region:[ 3  4 68] in 0.047s.
# -- checking combo, region:[ 5  6 69] in 0.031s.
# -- checking combo, region:[ 7  8 70] in 0.047s.
# -- checking combo, region:[ 9 10 71] in 0.048s.
# -- checking combo, region:[11 12 72] in 0.048s.
# -- checking combo, region:[13 14 73] in 0.061s.
# -- checking combo, region:[15 16 74] in 0.075s.
# -- checking combo, region:[17 18 75] in 0.066s.
# -- checking combo, region:[19 20 76] in 0.077s.
# -- checking combo, region:[21 22 77] in 0.062s.
# -- checking combo, region:[23 24 78] in 0.063s.
# -- checking combo, region:[25 26 79] in 0.078s.
# -- checking combo, region:[27 28 80] in 0.071s.
# -- checking combo, region:[29 30 81] in 0.070s.
# -- checking combo, region:[31 32 82] in 0.076s.
# -- checking combo, region:[33 34 83] in 0.063s.
# -- checking combo, region:[35 36 84] in 0.078s.
# -- checking combo, region:[37 38 85] in 0.070s.
# -- checking combo, region:[39 40 86] in 0.040s.
# -- checking combo, region:[41 42 87] in 0.062s.
# -- checking combo, region:[43 44 88] in 0.078s.
# -- checking combo, region:[45 46 89] in 0.079s.
# -- checking combo, region:[47 48 90] in 0.056s.
# -- checking combo, region:[49 50 91] in 0.067s.
# -- checking combo, region:[51 52 92] in 0.075s.
# -- checking combo, region:[53 54 93] in 0.052s.
# -- checking combo, region:[55 56 94] in 0.067s.
# -- checking combo, region:[57 58 95] in 0.053s.
# -- checking combo, region:[59 60 96] in 0.047s.
# -- checking combo, region:[61 62 97] in 0.049s.
# -- checking combo, region:[63 64 98] in 0.077s.
# -- checking combo, region:[65 66 99] in 0.061s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.062s.
# -- checking unique, region:[3 4] in 0.056s.
# -- checking unique, region:[5 6] in 0.042s.
# -- checking unique, region:[7 8] in 0.073s.
# -- checking unique, region:[ 9 10] in 0.028s.
# -- checking unique, region:[11 12] in 0.047s.
# -- checking unique, region:[13 14] in 0.047s.
# -- checking unique, region:[15 16] in 0.050s.
# -- checking unique, region:[17 18] in 0.062s.
# -- checking unique, region:[19 20] in 0.047s.
# -- checking unique, region:[21 22] in 0.062s.
# -- checking unique, region:[23 24] in 0.047s.
# -- checking unique, region:[25 26] in 0.031s.
# -- checking unique, region:[27 28] in 0.034s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_156.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 10.606s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_156.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_156.hdf5
# ++ base attributes loaded:[] in 0.029s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.078s.
# -- checking combo, region:[ 3  4 68] in 0.031s.
# -- checking combo, region:[ 5  6 69] in 0.047s.
# -- checking combo, region:[ 7  8 70] in 0.048s.
# -- checking combo, region:[ 9 10 71] in 0.062s.
# -- checking combo, region:[11 12 72] in 0.033s.
# -- checking combo, region:[13 14 73] in 0.044s.
# -- checking combo, region:[15 16 74] in 0.055s.
# -- checking combo, region:[17 18 75] in 0.038s.
# -- checking combo, region:[19 20 76] in 0.047s.
# -- checking combo, region:[21 22 77] in 0.062s.
# -- checking combo, region:[23 24 78] in 0.047s.
# -- checking combo, region:[25 26 79] in 0.047s.
# -- checking combo, region:[27 28 80] in 0.049s.
# -- checking combo, region:[29 30 81] in 0.062s.
# -- checking combo, region:[31 32 82] in 0.043s.
# -- checking combo, region:[33 34 83] in 0.043s.
# -- checking combo, region:[35 36 84] in 0.050s.
# -- checking combo, region:[37 38 85] in 0.047s.
# -- checking combo, region:[39 40 86] in 0.048s.
# -- checking combo, region:[41 42 87] in 0.057s.
# -- checking combo, region:[43 44 88] in 0.046s.
# -- checking combo, region:[45 46 89] in 0.031s.
# -- checking combo, region:[47 48 90] in 0.031s.
# -- checking combo, region:[49 50 91] in 0.032s.
# -- checking combo, region:[51 52 92] in 0.066s.
# -- checking combo, region:[53 54 93] in 0.042s.
# -- checking combo, region:[55 56 94] in 0.032s.
# -- checking combo, region:[57 58 95] in 0.061s.
# -- checking combo, region:[59 60 96] in 0.046s.
# -- checking combo, region:[61 62 97] in 0.033s.
# -- checking combo, region:[63 64 98] in 0.046s.
# -- checking combo, region:[65 66 99] in 0.057s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.031s.
# -- checking unique, region:[3 4] in 0.049s.
# -- checking unique, region:[5 6] in 0.043s.
# -- checking unique, region:[7 8] in 0.030s.
# -- checking unique, region:[ 9 10] in 0.036s.
# -- checking unique, region:[11 12] in 0.047s.
# -- checking unique, region:[13 14] in 0.039s.
# -- checking unique, region:[15 16] in 0.027s.
# -- checking unique, region:[17 18] in 0.031s.
# -- checking unique, region:[19 20] in 0.025s.
# -- checking unique, region:[21 22] in 0.016s.
# -- checking unique, region:[23 24] in 0.045s.
# -- checking unique, region:[25 26] in 0.030s.
# -- checking unique, region:[27 28] in 0.031s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 47
# - Number of field of views: 158
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_1\20220307-P_brain_CTP11_from_0303\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33U1', 'H34U2', 'H35U3', 'H36U4', 'H37U5', 'H38U6', 'H39U7', 'H40U8', 'H41U9', 'H42U10', 'H43U11', 'H44U12', 'H45U13', 'H46U14'])
# - 47 folders are found according to color-usage annotation.
# + loading fov_info from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_157.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im', 'unique_ref_im'] in 5.236s.
# + loading correction from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_157.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: \\franklin\SSD_01\Pu_Temp\20220307-P_brain_CTP11_from_0303\Conv_zscan_157.hdf5
# ++ base attributes loaded:[] in 0.027s.
# -- folders not selected, allow processing all 47 folders
# -- checking combo, region:[ 1  2 67] in 0.095s.
# -- checking combo, region:[ 3  4 68] in 0.062s.
# -- checking combo, region:[ 5  6 69] in 0.064s.
# -- checking combo, region:[ 7  8 70] in 0.079s.
# -- checking combo, region:[ 9 10 71] in 0.060s.
# -- checking combo, region:[11 12 72] in 0.048s.
# -- checking combo, region:[13 14 73] in 0.070s.
# -- checking combo, region:[15 16 74] in 0.067s.
# -- checking combo, region:[17 18 75] in 0.047s.
# -- checking combo, region:[19 20 76] in 0.049s.
# -- checking combo, region:[21 22 77] in 0.061s.
# -- checking combo, region:[23 24 78] in 0.081s.
# -- checking combo, region:[25 26 79] in 0.045s.
# -- checking combo, region:[27 28 80] in 0.061s.
# -- checking combo, region:[29 30 81] in 0.076s.
# -- checking combo, region:[31 32 82] in 0.063s.
# -- checking combo, region:[33 34 83] in 0.064s.
# -- checking combo, region:[35 36 84] in 0.092s.
# -- checking combo, region:[37 38 85] in 0.078s.
# -- checking combo, region:[39 40 86] in 0.077s.
# -- checking combo, region:[41 42 87] in 0.064s.
# -- checking combo, region:[43 44 88] in 0.086s.
# -- checking combo, region:[45 46 89] in 0.048s.
# -- checking combo, region:[47 48 90] in 0.051s.
# -- checking combo, region:[49 50 91] in 0.060s.
# -- checking combo, region:[51 52 92] in 0.087s.
# -- checking combo, region:[53 54 93] in 0.051s.
# -- checking combo, region:[55 56 94] in 0.065s.
# -- checking combo, region:[57 58 95] in 0.075s.
# -- checking combo, region:[59 60 96] in 0.060s.
# -- checking combo, region:[61 62 97] in 0.053s.
# -- checking combo, region:[63 64 98] in 0.073s.
# -- checking combo, region:[65 66 99] in 0.064s.
# - No combo images and spots requires processing, skip.
# -- folders not selected, allow processing all 47 folders
# -- checking unique, region:[1 2] in 0.045s.
# -- checking unique, region:[3 4] in 0.034s.
# -- checking unique, region:[5 6] in 0.047s.
# -- checking unique, region:[7 8] in 0.061s.
# -- checking unique, region:[ 9 10] in 0.032s.
# -- checking unique, region:[11 12] in 0.056s.
# -- checking unique, region:[13 14] in 0.055s.
# -- checking unique, region:[15 16] in 0.047s.
# -- checking unique, region:[17 18] in 0.047s.
# -- checking unique, region:[19 20] in 0.064s.
# -- checking unique, region:[21 22] in 0.039s.
# -- checking unique, region:[23 24] in 0.063s.
# -- checking unique, region:[25 26] in 0.049s.
# -- checking unique, region:[27 28] in 0.031s.
# - No unique images and spots requires processing, skip.
# directly return existing attribute.
