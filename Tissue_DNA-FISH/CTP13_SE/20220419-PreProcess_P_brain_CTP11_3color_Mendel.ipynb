# %% [markdown]
# # Analysis of DNA-MERFISH for CTP11
#
# by Pu Zheng
#
# 2022.03.16
#
# analysis for dataset:
#
# \\10.245.74.158\Chromatin_NAS_4\20220316-P_brain_CTP11-12-13_from_0304
#
# This data is DNA of uncleared MERFISH RNA:
#     \\10.245.74.158\Chromatin_NAS_0\20220303-P_brain_M1_nonclear_adaptor

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 45100

# %% [markdown]
# # 0. fov parameters

# %%
reload(ia)
reload(classes)
reload(classes.batch_functions)
reload(classes.field_of_view)
reload(io_tools.load)
reload(get_img_info)
reload(visual_tools)
reload(ia.correction_tools)
reload(ia.correction_tools.alignment)
reload(ia.spot_tools.matching)
reload(ia.segmentation_tools.chromosome)
reload(ia.spot_tools.fitting)
# Out:
# <module 'ImageAnalysis3.spot_tools.fitting' from 'E:\\Users\\puzheng\\Documents\\ImageAnalysis3\\spot_tools\\fitting.py'>

# %%
fov_param = {'data_folder':r'\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65',
             'save_folder':r'J:\Pu_Temp\20220419-CTP11-13_from_0415storm65',
             'experiment_type': 'DNA',
             'num_threads': 44,
             'correction_folder':r'\\10.245.74.158\Chromatin_NAS_0\Corrections\20210621-Corrections_lumencor_from_60_to_50',
             'shared_parameters':{
                     'single_im_size':[50,2048,2048],
                     'distance_zxy': [250, 108, 108],
                     'corr_channels':['750','647','561'],
                     'num_empty_frames': 0, 
                     'num_buffer_frames':0,
                     'corr_hot_pixel':True,
                     'corr_Z_shift':False,
                     'corr_bleed':True,
                     'min_num_seeds':5,
                     'max_num_seeds': 20000,
                     'spot_seeding_th': 800,
                     'normalize_intensity_local':False,
                     'normalize_intensity_background':False,
                     'corr_gaussian_highpass':True,
                 }, 
             }

# %% [markdown]
# # 1. Process Fov

# %% [markdown]
# ## 1.1 process first round

# %%
_overwrite = False

_save_images = False

_fit_spots = True

sel_fov_ids = np.arange(0,80) # batch 1 in mendel
#sel_fov_ids = np.arange(80,160) # batch1+2 in mendel


for _fov_id in sel_fov_ids:
    if 'bad_fovs_ids' in locals() and  _fov_id in bad_fovs_ids:
        continue
    
    fov = classes.field_of_view.Field_of_View(fov_param, _fov_id=_fov_id,
                                              _color_info_kwargs={
                                                  '_color_filename':'Color_Usage',
                                              }, 
                                              _prioritize_saved_attrs=False,
                                              _save_info_to_file=False, # whether overwrite
                                              )
    # 2. Process image into candidate spots
    fov.parallel = False
    setattr(fov, "combo_ref_id", 0)
    fov._process_image_to_spots('combo', 
                                _sel_ids=[1,2,67],
                                _load_common_reference=True, _load_with_multiple=False,
                                _save_images=_save_images,
                                _warp_images=False, _fit_spots=True,
                                _overwrite_drift=False, _overwrite_image=_overwrite,
                                _overwrite_spot=_overwrite)
    # 3. unique
    #setattr(fov, "unique_ref_id", 0)
    #fov._process_image_to_spots('unique', 
    #                            _load_common_reference=True, _load_with_multiple=False,
    #                            _save_images=_save_images,
    #                            _warp_images=False, _fit_spots=True,
    #                            _overwrite_drift=False, _overwrite_image=_overwrite,
    #                            _overwrite_spot=_overwrite)
    # 4. Process DAPI image
    fov._load_dapi_image()
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 16
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 16 folders are found according to color-usage annotation.
# + loading fov_info from file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_000.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 4.559s.
# + loading correction from file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_000.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_000.hdf5
# ++ base attributes loaded:[] in 0.012s.
# -- folders not selected, allow processing all 16 folders
# -- checking combo, region:[ 1  2 67] in 0.050s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_000.dax for channels:['561']
# - loading combo info from file:Conv_zscan_000.hdf5 in 0.527s.
# -- ['561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_000.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_000.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_000.dax  in 6.144s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 66.934s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 43.937s
# -- illumination correction for channels: 750, 647, 561, 488, in 9.719s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 5.644s.
# -- drift 1: [0. 0. 0.] in 9.537s.
# -- drift 2: [0. 0. 0.] in 7.168s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 22.691s
# -- generate translation function for chromatic correction for channels: ['561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 63.822s
# -- finish correction in 214.304s
# -- start fitting spots in channel:561, 4043 seeded with th=500, 4043 fitted in 336.565s.
# - writting combo spots into file:J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_000.hdf5
# -- updated spots for id:[67] in 0.030s
# in 552.63s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 17
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 17 folders are found according to color-usage annotation.
# + loading fov_info from file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_001.hdf5
# ++ base attributes loaded:['combo_ref_im'] in 2.007s.
# + loading correction from file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_001.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_001.hdf5
# ++ base attributes loaded:[] in 0.011s.
# -- folders not selected, allow processing all 17 folders
# -- checking combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_001.dax for channels:['750', '647', '561']
# - loading combo info from file:Conv_zscan_001.hdf5 in 1.292s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_001.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_001.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_001.dax  in 53.462s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 60.030s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 33.394s
# -- illumination correction for channels: 750, 647, 561, 488, in 18.841s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 7.603s.
# -- drift 1: [0. 0. 0.] in 5.177s.
# -- drift 2: [0. 0. 0.] in 5.408s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 18.772s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 64.607s
# -- finish correction in 251.872s
# -- start fitting spots in channel:750, 15583 seeded with th=700,
# E:\Users\puzheng\AppData\anaconda3\envs\ia3_postanalysis\lib\site-packages\scipy\optimize\minpack.py:476: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# 15583 fitted in 1123.093s.
# -- start fitting spots in channel:647, 13134 seeded with th=750, 13134 fitted in 756.724s.
# -- start fitting spots in channel:561, 6312 seeded with th=500, 6312 fitted in 449.661s.
# - writting combo spots into file:J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_001.hdf5
# -- updated spots for id:[1, 2, 67] in 0.098s
# in 2585.50s.
# -- choose dapi images from folder: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_001.dax
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_001.dax  in 10.287s
# -- removing hot pixels for channels:['405'] in 12.474s
# -- illumination correction for channels: 405, in 3.859s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 29.029s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_001.hdf5
# ++ base attributes saved:['dapi_im'] in 11.819s.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 17
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 17 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_561_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048.npy
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048_const.pkl
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_002.dax: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# * create savefile: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel', 'dapi_channel_index', 'data_folder', 'debug', 'drift', 'drift_channel', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'parallel', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi', 'verbose'] in 0.035s.
# -- saving segmentation to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# -- saving correction to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# -- saving 750_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 647_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 561_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 488_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 405_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 750_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 647_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 561_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5, skip.
# -- saving 561_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# -- saving 750_647_561_bleed profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5.
# dict_keys(['combo', 'unique'])
# save type: combo"
# -- saving combo to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# --- combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.015s.
# save type: unique"
# -- saving unique to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.012s.
# -- folders not selected, allow processing all 17 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax  in 10.082s
# -- removing hot pixels for channels:['488'] in 18.354s
# -- illumination correction for channels: 488, in 3.779s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 34.482s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# ++ base attributes saved:['combo_ref_im'] in 11.386s.
# -- checking combo, region:[ 1  2 67] in 0.018s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax for channels:['750', '647', '561']
# - loading combo info from file:Conv_zscan_002.hdf5 in 1.302s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax  in 5.738s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 59.974s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 32.684s
# -- illumination correction for channels: 750, 647, 561, 488, in 20.941s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 6.009s.
# -- drift 1: [0. 0. 0.] in 10.179s.
# -- drift 2: [0. 0. 0.] in 8.662s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 25.113s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 65.857s
# -- finish correction in 213.302s
# -- start fitting spots in channel:750, 13445 seeded with th=700, 13445 fitted in 1150.555s.
# -- start fitting spots in channel:647, 11397 seeded with th=750, 11396 fitted in 817.012s.
# -- start fitting spots in channel:561, 5791 seeded with th=500, 5791 fitted in 408.889s.
# - writting combo spots into file:J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# -- updated spots for id:[1, 2, 67] in 0.085s
# in 2594.06s.
# -- choose dapi images from folder: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_002.dax  in 5.971s
# -- removing hot pixels for channels:['405'] in 12.946s
# -- illumination correction for channels: 405, in 4.018s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 24.926s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_002.hdf5
# ++ base attributes saved:['dapi_im'] in 9.805s.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 17
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 17 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_561_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048.npy
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048_const.pkl
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_003.dax: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# * create savefile: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel', 'dapi_channel_index', 'data_folder', 'debug', 'drift', 'drift_channel', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'parallel', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi', 'verbose'] in 0.030s.
# -- saving segmentation to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# -- saving correction to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# -- saving 750_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 647_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 561_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 488_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 405_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 750_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 647_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 561_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5, skip.
# -- saving 561_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# -- saving 750_647_561_bleed profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5.
# dict_keys(['combo', 'unique'])
# save type: combo"
# -- saving combo to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# --- combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.013s.
# save type: unique"
# -- saving unique to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.011s.
# -- folders not selected, allow processing all 17 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax  in 11.212s
# -- removing hot pixels for channels:['488'] in 12.647s
# -- illumination correction for channels: 488, in 3.556s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 28.526s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# ++ base attributes saved:['combo_ref_im'] in 9.096s.
# -- checking combo, region:[ 1  2 67] in 0.018s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax for channels:['750', '647', '561']
# - loading combo info from file:Conv_zscan_003.hdf5 in 1.289s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax  in 4.709s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 50.548s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 30.858s
# -- illumination correction for channels: 750, 647, 561, 488, in 21.837s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 5.952s.
# -- drift 1: [0. 0. 0.] in 8.630s.
# -- drift 2: [0. 0. 0.] in 6.042s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 20.824s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 59.600s
# -- finish correction in 190.635s
# -- start fitting spots in channel:750, 12752 seeded with th=700, 12752 fitted in 829.826s.
# -- start fitting spots in channel:647, 10724 seeded with th=750, 10724 fitted in 588.773s.
# -- start fitting spots in channel:561, 5605 seeded with th=500, 5605 fitted in 347.927s.
# - writting combo spots into file:J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# -- updated spots for id:[1, 2, 67] in 0.089s
# in 1961.24s.
# -- choose dapi images from folder: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_003.dax  in 4.059s
# -- removing hot pixels for channels:['405'] in 10.434s
# -- illumination correction for channels: 405, in 3.399s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 18.911s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_003.hdf5
# ++ base attributes saved:['dapi_im'] in 10.179s.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 17
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 17 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_561_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048.npy
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048_const.pkl
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_004.dax: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# * create savefile: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel', 'dapi_channel_index', 'data_folder', 'debug', 'drift', 'drift_channel', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'parallel', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi', 'verbose'] in 0.029s.
# -- saving segmentation to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# -- saving correction to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# -- saving 750_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 647_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 561_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 488_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 405_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 750_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 647_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 561_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5, skip.
# -- saving 561_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# -- saving 750_647_561_bleed profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5.
# dict_keys(['combo', 'unique'])
# save type: combo"
# -- saving combo to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# --- combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.013s.
# save type: unique"
# -- saving unique to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.009s.
# -- folders not selected, allow processing all 17 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax  in 9.546s
# -- removing hot pixels for channels:['488'] in 9.453s
# -- illumination correction for channels: 488, in 3.090s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 23.066s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# ++ base attributes saved:['combo_ref_im'] in 7.974s.
# -- checking combo, region:[ 1  2 67] in 0.017s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax for channels:['750', '647', '561']
# - loading combo info from file:Conv_zscan_004.hdf5 in 1.999s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax  in 7.601s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 53.999s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 26.783s
# -- illumination correction for channels: 750, 647, 561, 488, in 17.048s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 4.698s.
# -- drift 1: [0. 0. 0.] in 6.220s.
# -- drift 2: [0. 0. 0.] in 8.537s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 19.757s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 57.546s
# -- finish correction in 185.097s
# -- start fitting spots in channel:750, 13188 seeded with th=700, 13188 fitted in 867.657s.
# -- start fitting spots in channel:647, 10692 seeded with th=750, 10692 fitted in 589.878s.
# -- start fitting spots in channel:561, 5311 seeded with th=500, 5311 fitted in 318.998s.
# - writting combo spots into file:J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# -- updated spots for id:[1, 2, 67] in 0.084s
# in 1966.70s.
# -- choose dapi images from folder: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_004.dax  in 52.737s
# -- removing hot pixels for channels:['405'] in 10.567s
# -- illumination correction for channels: 405, in 3.668s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 68.107s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_004.hdf5
# ++ base attributes saved:['dapi_im'] in 10.073s.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 18
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 17 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_561_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048.npy
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048_const.pkl
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_005.dax: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# * create savefile: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel', 'dapi_channel_index', 'data_folder', 'debug', 'drift', 'drift_channel', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'parallel', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi', 'verbose'] in 0.035s.
# -- saving segmentation to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# -- saving correction to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# -- saving 750_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 647_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 561_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 488_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 405_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 750_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 647_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 561_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5, skip.
# -- saving 561_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# -- saving 750_647_561_bleed profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5.
# dict_keys(['combo', 'unique'])
# save type: combo"
# -- saving combo to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# --- combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.016s.
# save type: unique"
# -- saving unique to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.013s.
# -- folders not selected, allow processing all 17 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax  in 55.847s
# -- removing hot pixels for channels:['488'] in 12.438s
# -- illumination correction for channels: 488, in 5.052s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.001s
# -- finish correction in 75.232s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# ++ base attributes saved:['combo_ref_im'] in 11.214s.
# -- checking combo, region:[ 1  2 67] in 0.018s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax for channels:['750', '647', '561']
# - loading combo info from file:Conv_zscan_005.hdf5 in 1.961s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax  in 53.845s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 58.540s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 40.605s
# -- illumination correction for channels: 750, 647, 561, 488, in 19.768s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 5.688s.
# -- drift 1: [0. 0. 0.] in 8.959s.
# -- drift 2: [0. 0. 0.] in 9.177s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 24.078s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 66.954s
# -- finish correction in 266.837s
# -- start fitting spots in channel:750, 13335 seeded with th=700, 13335 fitted in 1146.568s.
# -- start fitting spots in channel:647, 7668 seeded with th=750, 7668 fitted in 450.980s.
# -- start fitting spots in channel:561, 3773 seeded with th=500, 3773 fitted in 258.006s.
# - writting combo spots into file:J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# -- updated spots for id:[1, 2, 67] in 0.085s
# in 2127.13s.
# -- choose dapi images from folder: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_005.dax  in 8.867s
# -- removing hot pixels for channels:['405'] in 13.613s
# -- illumination correction for channels: 405, in 6.520s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 30.872s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_005.hdf5
# ++ base attributes saved:['dapi_im'] in 11.463s.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 18
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 18 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_561_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048.npy
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048_const.pkl
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_006.dax: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# * create savefile: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel', 'dapi_channel_index', 'data_folder', 'debug', 'drift', 'drift_channel', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'parallel', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi', 'verbose'] in 0.035s.
# -- saving segmentation to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5
# -- saving correction to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5
# -- saving 750_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 647_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 561_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 488_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 405_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 750_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 647_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 561_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_006.hdf5.
# ...
# - 24 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_561_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048.npy
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048_const.pkl
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_027.dax: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# * create savefile: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel', 'dapi_channel_index', 'data_folder', 'debug', 'drift', 'drift_channel', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'parallel', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi', 'verbose'] in 0.035s.
# -- saving segmentation to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# -- saving correction to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# -- saving 750_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 647_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 561_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 488_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 405_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 750_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 647_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 561_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5, skip.
# -- saving 561_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# -- saving 750_647_561_bleed profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5.
# dict_keys(['combo', 'unique'])
# save type: combo"
# -- saving combo to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# --- combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.017s.
# save type: unique"
# -- saving unique to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.012s.
# -- folders not selected, allow processing all 24 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax  in 55.615s
# -- removing hot pixels for channels:['488'] in 10.565s
# -- illumination correction for channels: 488, in 3.457s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 71.125s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# ++ base attributes saved:['combo_ref_im'] in 11.945s.
# -- checking combo, region:[ 1  2 67] in 0.020s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax for channels:['750', '647', '561']
# - loading combo info from file:Conv_zscan_027.hdf5 in 2.023s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax  in 48.229s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 47.807s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 26.252s
# -- illumination correction for channels: 750, 647, 561, 488, in 13.868s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 5.615s.
# -- drift 1: [0. 0. 0.] in 5.599s.
# -- drift 2: [0. 0. 0.] in 5.586s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 16.994s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 53.191s
# -- finish correction in 208.909s
# -- start fitting spots in channel:750, 16058 seeded with th=700, 16058 fitted in 1371.590s.
# -- start fitting spots in channel:647, 6460 seeded with th=750, 6460 fitted in 380.634s.
# -- start fitting spots in channel:561, 2981 seeded with th=500, 2981 fitted in 202.314s.
# - writting combo spots into file:J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# -- updated spots for id:[1, 2, 67] in 0.087s
# in 2168.18s.
# -- choose dapi images from folder: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax
# -- loading illumination correction profile from file:
# 	 405 illumination_correction_405_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_027.dax  in 9.010s
# -- removing hot pixels for channels:['405'] in 10.372s
# -- illumination correction for channels: 405, in 3.427s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 23.979s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_027.hdf5
# ++ base attributes saved:['dapi_im'] in 8.405s.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 24
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67U2', 'H68U3', 'H69U4', 'H70U5', 'H71U6', 'H72U7', 'H73U8', 'H74U9', 'H75U10', 'H76U1'])
# - 24 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_561_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048.npy
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# 	 561 chromatic_correction_561_647_50_2048_2048_const.pkl
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_028.dax: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# * create savefile: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel', 'dapi_channel_index', 'data_folder', 'debug', 'drift', 'drift_channel', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'parallel', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi', 'verbose'] in 0.035s.
# -- saving segmentation to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# -- saving correction to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# -- saving 750_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 647_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 561_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 488_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 405_illumination profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 750_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 647_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 561_chromatic profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5, skip.
# -- saving 561_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# -- saving 750_647_561_bleed profile to save_file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5.
# dict_keys(['combo', 'unique'])
# save type: combo"
# -- saving combo to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# --- combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.014s.
# save type: unique"
# -- saving unique to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.012s.
# -- folders not selected, allow processing all 24 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_028.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_028.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_028.dax  in 10.142s
# -- removing hot pixels for channels:['488'] in 14.250s
# -- illumination correction for channels: 488, in 2.776s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 28.695s
# -- saving fov_info to file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# ++ base attributes saved:['combo_ref_im'] in 11.145s.
# -- checking combo, region:[ 1  2 67] in 0.018s.
# + Start sequential pre-processing for 1 images
# ++ processed combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_028.dax for channels:['750', '647', '561']
# - loading combo info from file:Conv_zscan_028.hdf5 in 1.718s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: J:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_028.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_028.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_028.dax  in 5.788s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 55.585s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 24.986s
# -- illumination correction for channels: 750, 647, 561, 488, in 22.035s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [0. 0. 0.] in 7.888s.
# -- drift 1: [0. 0. 0.] in 8.674s.
# -- drift 2: [0. 0. 0.] in 5.982s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [0. 0. 0.] in 22.819s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[0. 0. 0.] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 56.403s
# -- finish correction in 190.053s
# -- start fitting spots in channel:750, 16348 seeded with th=700, 16348 fitted in 1423.882s.
# -- start fitting spots in channel:647, 6528 seeded with th=750,
