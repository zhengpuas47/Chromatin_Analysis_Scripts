# %% [markdown]
# # Analysis of DNA-MERFISH for CTP11
#
# by Pu Zheng
#
# 2022.03.16
#
# analysis for dataset:
#
# \\10.245.74.158\Chromatin_NAS_4\20220316-P_brain_CTP11-12-13_from_0304
#
# This data is DNA of uncleared MERFISH RNA:
#     \\10.245.74.158\Chromatin_NAS_0\20220303-P_brain_M1_nonclear_adaptor

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 10200

# %% [markdown]
# # 0. fov parameters

# %%
reload(ia)
reload(classes)
reload(classes.batch_functions)
reload(classes.field_of_view)
reload(io_tools.load)
reload(get_img_info)
reload(visual_tools)
reload(ia.correction_tools)
reload(ia.correction_tools.alignment)
reload(ia.spot_tools.matching)
reload(ia.segmentation_tools.chromosome)
reload(ia.spot_tools.fitting)
# Out:
# <module 'ImageAnalysis3.spot_tools.fitting' from 'E:\\Users\\puzheng\\Documents\\ImageAnalysis3\\spot_tools\\fitting.py'>

# %%
fov_param = {'data_folder':r'\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65',
             'save_folder':r'D:\Pu_Temp\20220419-CTP11-13_from_0415storm65',
             'experiment_type': 'DNA',
             'num_threads': 44,
             'correction_folder':r'\\10.245.74.158\Chromatin_NAS_0\Corrections\20210621-Corrections_lumencor_from_60_to_50',
             'shared_parameters':{
                     'single_im_size':[50,2048,2048],
                     'distance_zxy': [250, 108, 108],
                     'corr_channels':['750','647','561'],
                     'num_empty_frames': 0, 
                     'num_buffer_frames':0,
                     'corr_hot_pixel':True,
                     'corr_Z_shift':False,
                     'corr_bleed':True,
                     'min_num_seeds':5,
                     'max_num_seeds': 20000,
                     'spot_seeding_th': 800,
                     'normalize_intensity_local':False,
                     'normalize_intensity_background':False,
                     'corr_gaussian_highpass':True,
                 }, 
             }

# %% [markdown]
# # 1. Process Fov

# %% [markdown]
# ## 1.1 process first round

# %%
_overwrite = False

_save_images = False

_fit_spots = True

#sel_fov_ids = np.arange(0,80) # batch 1 in mendel
sel_fov_ids = np.arange(80,200) # batch 2 in franklin


for _fov_id in sel_fov_ids:
    if 'bad_fovs_ids' in locals() and  _fov_id in bad_fovs_ids:
        continue
    
    fov = classes.field_of_view.Field_of_View(fov_param, _fov_id=_fov_id,
                                              _color_info_kwargs={
                                                  '_color_filename':'Color_Usage',
                                              }, 
                                              _prioritize_saved_attrs=False,
                                              _save_info_to_file=False, # whether overwrite
                                              )
    # 2.1 Process image into candidate spots
    #fov.parallel = False
    #setattr(fov, "combo_ref_id", 0)
    #fov._process_image_to_spots('combo', 
    #                            _sel_ids=[1,2,67],
    #                            _load_common_reference=True, _load_with_multiple=False,
    #                            _save_images=_save_images,
    #                            _warp_images=False, _fit_spots=True,
    #                            _overwrite_drift=False, _overwrite_image=_overwrite,
    #                            _overwrite_spot=_overwrite)
    # 2.2 Process image into candidate spots
    fov.parallel = False
    try:
        fov._save_to_file('relabeled_combo')
    except:
        pass
    setattr(fov, "relabeled_combo_ref_id", 0)
    fov._process_image_to_spots('relabeled_combo', 
                                #_sel_ids=[1,2,67],
                                _load_common_reference=True, _load_with_multiple=False,
                                _save_images=_save_images,
                                _warp_images=False, _fit_spots=True,
                                _overwrite_drift=False, _overwrite_image=_overwrite,
                                _overwrite_spot=_overwrite)
    # 3. unique
    #setattr(fov, "unique_ref_id", 0)
    #fov._process_image_to_spots('unique', 
    #                            _load_common_reference=True, _load_with_multiple=False,
    #                            _save_images=_save_images,
    #                            _warp_images=False, _fit_spots=True,
    #                            _overwrite_drift=False, _overwrite_image=_overwrite,
    #                            _overwrite_spot=_overwrite)
    # 4. Process DAPI image
    fov._load_dapi_image()
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_080.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 5.541s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_080.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_080.hdf5
# ++ base attributes loaded:[] in 0.016s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_080.hdf5
# --- relabeled_combo attributes updated:[] in 0.016s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_080.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_080.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_080.dax  in 41.410s
# -- removing hot pixels for channels:['488'] in 13.623s
# -- illumination correction for channels: 488, in 3.604s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 59.656s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_080.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 9.830s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_080.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_080.hdf5 in 1.323s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_080.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_080.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_080.dax  in 40.905s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 50.798s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 29.268s
# -- illumination correction for channels: 750, 647, 561, 488, in 8.106s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.03 -22.77  -6.74] in 5.187s.
# -- drift 1: [  0.   -22.82  -6.56] in 6.000s.
# -- drift 2: [  0.03 -22.78  -6.22] in 5.297s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [ 2.000e-02 -2.279e+01 -6.510e+00] in 17.031s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[ 2.000e-02 -2.279e+01 -6.510e+00] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 72.563s
# -- finish correction in 220.360s
# -- start fitting spots in channel:750, 3942 seeded with th=700.0, 3942 fitted in 330.484s.
# -- start fitting spots in channel:647, 1557 seeded with th=750.0, 1557 fitted in 142.810s.
# -- start fitting spots in channel:561, 3956 seeded with th=500.0, 3956 fitted in 273.375s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_080.hdf5
# -- updated spots for id:[1, 2, 67] in 0.089s
# in 977.17s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_081.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 4.562s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_081.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_081.hdf5
# ++ base attributes loaded:[] in 0.014s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_081.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.106s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_081.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_081.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_081.dax  in 43.253s
# -- removing hot pixels for channels:['488'] in 9.640s
# -- illumination correction for channels: 488, in 2.890s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 56.684s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_081.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 5.545s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_081.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_081.hdf5 in 0.500s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_081.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_081.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_081.dax  in 38.436s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 33.103s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 18.406s
# -- illumination correction for channels: 750, 647, 561, 488, in 5.946s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.12 -22.86  -5.1 ] in 3.402s.
# -- drift 1: [  0.09 -23.36  -5.25] in 3.077s.
# -- drift 2: [  0.12 -22.7   -4.83] in 3.157s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.11 -22.97  -5.06] in 9.841s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.11 -22.97  -5.06] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 52.393s
# -- finish correction in 159.031s
# -- start fitting spots in channel:750, 3059 seeded with th=700.0, 3059 fitted in 187.567s.
# -- start fitting spots in channel:647, 1141 seeded with th=750.0, 1141 fitted in 92.875s.
# -- start fitting spots in channel:561, 3143 seeded with th=500.0, 3143 fitted in 184.687s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_081.hdf5
# -- updated spots for id:[1, 2, 67] in 0.032s
# in 628.09s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_082.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 3.547s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_082.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_082.hdf5
# ++ base attributes loaded:[] in 0.016s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_082.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.018s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_082.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_082.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_082.dax  in 115.297s
# -- removing hot pixels for channels:['488'] in 6.641s
# -- illumination correction for channels: 488, in 2.125s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 146.859s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_082.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 6.000s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_082.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_082.hdf5 in 0.313s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_082.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_082.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_082.dax  in 83.219s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 30.391s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 17.016s
# -- illumination correction for channels: 750, 647, 561, 488, in 6.672s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.74 -23.28  -3.07] in 3.806s.
# -- drift 1: [  0.51 -22.81  -3.04] in 3.882s.
# -- drift 2: [  0.56 -23.13  -3.19] in 3.844s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.6  -23.07  -3.1 ] in 11.813s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.6  -23.07  -3.1 ] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 54.750s
# -- finish correction in 205.734s
# -- start fitting spots in channel:750, 2861 seeded with th=700.0, 2861 fitted in 251.484s.
# -- start fitting spots in channel:647, 1103 seeded with th=750.0, 1103 fitted in 138.725s.
# -- start fitting spots in channel:561, 3047 seeded with th=500.0, 3047 fitted in 281.047s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_082.hdf5
# -- updated spots for id:[1, 2, 67] in 0.031s
# in 886.97s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_083.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 6.562s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_083.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_083.hdf5
# ++ base attributes loaded:[] in 0.000s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_083.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.031s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_083.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_083.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_083.dax  in 45.687s
# -- removing hot pixels for channels:['488'] in 12.453s
# -- illumination correction for channels: 488, in 3.500s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 62.649s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_083.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 6.835s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_083.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_083.hdf5 in 0.391s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_083.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_083.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_083.dax  in 46.344s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 46.765s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 23.407s
# -- illumination correction for channels: 750, 647, 561, 488, in 5.767s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.37 -22.39 -22.47] in 3.747s.
# -- drift 1: [  0.19 -22.44 -22.36] in 3.625s.
# -- drift 2: [  0.45 -22.65 -22.86] in 3.510s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.34 -22.49 -22.56] in 11.181s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.34 -22.49 -22.56] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 72.834s
# -- finish correction in 209.188s
# -- start fitting spots in channel:750, 4557 seeded with th=700.0, 4557 fitted in 385.968s.
# -- start fitting spots in channel:647, 1811 seeded with th=750.0, 1811 fitted in 191.735s.
# -- start fitting spots in channel:561, 5305 seeded with th=500.0, 5305 fitted in 454.922s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_083.hdf5
# -- updated spots for id:[1, 2, 67] in 0.061s
# in 1250.72s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_084.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 8.109s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_084.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_084.hdf5
# ++ base attributes loaded:[] in 0.016s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_084.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.017s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_084.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_084.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_084.dax  in 53.078s
# -- removing hot pixels for channels:['488'] in 11.078s
# -- illumination correction for channels: 488, in 3.000s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 68.425s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_084.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 8.625s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.031s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_084.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_084.hdf5 in 0.453s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_084.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_084.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_084.dax  in 49.531s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 42.672s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 30.515s
# -- illumination correction for channels: 750, 647, 561, 488, in 10.078s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.17 -16.71 -10.98] in 5.359s.
# -- drift 1: [  0.17 -16.6  -10.68] in 5.828s.
# -- drift 2: [  0.1  -16.77 -10.75] in 5.889s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.15 -16.69 -10.8 ] in 17.453s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.15 -16.69 -10.8 ] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 72.187s
# -- finish correction in 224.266s
# -- start fitting spots in channel:750, 3586 seeded with th=700.0, 3586 fitted in 313.718s.
# -- start fitting spots in channel:647, 1361 seeded with th=750.0, 1361 fitted in 169.125s.
# -- start fitting spots in channel:561, 4056 seeded with th=500.0, 4056 fitted in 350.750s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_084.hdf5
# -- updated spots for id:[1, 2, 67] in 0.047s
# in 1067.61s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_085.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 7.281s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_085.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_085.hdf5
# ++ base attributes loaded:[] in 0.016s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_085.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.026s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_085.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_085.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_085.dax  in 44.000s
# -- removing hot pixels for channels:['488'] in 12.906s
# -- illumination correction for channels: 488, in 2.563s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 60.479s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_085.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 7.156s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_085.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_085.hdf5 in 0.516s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_085.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_085.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_085.dax  in 36.047s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 38.406s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 18.516s
# -- illumination correction for channels: 750, 647, 561, 488, in 6.375s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.1  -21.37  -7.41] in 3.766s.
# -- drift 1: [  0.1  -21.4   -7.29] in 3.656s.
# -- drift 2: [  0.08 -21.37  -7.19] in 3.875s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.09 -21.38  -7.3 ] in 11.562s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.09 -21.38  -7.3 ] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 66.937s
# -- finish correction in 179.531s
# -- start fitting spots in channel:750, 3311 seeded with th=700.0, 3311 fitted in 268.672s.
# -- start fitting spots in channel:647, 1294 seeded with th=750.0, 1294 fitted in 171.203s.
# -- start fitting spots in channel:561, 3592 seeded with th=500.0, 3592 fitted in 316.406s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_085.hdf5
# -- updated spots for id:[1, 2, 67] in 0.047s
# in 941.84s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_086.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 7.266s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_086.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_086.hdf5
# ++ base attributes loaded:[] in 0.000s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_086.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.026s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_086.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_086.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_086.dax  in 54.234s
# -- removing hot pixels for channels:['488'] in 14.469s
# -- illumination correction for channels: 488, in 3.532s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 103.203s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_086.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 8.592s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_086.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_086.hdf5 in 0.937s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_086.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_086.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_086.dax  in 41.344s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 39.578s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 28.813s
# -- illumination correction for channels: 750, 647, 561, 488, in 9.156s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.07 -21.31  -8.94] in 4.265s.
# -- drift 1: [ -0.17 -21.75  -9.09] in 4.016s.
# -- drift 2: [ -0.27 -21.76  -9.01] in 5.047s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [ -0.17 -21.61  -9.01] in 13.781s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[ -0.17 -21.61  -9.01] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 70.703s
# -- finish correction in 206.793s
# -- start fitting spots in channel:750, 3825 seeded with th=700.0, 3825 fitted in 321.829s.
# -- start fitting spots in channel:647, 1443 seeded with th=750.0, 1443 fitted in 139.031s.
# -- start fitting spots in channel:561, 4223 seeded with th=500.0, 4223 fitted in 259.127s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_086.hdf5
# -- updated spots for id:[1, 2, 67] in 0.016s
# in 931.66s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_087.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 3.500s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_087.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_087.hdf5
# ++ base attributes loaded:[] in 0.004s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_087.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.018s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_087.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_087.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_087.dax  in 41.815s
# -- removing hot pixels for channels:['488'] in 5.047s
# -- illumination correction for channels: 488, in 1.734s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 49.102s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_087.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 5.211s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.000s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_087.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_087.hdf5 in 0.327s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_087.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_087.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_087.dax  in 35.656s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 19.656s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 11.391s
# -- illumination correction for channels: 750, 647, 561, 488, in 4.516s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.16 -21.94  -6.37] in 2.875s.
# -- drift 1: [ -0.2  -21.33  -6.36] in 3.014s.
# -- drift 2: [ -0.17 -21.79  -6.26] in 2.987s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [ -0.18 -21.69  -6.33] in 9.079s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[ -0.18 -21.69  -6.33] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 45.702s
# -- finish correction in 126.796s
# -- start fitting spots in channel:750, 4260 seeded with th=700.0, 4260 fitted in 224.218s.
# -- start fitting spots in channel:647, 1610 seeded with th=750.0, 1610 fitted in 106.484s.
# -- start fitting spots in channel:561, 4453 seeded with th=500.0, 4453 fitted in 228.610s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_087.hdf5
# -- updated spots for id:[1, 2, 67] in 0.017s
# in 689.59s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_088.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 3.324s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_088.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_088.hdf5
# ++ base attributes loaded:[] in 0.007s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_088.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.016s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_088.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_088.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_088.dax  in 53.234s
# -- removing hot pixels for channels:['488'] in 4.782s
# -- illumination correction for channels: 488, in 1.640s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 60.197s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_088.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 5.073s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.013s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_088.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_088.hdf5 in 0.285s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_088.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_088.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_088.dax  in 38.156s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 20.250s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 11.390s
# -- illumination correction for channels: 750, 647, 561, 488, in 4.547s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.22 -20.45  -8.66] in 2.761s.
# -- drift 1: [ -0.26 -20.3   -8.68] in 2.844s.
# -- drift 2: [ -0.53 -20.29  -8.62] in 2.766s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [ -0.34 -20.35  -8.65] in 8.578s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[ -0.34 -20.35  -8.65] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 43.682s
# -- finish correction in 127.417s
# -- start fitting spots in channel:750, 4014 seeded with th=700.0, 4014 fitted in 208.422s.
# -- start fitting spots in channel:647, 1523 seeded with th=750.0, 1523 fitted in 102.234s.
# -- start fitting spots in channel:561, 4069 seeded with th=500.0, 4069 fitted in 213.965s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_088.hdf5
# -- updated spots for id:[1, 2, 67] in 0.031s
# in 655.18s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_089.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 3.375s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_089.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_089.hdf5
# ++ base attributes loaded:[] in 0.008s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_089.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.014s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_089.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_089.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_089.dax  in 49.346s
# -- removing hot pixels for channels:['488'] in 4.953s
# -- illumination correction for channels: 488, in 1.563s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 56.481s
# ...
# -- drift 1: [  0.1  -18.67  -9.76] in 2.594s.
# -- drift 2: [  0.07 -18.62  -9.44] in 2.656s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.09 -18.52  -9.62] in 8.203s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.09 -18.52  -9.62] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 43.484s
# -- finish correction in 95.531s
# -- start fitting spots in channel:750, 3128 seeded with th=700.0, 3128 fitted in 167.562s.
# -- start fitting spots in channel:647, 1333 seeded with th=750.0, 1333 fitted in 92.703s.
# -- start fitting spots in channel:561, 3001 seeded with th=500.0, 3001 fitted in 164.203s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_196.hdf5
# -- updated spots for id:[1, 2, 67] in 0.031s
# in 523.31s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_197.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 3.359s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_197.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_197.hdf5
# ++ base attributes loaded:[] in 0.016s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_197.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.010s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_197.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_197.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_197.dax  in 6.790s
# -- removing hot pixels for channels:['488'] in 4.616s
# -- illumination correction for channels: 488, in 1.672s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 13.490s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_197.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 5.078s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.000s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_197.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_197.hdf5 in 0.296s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_197.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_197.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_197.dax  in 5.953s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 20.641s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 12.609s
# -- illumination correction for channels: 750, 647, 561, 488, in 4.312s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [ -0.06 -18.23  -8.11] in 2.750s.
# -- drift 1: [ -0.05 -18.51  -8.55] in 2.578s.
# -- drift 2: [ -0.14 -18.46  -8.47] in 2.625s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [ -0.08 -18.4   -8.38] in 8.141s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[ -0.08 -18.4   -8.38] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 43.312s
# -- finish correction in 95.766s
# -- start fitting spots in channel:750, 4324 seeded with th=700.0, 4324 fitted in 216.954s.
# -- start fitting spots in channel:647, 1797 seeded with th=750.0, 1797 fitted in 111.125s.
# -- start fitting spots in channel:561, 4208 seeded with th=500.0, 4208 fitted in 217.563s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_197.hdf5
# -- updated spots for id:[1, 2, 67] in 0.016s
# in 644.53s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_198.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 3.328s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_198.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_198.hdf5
# ++ base attributes loaded:[] in 0.000s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_198.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.014s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_198.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_198.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_198.dax  in 8.609s
# -- removing hot pixels for channels:['488'] in 4.672s
# -- illumination correction for channels: 488, in 1.656s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 15.390s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_198.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 4.953s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_198.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_198.hdf5 in 0.313s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_198.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_198.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_198.dax  in 6.969s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 20.453s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 12.594s
# -- illumination correction for channels: 750, 647, 561, 488, in 4.422s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.03 -17.59  -9.32] in 2.625s.
# -- drift 1: [  0.08 -17.05  -8.95] in 2.656s.
# -- drift 2: [  0.06 -17.17  -9.08] in 2.641s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.06 -17.27  -9.12] in 8.250s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.06 -17.27  -9.12] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 42.781s
# -- finish correction in 96.265s
# -- start fitting spots in channel:750, 4243 seeded with th=700.0, 4243 fitted in 211.172s.
# -- start fitting spots in channel:647, 1816 seeded with th=750.0, 1816 fitted in 111.906s.
# -- start fitting spots in channel:561, 4398 seeded with th=500.0, 4397 fitted in 226.797s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_198.hdf5
# -- updated spots for id:[1, 2, 67] in 0.016s
# in 649.29s.
# directly return existing attribute.
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 68
# - Number of field of views: 217
# - Importing csv format color_usage file: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '488', '405']
# dict_keys(['H0C1', 'H1C2', 'H2C3', 'H3C4', 'H4C5', 'H5C6', 'H6C7', 'H7C8', 'H8C9', 'H9C10', 'H10C11', 'H11C12', 'H12C13', 'H13C14', 'H14C15', 'H15C16', 'H16C17', 'H17C18', 'H18C19', 'H19C20', 'H20C21', 'H21C22', 'H22C23', 'H23C24', 'H24C25', 'H25C26', 'H26C27', 'H27C28', 'H28C29', 'H29C30', 'H30C31', 'H31C32', 'H32C33', 'H33C34', 'H34C35', 'H35C36', 'H36C37', 'H37C38', 'H38C39', 'H39C40', 'H40C41', 'H41C42', 'H42C43', 'H43C44', 'H44C45', 'H45C46', 'H46C47', 'H47C48', 'H48C49', 'H49C50', 'H50C51', 'H51C52', 'H52C53', 'H53C54', 'H54C55', 'H55C56', 'H56C57', 'H57C58', 'H58C59', 'H59C60', 'H60C61', 'H61C62', 'H62C63', 'H63C64', 'H64C65', 'H65C66', 'H66C67', 'H67C1_rep', 'H68U2', 'H69U3', 'H70U4', 'H71U5', 'H72U6', 'H73U7', 'H74U8', 'H75U9', 'H76U10', 'H77U1'])
# - 68 folders are found according to color-usage annotation.
# + loading fov_info from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_199.hdf5
# ++ base attributes loaded:['combo_ref_im', 'dapi_im'] in 3.281s.
# + loading correction from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_199.hdf5
# ++ load bleed correction profile directly from savefile.
# ++ load chromatic correction profile directly from savefile.
# ++ load chromatic_constants correction profile directly from savefile.
# ++ load illumination correction profile directly from savefile.
# + loading segmentation from file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_199.hdf5
# ++ base attributes loaded:[] in 0.016s.
# -- saving relabeled_combo to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_199.hdf5
# --- relabeled_combo attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.000s.
# -- folders not selected, allow processing all 68 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_199.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_199.dax
# -- loading illumination correction profile from file:
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H0C1\Conv_zscan_199.dax  in 7.891s
# -- removing hot pixels for channels:['488'] in 4.734s
# -- illumination correction for channels: 488, in 1.563s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 14.609s
# -- saving fov_info to file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_199.hdf5
# ++ base attributes saved:['relabeled_combo_ref_im'] in 5.000s.
# -- checking relabeled_combo, region:[ 1  2 67] in 0.016s.
# + Start sequential pre-processing for 1 images
# ++ processed relabeled_combo ids: [ 1  2 67] + batch process image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_199.dax for channels:['750', '647', '561']
# - loading relabeled_combo info from file:Conv_zscan_199.hdf5 in 0.266s.
# -- ['750', '647', '561'] images are required to process, [] images are loaded from save file: D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_199.hdf5
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_199.dax
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_5\20220419-P_brain_CTP11-13_from_0415storm65\H67C1_rep\Conv_zscan_199.dax  in 5.859s
# -- removing hot pixels for channels:['750', '647', '561', '488'] in 20.125s
# -- bleedthrough correction for channels: ['750', '647', '561'] in 12.516s
# -- illumination correction for channels: 750, 647, 561, 488, in 4.484s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# -- drift 0: [  0.   -16.51  -7.56] in 2.703s.
# -- drift 1: [  0.   -16.87  -7.68] in 2.594s.
# -- drift 2: [  0.   -16.87  -7.54] in 2.609s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [  0.   -16.75  -7.59] in 8.109s
# -- generate translation function for chromatic correction for channels: ['750', '561'] and drift:[  0.   -16.75  -7.59] in 0.000s
# -- applying gaussian highpass filte, sigma=5 in 44.031s
# -- finish correction in 95.906s
# -- start fitting spots in channel:750, 3315 seeded with th=700.0, 3315 fitted in 172.969s.
# -- start fitting spots in channel:647, 1406 seeded with th=750.0, 1406 fitted in 95.672s.
# -- start fitting spots in channel:561, 3134 seeded with th=500.0, 3134 fitted in 166.187s.
# - writting relabeled_combo spots into file:D:\Pu_Temp\20220419-CTP11-13_from_0415storm65\Conv_zscan_199.hdf5
# -- updated spots for id:[1, 2, 67] in 0.016s
# in 533.66s.
# directly return existing attribute.
