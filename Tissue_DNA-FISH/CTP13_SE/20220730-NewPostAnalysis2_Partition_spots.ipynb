# %% [markdown]
# # Analysis of DNA-MERFISH for CTP11-13 in Mecp2 +/-
#
# by Pu Zheng
#
# 2022.07.30
#
# analysis for dataset:
#
#     \\10.245.74.158\Chromatin_NAS_8\20220729_Mecp2_0724_DNA
#
# This data is DNA of uncleared MERFISH RNA:
#
#     \\10.245.74.158\Chromatin_NAS_6\20220724_MOp_Mecp2

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 35352

# %% [markdown]
# ## 0.1 Folders

# %%
save_folder = r'J:\Pu_Temp\20220729_Mecp2_0724_DNA'
save_filenames = [os.path.join(save_folder, _fl) for _fl in os.listdir(save_folder)
                  if _fl.split(os.extsep)[-1]=='hdf5']
# extract fov_id
save_fov_ids = [int(os.path.basename(_fl).split('.hdf5')[0].split('_')[-1]) for _fl in save_filenames]

debug = False

print(f"{len(save_filenames)} fovs detected")

analysis_folder = os.path.join(save_folder, 'Analysis_0802')

segmentation_folder = os.path.join(analysis_folder, 'Segmentation')
if not os.path.exists(segmentation_folder):
    os.makedirs(segmentation_folder)
    print(f"Creating segmentation_folder: {segmentation_folder}")
else:
    print(f"Use segmentation_folder: {segmentation_folder}")

cand_spot_folder = os.path.join(analysis_folder, 'CandSpots')
if not os.path.exists(cand_spot_folder):
    os.makedirs(cand_spot_folder)
    print(f"Creating cand_spot_folder: {cand_spot_folder}")
else:
    print(f"Use cand_spot_folder: {cand_spot_folder}")

decoder_folder = cand_spot_folder.replace('CandSpots', 'Decoder')
if debug:
    _version = 0
    while os.path.exists(os.path.join(decoder_folder, f'v{_version}')):
        _version += 1
    decoder_folder = os.path.join(decoder_folder, f'v{_version}')
if not os.path.exists(decoder_folder):
    os.makedirs(decoder_folder)
    print(f"Creating decoder_folder: {decoder_folder}")
else:
    print(f"Use decoder_folder: {decoder_folder}")
    
picked_folder = os.path.join(analysis_folder, 'Picked_v0')
if not os.path.exists(picked_folder):
    os.makedirs(picked_folder)
    print(f"Creating picked_folder: {picked_folder}")
else:
    print(f"Use picked_folder: {picked_folder}")
# Out:
# 46 fovs detected
# Use segmentation_folder: J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\Segmentation
# Use cand_spot_folder: J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\CandSpots
# Use decoder_folder: J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\Decoder
# Use picked_folder: J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\Picked_v0

# %% [raw]
# save_fov_ids = save_fov_ids[:7]
# save_filenames = save_filenames[:7]

# %%
pixel_sizes = np.array([250,108,108])
single_im_size = np.array([50,2048,2048])

# %% [markdown]
# # 1. Partition DNA-MERFISH spots

# %%
from ImageAnalysis3.classes.partition_spots import Spots_Partition
from ImageAnalysis3.classes.preprocess import Spots3D
from ImageAnalysis3.figure_tools import plot_partition
import pandas as pd

# %%
from ImageAnalysis3.segmentation_tools.cell import Align_Segmentation
import ImageAnalysis3.io_tools.spots

# %%
search_radius = 3
overwrite_cand_spots = False
add_relabel_spots = False
data_type = 'combo' # 'combo'
#_total_seg_save_file defined in 2.3
if not os.path.exists(os.path.join(cand_spot_folder, data_type)):
    print(os.path.join(cand_spot_folder, data_type))
    os.makedirs(os.path.join(cand_spot_folder, data_type))
# load microscope.json
dna_microscope_file = r'\\mendel\pu_documents\Merfish_analysis\Merfish_Analysis_Scripts\merlin_parameters\microscope\storm6_microscope.json'
# Out:
# J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\CandSpots\combo

# %%
# %%time
_partition_args = []

for _fov_id, _save_filename in zip(save_fov_ids, save_filenames):

    _segmentation_savefile = os.path.join(segmentation_folder, 
        os.path.basename(_save_filename).replace('.hdf5', '_Segmentation.hdf5') )
    # savename
    _cand_spot_filename = os.path.join(cand_spot_folder, data_type, 
                                      os.path.basename(_save_filename).replace('.hdf5', f'_CandSpots.csv') )
    if os.path.isfile(_cand_spot_filename) and not overwrite_cand_spots:
        continue
    # load segmentation label matrix and uids
    _align_seg = Align_Segmentation('', '', _save_filename, '', dna_microscope_file, np.array([]))
    _align_seg._load(_segmentation_savefile)
    seg_label, fovcell_2_uid = _align_seg.dna_mask, _align_seg.fovcell_2_uid
    # load spots
    spots_list, combo_bits = ia.io_tools.spots.load_preprocess_spots(
        _save_filename, data_type, None, pixel_sizes=pixel_sizes,
    )
    # add relabeled spots if specified.
    if add_relabel_spots:
        relabel_spots_list, relabel_bits = ia.io_tools.spots.load_preprocess_spots(
            _save_filename, f'relabeled_{data_type}', None, pixel_sizes=pixel_sizes,
        )
        for _rspots, _rbit in zip(relabel_spots_list, relabel_bits):
            _ind = list(combo_bits).index(_rbit)
            _old_spots = spots_list[_ind]
            # merge
            _merged_spots = ia.io_tools.spots.merge_RelabelSpots(
                _old_spots, _rspots, pixel_sizes=pixel_sizes,
            )
            # replace
            spots_list[_ind] = _merged_spots
    # 
    _all_spots = ia.io_tools.spots.merge_Spots3DList(spots_list, pixel_sizes=pixel_sizes)
    # partition args
    _args = (
        _fov_id, 
        np.array(_all_spots), _all_spots.bits, _all_spots.channels,
        seg_label, fovcell_2_uid,
        dna_microscope_file,
        search_radius, pixel_sizes,
        True, 
        True, _cand_spot_filename,
        True, 60, 
        False, True,
    )
    _partition_args.append(_args)
    
print(len(_partition_args))
# Out:
# -- loading segmentation info from fov:1 into file: J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\Segmentation\Conv_zscan_001_Segmentation.hdf5
# 1
# Wall time: 5.4 s

# %% [markdown]
# ## 1.1 parallel process

# %%
# %%time
import multiprocessing as mp
# Multiprocessing
print(f"- Start multiprocessing spot partitioning", end=' ')
_start_time = time.time()
with mp.Pool(12) as _partition_pool:
    # start multiprocessing
    _partition_pool.starmap(ia.classes.partition_spots.batch_partition_DNA_spots, 
                            _partition_args, chunksize=1)
    # close multiprocessing
    _partition_pool.close()
    _partition_pool.join()
    _partition_pool.terminate()
print(f"finish in {time.time()-_start_time:.3f}s. ")
# Out:
# - Start multiprocessing spot partitioning finish in 3355.008s.
# Wall time: 55min 55s

# %% [markdown]
# ### 1.1.2 sequential version

# %%
# sequential
for _args in _partition_args:
    ia.classes.partition_spots.batch_partition_DNA_spots(*_args)
    break
# Out:
# - Partition cand_spots for fov:1
# -- partition barcodes for 1371397 spots
# 1371397it [01:16, 18028.16it/s]
# - Save 1183633 spots to file: J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\CandSpots\combo\Conv_zscan_001_CandSpots.csv
# <img src="data:image/png;base64,..." width="599.9999869953505">
# -- save iamage to file: J:\Pu_Temp\20220729_Mecp2_0724_DNA\Analysis_0802\CandSpots\combo\Figures\Fov-1_SpotCountPerCell.png
# -- finish partition in 187.568s.

# %% [markdown]
# ## Partition sequential genes

# %%
search_radius = 3
overwrite_cand_spots = False
add_relabel_spots = False
data_type = 'unique'
expect_spot_num = 4

#_total_seg_save_file defined in 2.3
if not os.path.exists(os.path.join(cand_spot_folder,data_type)):
    print(os.path.join(cand_spot_folder,data_type))
    os.makedirs(os.path.join(cand_spot_folder,data_type))
# load microscope.json
dna_microscope_file = r'\\mendel\pu_documents\Merfish_analysis\Merfish_Analysis_Scripts\merlin_parameters\microscope\storm6_microscope.json'
# Out:
# F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\CandSpots\unique

# %%
# %%time
_partition_args = []

for _fov_id, _save_filename in zip(save_fov_ids, save_filenames):

    _segmentation_savefile = os.path.join(segmentation_folder, 
        os.path.basename(_save_filename).replace('.hdf5', '_Segmentation.hdf5') )
    # savename
    _cand_spot_filename = os.path.join(cand_spot_folder, data_type, 
                                      os.path.basename(_save_filename).replace('.hdf5', f'_CandSpots.csv') )
    if os.path.isfile(_cand_spot_filename) and not overwrite_cand_spots:
        continue
    # load segmentation label matrix and uids
    _align_seg = Align_Segmentation('', '', _save_filename, '', dna_microscope_file, np.array([]))
    _align_seg._load(_segmentation_savefile)
    seg_label, fovcell_2_uid = _align_seg.dna_mask, _align_seg.fovcell_2_uid
    # load spots
    spots_list, combo_bits = ia.io_tools.spots.load_preprocess_spots(
        _save_filename, data_type, None, pixel_sizes=pixel_sizes,
    )
    # add relabeled spots if specified.
    if add_relabel_spots:
        relabel_spots_list, relabel_bits = ia.io_tools.spots.load_preprocess_spots(
            _save_filename, f'relabeled_{data_type}', None, pixel_sizes=pixel_sizes,
        )
        for _rspots, _rbit in zip(relabel_spots_list, relabel_bits):
            _ind = list(combo_bits).index(_rbit)
            _old_spots = spots_list[_ind]
            # merge
            _merged_spots = ia.io_tools.spots.merge_RelabelSpots(
                _old_spots, _rspots, pixel_sizes=pixel_sizes,
            )
            # replace
            spots_list[_ind] = _merged_spots
    # 
    _all_spots = ia.io_tools.spots.merge_Spots3DList(spots_list, pixel_sizes=pixel_sizes)
    # partition args
    _args = (
        _fov_id, 
        np.array(_all_spots), _all_spots.bits, _all_spots.channels,
        seg_label, fovcell_2_uid,
        dna_microscope_file,
        search_radius, pixel_sizes,
        True, 
        True, _cand_spot_filename,
        True, expect_spot_num, 
        False, True,
    )
    _partition_args.append(_args)
    
print(len(_partition_args))
# Out:
# -- loading segmentation info from fov:0 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_000_Segmentation.hdf5
# -- loading segmentation info from fov:1 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_001_Segmentation.hdf5
# -- loading segmentation info from fov:2 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_002_Segmentation.hdf5
# -- loading segmentation info from fov:3 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_003_Segmentation.hdf5
# -- loading segmentation info from fov:4 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_004_Segmentation.hdf5
# -- loading segmentation info from fov:5 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_005_Segmentation.hdf5
# -- loading segmentation info from fov:6 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_006_Segmentation.hdf5
# -- loading segmentation info from fov:7 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_007_Segmentation.hdf5
# -- loading segmentation info from fov:8 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_008_Segmentation.hdf5
# -- loading segmentation info from fov:9 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_009_Segmentation.hdf5
# -- loading segmentation info from fov:10 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_010_Segmentation.hdf5
# -- loading segmentation info from fov:11 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_011_Segmentation.hdf5
# -- loading segmentation info from fov:12 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_012_Segmentation.hdf5
# -- loading segmentation info from fov:13 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_013_Segmentation.hdf5
# -- loading segmentation info from fov:14 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_014_Segmentation.hdf5
# -- loading segmentation info from fov:15 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_015_Segmentation.hdf5
# -- loading segmentation info from fov:16 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_016_Segmentation.hdf5
# -- loading segmentation info from fov:18 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_018_Segmentation.hdf5
# -- loading segmentation info from fov:19 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_019_Segmentation.hdf5
# -- loading segmentation info from fov:20 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_020_Segmentation.hdf5
# -- loading segmentation info from fov:21 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_021_Segmentation.hdf5
# -- loading segmentation info from fov:22 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_022_Segmentation.hdf5
# -- loading segmentation info from fov:23 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_023_Segmentation.hdf5
# -- loading segmentation info from fov:24 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_024_Segmentation.hdf5
# -- loading segmentation info from fov:26 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_026_Segmentation.hdf5
# -- loading segmentation info from fov:27 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_027_Segmentation.hdf5
# -- loading segmentation info from fov:28 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_028_Segmentation.hdf5
# -- loading segmentation info from fov:29 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_029_Segmentation.hdf5
# -- loading segmentation info from fov:30 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_030_Segmentation.hdf5
# -- loading segmentation info from fov:31 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_031_Segmentation.hdf5
# -- loading segmentation info from fov:32 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_032_Segmentation.hdf5
# -- loading segmentation info from fov:33 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_033_Segmentation.hdf5
# -- loading segmentation info from fov:34 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_034_Segmentation.hdf5
# -- loading segmentation info from fov:35 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_035_Segmentation.hdf5
# -- loading segmentation info from fov:36 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_036_Segmentation.hdf5
# -- loading segmentation info from fov:37 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_037_Segmentation.hdf5
# -- loading segmentation info from fov:38 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_038_Segmentation.hdf5
# -- loading segmentation info from fov:39 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_039_Segmentation.hdf5
# -- loading segmentation info from fov:40 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_040_Segmentation.hdf5
# -- loading segmentation info from fov:41 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_041_Segmentation.hdf5
# -- loading segmentation info from fov:42 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_042_Segmentation.hdf5
# -- loading segmentation info from fov:43 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_043_Segmentation.hdf5
# -- loading segmentation info from fov:44 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_044_Segmentation.hdf5
# -- loading segmentation info from fov:45 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_045_Segmentation.hdf5
# -- loading segmentation info from fov:46 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_046_Segmentation.hdf5
# -- loading segmentation info from fov:47 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_047_Segmentation.hdf5
# -- loading segmentation info from fov:48 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_048_Segmentation.hdf5
# -- loading segmentation info from fov:49 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_049_Segmentation.hdf5
# -- loading segmentation info from fov:50 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_050_Segmentation.hdf5
# -- loading segmentation info from fov:51 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_051_Segmentation.hdf5
# -- loading segmentation info from fov:52 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_052_Segmentation.hdf5
# -- loading segmentation info from fov:53 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_053_Segmentation.hdf5
# -- loading segmentation info from fov:54 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_054_Segmentation.hdf5
# -- loading segmentation info from fov:55 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_055_Segmentation.hdf5
# -- loading segmentation info from fov:56 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_056_Segmentation.hdf5
# -- loading segmentation info from fov:57 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_057_Segmentation.hdf5
# -- loading segmentation info from fov:58 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_058_Segmentation.hdf5
# -- loading segmentation info from fov:59 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_059_Segmentation.hdf5
# -- loading segmentation info from fov:60 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_060_Segmentation.hdf5
# -- loading segmentation info from fov:61 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_061_Segmentation.hdf5
# -- loading segmentation info from fov:62 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_062_Segmentation.hdf5
# -- loading segmentation info from fov:63 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_063_Segmentation.hdf5
# -- loading segmentation info from fov:64 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_064_Segmentation.hdf5
# -- loading segmentation info from fov:65 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_065_Segmentation.hdf5
# -- loading segmentation info from fov:66 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_066_Segmentation.hdf5
# -- loading segmentation info from fov:67 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_067_Segmentation.hdf5
# -- loading segmentation info from fov:68 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_068_Segmentation.hdf5
# -- loading segmentation info from fov:70 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_070_Segmentation.hdf5
# -- loading segmentation info from fov:71 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_071_Segmentation.hdf5
# -- loading segmentation info from fov:72 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_072_Segmentation.hdf5
# -- loading segmentation info from fov:73 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_073_Segmentation.hdf5
# -- loading segmentation info from fov:74 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_074_Segmentation.hdf5
# -- loading segmentation info from fov:75 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_075_Segmentation.hdf5
# -- loading segmentation info from fov:76 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_076_Segmentation.hdf5
# -- loading segmentation info from fov:78 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_078_Segmentation.hdf5
# -- loading segmentation info from fov:79 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_079_Segmentation.hdf5
# -- loading segmentation info from fov:80 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_080_Segmentation.hdf5
# -- loading segmentation info from fov:81 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_081_Segmentation.hdf5
# -- loading segmentation info from fov:82 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_082_Segmentation.hdf5
# -- loading segmentation info from fov:83 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_083_Segmentation.hdf5
# -- loading segmentation info from fov:84 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_084_Segmentation.hdf5
# -- loading segmentation info from fov:86 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_086_Segmentation.hdf5
# -- loading segmentation info from fov:87 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_087_Segmentation.hdf5
# -- loading segmentation info from fov:89 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_089_Segmentation.hdf5
# -- loading segmentation info from fov:90 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_090_Segmentation.hdf5
# -- loading segmentation info from fov:91 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_091_Segmentation.hdf5
# -- loading segmentation info from fov:92 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_092_Segmentation.hdf5
# -- loading segmentation info from fov:93 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_093_Segmentation.hdf5
# -- loading segmentation info from fov:94 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_094_Segmentation.hdf5
# -- loading segmentation info from fov:95 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_095_Segmentation.hdf5
# -- loading segmentation info from fov:96 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_096_Segmentation.hdf5
# -- loading segmentation info from fov:97 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_097_Segmentation.hdf5
# -- loading segmentation info from fov:98 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_098_Segmentation.hdf5
# -- loading segmentation info from fov:99 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_099_Segmentation.hdf5
# -- loading segmentation info from fov:100 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_100_Segmentation.hdf5
# -- loading segmentation info from fov:101 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_101_Segmentation.hdf5
# -- loading segmentation info from fov:102 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_102_Segmentation.hdf5
# -- loading segmentation info from fov:103 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_103_Segmentation.hdf5
# -- loading segmentation info from fov:104 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_104_Segmentation.hdf5
# -- loading segmentation info from fov:105 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_105_Segmentation.hdf5
# -- loading segmentation info from fov:107 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_107_Segmentation.hdf5
# -- loading segmentation info from fov:108 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_108_Segmentation.hdf5
# -- loading segmentation info from fov:109 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_109_Segmentation.hdf5
# -- loading segmentation info from fov:110 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_110_Segmentation.hdf5
# -- loading segmentation info from fov:111 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_111_Segmentation.hdf5
# -- loading segmentation info from fov:112 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_112_Segmentation.hdf5
# -- loading segmentation info from fov:113 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_113_Segmentation.hdf5
# -- loading segmentation info from fov:114 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_114_Segmentation.hdf5
# -- loading segmentation info from fov:116 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_116_Segmentation.hdf5
# -- loading segmentation info from fov:117 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_117_Segmentation.hdf5
# -- loading segmentation info from fov:118 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_118_Segmentation.hdf5
# -- loading segmentation info from fov:119 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_119_Segmentation.hdf5
# -- loading segmentation info from fov:120 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_120_Segmentation.hdf5
# -- loading segmentation info from fov:122 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_122_Segmentation.hdf5
# -- loading segmentation info from fov:123 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_123_Segmentation.hdf5
# -- loading segmentation info from fov:125 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_125_Segmentation.hdf5
# -- loading segmentation info from fov:126 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_126_Segmentation.hdf5
# -- loading segmentation info from fov:127 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_127_Segmentation.hdf5
# -- loading segmentation info from fov:128 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_128_Segmentation.hdf5
# -- loading segmentation info from fov:129 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_129_Segmentation.hdf5
# -- loading segmentation info from fov:130 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_130_Segmentation.hdf5
# -- loading segmentation info from fov:131 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_131_Segmentation.hdf5
# -- loading segmentation info from fov:132 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_132_Segmentation.hdf5
# -- loading segmentation info from fov:133 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_133_Segmentation.hdf5
# -- loading segmentation info from fov:134 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_134_Segmentation.hdf5
# -- loading segmentation info from fov:135 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_135_Segmentation.hdf5
# -- loading segmentation info from fov:136 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_136_Segmentation.hdf5
# -- loading segmentation info from fov:137 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_137_Segmentation.hdf5
# -- loading segmentation info from fov:138 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_138_Segmentation.hdf5
# -- loading segmentation info from fov:139 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_139_Segmentation.hdf5
# -- loading segmentation info from fov:140 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_140_Segmentation.hdf5
# -- loading segmentation info from fov:141 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_141_Segmentation.hdf5
# -- loading segmentation info from fov:142 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_142_Segmentation.hdf5
# -- loading segmentation info from fov:143 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_143_Segmentation.hdf5
# -- loading segmentation info from fov:144 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_144_Segmentation.hdf5
# -- loading segmentation info from fov:145 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_145_Segmentation.hdf5
# -- loading segmentation info from fov:146 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_146_Segmentation.hdf5
# -- loading segmentation info from fov:147 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_147_Segmentation.hdf5
# -- loading segmentation info from fov:149 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_149_Segmentation.hdf5
# -- loading segmentation info from fov:150 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_150_Segmentation.hdf5
# -- loading segmentation info from fov:151 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_151_Segmentation.hdf5
# -- loading segmentation info from fov:153 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_153_Segmentation.hdf5
# -- loading segmentation info from fov:154 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_154_Segmentation.hdf5
# -- loading segmentation info from fov:155 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_155_Segmentation.hdf5
# -- loading segmentation info from fov:156 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_156_Segmentation.hdf5
# -- loading segmentation info from fov:157 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_157_Segmentation.hdf5
# -- loading segmentation info from fov:158 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_158_Segmentation.hdf5
# -- loading segmentation info from fov:160 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_160_Segmentation.hdf5
# -- loading segmentation info from fov:161 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_161_Segmentation.hdf5
# -- loading segmentation info from fov:162 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_162_Segmentation.hdf5
# -- loading segmentation info from fov:163 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_163_Segmentation.hdf5
# -- loading segmentation info from fov:164 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_164_Segmentation.hdf5
# -- loading segmentation info from fov:165 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_165_Segmentation.hdf5
# -- loading segmentation info from fov:166 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_166_Segmentation.hdf5
# -- loading segmentation info from fov:167 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_167_Segmentation.hdf5
# -- loading segmentation info from fov:168 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_168_Segmentation.hdf5
# -- loading segmentation info from fov:169 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_169_Segmentation.hdf5
# -- loading segmentation info from fov:171 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_171_Segmentation.hdf5
# -- loading segmentation info from fov:172 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_172_Segmentation.hdf5
# -- loading segmentation info from fov:173 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_173_Segmentation.hdf5
# -- loading segmentation info from fov:174 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_174_Segmentation.hdf5
# -- loading segmentation info from fov:175 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_175_Segmentation.hdf5
# -- loading segmentation info from fov:176 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_176_Segmentation.hdf5
# -- loading segmentation info from fov:177 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_177_Segmentation.hdf5
# -- loading segmentation info from fov:178 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_178_Segmentation.hdf5
# -- loading segmentation info from fov:180 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_180_Segmentation.hdf5
# -- loading segmentation info from fov:181 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_181_Segmentation.hdf5
# -- loading segmentation info from fov:182 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_182_Segmentation.hdf5
# -- loading segmentation info from fov:183 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_183_Segmentation.hdf5
# -- loading segmentation info from fov:184 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_184_Segmentation.hdf5
# -- loading segmentation info from fov:185 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_185_Segmentation.hdf5
# -- loading segmentation info from fov:186 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_186_Segmentation.hdf5
# -- loading segmentation info from fov:187 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_187_Segmentation.hdf5
# -- loading segmentation info from fov:188 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_188_Segmentation.hdf5
# -- loading segmentation info from fov:189 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_189_Segmentation.hdf5
# -- loading segmentation info from fov:190 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_190_Segmentation.hdf5
# -- loading segmentation info from fov:191 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_191_Segmentation.hdf5
# -- loading segmentation info from fov:192 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_192_Segmentation.hdf5
# -- loading segmentation info from fov:193 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_193_Segmentation.hdf5
# -- loading segmentation info from fov:194 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_194_Segmentation.hdf5
# -- loading segmentation info from fov:195 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_195_Segmentation.hdf5
# -- loading segmentation info from fov:196 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_196_Segmentation.hdf5
# -- loading segmentation info from fov:198 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_198_Segmentation.hdf5
# -- loading segmentation info from fov:199 into file: F:\Pu_Temp\20220713-P_brain_CTP11-13_from_0418\Analysis_0709\Segmentation\Conv_zscan_199_Segmentation.hdf5
# 184
# Wall time: 9min 5s

# %%
# %%time
import multiprocessing as mp
# Multiprocessing
print(f"- Start multiprocessing spot partitioning", end=' ')
_start_time = time.time()
with mp.Pool(12) as _partition_pool:
    # start multiprocessing
    _partition_pool.starmap(ia.classes.partition_spots.batch_partition_DNA_spots, 
                            _partition_args, chunksize=1)
    # close multiprocessing
    _partition_pool.close()
    _partition_pool.join()
    _partition_pool.terminate()
print(f"finish in {time.time()-_start_time:.3f}s. ")
# Out:
# - Start multiprocessing spot partitioning finish in 299.337s.
# Wall time: 4min 59s

# %% [markdown]
# ### 1.2.2 sequential version

# %%
# sequential
for _args in _partition_args[]:
    ia.classes.partition_spots.batch_partition_DNA_spots(*_args)
    break
