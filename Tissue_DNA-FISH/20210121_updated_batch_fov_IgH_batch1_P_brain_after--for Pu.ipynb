# %% [markdown]
# # 0. required packages for h5py

# %%
# %run "C:\Users\shiwei\Data Analysis\ImageAnalysis3\required_files\Startup_py3.py" 

sys.path.append(r"C:\Users\shiwei\Data Analysis")
import ImageAnalysis3 as ia 
# %matplotlib notebook
from ImageAnalysis3 import *
print(os.getpid())


import h5py
from ImageAnalysis3.classes import _allowed_kwds
import ast
# Out:
# 16828

# %% [markdown]
# # 1. Create field-of-view class

# %%
reload(ia)
reload(classes)
reload(classes.batch_functions)
reload(classes.field_of_view)
reload(io_tools.load)

reload(visual_tools)
reload(ia.correction_tools)
reload(ia.correction_tools.alignment)
reload(ia.spot_tools.matching)
reload(ia.segmentation_tools.chromosome)
reload(ia.spot_tools.fitting)


after_fov_param = {'data_folder':r'\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing',
                   'save_folder':r'V:\20201221-Acr_ctp08_P_brain\After_clearing\New',
                 #'save_folder':r'D:\Pu_Temp\202009_IgH_proB_DMSO_2color',
                 'experiment_type': 'DNA',
                 'num_threads': 12,
                 'correction_folder':r'\\10.245.74.158\Chromatin_NAS_0\Corrections\20201204-Corrections_3color_50',
                 'shared_parameters':{
                         'single_im_size':[50,2048,2048],
                         'corr_channels':['750','647'],
                         'num_empty_frames': 0, 
                         'corr_hot_pixel':True,
                         'corr_Z_shift':False,
                         'min_num_seeds':500,
                         'max_num_seeds': 2500,
                         'spot_seeding_th':150,
                         'normalize_intensity_local':False,
                         'normalize_intensity_background':False,
                     },             
             }

fov_ids = np.arange(5,11)

# %%
reload(io_tools.load)
from ImageAnalysis3.spot_tools.picking import assign_spots_to_chromosomes

overwrite_spot=False
overwrite_chrom=False
intensity_th = 200

before_fov_ids_list = []
before_chrom_ims = []
before_chrom_coords_list = []
before_cand_chr_spots_list = []


reload(io_tools.load)
from ImageAnalysis3.spot_tools.picking import assign_spots_to_chromosomes

overwrite_spot=False
overwrite_chrom=True
#intensity_th = 200

after_fov_ids_list = []
after_chrom_ims = []
after_chrom_coords_list = []
after_cand_chr_spots_list = []

for _fov_id in fov_ids:

    # create fov class
    after_fov = classes.field_of_view.Field_of_View(after_fov_param, _fov_id=_fov_id,
        _color_info_kwargs={
          '_color_filename':'Color_Usage',
        }, 
        _prioritize_saved_attrs=False,
        )

    # process image into spots
    after_id_list, after_spot_list = after_fov._process_image_to_spots('unique', 
         #_sel_ids=np.arange(41,72),
         _load_common_reference=True,
         _load_with_multiple=False,
         _save_images=True,
         _warp_images=False, 
         _overwrite_drift=False,
         _overwrite_image=False,
         _overwrite_spot=overwrite_spot,
         _verbose=True)
    # identify chromosomes
    after_fov._load_from_file('unique')
    
    if not hasattr(after_fov, 'chrom_im'):
        _chrom_im = after_fov._load_chromosome_image(_overwrite=overwrite_chrom)
    if not hasattr(after_fov, 'chrom_coords'):
        _chrom_coords = after_fov._find_candidate_chromosomes_by_segmentation(
            _filt_size=4,
            _binary_per_th=99.75,
            _morphology_size=2,
            _overwrite=overwrite_chrom)
        _chrom_coords = after_fov._select_chromosome_by_candidate_spots(
            _good_chr_loss_th=0.3, _cand_spot_intensity_th=200,
            _overwrite=overwrite_chrom,
            _save=True)

    # append
    after_chrom_ims.append(after_fov.chrom_im)
    after_chrom_coords_list.append(after_fov.chrom_coords)
    after_fov_ids_list.append(_fov_id*np.ones(len(after_fov.chrom_coords)))
    
    after_fov_cand_chr_spots_list = [[] for _ct in after_fov.chrom_coords]

    # finalize candidate spots
    for _spots in after_fov.unique_spots_list:
        _cands_list = assign_spots_to_chromosomes(_spots, after_fov.chrom_coords)
        for _i, _cands in enumerate(_cands_list):
            after_fov_cand_chr_spots_list[_i].append(_cands)
            
    after_cand_chr_spots_list += after_fov_cand_chr_spots_list
    
    print(f"kept chromosomes: {len(after_fov.chrom_coords)}")

# combine acquired spots and chromosomes
after_chrom_coords = np.concatenate(after_chrom_coords_list)
after_fov_ids_list = np.concatenate(after_fov_ids_list).astype(np.int)

from ImageAnalysis3.spot_tools.picking import convert_spots_to_hzxys
after_dna_cand_hzxys_list = [convert_spots_to_hzxys(_spots, after_fov.shared_parameters['distance_zxy'])
                       for _spots in after_cand_chr_spots_list]
after_dna_reg_ids = after_fov.unique_ids

print(f"{len(after_chrom_coords)} are found.")
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 11
# - Number of field of views: 88
# - Importing csv file: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '405']
# -- Hyb H0R0 exists in this data
# -- DAPI exists in hyb: H0R0
# - 11 folders are found according to color-usage annotation.
# + creating save folder: V:\20201221-Acr_ctp08_P_brain\After_clearing\New
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_05.dax: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# * create savefile: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'bead_channel_index', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel_index', 'data_folder', 'drift', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi'] in 0.018s.
# -- saving segmentation to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# -- saving correction to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# -- saving 750_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- saving 647_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- saving 561_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- saving 405_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- saving 750_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- saving 647_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5, skip.
# -- saving 750_647_bleed profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5.
# -- saving unique to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 1.202s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'bead_channel_index', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel_index', 'data_folder', 'drift', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi'] in 0.342s.
# -- No folder selected, allow processing all 11 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_05.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_05.dax
# -- loading illumination correction profile from file:
# 	 561 illumination_correction_561_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_05.dax  in 3.702s
# -- removing hot pixels for channels:['561'] in 12.822s
# -- illumination correction for channels: 561, in 2.430s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 19.518s
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# ++ base attributes saved:['ref_im'] in 14.965s.
# -- checking unique, region:[45] in 0.010s.
# -- checking unique, region:[96 97] in 0.008s.
# -- checking unique, region:[ 99 100] in 0.010s.
# -- checking unique, region:[102 103] in 0.002s.
# -- checking unique, region:[105 106] in 0.010s.
# -- checking unique, region:[108 109] in 0.014s.
# -- checking unique, region:[111 112] in 0.009s.
# -- checking unique, region:[114 113] in 0.009s.
# -- checking unique, region:[98 95] in 0.009s.
# -- checking unique, region:[104 101] in 0.008s.
# -- checking unique, region:[110 107] in 0.008s.
# + Start multi-processing of pre-processing for 11 images with 12 threads
# ++ processed unique ids: [ 45  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111
#  112 113 114] in 1646.71s.
# + loading unique from file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# C:\Users\shiwei\Data Analysis\ImageAnalysis3\classes\field_of_view.py:1448: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   _spots_list = np.array([_spots[_spots[:,0] > 0] for _flg, _spots in zip(_flags, _grp['spots'][:]) if _flg > 0])
# ++ finish loading unique in 0.198s.
# -- choose chrom images from folder: \.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_05.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_05.dax  in 6.372s
# -- removing hot pixels for channels:['750'] in 18.075s
# -- illumination correction for channels: 750, in 2.549s
# -- warp image with chromatic correction for channels: ['750'] and drift:[0. 0. 0.] 750, in 141.885s
# -- finish correction in 181.703s
# -- chromosome image has drift: [0. 0. 0.]
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# ++ base attributes saved:['chrom_im'] in 11.028s.
# -- adjust seed image with filter size=4
# -- binarize image with threshold: 99.75%
# -- erosion and dialation with size=2.
# -- find close objects.
# -- random walk segmentation, beta=10.
# C:\Users\shiwei\Anaconda3\lib\site-packages\skimage\segmentation\random_walker_segmentation.py:470: UserWarning: Random walker only segments unlabeled areas, where labels == 0. No zero valued areas in labels were found. Returning provided labels.
#   inds_isolated_seeds, isolated_values) = _preprocess(labels)
# -- find objects larger than size=50
# -- 283 objects are found by segmentation.
# - Start multiprocessing caluclate chromosome coordinates with 12 threads in 273.119s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# ++ base attributes saved:['cand_chrom_coords'] in 0.042s.
# - start select from 283 chromosomes with loss threshold=0.3
# -- remove chr id 59, percentage of lost rounds:1.000.
# -- remove chr id 100, percentage of lost rounds:0.952.
# -- remove chr id 105, percentage of lost rounds:0.952.
# -- remove chr id 163, percentage of lost rounds:0.952.
# -- remove chr id 44, percentage of lost rounds:0.905.
# -- remove chr id 219, percentage of lost rounds:0.905.
# -- remove chr id 32, percentage of lost rounds:0.857.
# -- remove chr id 35, percentage of lost rounds:0.857.
# -- remove chr id 57, percentage of lost rounds:0.857.
# -- remove chr id 57, percentage of lost rounds:0.857.
# -- remove chr id 60, percentage of lost rounds:0.857.
# -- remove chr id 84, percentage of lost rounds:0.857.
# -- remove chr id 227, percentage of lost rounds:0.857.
# -- remove chr id 24, percentage of lost rounds:0.810.
# -- remove chr id 115, percentage of lost rounds:0.810.
# -- remove chr id 198, percentage of lost rounds:0.810.
# -- remove chr id 265, percentage of lost rounds:0.810.
# -- remove chr id 3, percentage of lost rounds:0.762.
# -- remove chr id 6, percentage of lost rounds:0.762.
# -- remove chr id 35, percentage of lost rounds:0.762.
# -- remove chr id 52, percentage of lost rounds:0.762.
# -- remove chr id 58, percentage of lost rounds:0.762.
# -- remove chr id 93, percentage of lost rounds:0.762.
# -- remove chr id 106, percentage of lost rounds:0.762.
# -- remove chr id 215, percentage of lost rounds:0.762.
# -- remove chr id 248, percentage of lost rounds:0.762.
# -- remove chr id 113, percentage of lost rounds:0.714.
# -- remove chr id 144, percentage of lost rounds:0.714.
# -- remove chr id 147, percentage of lost rounds:0.714.
# -- remove chr id 210, percentage of lost rounds:0.714.
# -- remove chr id 210, percentage of lost rounds:0.714.
# -- remove chr id 13, percentage of lost rounds:0.667.
# -- remove chr id 13, percentage of lost rounds:0.667.
# -- remove chr id 30, percentage of lost rounds:0.667.
# -- remove chr id 71, percentage of lost rounds:0.667.
# -- remove chr id 115, percentage of lost rounds:0.667.
# -- remove chr id 143, percentage of lost rounds:0.667.
# -- remove chr id 163, percentage of lost rounds:0.667.
# -- remove chr id 190, percentage of lost rounds:0.667.
# -- remove chr id 204, percentage of lost rounds:0.667.
# -- remove chr id 44, percentage of lost rounds:0.619.
# -- remove chr id 67, percentage of lost rounds:0.619.
# -- remove chr id 74, percentage of lost rounds:0.619.
# -- remove chr id 97, percentage of lost rounds:0.619.
# -- remove chr id 133, percentage of lost rounds:0.619.
# -- remove chr id 159, percentage of lost rounds:0.619.
# -- remove chr id 164, percentage of lost rounds:0.619.
# -- remove chr id 195, percentage of lost rounds:0.619.
# -- remove chr id 202, percentage of lost rounds:0.619.
# -- remove chr id 15, percentage of lost rounds:0.571.
# -- remove chr id 36, percentage of lost rounds:0.571.
# -- remove chr id 40, percentage of lost rounds:0.571.
# -- remove chr id 98, percentage of lost rounds:0.571.
# -- remove chr id 98, percentage of lost rounds:0.571.
# -- remove chr id 120, percentage of lost rounds:0.571.
# -- remove chr id 137, percentage of lost rounds:0.571.
# -- remove chr id 171, percentage of lost rounds:0.571.
# -- remove chr id 196, percentage of lost rounds:0.571.
# -- remove chr id 223, percentage of lost rounds:0.571.
# -- remove chr id 20, percentage of lost rounds:0.524.
# -- remove chr id 44, percentage of lost rounds:0.524.
# -- remove chr id 48, percentage of lost rounds:0.524.
# -- remove chr id 67, percentage of lost rounds:0.524.
# -- remove chr id 70, percentage of lost rounds:0.524.
# -- remove chr id 71, percentage of lost rounds:0.524.
# -- remove chr id 75, percentage of lost rounds:0.524.
# -- remove chr id 128, percentage of lost rounds:0.524.
# -- remove chr id 151, percentage of lost rounds:0.524.
# -- remove chr id 151, percentage of lost rounds:0.524.
# -- remove chr id 154, percentage of lost rounds:0.524.
# -- remove chr id 156, percentage of lost rounds:0.524.
# -- remove chr id 157, percentage of lost rounds:0.524.
# -- remove chr id 165, percentage of lost rounds:0.524.
# -- remove chr id 165, percentage of lost rounds:0.524.
# -- remove chr id 178, percentage of lost rounds:0.524.
# -- remove chr id 182, percentage of lost rounds:0.524.
# -- remove chr id 196, percentage of lost rounds:0.524.
# -- remove chr id 204, percentage of lost rounds:0.524.
# -- remove chr id 4, percentage of lost rounds:0.476.
# -- remove chr id 4, percentage of lost rounds:0.476.
# -- remove chr id 39, percentage of lost rounds:0.476.
# -- remove chr id 44, percentage of lost rounds:0.476.
# -- remove chr id 47, percentage of lost rounds:0.476.
# -- remove chr id 48, percentage of lost rounds:0.476.
# -- remove chr id 48, percentage of lost rounds:0.476.
# -- remove chr id 51, percentage of lost rounds:0.476.
# -- remove chr id 51, percentage of lost rounds:0.476.
# -- remove chr id 51, percentage of lost rounds:0.476.
# -- remove chr id 59, percentage of lost rounds:0.476.
# -- remove chr id 59, percentage of lost rounds:0.476.
# -- remove chr id 59, percentage of lost rounds:0.476.
# -- remove chr id 62, percentage of lost rounds:0.476.
# -- remove chr id 64, percentage of lost rounds:0.476.
# -- remove chr id 65, percentage of lost rounds:0.476.
# -- remove chr id 65, percentage of lost rounds:0.476.
# -- remove chr id 65, percentage of lost rounds:0.476.
# -- remove chr id 65, percentage of lost rounds:0.476.
# -- remove chr id 68, percentage of lost rounds:0.476.
# -- remove chr id 68, percentage of lost rounds:0.476.
# -- remove chr id 70, percentage of lost rounds:0.476.
# -- remove chr id 72, percentage of lost rounds:0.476.
# -- remove chr id 77, percentage of lost rounds:0.476.
# -- remove chr id 81, percentage of lost rounds:0.476.
# -- remove chr id 88, percentage of lost rounds:0.476.
# -- remove chr id 98, percentage of lost rounds:0.476.
# -- remove chr id 99, percentage of lost rounds:0.476.
# -- remove chr id 99, percentage of lost rounds:0.476.
# -- remove chr id 102, percentage of lost rounds:0.476.
# -- remove chr id 112, percentage of lost rounds:0.476.
# -- remove chr id 112, percentage of lost rounds:0.476.
# -- remove chr id 113, percentage of lost rounds:0.476.
# -- remove chr id 113, percentage of lost rounds:0.476.
# -- remove chr id 115, percentage of lost rounds:0.476.
# -- remove chr id 116, percentage of lost rounds:0.476.
# -- remove chr id 116, percentage of lost rounds:0.476.
# -- remove chr id 117, percentage of lost rounds:0.476.
# -- remove chr id 117, percentage of lost rounds:0.476.
# -- remove chr id 121, percentage of lost rounds:0.476.
# -- remove chr id 121, percentage of lost rounds:0.476.
# -- remove chr id 122, percentage of lost rounds:0.476.
# -- remove chr id 122, percentage of lost rounds:0.476.
# -- remove chr id 122, percentage of lost rounds:0.476.
# -- remove chr id 122, percentage of lost rounds:0.476.
# -- remove chr id 122, percentage of lost rounds:0.476.
# -- remove chr id 125, percentage of lost rounds:0.476.
# -- remove chr id 134, percentage of lost rounds:0.476.
# -- remove chr id 134, percentage of lost rounds:0.476.
# -- remove chr id 135, percentage of lost rounds:0.476.
# -- remove chr id 138, percentage of lost rounds:0.476.
# -- remove chr id 139, percentage of lost rounds:0.476.
# -- remove chr id 141, percentage of lost rounds:0.476.
# -- remove chr id 143, percentage of lost rounds:0.476.
# -- remove chr id 143, percentage of lost rounds:0.476.
# -- remove chr id 144, percentage of lost rounds:0.476.
# -- remove chr id 144, percentage of lost rounds:0.476.
# -- remove chr id 147, percentage of lost rounds:0.476.
# -- remove chr id 36, percentage of lost rounds:0.429.
# -- remove chr id 38, percentage of lost rounds:0.429.
# -- remove chr id 45, percentage of lost rounds:0.429.
# -- remove chr id 45, percentage of lost rounds:0.429.
# -- remove chr id 50, percentage of lost rounds:0.429.
# -- remove chr id 59, percentage of lost rounds:0.429.
# -- remove chr id 61, percentage of lost rounds:0.429.
# -- remove chr id 61, percentage of lost rounds:0.429.
# -- remove chr id 67, percentage of lost rounds:0.429.
# -- remove chr id 67, percentage of lost rounds:0.429.
# -- remove chr id 67, percentage of lost rounds:0.429.
# -- remove chr id 68, percentage of lost rounds:0.429.
# -- remove chr id 69, percentage of lost rounds:0.429.
# -- remove chr id 69, percentage of lost rounds:0.429.
# -- remove chr id 75, percentage of lost rounds:0.429.
# -- remove chr id 80, percentage of lost rounds:0.429.
# -- remove chr id 80, percentage of lost rounds:0.429.
# -- remove chr id 82, percentage of lost rounds:0.429.
# -- remove chr id 84, percentage of lost rounds:0.429.
# -- remove chr id 84, percentage of lost rounds:0.429.
# -- remove chr id 86, percentage of lost rounds:0.429.
# -- remove chr id 87, percentage of lost rounds:0.429.
# -- remove chr id 87, percentage of lost rounds:0.429.
# -- remove chr id 89, percentage of lost rounds:0.429.
# -- remove chr id 91, percentage of lost rounds:0.429.
# -- remove chr id 93, percentage of lost rounds:0.429.
# -- remove chr id 95, percentage of lost rounds:0.429.
# -- remove chr id 95, percentage of lost rounds:0.429.
# -- remove chr id 97, percentage of lost rounds:0.429.
# -- remove chr id 97, percentage of lost rounds:0.429.
# -- remove chr id 100, percentage of lost rounds:0.429.
# -- remove chr id 100, percentage of lost rounds:0.429.
# -- remove chr id 103, percentage of lost rounds:0.429.
# -- remove chr id 103, percentage of lost rounds:0.429.
# -- remove chr id 103, percentage of lost rounds:0.429.
# -- remove chr id 104, percentage of lost rounds:0.429.
# -- remove chr id 104, percentage of lost rounds:0.429.
# -- remove chr id 104, percentage of lost rounds:0.429.
# -- remove chr id 104, percentage of lost rounds:0.429.
# -- remove chr id 104, percentage of lost rounds:0.429.
# -- remove chr id 106, percentage of lost rounds:0.429.
# -- remove chr id 8, percentage of lost rounds:0.381.
# -- remove chr id 19, percentage of lost rounds:0.381.
# -- remove chr id 19, percentage of lost rounds:0.381.
# -- remove chr id 50, percentage of lost rounds:0.381.
# -- remove chr id 52, percentage of lost rounds:0.381.
# -- remove chr id 55, percentage of lost rounds:0.381.
# -- remove chr id 55, percentage of lost rounds:0.381.
# -- remove chr id 57, percentage of lost rounds:0.381.
# -- remove chr id 62, percentage of lost rounds:0.381.
# -- remove chr id 64, percentage of lost rounds:0.381.
# -- remove chr id 64, percentage of lost rounds:0.381.
# -- remove chr id 65, percentage of lost rounds:0.381.
# -- remove chr id 66, percentage of lost rounds:0.381.
# -- remove chr id 75, percentage of lost rounds:0.381.
# -- remove chr id 75, percentage of lost rounds:0.381.
# -- remove chr id 75, percentage of lost rounds:0.381.
# -- remove chr id 76, percentage of lost rounds:0.381.
# -- remove chr id 76, percentage of lost rounds:0.381.
# -- remove chr id 80, percentage of lost rounds:0.381.
# -- remove chr id 81, percentage of lost rounds:0.381.
# -- remove chr id 81, percentage of lost rounds:0.381.
# -- remove chr id 83, percentage of lost rounds:0.381.
# -- remove chr id 38, percentage of lost rounds:0.333.
# -- remove chr id 40, percentage of lost rounds:0.333.
# -- remove chr id 41, percentage of lost rounds:0.333.
# -- remove chr id 47, percentage of lost rounds:0.333.
# -- remove chr id 58, percentage of lost rounds:0.333.
# -- remove chr id 59, percentage of lost rounds:0.333.
# -- remove chr id 60, percentage of lost rounds:0.333.
# -- remove chr id 63, percentage of lost rounds:0.333.
# -- remove chr id 65, percentage of lost rounds:0.333.
# -- remove chr id 72, percentage of lost rounds:0.333.
# -- remove chr id 73, percentage of lost rounds:0.333.
# -- 73 chromosomes are kept.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_05.hdf5
# ++ base attributes saved:['chrom_coords'] in 0.042s.
# kept chromosomes: 73
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 11
# - Number of field of views: 88
# - Importing csv file: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '405']
# -- Hyb H0R0 exists in this data
# -- DAPI exists in hyb: H0R0
# - 11 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_06.dax: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# * create savefile: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'bead_channel_index', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel_index', 'data_folder', 'drift', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi'] in 0.020s.
# -- saving segmentation to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# -- saving correction to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# -- saving 750_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- saving 647_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- saving 561_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- saving 405_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- saving 750_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- saving 647_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5, skip.
# -- saving 750_647_bleed profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5.
# -- saving unique to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 3.252s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'bead_channel_index', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel_index', 'data_folder', 'drift', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi'] in 0.356s.
# -- No folder selected, allow processing all 11 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_06.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_06.dax
# -- loading illumination correction profile from file:
# 	 561 illumination_correction_561_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_06.dax  in 4.301s
# -- removing hot pixels for channels:['561'] in 19.554s
# -- illumination correction for channels: 561, in 3.826s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 28.628s
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# ++ base attributes saved:['ref_im'] in 12.970s.
# -- checking unique, region:[45] in 0.020s.
# -- checking unique, region:[96 97] in 0.010s.
# -- checking unique, region:[ 99 100] in 0.010s.
# -- checking unique, region:[102 103] in 0.010s.
# -- checking unique, region:[105 106] in 0.010s.
# -- checking unique, region:[108 109] in 0.010s.
# -- checking unique, region:[111 112] in 0.010s.
# -- checking unique, region:[114 113] in 0.010s.
# -- checking unique, region:[98 95] in 0.018s.
# -- checking unique, region:[104 101] in 0.010s.
# -- checking unique, region:[110 107] in 0.010s.
# + Start multi-processing of pre-processing for 11 images with 12 threads
# ++ processed unique ids: [ 45  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111
#  112 113 114] in 1516.96s.
# + loading unique from file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# ++ finish loading unique in 0.073s.
# -- choose chrom images from folder: \.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_06.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_06.dax  in 4.282s
# -- removing hot pixels for channels:['750'] in 13.335s
# -- illumination correction for channels: 750, in 2.559s
# -- warp image with chromatic correction for channels: ['750'] and drift:[0. 0. 0.] 750, in 141.131s
# -- finish correction in 169.927s
# -- chromosome image has drift: [0. 0. 0.]
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# ++ base attributes saved:['chrom_im'] in 11.882s.
# -- adjust seed image with filter size=4
# -- binarize image with threshold: 99.75%
# -- erosion and dialation with size=2.
# -- find close objects.
# -- random walk segmentation, beta=10.
# -- find objects larger than size=50
# -- 288 objects are found by segmentation.
# - Start multiprocessing caluclate chromosome coordinates with 12 threads in 506.625s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# ++ base attributes saved:['cand_chrom_coords'] in 0.346s.
# - start select from 288 chromosomes with loss threshold=0.3
# -- remove chr id 69, percentage of lost rounds:1.000.
# -- remove chr id 12, percentage of lost rounds:0.952.
# -- remove chr id 17, percentage of lost rounds:0.952.
# -- remove chr id 35, percentage of lost rounds:0.952.
# -- remove chr id 46, percentage of lost rounds:0.952.
# -- remove chr id 125, percentage of lost rounds:0.952.
# -- remove chr id 125, percentage of lost rounds:0.952.
# -- remove chr id 36, percentage of lost rounds:0.905.
# -- remove chr id 38, percentage of lost rounds:0.905.
# -- remove chr id 69, percentage of lost rounds:0.905.
# -- remove chr id 24, percentage of lost rounds:0.857.
# -- remove chr id 60, percentage of lost rounds:0.857.
# -- remove chr id 150, percentage of lost rounds:0.857.
# -- remove chr id 8, percentage of lost rounds:0.810.
# -- remove chr id 36, percentage of lost rounds:0.810.
# -- remove chr id 78, percentage of lost rounds:0.810.
# -- remove chr id 46, percentage of lost rounds:0.762.
# -- remove chr id 68, percentage of lost rounds:0.762.
# -- remove chr id 101, percentage of lost rounds:0.762.
# -- remove chr id 9, percentage of lost rounds:0.714.
# -- remove chr id 41, percentage of lost rounds:0.714.
# -- remove chr id 43, percentage of lost rounds:0.714.
# -- remove chr id 48, percentage of lost rounds:0.714.
# -- remove chr id 82, percentage of lost rounds:0.714.
# -- remove chr id 124, percentage of lost rounds:0.714.
# -- remove chr id 221, percentage of lost rounds:0.714.
# -- remove chr id 238, percentage of lost rounds:0.714.
# -- remove chr id 250, percentage of lost rounds:0.714.
# -- remove chr id 7, percentage of lost rounds:0.667.
# -- remove chr id 15, percentage of lost rounds:0.667.
# -- remove chr id 21, percentage of lost rounds:0.667.
# -- remove chr id 35, percentage of lost rounds:0.667.
# -- remove chr id 45, percentage of lost rounds:0.667.
# -- remove chr id 57, percentage of lost rounds:0.667.
# -- remove chr id 70, percentage of lost rounds:0.667.
# -- remove chr id 97, percentage of lost rounds:0.667.
# -- remove chr id 121, percentage of lost rounds:0.667.
# -- remove chr id 137, percentage of lost rounds:0.667.
# -- remove chr id 208, percentage of lost rounds:0.667.
# -- remove chr id 7, percentage of lost rounds:0.619.
# -- remove chr id 14, percentage of lost rounds:0.619.
# -- remove chr id 98, percentage of lost rounds:0.619.
# -- remove chr id 130, percentage of lost rounds:0.619.
# -- remove chr id 135, percentage of lost rounds:0.619.
# -- remove chr id 139, percentage of lost rounds:0.619.
# -- remove chr id 154, percentage of lost rounds:0.619.
# -- remove chr id 201, percentage of lost rounds:0.619.
# -- remove chr id 227, percentage of lost rounds:0.619.
# -- remove chr id 8, percentage of lost rounds:0.571.
# -- remove chr id 26, percentage of lost rounds:0.571.
# -- remove chr id 56, percentage of lost rounds:0.571.
# -- remove chr id 63, percentage of lost rounds:0.571.
# -- remove chr id 77, percentage of lost rounds:0.571.
# -- remove chr id 95, percentage of lost rounds:0.571.
# -- remove chr id 96, percentage of lost rounds:0.571.
# -- remove chr id 105, percentage of lost rounds:0.571.
# -- remove chr id 131, percentage of lost rounds:0.571.
# -- remove chr id 150, percentage of lost rounds:0.571.
# -- remove chr id 192, percentage of lost rounds:0.571.
# -- remove chr id 202, percentage of lost rounds:0.571.
# -- remove chr id 225, percentage of lost rounds:0.571.
# -- remove chr id 11, percentage of lost rounds:0.524.
# -- remove chr id 22, percentage of lost rounds:0.524.
# -- remove chr id 25, percentage of lost rounds:0.524.
# -- remove chr id 25, percentage of lost rounds:0.524.
# -- remove chr id 26, percentage of lost rounds:0.524.
# -- remove chr id 43, percentage of lost rounds:0.524.
# -- remove chr id 74, percentage of lost rounds:0.524.
# -- remove chr id 76, percentage of lost rounds:0.524.
# -- remove chr id 92, percentage of lost rounds:0.524.
# -- remove chr id 94, percentage of lost rounds:0.524.
# -- remove chr id 94, percentage of lost rounds:0.524.
# -- remove chr id 116, percentage of lost rounds:0.524.
# -- remove chr id 120, percentage of lost rounds:0.524.
# -- remove chr id 134, percentage of lost rounds:0.524.
# -- remove chr id 151, percentage of lost rounds:0.524.
# -- remove chr id 153, percentage of lost rounds:0.524.
# -- remove chr id 164, percentage of lost rounds:0.524.
# -- remove chr id 169, percentage of lost rounds:0.524.
# -- remove chr id 190, percentage of lost rounds:0.524.
# -- remove chr id 200, percentage of lost rounds:0.524.
# -- remove chr id 26, percentage of lost rounds:0.476.
# -- remove chr id 39, percentage of lost rounds:0.476.
# -- remove chr id 40, percentage of lost rounds:0.476.
# -- remove chr id 49, percentage of lost rounds:0.476.
# -- remove chr id 54, percentage of lost rounds:0.476.
# -- remove chr id 58, percentage of lost rounds:0.476.
# -- remove chr id 60, percentage of lost rounds:0.476.
# -- remove chr id 60, percentage of lost rounds:0.476.
# -- remove chr id 62, percentage of lost rounds:0.476.
# -- remove chr id 64, percentage of lost rounds:0.476.
# -- remove chr id 67, percentage of lost rounds:0.476.
# -- remove chr id 67, percentage of lost rounds:0.476.
# -- remove chr id 70, percentage of lost rounds:0.476.
# -- remove chr id 71, percentage of lost rounds:0.476.
# -- remove chr id 71, percentage of lost rounds:0.476.
# -- remove chr id 71, percentage of lost rounds:0.476.
# -- remove chr id 71, percentage of lost rounds:0.476.
# -- remove chr id 77, percentage of lost rounds:0.476.
# -- remove chr id 77, percentage of lost rounds:0.476.
# -- remove chr id 80, percentage of lost rounds:0.476.
# -- remove chr id 80, percentage of lost rounds:0.476.
# -- remove chr id 82, percentage of lost rounds:0.476.
# -- remove chr id 83, percentage of lost rounds:0.476.
# -- remove chr id 86, percentage of lost rounds:0.476.
# -- remove chr id 92, percentage of lost rounds:0.476.
# -- remove chr id 102, percentage of lost rounds:0.476.
# -- remove chr id 102, percentage of lost rounds:0.476.
# -- remove chr id 102, percentage of lost rounds:0.476.
# -- remove chr id 108, percentage of lost rounds:0.476.
# -- remove chr id 109, percentage of lost rounds:0.476.
# -- remove chr id 110, percentage of lost rounds:0.476.
# -- remove chr id 111, percentage of lost rounds:0.476.
# -- remove chr id 113, percentage of lost rounds:0.476.
# -- remove chr id 114, percentage of lost rounds:0.476.
# -- remove chr id 115, percentage of lost rounds:0.476.
# -- remove chr id 117, percentage of lost rounds:0.476.
# -- remove chr id 117, percentage of lost rounds:0.476.
# -- remove chr id 124, percentage of lost rounds:0.476.
# -- remove chr id 126, percentage of lost rounds:0.476.
# -- remove chr id 126, percentage of lost rounds:0.476.
# -- remove chr id 132, percentage of lost rounds:0.476.
# -- remove chr id 136, percentage of lost rounds:0.476.
# -- remove chr id 139, percentage of lost rounds:0.476.
# -- remove chr id 142, percentage of lost rounds:0.476.
# -- remove chr id 142, percentage of lost rounds:0.476.
# -- remove chr id 142, percentage of lost rounds:0.476.
# -- remove chr id 145, percentage of lost rounds:0.476.
# -- remove chr id 145, percentage of lost rounds:0.476.
# -- remove chr id 147, percentage of lost rounds:0.476.
# -- remove chr id 151, percentage of lost rounds:0.476.
# -- remove chr id 151, percentage of lost rounds:0.476.
# -- remove chr id 29, percentage of lost rounds:0.429.
# -- remove chr id 36, percentage of lost rounds:0.429.
# -- remove chr id 36, percentage of lost rounds:0.429.
# -- remove chr id 40, percentage of lost rounds:0.429.
# -- remove chr id 40, percentage of lost rounds:0.429.
# -- remove chr id 42, percentage of lost rounds:0.429.
# -- remove chr id 42, percentage of lost rounds:0.429.
# -- remove chr id 46, percentage of lost rounds:0.429.
# -- remove chr id 46, percentage of lost rounds:0.429.
# -- remove chr id 59, percentage of lost rounds:0.429.
# -- remove chr id 59, percentage of lost rounds:0.429.
# -- remove chr id 59, percentage of lost rounds:0.429.
# -- remove chr id 64, percentage of lost rounds:0.429.
# -- remove chr id 71, percentage of lost rounds:0.429.
# -- remove chr id 75, percentage of lost rounds:0.429.
# -- remove chr id 75, percentage of lost rounds:0.429.
# -- remove chr id 75, percentage of lost rounds:0.429.
# -- remove chr id 75, percentage of lost rounds:0.429.
# -- remove chr id 75, percentage of lost rounds:0.429.
# -- remove chr id 76, percentage of lost rounds:0.429.
# -- remove chr id 80, percentage of lost rounds:0.429.
# -- remove chr id 82, percentage of lost rounds:0.429.
# -- remove chr id 86, percentage of lost rounds:0.429.
# -- remove chr id 87, percentage of lost rounds:0.429.
# -- remove chr id 87, percentage of lost rounds:0.429.
# -- remove chr id 91, percentage of lost rounds:0.429.
# -- remove chr id 93, percentage of lost rounds:0.429.
# -- remove chr id 94, percentage of lost rounds:0.429.
# -- remove chr id 97, percentage of lost rounds:0.429.
# -- remove chr id 101, percentage of lost rounds:0.429.
# -- remove chr id 104, percentage of lost rounds:0.429.
# -- remove chr id 105, percentage of lost rounds:0.429.
# -- remove chr id 107, percentage of lost rounds:0.429.
# -- remove chr id 108, percentage of lost rounds:0.429.
# -- remove chr id 108, percentage of lost rounds:0.429.
# -- remove chr id 108, percentage of lost rounds:0.429.
# -- remove chr id 108, percentage of lost rounds:0.429.
# -- remove chr id 108, percentage of lost rounds:0.429.
# -- remove chr id 108, percentage of lost rounds:0.429.
# -- remove chr id 110, percentage of lost rounds:0.429.
# -- remove chr id 114, percentage of lost rounds:0.429.
# -- remove chr id 31, percentage of lost rounds:0.381.
# -- remove chr id 41, percentage of lost rounds:0.381.
# -- remove chr id 41, percentage of lost rounds:0.381.
# -- remove chr id 42, percentage of lost rounds:0.381.
# -- remove chr id 42, percentage of lost rounds:0.381.
# -- remove chr id 46, percentage of lost rounds:0.381.
# -- remove chr id 52, percentage of lost rounds:0.381.
# -- remove chr id 54, percentage of lost rounds:0.381.
# -- remove chr id 56, percentage of lost rounds:0.381.
# -- remove chr id 59, percentage of lost rounds:0.381.
# -- remove chr id 59, percentage of lost rounds:0.381.
# -- remove chr id 72, percentage of lost rounds:0.381.
# -- remove chr id 80, percentage of lost rounds:0.381.
# -- remove chr id 80, percentage of lost rounds:0.381.
# -- remove chr id 84, percentage of lost rounds:0.381.
# -- remove chr id 87, percentage of lost rounds:0.381.
# -- remove chr id 88, percentage of lost rounds:0.381.
# -- remove chr id 88, percentage of lost rounds:0.381.
# -- remove chr id 89, percentage of lost rounds:0.381.
# -- remove chr id 90, percentage of lost rounds:0.381.
# -- remove chr id 91, percentage of lost rounds:0.381.
# -- remove chr id 91, percentage of lost rounds:0.381.
# -- remove chr id 92, percentage of lost rounds:0.381.
# -- remove chr id 7, percentage of lost rounds:0.333.
# -- remove chr id 23, percentage of lost rounds:0.333.
# -- remove chr id 25, percentage of lost rounds:0.333.
# -- remove chr id 33, percentage of lost rounds:0.333.
# -- remove chr id 44, percentage of lost rounds:0.333.
# -- remove chr id 50, percentage of lost rounds:0.333.
# -- remove chr id 52, percentage of lost rounds:0.333.
# -- remove chr id 55, percentage of lost rounds:0.333.
# -- remove chr id 67, percentage of lost rounds:0.333.
# -- remove chr id 72, percentage of lost rounds:0.333.
# -- remove chr id 74, percentage of lost rounds:0.333.
# -- remove chr id 75, percentage of lost rounds:0.333.
# -- remove chr id 76, percentage of lost rounds:0.333.
# -- remove chr id 76, percentage of lost rounds:0.333.
# -- 78 chromosomes are kept.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_06.hdf5
# ++ base attributes saved:['chrom_coords'] in 0.053s.
# kept chromosomes: 78
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 11
# - Number of field of views: 88
# - Importing csv file: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\Analysis\Color_Usage.csv
# - header: ['Hyb', '750', '647', '561', '405']
# -- Hyb H0R0 exists in this data
# -- DAPI exists in hyb: H0R0
# - 11 folders are found according to color-usage annotation.
# ++ load bleed correction profile from original file.
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_2048_2048.npy
# ++ load chromatic correction profile from original file.
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# ++ load chromatic_constants correction profile from original file.
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# ++ load illumination correction profile from original file.
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# 	 561 illumination_correction_561_2048x2048.npy
# 	 405 illumination_correction_405_2048x2048.npy
# - Creating save file for fov:Conv_zscan_07.dax: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# * create savefile: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'bead_channel_index', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel_index', 'data_folder', 'drift', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi'] in 0.061s.
# -- saving segmentation to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# -- saving correction to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# -- saving 750_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- saving 647_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- saving 561_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- saving 405_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- saving 750_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- saving 647_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5, skip.
# -- saving 750_647_bleed profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5.
# -- saving unique to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.355s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'bead_channel_index', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel_index', 'data_folder', 'drift', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi'] in 0.345s.
# -- No folder selected, allow processing all 11 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_07.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_07.dax
# -- loading illumination correction profile from file:
# 	 561 illumination_correction_561_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_07.dax  in 16.115s
# -- removing hot pixels for channels:['561'] in 43.097s
# -- illumination correction for channels: 561, in 6.263s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 66.832s
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# ++ base attributes saved:['ref_im'] in 14.396s.
# -- checking unique, region:[45] in 0.020s.
# -- checking unique, region:[96 97] in 0.018s.
# -- checking unique, region:[ 99 100] in 0.012s.
# -- checking unique, region:[102 103] in 0.010s.
# -- checking unique, region:[105 106] in 0.020s.
# -- checking unique, region:[108 109] in 0.018s.
# -- checking unique, region:[111 112] in 0.012s.
# -- checking unique, region:[114 113] in 0.010s.
# -- checking unique, region:[98 95] in 0.010s.
# -- checking unique, region:[104 101] in 0.018s.
# -- checking unique, region:[110 107] in 0.012s.
# + Start multi-processing of pre-processing for 11 images with 12 threads
# ++ processed unique ids: [ 45  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111
#  112 113 114] in 1229.01s.
# + loading unique from file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# ++ finish loading unique in 0.022s.
# -- choose chrom images from folder: \.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_07.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_07.dax  in 5.198s
# -- removing hot pixels for channels:['750'] in 16.607s
# -- illumination correction for channels: 750, in 3.134s
# -- warp image with chromatic correction for channels: ['750'] and drift:[0. 0. 0.] 750, in 148.984s
# -- finish correction in 187.259s
# -- chromosome image has drift: [0. 0. 0.]
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# ++ base attributes saved:['chrom_im'] in 10.974s.
# -- adjust seed image with filter size=4
# -- binarize image with threshold: 99.75%
# -- erosion and dialation with size=2.
# -- find close objects.
# -- random walk segmentation, beta=10.
# -- find objects larger than size=50
# -- 267 objects are found by segmentation.
# - Start multiprocessing caluclate chromosome coordinates with 12 threads in 599.578s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_07.hdf5
# ++ base attributes saved:['cand_chrom_coords'] in 0.038s.
# - start select from 267 chromosomes with loss threshold=0.3
# -- remove chr id 116, percentage of lost rounds:1.000.
# -- remove chr id 54, percentage of lost rounds:0.952.
# -- remove chr id 154, percentage of lost rounds:0.952.
# -- remove chr id 46, percentage of lost rounds:0.905.
# -- remove chr id 66, percentage of lost rounds:0.905.
# -- remove chr id 4, percentage of lost rounds:0.857.
# -- remove chr id 61, percentage of lost rounds:0.857.
# -- remove chr id 64, percentage of lost rounds:0.810.
# -- remove chr id 30, percentage of lost rounds:0.762.
# -- remove chr id 58, percentage of lost rounds:0.762.
# -- remove chr id 73, percentage of lost rounds:0.762.
# -- remove chr id 77, percentage of lost rounds:0.762.
# -- remove chr id 90, percentage of lost rounds:0.762.
# -- remove chr id 163, percentage of lost rounds:0.762.
# -- remove chr id 247, percentage of lost rounds:0.762.
# -- remove chr id 54, percentage of lost rounds:0.714.
# -- remove chr id 101, percentage of lost rounds:0.714.
# -- remove chr id 137, percentage of lost rounds:0.714.
# -- remove chr id 23, percentage of lost rounds:0.667.
# -- remove chr id 24, percentage of lost rounds:0.667.
# -- remove chr id 66, percentage of lost rounds:0.667.
# -- remove chr id 72, percentage of lost rounds:0.667.
# -- remove chr id 91, percentage of lost rounds:0.667.
# -- remove chr id 95, percentage of lost rounds:0.667.
# -- remove chr id 95, percentage of lost rounds:0.667.
# -- remove chr id 142, percentage of lost rounds:0.667.
# -- remove chr id 155, percentage of lost rounds:0.667.
# -- remove chr id 2, percentage of lost rounds:0.619.
# -- remove chr id 34, percentage of lost rounds:0.619.
# -- remove chr id 43, percentage of lost rounds:0.619.
# -- remove chr id 51, percentage of lost rounds:0.619.
# -- remove chr id 66, percentage of lost rounds:0.619.
# ...
# -- saving segmentation to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# -- saving correction to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# -- saving 750_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- saving 647_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- saving 561_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- saving 405_illumination profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- saving 750_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- saving 647_chromatic profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- saving 750_chromatic_constants profile with ['fitting_orders', 'constants', 'rsquares', 'ref_center'] to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- 647_chromatic_constants profile already exist in save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5, skip.
# -- saving 750_647_bleed profile to save_file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5.
# -- saving unique to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# --- unique attributes updated:['ids', 'channels', 'ims', 'spots', 'raw_spots', 'drifts', 'flags'] in 0.344s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# ++ base attributes saved:['analysis_folder', 'annotated_folders', 'bead_channel_index', 'channels', 'color_dic', 'color_filename', 'color_format', 'correction_folder', 'dapi_channel_index', 'data_folder', 'drift', 'drift_filename', 'drift_folder', 'experiment_folder', 'folders', 'fov_id', 'fov_name', 'map_folder', 'num_threads', 'ref_filename', 'ref_id', 'rotation', 'save_filename', 'save_folder', 'segmentation_dim', 'segmentation_folder', 'shared_parameters', 'use_dapi'] in 0.346s.
# -- No folder selected, allow processing all 11 folders
# + load reference image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_10.dax
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_10.dax
# -- loading illumination correction profile from file:
# 	 561 illumination_correction_561_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_10.dax  in 12.178s
# -- removing hot pixels for channels:['561'] in 30.254s
# -- illumination correction for channels: 561, in 2.728s
# -- -- generate translation function with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 45.959s
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# ++ base attributes saved:['ref_im'] in 11.265s.
# -- checking unique, region:[45] in 0.010s.
# -- checking unique, region:[96 97] in 0.010s.
# -- checking unique, region:[ 99 100] in 0.010s.
# -- checking unique, region:[102 103] in 0.008s.
# -- checking unique, region:[105 106] in 0.002s.
# -- checking unique, region:[108 109] in 0.010s.
# -- checking unique, region:[111 112] in 0.010s.
# -- checking unique, region:[114 113] in 0.010s.
# -- checking unique, region:[98 95] in 0.008s.
# -- checking unique, region:[104 101] in 0.004s.
# -- checking unique, region:[110 107] in 0.008s.
# + Start multi-processing of pre-processing for 11 images with 12 threads
# ++ processed unique ids: [ 45  95  96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111
#  112 113 114] in 1067.53s.
# + loading unique from file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# ++ finish loading unique in 0.018s.
# -- choose chrom images from folder: \.
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_10.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_1\20201221-Acr_ctp08_P_brain\After_clearing\H0R0\Conv_zscan_10.dax  in 4.584s
# -- removing hot pixels for channels:['750'] in 14.639s
# -- illumination correction for channels: 750, in 2.731s
# -- warp image with chromatic correction for channels: ['750'] and drift:[0. 0. 0.] 750, in 140.971s
# -- finish correction in 176.347s
# -- chromosome image has drift: [0. 0. 0.]
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# ++ base attributes saved:['chrom_im'] in 10.753s.
# -- adjust seed image with filter size=4
# -- binarize image with threshold: 99.75%
# -- erosion and dialation with size=2.
# -- find close objects.
# -- random walk segmentation, beta=10.
# -- find objects larger than size=50
# -- 287 objects are found by segmentation.
# - Start multiprocessing caluclate chromosome coordinates with 12 threads in 235.454s.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# ++ base attributes saved:['cand_chrom_coords'] in 0.050s.
# - start select from 287 chromosomes with loss threshold=0.3
# -- remove chr id 245, percentage of lost rounds:0.952.
# -- remove chr id 82, percentage of lost rounds:0.905.
# -- remove chr id 257, percentage of lost rounds:0.905.
# -- remove chr id 35, percentage of lost rounds:0.857.
# -- remove chr id 173, percentage of lost rounds:0.857.
# -- remove chr id 184, percentage of lost rounds:0.857.
# -- remove chr id 252, percentage of lost rounds:0.857.
# -- remove chr id 9, percentage of lost rounds:0.810.
# -- remove chr id 90, percentage of lost rounds:0.810.
# -- remove chr id 162, percentage of lost rounds:0.810.
# -- remove chr id 16, percentage of lost rounds:0.762.
# -- remove chr id 175, percentage of lost rounds:0.762.
# -- remove chr id 200, percentage of lost rounds:0.762.
# -- remove chr id 248, percentage of lost rounds:0.762.
# -- remove chr id 46, percentage of lost rounds:0.714.
# -- remove chr id 60, percentage of lost rounds:0.714.
# -- remove chr id 111, percentage of lost rounds:0.714.
# -- remove chr id 121, percentage of lost rounds:0.714.
# -- remove chr id 191, percentage of lost rounds:0.714.
# -- remove chr id 226, percentage of lost rounds:0.714.
# -- remove chr id 226, percentage of lost rounds:0.714.
# -- remove chr id 16, percentage of lost rounds:0.667.
# -- remove chr id 59, percentage of lost rounds:0.667.
# -- remove chr id 131, percentage of lost rounds:0.667.
# -- remove chr id 223, percentage of lost rounds:0.667.
# -- remove chr id 239, percentage of lost rounds:0.667.
# -- remove chr id 4, percentage of lost rounds:0.619.
# -- remove chr id 9, percentage of lost rounds:0.619.
# -- remove chr id 18, percentage of lost rounds:0.619.
# -- remove chr id 66, percentage of lost rounds:0.619.
# -- remove chr id 95, percentage of lost rounds:0.619.
# -- remove chr id 122, percentage of lost rounds:0.619.
# -- remove chr id 173, percentage of lost rounds:0.619.
# -- remove chr id 185, percentage of lost rounds:0.619.
# -- remove chr id 205, percentage of lost rounds:0.619.
# -- remove chr id 212, percentage of lost rounds:0.619.
# -- remove chr id 222, percentage of lost rounds:0.619.
# -- remove chr id 242, percentage of lost rounds:0.619.
# -- remove chr id 75, percentage of lost rounds:0.571.
# -- remove chr id 92, percentage of lost rounds:0.571.
# -- remove chr id 146, percentage of lost rounds:0.571.
# -- remove chr id 146, percentage of lost rounds:0.571.
# -- remove chr id 177, percentage of lost rounds:0.571.
# -- remove chr id 183, percentage of lost rounds:0.571.
# -- remove chr id 190, percentage of lost rounds:0.571.
# -- remove chr id 199, percentage of lost rounds:0.571.
# -- remove chr id 227, percentage of lost rounds:0.571.
# -- remove chr id 238, percentage of lost rounds:0.571.
# -- remove chr id 33, percentage of lost rounds:0.524.
# -- remove chr id 68, percentage of lost rounds:0.524.
# -- remove chr id 88, percentage of lost rounds:0.524.
# -- remove chr id 93, percentage of lost rounds:0.524.
# -- remove chr id 109, percentage of lost rounds:0.524.
# -- remove chr id 126, percentage of lost rounds:0.524.
# -- remove chr id 171, percentage of lost rounds:0.524.
# -- remove chr id 180, percentage of lost rounds:0.524.
# -- remove chr id 203, percentage of lost rounds:0.524.
# -- remove chr id 211, percentage of lost rounds:0.524.
# -- remove chr id 213, percentage of lost rounds:0.524.
# -- remove chr id 226, percentage of lost rounds:0.524.
# -- remove chr id 21, percentage of lost rounds:0.476.
# -- remove chr id 31, percentage of lost rounds:0.476.
# -- remove chr id 46, percentage of lost rounds:0.476.
# -- remove chr id 65, percentage of lost rounds:0.476.
# -- remove chr id 65, percentage of lost rounds:0.476.
# -- remove chr id 69, percentage of lost rounds:0.476.
# -- remove chr id 73, percentage of lost rounds:0.476.
# -- remove chr id 89, percentage of lost rounds:0.476.
# -- remove chr id 92, percentage of lost rounds:0.476.
# -- remove chr id 97, percentage of lost rounds:0.476.
# -- remove chr id 97, percentage of lost rounds:0.476.
# -- remove chr id 100, percentage of lost rounds:0.476.
# -- remove chr id 101, percentage of lost rounds:0.476.
# -- remove chr id 101, percentage of lost rounds:0.476.
# -- remove chr id 108, percentage of lost rounds:0.476.
# -- remove chr id 109, percentage of lost rounds:0.476.
# -- remove chr id 111, percentage of lost rounds:0.476.
# -- remove chr id 114, percentage of lost rounds:0.476.
# -- remove chr id 118, percentage of lost rounds:0.476.
# -- remove chr id 119, percentage of lost rounds:0.476.
# -- remove chr id 119, percentage of lost rounds:0.476.
# -- remove chr id 120, percentage of lost rounds:0.476.
# -- remove chr id 124, percentage of lost rounds:0.476.
# -- remove chr id 125, percentage of lost rounds:0.476.
# -- remove chr id 125, percentage of lost rounds:0.476.
# -- remove chr id 130, percentage of lost rounds:0.476.
# -- remove chr id 131, percentage of lost rounds:0.476.
# -- remove chr id 132, percentage of lost rounds:0.476.
# -- remove chr id 132, percentage of lost rounds:0.476.
# -- remove chr id 136, percentage of lost rounds:0.476.
# -- remove chr id 142, percentage of lost rounds:0.476.
# -- remove chr id 145, percentage of lost rounds:0.476.
# -- remove chr id 146, percentage of lost rounds:0.476.
# -- remove chr id 147, percentage of lost rounds:0.476.
# -- remove chr id 154, percentage of lost rounds:0.476.
# -- remove chr id 156, percentage of lost rounds:0.476.
# -- remove chr id 156, percentage of lost rounds:0.476.
# -- remove chr id 157, percentage of lost rounds:0.476.
# -- remove chr id 160, percentage of lost rounds:0.476.
# -- remove chr id 161, percentage of lost rounds:0.476.
# -- remove chr id 161, percentage of lost rounds:0.476.
# -- remove chr id 161, percentage of lost rounds:0.476.
# -- remove chr id 165, percentage of lost rounds:0.476.
# -- remove chr id 171, percentage of lost rounds:0.476.
# -- remove chr id 174, percentage of lost rounds:0.476.
# -- remove chr id 178, percentage of lost rounds:0.476.
# -- remove chr id 4, percentage of lost rounds:0.429.
# -- remove chr id 7, percentage of lost rounds:0.429.
# -- remove chr id 23, percentage of lost rounds:0.429.
# -- remove chr id 24, percentage of lost rounds:0.429.
# -- remove chr id 35, percentage of lost rounds:0.429.
# -- remove chr id 39, percentage of lost rounds:0.429.
# -- remove chr id 42, percentage of lost rounds:0.429.
# -- remove chr id 44, percentage of lost rounds:0.429.
# -- remove chr id 56, percentage of lost rounds:0.429.
# -- remove chr id 56, percentage of lost rounds:0.429.
# -- remove chr id 59, percentage of lost rounds:0.429.
# -- remove chr id 69, percentage of lost rounds:0.429.
# -- remove chr id 73, percentage of lost rounds:0.429.
# -- remove chr id 74, percentage of lost rounds:0.429.
# -- remove chr id 79, percentage of lost rounds:0.429.
# -- remove chr id 81, percentage of lost rounds:0.429.
# -- remove chr id 81, percentage of lost rounds:0.429.
# -- remove chr id 85, percentage of lost rounds:0.429.
# -- remove chr id 86, percentage of lost rounds:0.429.
# -- remove chr id 95, percentage of lost rounds:0.429.
# -- remove chr id 99, percentage of lost rounds:0.429.
# -- remove chr id 101, percentage of lost rounds:0.429.
# -- remove chr id 102, percentage of lost rounds:0.429.
# -- remove chr id 102, percentage of lost rounds:0.429.
# -- remove chr id 104, percentage of lost rounds:0.429.
# -- remove chr id 109, percentage of lost rounds:0.429.
# -- remove chr id 110, percentage of lost rounds:0.429.
# -- remove chr id 111, percentage of lost rounds:0.429.
# -- remove chr id 111, percentage of lost rounds:0.429.
# -- remove chr id 113, percentage of lost rounds:0.429.
# -- remove chr id 113, percentage of lost rounds:0.429.
# -- remove chr id 121, percentage of lost rounds:0.429.
# -- remove chr id 123, percentage of lost rounds:0.429.
# -- remove chr id 123, percentage of lost rounds:0.429.
# -- remove chr id 131, percentage of lost rounds:0.429.
# -- remove chr id 131, percentage of lost rounds:0.429.
# -- remove chr id 138, percentage of lost rounds:0.429.
# -- remove chr id 138, percentage of lost rounds:0.429.
# -- remove chr id 139, percentage of lost rounds:0.429.
# -- remove chr id 139, percentage of lost rounds:0.429.
# -- remove chr id 139, percentage of lost rounds:0.429.
# -- remove chr id 139, percentage of lost rounds:0.429.
# -- remove chr id 6, percentage of lost rounds:0.381.
# -- remove chr id 16, percentage of lost rounds:0.381.
# -- remove chr id 35, percentage of lost rounds:0.381.
# -- remove chr id 38, percentage of lost rounds:0.381.
# -- remove chr id 43, percentage of lost rounds:0.381.
# -- remove chr id 46, percentage of lost rounds:0.381.
# -- remove chr id 46, percentage of lost rounds:0.381.
# -- remove chr id 59, percentage of lost rounds:0.381.
# -- remove chr id 74, percentage of lost rounds:0.381.
# -- remove chr id 78, percentage of lost rounds:0.381.
# -- remove chr id 82, percentage of lost rounds:0.381.
# -- remove chr id 85, percentage of lost rounds:0.381.
# -- remove chr id 86, percentage of lost rounds:0.381.
# -- remove chr id 103, percentage of lost rounds:0.381.
# -- remove chr id 104, percentage of lost rounds:0.381.
# -- remove chr id 105, percentage of lost rounds:0.381.
# -- remove chr id 108, percentage of lost rounds:0.381.
# -- remove chr id 111, percentage of lost rounds:0.381.
# -- remove chr id 111, percentage of lost rounds:0.381.
# -- remove chr id 112, percentage of lost rounds:0.381.
# -- remove chr id 112, percentage of lost rounds:0.381.
# -- remove chr id 113, percentage of lost rounds:0.381.
# -- remove chr id 6, percentage of lost rounds:0.333.
# -- remove chr id 39, percentage of lost rounds:0.333.
# -- remove chr id 48, percentage of lost rounds:0.333.
# -- remove chr id 52, percentage of lost rounds:0.333.
# -- remove chr id 65, percentage of lost rounds:0.333.
# -- remove chr id 65, percentage of lost rounds:0.333.
# -- remove chr id 71, percentage of lost rounds:0.333.
# -- remove chr id 78, percentage of lost rounds:0.333.
# -- remove chr id 83, percentage of lost rounds:0.333.
# -- remove chr id 88, percentage of lost rounds:0.333.
# -- remove chr id 102, percentage of lost rounds:0.333.
# -- remove chr id 104, percentage of lost rounds:0.333.
# -- 105 chromosomes are kept.
# -- saving fov_info to file: V:\20201221-Acr_ctp08_P_brain\After_clearing\New\Conv_zscan_10.hdf5
# ++ base attributes saved:['chrom_coords'] in 0.048s.
# kept chromosomes: 105
# 447 are found.

# %%
fov = classes.field_of_view.Field_of_View(fov_param, _fov_id=30,
                                          _color_info_kwargs={
                                              '_color_filename':'Color_Usage',
                                          }, 
                                          _prioritize_saved_attrs=False,
                                          
                                          )

# %% [markdown]
# ### 2. Process image into candidate spots

# %%
reload(io_tools.load)
reload(spot_tools.fitting)
reload(correction_tools.chromatic)
reload(classes.batch_functions)

# process image into spots
id_list, spot_list = fov._process_image_to_spots('unique', 
                                                 #_sel_ids=np.arange(41,47),
                                                 _load_common_reference=True,
                                                 _load_with_multiple=False,
                                                 _save_images=True,
                                                 _warp_images=False, 
                                                 _overwrite_drift=False,
                                                 _overwrite_image=False,
                                                 _overwrite_spot=False,
                                                 _verbose=True)

# %% [markdown]
# # 3. Find chromosomes

# %% [markdown]
# ## 3.1 load chromosome image

# %%
overwrite_chrom = False
chrom_im = fov._load_chromosome_image(_type='reverse', 
                                      _overwrite=overwrite_chrom)

# %% [markdown]
# ## 3.2 find candidate chromosomes

# %%
chrom_coords = fov._find_candidate_chromosomes_by_segmentation(_filt_size=4,
                                                               _binary_per_th=99.75, 
                                                               _morphology_size=2,
                                                               _overwrite=overwrite_chrom)

# %% [markdown]
# ## 3.3 select among candidate chromosomes

# %%
chrom_coords = fov._select_chromosome_by_candidate_spots(_good_chr_loss_th=0.3,
                                                         _cand_spot_intensity_th=200,
                                                         _save=True, 
                                                         _overwrite=overwrite_chrom)

# %% [markdown]
# ### visualize chromosomes selections

# %%
# %matplotlib notebook
# %matplotlib notebook
## visualize
coord_dict = {'coords':[np.flipud(_coord) for _coord in fov.chrom_coords],
              'class_ids':list(np.zeros(len(fov.chrom_coords),dtype=np.int)),
             }

visual_tools.imshow_mark_3d_v2([fov.chrom_im], 
                               given_dic=coord_dict,
                               save_file=None,
                               )

# %% [markdown]
# ## select spots based on chromosomes

# %%
fov._load_from_file('unique')

# %%
intensity_th = 200
from ImageAnalysis3.spot_tools.picking import assign_spots_to_chromosomes

kept_spots_list = []
for _spots in fov.unique_spots_list:
    kept_spots_list.append(_spots[_spots[:,0] > intensity_th])
# finalize candidate spots
cand_chr_spots_list = [[] for _ct in fov.chrom_coords]
for _spots in kept_spots_list:
    _cands_list = assign_spots_to_chromosomes(_spots, fov.chrom_coords)
    for _i, _cands in enumerate(_cands_list):
        cand_chr_spots_list[_i].append(_cands)
print(f"kept chromosomes: {len(fov.chrom_coords)}")

# %%
reload(spot_tools.picking)
from ImageAnalysis3.spot_tools.picking import convert_spots_to_hzxys

dna_cand_hzxys_list = [convert_spots_to_hzxys(_spots, fov.shared_parameters['distance_zxy'])
                       for _spots in cand_chr_spots_list]
dna_reg_ids = fov.unique_ids
dna_reg_channels = fov.unique_channels
chrom_coords = fov.chrom_coords


# select_hzxys close to the chromosome center
dist_th = 3000 # upper limit is 3000nm
good_chr_th = 0.8 # 80% of regions should have candidate spots

sel_dna_cand_hzxys_list = []
sel_chrom_coords = []
chr_cand_pers = []
sel_chr_cand_pers = []
for _cand_hzxys, _chrom_coord in zip(dna_cand_hzxys_list, chrom_coords):
    _chr_cand_per = 0
    _sel_cands_list = []
    
    for _cands in _cand_hzxys:
        if len(_cands) == 0:
            _sel_cands_list.append([])
        else:
            _dists = np.linalg.norm(_cands[:,1:4] - _chrom_coord*np.array([200,108,108]), axis=1)
            _sel_cands_list.append(_cands[(_dists < dist_th)])
            _chr_cand_per += 1
    
    _chr_cand_per *= 1/len(_cand_hzxys)
    # append
    if _chr_cand_per >= good_chr_th:
        sel_dna_cand_hzxys_list.append(_sel_cands_list)
        sel_chrom_coords.append(_chrom_coord)
        sel_chr_cand_pers.append(_chr_cand_per)
    
    chr_cand_pers.append(_chr_cand_per)
    
print(f"kept chromosomes: {len(sel_chrom_coords)}")

# %% [markdown]
# ### EM pick spots

# %%
# %matplotlib inline
reload(spot_tools.picking)
from ImageAnalysis3.spot_tools.picking import _maximize_score_spot_picking_of_chr, pick_spots_by_intensities,pick_spots_by_scores, generate_reference_from_population, evaluate_differences

niter= 10
num_threads = 24
ref_chr_cts = None
# initialize
init_dna_hzxys = pick_spots_by_intensities(sel_dna_cand_hzxys_list)
# set save list
sel_dna_hzxys_list, sel_dna_scores_list, all_dna_scores_list = [init_dna_hzxys], [], []

for _iter in range(niter):
    print(f"+ iter:{_iter}")
    # E: generate reference
    ref_ct_dists, ref_local_dists, ref_ints = generate_reference_from_population(
        sel_dna_hzxys_list[-1], dna_reg_ids, 
        sel_dna_hzxys_list[-1], dna_reg_ids,
        ref_channels=dna_reg_channels,
        ref_chr_cts=ref_chr_cts,
        num_threads=num_threads,
        collapse_regions=True,
        split_channels=True,
        verbose=True,
    )
    
    plt.figure(figsize=(4,2), dpi=100)
    for _k, _v in ref_ct_dists.items():
        plt.hist(np.array(_v), bins=np.arange(0,5000,100), alpha=0.5, label=_k)
    plt.legend(fontsize=8)
    plt.title('center dist', fontsize=8)
    plt.show()
    
    plt.figure(figsize=(4,2), dpi=100)
    for _k, _v in ref_local_dists.items():
        plt.hist(np.array(_v), bins=np.arange(0,5000,100), alpha=0.5, label=_k)
    plt.legend(fontsize=8)
    plt.title('local dist', fontsize=8)
    plt.show()
    
    plt.figure(figsize=(4,2), dpi=100)
    for _k, _v in ref_ints.items():
        plt.hist(np.array(_v), bins=np.arange(0,5000,100), alpha=0.5, label=_k)
    plt.legend(fontsize=8)
    plt.title('intensity', fontsize=8)
    plt.show()
    
    # M: pick based on scores
    sel_hzxys_list, sel_scores_list, all_scores_list, other_scores_list = \
    pick_spots_by_scores(
        sel_dna_cand_hzxys_list, dna_reg_ids,
        cand_channels=dna_reg_channels, 
        ref_hzxys_list=sel_dna_hzxys_list[-1], ref_ids=dna_reg_ids, ref_channels=dna_reg_channels,
        ref_ct_dists=ref_ct_dists, ref_local_dists=ref_local_dists, ref_ints=ref_ints, 
        ref_chr_cts=ref_chr_cts,
        num_threads=num_threads,
        collapse_regions=True,
        split_channels=True,
        return_other_scores=True,
        verbose=True,
    )
    # check updating rate
    update_rate = evaluate_differences(sel_hzxys_list, sel_dna_hzxys_list[-1])
    print(f"-- region kept: {update_rate:.4f}")
    # append
    sel_dna_hzxys_list.append(sel_hzxys_list)
    sel_dna_scores_list.append(sel_scores_list)
    all_dna_scores_list.append(all_scores_list)
    
    plt.figure(figsize=(4,2), dpi=100)
    plt.hist(np.concatenate([np.concatenate(_scores) 
                       for _scores in other_scores_list]), 
             bins=np.arange(-15,0), alpha=0.5, label='unselected')
    plt.hist(np.ravel([np.array(_sel_scores) 
                       for _sel_scores in sel_dna_scores_list[-1]]), 
             bins=np.arange(-15,0), alpha=0.5, label='selected')
    plt.legend(fontsize=8)
    plt.show()
    
    if update_rate > 0.998:
        break

# %%
dna_reg_ids

# %%
from scipy.spatial.distance import pdist, squareform
sel_iter = -1

final_dna_hzxys_list = []
kept_chr_ids = []
distmap_list = []
score_th = -5
int_th = 200
bad_spot_percentage = 0.5

for _hzxys, _scores in zip(sel_dna_hzxys_list[sel_iter], sel_dna_scores_list[sel_iter]):
    _kept_hzxys = np.array(_hzxys).copy()
    # remove spots by intensity
    _bad_inds = _kept_hzxys[:,0] < int_th
    # remove spots by scores
    _bad_inds += _scores < score_th
    #print(np.mean(_bad_inds))
    _kept_hzxys[_bad_inds] = np.nan
    
    
    if np.mean(np.isnan(_kept_hzxys).sum(1)>0)<bad_spot_percentage:
        kept_chr_ids.append(True)
        final_dna_hzxys_list.append(_kept_hzxys)
        distmap_list.append(squareform(pdist(_kept_hzxys[:,1:4])))
    else:
        kept_chr_ids.append(False)

kept_chr_ids = np.array(kept_chr_ids, dtype=np.bool)
#kept_chrom_coords = np.array(sel_chrom_coords)[kept_chr_ids]
distmap_list = np.array(distmap_list)
median_distmap = np.nanmedian(distmap_list, axis=0)

# %%
loss_rates = np.mean(np.sum(np.isnan(final_dna_hzxys_list), axis=2)>0, axis=0)
print(np.mean(loss_rates))
fig, ax = plt.subplots(figsize=(4,2),dpi=200)
ax.plot(loss_rates, '.-')
ax.set_ylim([0,1])
ax.set_xticks(np.arange(0,len(dna_reg_ids),int(len(dna_reg_ids)/5)))
plt.show()

# %%
dna_reg_ids[np.where(loss_rates>0.8)[0]]

# %%
imaging_order = []
for _fd, _infos in fov.color_dic.items():
    for _info in _infos:
        if len(_info) > 0 and _info[0] == 'u':
            if int(_info[1:]) in dna_reg_ids:
                imaging_order.append(list(dna_reg_ids).index(int(_info[1:])))
imaging_order = np.array(imaging_order, dtype=np.int)
#kept_inds = imaging_order # plot imaging ordered regions

#kept_inds = np.where(loss_rates<0.5)[0] # plot good regions only
kept_inds = np.arange(len(fov.unique_ids)) # plot all

# %matplotlib inline

fig, ax = plt.subplots(figsize=(4,3),dpi=200)
ax = ia.figure_tools.distmap.plot_distance_map(median_distmap[kept_inds][:,kept_inds], 
                                               color_limits=[0,600],
                                               ax=ax,
                                               ticks=np.arange(0,150,20), 
                                               figure_dpi=500)
ax.set_title(f"v-Abl ProB iaa_dox_STI+, n={len(distmap_list)}", fontsize=7.5)

_ticks = np.arange(0, len(kept_inds), 20)
ax.set_xticks(_ticks)
ax.set_xticklabels(dna_reg_ids[kept_inds][_ticks])
ax.set_xlabel(f"5kb region id", fontsize=7, labelpad=2)
ax.set_yticks(_ticks)
ax.set_yticklabels(dna_reg_ids[kept_inds][_ticks])
ax.set_ylabel(f"5kb region id", fontsize=7, labelpad=2)


ax.axvline(x=np.where(fov.unique_ids[kept_inds]>300)[0][0], color=[1,1,0])
ax.axhline(y=np.where(fov.unique_ids[kept_inds]>300)[0][0], color=[1,1,0])

plt.gcf().subplots_adjust(bottom=0.1)
plt.show()

# %% [markdown]
# ## visualize single example

# %%
# %matplotlib inline


reload(figure_tools.image)

chrom_id = 3

import matplotlib
import copy

sc_cmap = copy.copy(matplotlib.cm.get_cmap('seismic_r'))
sc_cmap.set_bad(color=[0.5,0.5,0.5,1])

#valid_inds = np.where(np.isnan(final_dna_hzxys_list[chrom_id]).sum(1) == 0)[0]
valid_inds = np.ones(len(final_dna_hzxys_list[chrom_id]), dtype=np.bool) # all spots

fig, ax = plt.subplots(figsize=(4,3),dpi=200)
ax = ia.figure_tools.distmap.plot_distance_map(
        distmap_list[chrom_id][valid_inds][:,valid_inds], 
        color_limits=[0,600],
        ax=ax,
        cmap=sc_cmap,
        ticks=np.arange(0,150,20), 
        figure_dpi=200)
ax.set_title(f"proB DMSO chrom: {chrom_id}", fontsize=7.5)
plt.gcf().subplots_adjust(bottom=0.1)
plt.show()

ax3d = figure_tools.image.chromosome_structure_3d_rendering(
        final_dna_hzxys_list[chrom_id][valid_inds, 1:], 
        marker_edge_line_width=0,
        reference_bar_length=200, image_radius=300, 
        line_width=0.5, figure_dpi=300, depthshade=False)
plt.show()

# %%
# ?figure_tools.image.chromosome_structure_3d_rendering

# %% [markdown]
# ## visualize all fitted spots

# %%
with h5py.File(fov.save_filename, "r", libver='latest') as _f:
    _grp = _f['unique']
    raw_spots_list = [_spots[_spots[:,0] > 0] for _spots in _grp['raw_spots'][:]]
    spots_list = [_spots[_spots[:,0] > 0] for _spots in _grp['spots'][:]]

# %%
from scipy.spatial.distance import cdist
picked_spot_inds_list = []
for _i, _id in enumerate(dna_reg_ids):
    _cand_hzxys = spots_list[_i][:,1:4] * fov.shared_parameters['distance_zxy']
    _dists = cdist(np.array(final_dna_hzxys_list)[:,_i,1:], _cand_hzxys)#, axis=1
    _matched_spot_inds = []
    for _ds in _dists:
        if np.sum(np.isnan(_ds)) < len(_ds) and np.nanmin(_ds) < 0.01:
            _matched_spot_inds.append(np.argmin(_ds))
        else:
            _matched_spot_inds.append(np.nan)
    # append
    picked_spot_inds_list.append(np.array(_matched_spot_inds))

# %%
#vis_inds = [0,1,2,3,4,5]
vis_inds = np.where(loss_rates > 0.8)[0]
vis_ims, vis_ids, vis_spot_list, vis_raw_spot_list = [], [], [], []

with h5py.File(fov.save_filename, "r", libver='latest') as _f:
    _grp = _f['unique']
    
    for _ind in vis_inds:
        vis_ims.append(_grp['ims'][_ind])
        vis_ids.append(_grp['ids'][_ind])
        _picked_inds = picked_spot_inds_list[_ind]
        _picked_inds = np.array(_picked_inds[np.isnan(_picked_inds)==False], dtype=np.int)
        vis_spot_list.append(raw_spots_list[_ind][_picked_inds])

# %%
dna_reg_ids[59]

# %%
fov.color_dic

# %%
# visualize_all_chromosomes
# %matplotlib notebook
# %matplotlib notebook

## visualize
coord_dict = {'coords':[],
              'class_ids':[],
             }
for _i, _spots in enumerate(vis_spot_list):
    coord_dict['coords'] += list(np.flipud(_spot[1:4]) for _spot in _spots)
    coord_dict['class_ids'] += list(_i * np.ones(len(_spots),dtype=np.int))

fig=plt.figure(figsize=(4,6), dpi=150)    
    
visual_tools.imshow_mark_3d_v2(vis_ims, 
                               fig=fig,
                               given_dic=coord_dict,
                               save_file=None,
                               )
