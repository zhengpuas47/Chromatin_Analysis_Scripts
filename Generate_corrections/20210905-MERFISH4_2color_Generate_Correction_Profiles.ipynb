# %% [markdown]
# # Generate correction profiles for MERFISH4
#
# by Pu Zheng
#
# 2021.09.06

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *

print(os.getpid())
# Out:
# 20120

# %%
reload(ia.get_img_info)
reload(ia.corrections)
reload(ia.visual_tools)
reload(ia.classes)
reload(ia.alignment_tools)
reload(ia.correction_tools.illumination)
# Out:
# <module 'ImageAnalysis3.correction_tools.illumination' from 'E:\\Users\\puzheng\\Documents\\ImageAnalysis3\\correction_tools\\illumination.py'>

# %% [markdown]
# ## resave files

# %%
import shutil

source_folder = r'\\10.245.74.158\Chromatin_NAS_0\Corrections\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\old'
target_folder = r'D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4'
folders, fovs = get_img_info.get_folders(source_folder)

for _fd in folders:
    _tar_fd = _fd.replace(source_folder, target_folder)
    
    if not os.path.exists(_tar_fd):
        os.makedirs(_tar_fd)
        print(_tar_fd)
    # swap folder
    _basenames = [_fl for _fl in os.listdir(_fd) if '750_650_473' in _fl]
    _fov_ids = [_fl.split('_')[-2] for _fl in _basenames]
    _fov_postfixs = [_fl.split(os.extsep)[-1] for _fl in _basenames]
    _new_basenames = [f'Conv_zscan_{_id}.{_ext}' for _id,_ext in zip(_fov_ids, _fov_postfixs)]
    
    for _fl, _tar_fl in zip(_basenames, _new_basenames):
        if not os.path.isfile(_tar_fl):
            print(f"copy {_fl} to {_tar_fl}")
            shutil.copyfile(os.path.join(_fd, _fl), 
                            os.path.join(_tar_fd, _tar_fl))
        else:
            print(f"{_tar_fl} already exist, skip")
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 2
# - Number of field of views: 63
# D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7
# copy Hal_config_750_650_473_408_50step200_5Hz_00_0.dax to Conv_zscan_00.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_00_0.inf to Conv_zscan_00.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_00_0.off to Conv_zscan_00.off
# copy Hal_config_750_650_473_408_50step200_5Hz_00_0.power to Conv_zscan_00.power
# copy Hal_config_750_650_473_408_50step200_5Hz_00_0.xml to Conv_zscan_00.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_00_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_01_0.dax to Conv_zscan_01.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_01_0.inf to Conv_zscan_01.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_01_0.off to Conv_zscan_01.off
# copy Hal_config_750_650_473_408_50step200_5Hz_01_0.power to Conv_zscan_01.power
# copy Hal_config_750_650_473_408_50step200_5Hz_01_0.xml to Conv_zscan_01.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_01_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_02_0.dax to Conv_zscan_02.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_02_0.inf to Conv_zscan_02.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_02_0.off to Conv_zscan_02.off
# copy Hal_config_750_650_473_408_50step200_5Hz_02_0.power to Conv_zscan_02.power
# copy Hal_config_750_650_473_408_50step200_5Hz_02_0.xml to Conv_zscan_02.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_02_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_03_0.dax to Conv_zscan_03.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_03_0.inf to Conv_zscan_03.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_03_0.off to Conv_zscan_03.off
# copy Hal_config_750_650_473_408_50step200_5Hz_03_0.power to Conv_zscan_03.power
# copy Hal_config_750_650_473_408_50step200_5Hz_03_0.xml to Conv_zscan_03.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_03_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_04_0.dax to Conv_zscan_04.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_04_0.inf to Conv_zscan_04.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_04_0.off to Conv_zscan_04.off
# copy Hal_config_750_650_473_408_50step200_5Hz_04_0.power to Conv_zscan_04.power
# copy Hal_config_750_650_473_408_50step200_5Hz_04_0.xml to Conv_zscan_04.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_04_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_05_0.dax to Conv_zscan_05.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_05_0.inf to Conv_zscan_05.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_05_0.off to Conv_zscan_05.off
# copy Hal_config_750_650_473_408_50step200_5Hz_05_0.power to Conv_zscan_05.power
# copy Hal_config_750_650_473_408_50step200_5Hz_05_0.xml to Conv_zscan_05.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_05_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_06_0.dax to Conv_zscan_06.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_06_0.inf to Conv_zscan_06.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_06_0.off to Conv_zscan_06.off
# copy Hal_config_750_650_473_408_50step200_5Hz_06_0.power to Conv_zscan_06.power
# copy Hal_config_750_650_473_408_50step200_5Hz_06_0.xml to Conv_zscan_06.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_06_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_07_0.dax to Conv_zscan_07.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_07_0.inf to Conv_zscan_07.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_07_0.off to Conv_zscan_07.off
# copy Hal_config_750_650_473_408_50step200_5Hz_07_0.power to Conv_zscan_07.power
# copy Hal_config_750_650_473_408_50step200_5Hz_07_0.xml to Conv_zscan_07.xml
# copy Hal_config_750_650_473_408_50step200_5Hz_07_0_.png to Conv_zscan_0.png
# copy Hal_config_750_650_473_408_50step200_5Hz_08_0.dax to Conv_zscan_08.dax
# copy Hal_config_750_650_473_408_50step200_5Hz_08_0.inf to Conv_zscan_08.inf
# copy Hal_config_750_650_473_408_50step200_5Hz_08_0.off to Conv_zscan_08.off
# copy Hal_config_750_650_473_408_50step200_5Hz_08_
:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4'
# correction folder
correction_folder=os.path.join(master_folder, 'Corrections')
if not os.path.exists(correction_folder):
    print(f"creating folder: {correction_folder}")
    os.makedirs(correction_folder)
# Out:
# creating folder: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\Corrections

# %%
#master_folder = r'\\10.245.74.116\Chromatin_NAS_4\20191218_CTP05-chr21_HCT116_6hauxin'
#correction_folder =os.path.join(master_folder, 'Corrections')
folders, fovs = ia.get_img_info.get_folders(master_folder, 'H')
folders = [_fd for _fd in folders if 'Cy' in _fd]
print(folders)
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 2
# - Number of field of views: 63
# ['D:\\Data\\20210905-colorswap_MEF_CTP-08_MERFISH4\\H0U1_Cy7', 'D:\\Data\\20210905-colorswap_MEF_CTP-08_MERFISH4\\H1U1_Cy5']

# %%
# shared parameters
single_im_size = np.array([50,2048,2048])
all_colors = ['null', '750', '647', '488', '405']
num_buffer_frames = 0
# image and threads
num_images = 63
num_threads = 16

# %% [markdown]
# # Illumination correction

# %%
# %matplotlib inline
reload(ia.correction_tools.illumination)

illumination_pfs = correction_tools.illumination.Generate_illumination_correction(
                        folders[0], 
                        all_colors[1:],
                        all_channels=all_colors,
                        num_threads=num_threads, parallel=True,
                        num_images=num_images,
                        single_im_size=single_im_size,
                        correction_folder=correction_folder,
                        num_buffer_frames=num_buffer_frames,
                        gaussian_filter_size=40,
                        save=True, save_folder=correction_folder,
                        overwrite=True,
                        )
# Out:
# -- directly load:[] illumination profiles for files
# -- start calculating ['750', '647', '488', '405'] illumination profiles
# -- 63 among 63 dax files will be loaded in data_folder: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7
# ++ start multi-processing illumination profile calculateion with 16 threads for 63 images in 956.84s.
# -- saving updated profiles
# --- saving 750 profile into file: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\Corrections\illumination_correction_750_2048x2048.npy
# --- saving 647 profile into file: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\Corrections\illumination_correction_647_2048x2048.npy
# --- saving 488 profile into file: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\Corrections\illumination_correction_488_2048x2048.npy
# --- saving 405 profile into file: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\Corrections\illumination_correction_405_2048x2048.npy
# -- finish generating illumination profiles, time:969.77s

# %% [markdown]
# # Chromatic Abbrevation

# %% [markdown]
# ## chromatic for 750

# %%
cc_folder = folders[0]
ref_folder = folders[1]
print(f"chromatic_corr_folder: {cc_folder},\nref_folder:{ref_folder}")
# Out:
# chromatic_corr_folder: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7,
# ref_folder:D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H1U1_Cy5

# %%
# %matplotlib inline
reload(correction_tools.chromatic)
chromatic_pfs, chromatic_consts = correction_tools.chromatic.Generate_chromatic_abbrevation(
                                    cc_folder, ref_folder, '750',
                                    num_images=num_images, 
                                    num_threads=num_threads, parallel=True,
                                    fitting_orders=[1,1,1],
                                    correction_args={'correction_folder':correction_folder,
                                                     'single_im_size': single_im_size,
                                                     'all_channels': all_colors,
                                                     'corr_channels': ['750', '647'],
                                                     'num_buffer_frames':0,
                                                     'illumination_corr':False,
                                                     },
                                    save_folder=correction_folder,
                                    rsq_th=0.9,
                                    overwrite_temp=False,
                                    overwrite_profile=True)
# Out:
# -- loading illumination correction profile from file:
# 	 647 illumination_correction_647_2048x2048.npy
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# ++ generating chromatic info for 63 images in 16 threads in 1660.996s.
# ++ fitting polynomial orders: [1 1 1]
# -- constants: [-1.15423533e-01  3.47256526e-03  4.54078165e-05 -1.24364522e-04] with rsquare=0.06559066431882943
# -- constants: [-6.19981980e-02  1.24022212e-03 -1.78989252e-03 -5.12597599e-06] with rsquare=0.925644184927879
# -- constants: [-9.87261384e-02 -1.09531381e-03 -1.19328478e-05 -1.79072073e-03] with rsquare=0.9176437027519884
# ++ saving new profiles into folder: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\Corrections

# %% [markdown]
# ### check chromatic abbrevation, 750-647

# %%
fov_id = 2
ref_filename = os.path.join(ref_folder, fovs[fov_id])
cc_filename = os.path.join(cc_folder, fovs[fov_id])

# %%
# reference image
ref_ims, = ia.io_tools.load.correct_fov_image(ref_filename, 
                                            [647, 488], 
                                            single_im_size=single_im_size,
                                            num_buffer_frames=num_buffer_frames,
                                            all_channels=all_colors,
                                            calculate_drift=False,                                                    
                                            warp_image=True,
                                            illumination_corr=True,
                                            chromatic_corr=False,
                                            bleed_corr=False, 
                                            correction_folder=correction_folder)

# target image, not warpping
raw_ims, corr_funcs, drift = ia.io_tools.load.correct_fov_image(cc_filename, 
                                                                [750, 488], 
                                                                calculate_drift=True,
                                                                ref_filename=ref_ims[-1],
                                                                single_im_size=single_im_size,
                                                                num_buffer_frames=num_buffer_frames,
                                                                all_channels=all_colors,
                                                                corr_channels=[750,647],
                                                                warp_image=False,
                                                                illumination_corr=True,
                                                                chromatic_corr=True,
                                                                bleed_corr=False, 
                                                                correction_folder=correction_folder,
                                                                return_drift=True)

# target image, warppring
warpped_ims, = ia.io_tools.load.correct_fov_image(cc_filename, 
                                                [750, 488], 
                                                calculate_drift=False,
                                                drift=drift,
                                                ref_filename=ref_ims[-1],
                                                single_im_size=single_im_size,
                                                num_buffer_frames=num_buffer_frames,
                                                all_channels=all_colors,
                                                  corr_channels=[750,647],
                                                warp_image=True,
                                                illumination_corr=True,
                                                chromatic_corr=True, 
                                                bleed_corr=False, 
                                                correction_folder=correction_folder,
                                                return_drift=False)
# Out:
# - correct the whole fov for image: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H1U1_Cy5\Conv_zscan_02.dax
# -- loading illumination correction profile from file:
# 	 647 illumination_correction_647_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H1U1_Cy5\Conv_zscan_02.dax  in 4.155s
# -- removing hot pixels for channels:['647', '488'] in 9.392s
# -- illumination correction for channels: 647, 488, in 3.187s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 17.528s
# - correct the whole fov for image: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_02.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048_const.pkl
# 	 647 None
# -- loading image from file:D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_02.dax  in 5.203s
# -- removing hot pixels for channels:['750', '488'] in 9.695s
# -- illumination correction for channels: 750, 488, in 3.198s
# -- apply bead_drift calculate for channel: 488
# -- start aligning given source image to given reference image.
# --- align image 0 in 5.594s.
# --- align image 1 in 5.328s.
# --- align image 2 in 5.517s.
# --- drifts for crops:[0 1 2] pass the thresold, exit cycle.
# --- finish drift: [ 0.44 35.97  0.55] in 16.687s
# -- generate translation function for chromatic correction for channels: ['750'] and drift:[ 0.44 35.97  0.55] in 0.000s
# -- finish correction in 35.453s
# - correct the whole fov for image: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_02.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_50_2048_2048.npy
# 	 647 None
# -- loading image from file:D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_02.dax  in 1.015s
# -- removing hot pixels for channels:['750', '488'] in 9.393s
# -- illumination correction for channels: 750, 488, in 3.185s
# -- warp image with chromatic correction for channels: ['750'] and drift:[ 0.44 35.97  0.55] 750, 488, in 150.400s
# -- finish correction in 166.892s

# %% [markdown]
# ## visualize

# %%
# %matplotlib notebook
visual_tools.imshow_mark_3d_v2([raw_ims[0], warpped_ims[0], ref_ims[0]])
# Out:
# <img src="data:image/png;base64,..." width="288">

# %%
reload(ia.io_tools.load)
reload(ia.correction_tools.chromatic)
from ImageAnalysis3.spot_tools.fitting import fit_fov_image
# fitting
int_th = 300

warp_spots = fit_fov_image(warpped_ims[0], '750', th_seed=200, normalize_background=False)
raw_spots = fit_fov_image(raw_ims[0], '750', th_seed=200, normalize_background=False)
ref_spots = fit_fov_image(ref_ims[0], '647', th_seed=300, normalize_background=False)

warp_spots = warp_spots[warp_spots[:,0] >= int_th]
raw_spots = raw_spots[raw_spots[:,0] >= int_th]
corr_raw_spots = corr_funcs[0](raw_spots)
ref_spots = ref_spots[ref_spots[:,0] >= int_th]
# Out:
# -- start fitting spots in channel:750, 500 seeded, 500 fitted in 243.628s.
# -- start fitting spots in channel:750, 500 seeded, 500 fitted in 249.003s.
# -- start fitting spots in channel:647, 500 seeded,
# ..\..\..\Documents\ImageAnalysis3\External\Fitting_v4.py:285: RuntimeWarning: overflow encountered in exp
#   self.f = np.exp(bk)+self.f0
# 500 fitted in 250.012s.

# %%
raw_spots
# Out:
# (500, 11)

# %%
ch_info_list = pickle.load(open(r'\\10.245.74.158\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H0R0\chromatic_Conv_zscan_00_channel_750_ref_647.pkl', 'rb'))

# %%
chromatic_infos = []
rsq_th = 0.9
ch_info_filenames = [os.path.join(folders[0], _fl) for _fl in os.listdir(folders[0]) if _fl.split(os.extsep)[-1]=='pkl' and 'chromatic' in _fl]
for _fl in ch_info_filenames:
    _loaded_infos = pickle.load(open(_fl, 'rb'))
    chromatic_infos.extend([_info for _info in _loaded_infos if _info['rsquare'] >= rsq_th])
    print(len(chromatic_infos))
# Out:
# 151
# 263
# 388
# 521
# 613
# 690
# 770
# 851
# 918
# 1027
# 1151
# 1264
# 1415
# 1549
# 1700
# 1851
# 2003
# 2042
# 2097
# 2131
# 2236
# 2294
# 2334
# 2382
# 2449
# 2541
# 2611
# 2735
# 2835
# 2917
# 3053
# 3184
# 3306
# 3360
# 3391
# 3422
# 3457
# 3500
# 3540
# 3599
# 3657
# 3710
# 3779
# 3862
# 3926
# 3998
# 4115
# 4227
# 4338
# 4385
# 4413
# 4438
# 4460
# 4505
# 4541
# 4607
# 4684
# 4727
# 4776
# 4839
# 4889
# 4970
# 5080
# 5106

# %%
ref_coords = np.array([_info['ref_coord'] for _info in chromatic_infos])
ca_coords = np.array([_info['ca_coord'] + _info['drift'] for _info in chromatic_infos])
raw_ca_coords = np.array([_info['ca_coord'] for _info in chromatic_infos])

# %%
dz = ca_coords[:,0] - ref_coords[:,0]

# %%
dx = ca_coords[:,1] - ref_coords[:,1]

# %%
plt.figure()
plt.plot(raw_ca_coords[:,1],  dz, '.', markersize=1, label='ca')
plt.plot(ref_coords[:,1],  dz, '.', markersize=1, label='ref')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="474.545444259959">

# %%
len(chromatic_infos)
# Out:
# 5106

# %%
from copy import copy
# %matplotlib inline

# %%
del(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-205-cbcb123ff81f> in <module>
# ----> 1 del(model)
#
# NameError: name 'model' is not defined

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import *#LinearRegression, Ridge, Lasso, ElasticNet,TheilSenRegressor,RANSACRegressor,HuberRegressor


def calculate_chromatic_abbrevation(tar_coords, ref_coords, model_type=LinearRegression, base='target'):
    
    _models = [model_type() for _i in np.arange(tar_coords.shape[1])]
    _yps = []
    for _iy, _y in enumerate(np.transpose(tar_coords - ref_coords)):
        print(_y.shape)
        if base == 'target':
            _X = tar_coords
        elif base == 'ref':
            _X = ref_coords
        elif base == 'middle':
            _X = (tar_coords + ref_coords) / 2
        else:
            raise ValueError(f"Wrong base, should be in ['target', 'ref', 'middle']")
        _model = _models[_iy]
        _model.fit(_X, _y)
        _yp = _model.predict(_X)
        _yps.append(_yp)
        # plot regression
        
        fig, axes = plt.subplots(1,3, figsize=(12,3),dpi=100)
        for _ix, (_ax, _x) in enumerate(zip(axes, np.transpose(_X))):
            _ax.plot(_x, _y, 'r.', markersize=1, label=f'data_axis{_iy}')
            _ax.plot(_x, _yp, 'b.', markersize=1, label=f'model_axis{_iy}')
            _ax.hlines(0, min(_x), max(_x), color='black', linestyle='-.')
            _ax.set_ylim([-2,2])
            _ax.legend(loc='upper right')
            _ax.set_xlabel(f"axis: {_ix}")
        plt.show()
        # plot residues
        
    return _models, np.transpose(np.array(_yps))

# %%
# %matplotlib inline
models, yps = calculate_chromatic_abbrevation(ca_coords, ref_coords, model_type=LinearRegression, base='target')
# Out:
# (5106,)
# (5106,)
# (5106,)

# %%
_dft, _ccoords, _rcoords = spot_tools.matching.find_paired_centers(corr_raw_spots[:,1:4], ref_spots[:,1:4])
_dft2, _raw_coords, _rcoords, _raw_inds, _rinds = spot_tools.matching.find_paired_centers(raw_spots[:,1:4]+drift, _rcoords, return_kept_inds=True)
_dft3, _ccoords, _rcoords = spot_tools.matching.find_paired_centers(corr_raw_spots[:,1:4], _rcoords)

_ncoords = _raw_coords - np.transpose([_model.predict(_raw_coords) for _model in models])


ax_id = 0

old_ax_err = (_ccoords-_rcoords)[:,ax_id]*ia._distance_zxy[ax_id]

new_ax_err = (_ncoords-_rcoords)[:,ax_id]*ia._distance_zxy[ax_id]

print(np.std(old_ax_err))
print(np.std(new_ax_err))

plt.figure(figsize=(6,2),dpi=100)
plt.hist(old_ax_err, alpha=0.7, density=True, bins=np.arange(-200,220,20), label=f'old, median={np.median(old_ax_err):.1f}')
plt.hist(new_ax_err, alpha=0.7, density=True, bins=np.arange(-200,220,20), label=f'new, median={np.median(new_ax_err):.1f}')
plt.legend()
plt.show()

old_err = np.linalg.norm((_rcoords-_ccoords)[:,:]*ia._distance_zxy[:], axis=1)

new_err = np.linalg.norm((_ncoords-_rcoords)[:,:]*ia._distance_zxy[:], axis=1)

plt.figure(figsize=(6,2),dpi=100)
plt.hist(old_err, alpha=0.7, density=True, bins=np.arange(0,300,20), label=f'old, median={np.median(old_err):.1f}')
plt.hist(new_err, alpha=0.7, density=True, bins=np.arange(0,300,20), label=f'new, median={np.median(new_err):.1f}')
plt.legend()
plt.show()
# Out:
# 61.026463
# 60.92747298230027

# %%
import statsmodels.api as sm
ys = ca_coords - ref_coords
_X = ca_coords

ax_id = 2
model = sm.OLS(ys[:,ax_id],sm.add_constant(_X))
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                 1.065e+04
# Date:                Tue, 29 Jun 2021   Prob (F-statistic):               0.00
# Time:                        16:34:15   Log-Likelihood:                -1898.7
# No. Observations:                5106   AIC:                             3805.
# Df Residuals:                    5102   BIC:                             3831.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6853      0.020     85.134      0.000       1.647       1.724
# x1             0.0014      0.001      2.595      0.009       0.000       0.003
# x2          1.922e-06   9.97e-06      0.193      0.847   -1.76e-05    2.15e-05
# x3            -0.0018   1.04e-05   -174.953      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                       66.947   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.259
# Skew:                           0.065   Prob(JB):                     5.68e-26
# Kurtosis:                       3.728   Cond. No.                     6.37e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
ys[0]
# Out:
# (5106, 3)

# %%
models[0].intercept_, models[0].coef_
# Out:
# (-1.3169098044550271, array([0.01215139, 0.00021077, 0.00026969]))

# %%
from scipy import stats
ax_id = 1
MSE = (sum((ys-yps)[:,ax_id]**2))/(len(_X)-_X.shape[1])
print(MSE)
se = np.sqrt(MSE) / np.sqrt(np.sum((_X - np.mean(_X,axis=0))**2, axis=0))
t_stats = models[ax_id].coef_ / se

[1-stats.t.cdf(_ts, (len(_X)-_X.shape[1])) for _ts in t_stats]
# Out:
# 0.12444354891935043
# [0.978414089159235, 1.0, 0.9823002657542234]

# %%
rss = np.sum((ys - yps)**2, axis=0)
rse = np.sqrt(rss / (len(_X)-_X.shape[1]))
tss = np.sum((ys - np.mean(ys,axis=0))**2, axis=0)
rsqs = 1 - rss/tss
print(rsqs)
# Out:
# [0.31852614 0.86632431 0.86227216]

# %%
ax_id = 0
old_z_err = (_ccoords-_rcoords)[:,ax_id]*ia._distance_zxy[ax_id]

new_z_err = (_ncoords-_rcoords)[:,ax_id]*ia._distance_zxy[ax_id]

print(np.std(old_z_err))
print(np.std(new_z_err))

plt.figure()
plt.hist(old_z_err, alpha=0.7, density=True, bins=np.arange(-200,220,20), label=f'old, median={np.median(old_z_err):.1f}')
plt.hist(new_z_err, alpha=0.7, density=True, bins=np.arange(-200,220,20), label=f'new, median={np.median(new_z_err):.1f}')
plt.legend()
plt.show()
# Out:
# 61.026463
# 60.92747298230027

# %%
old_err = np.linalg.norm((_rcoords-_ccoords)[:,1:]*ia._distance_zxy[1:], axis=1)

new_err = np.linalg.norm((_ncoords-_rcoords)[:,1:]*ia._distance_zxy[1:], axis=1)

plt.figure()
plt.hist(old_err, alpha=0.7, density=True, bins=np.arange(0,300,20), label=f'old, median={np.median(old_err):.1f}')
plt.hist(new_err, alpha=0.7, density=True, bins=np.arange(0,300,20), label=f'new, median={np.median(new_err):.1f}')
plt.legend()
plt.show()

# %%
# %matplotlib notebook

ax_pair = [1,2]

plt.figure(figsize=(6,6),dpi=100)
plt.plot(_ccoords[:,ax_pair[0]], _ccoords[:,ax_pair[1]], 'go', label='old')
plt.plot(_ncoords[:,ax_pair[0]], _ncoords[:,ax_pair[1]], 'bx', label='corrected')
plt.plot(_rcoords[:,ax_pair[0]], _rcoords[:,ax_pair[1]], 'r.', label='ref')

plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
plt.figure(figsize=(6,6),dpi=100)
plt.plot(ref_spots[:,2], ref_spots[:,3], 'bx', label='ref')
plt.plot(warp_spots[:,2], warp_spots[:,3], 'r.', label='warp image')
plt.plot(corr_raw_spots[:,2], corr_raw_spots[:,3], 'g.', label='translate spots')
plt.plot(raw_spots[:,2]+drift[1], raw_spots[:,3]+drift[2], 'y.', label='drifted')

plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %% [markdown]
# # bleedthrough correction

# %%
from ImageAnalysis3 import _image_size, _correction_folder, _allowed_colors
reload(correction_tools.bleedthrough)
from ImageAnalysis3.correction_tools.bleedthrough import find_bleedthrough_pairs, interploate_bleedthrough_correction_from_channel
import multiprocessing as mp
from ImageAnalysis3.correction_tools.chromatic import generate_polynomial_data


bleedthrough_channels=['750', '647']

bleedthrough_correction_args = {
    'correction_folder': _correction_folder,
    'single_im_size':single_im_size,
    'all_channels':all_colors,
    'corr_channels':['750','647','561'],
    'bleed_corr':False,
    'illumination_corr':False,
    'chromatic_corr':False,
    'num_buffer_frames':num_buffer_frames,
}

bleedthrough_fitting_args = {'max_num_seeds':1000,
    'th_seed': 500,
    'use_dynamic_th':True,
}
reload(correction_tools.bleedthrough)
# Out:
# <module 'ImageAnalysis3.correction_tools.bleedthrough' from 'E:\\Users\\puzheng\\Documents\\ImageAnalysis3\\correction_tools\\bleedthrough.py'>

# %%
# %matplotlib inline
reload(correction_tools.bleedthrough)
bleed_pf = correction_tools.bleedthrough.Generate_bleedthrough_correction(
            folders[:3],
            rsq_th=0.9,
            intensity_th=1000,
            corr_channels=bleedthrough_channels,
            correction_args=bleedthrough_correction_args,
            fitting_order=1,
            fitting_args=bleedthrough_fitting_args,
            interpolate_args={'check_params':{'outlier_sigma':3.}, 'min_num_spots':100, 'max_num_spots':2000},
            num_images=num_images, 
            num_threads=num_threads,parallel=True,
            save_folder=correction_folder,
            overwrite_profile=True,
            overwrite_temp=False,
            )
# Out:
# + generating bleedthrough profiles.
# ++ generating bleedthrough info for 62 images with 16 threads in 1801.481s.
# -- only keep the top 2000 spots from 5670 for bleedthrough interpolation.
# - check 2000 bleedthrough pairs.
# - start iteration with outlier_sigma=3.00, keep_percentage=0.95
# -- iter: 1, kept in this round: 0.949, total: 0.949 in 77.316s
# E:\Users\puzheng\Documents\ImageAnalysis3\correction_tools\bleedthrough.py:206: RuntimeWarning: divide by zero encountered in true_divide
#   _nb_weights = 1 / np.linalg.norm(_nb_coords-_coord, axis=1)
# E:\Users\puzheng\Documents\ImageAnalysis3\correction_tools\bleedthrough.py:207: RuntimeWarning: invalid value encountered in true_divide
#   _nb_weights = _nb_weights / np.sum(_nb_weights)
# -- iter: 2, kept in this round: 0.952, total: 0.903 in 66.879s
# - 1807 pairs passed.
# -- 1807 spots are used to generate profiles from 750 to 647
# [ 2.27125372e-01  1.56243653e-04 -3.25350532e-06  2.71282667e-06] 0.010213819656925693
# [ 2.79268168e+03  2.43613177e+00 -1.41169166e-01  4.15309018e-02] 0.07121081923761141
# -- saving bleedthrough temp profile from channel: 750 to channel: 647.
# -- not enough spots (4) from 647 to 750
# -- generating inverse matrix.
# -- saving to file:D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\Corrections\bleedthrough_correction_750_647_2048_2048.npy

# %% [markdown]
# ### Check bleedthorugh for cy7

# %%
from ImageAnalysis3.io_tools.load import correct_fov_image
from ImageAnalysis3.io_tools.crop import crop_neighboring_area

# %%
cy7_filename = os.path.join(folders[0], fovs[3])

# %%
reload(ia.io_tools.load)
cy7_filename = os.path.join(folders[0], fovs[3])
print(cy7_filename)

cy7_raw_ims, = ia.io_tools.load.correct_fov_image(cy7_filename, 
                                                  bleedthrough_channels, 
                                                  bleed_corr=False, chromatic_corr=False,
                                                  hot_pixel_corr=False, z_shift_corr=True,
                                                  corr_channels=bleedthrough_channels,
                                                  single_im_size=single_im_size,
                                                  num_buffer_frames=num_buffer_frames,
                                                  all_channels=all_colors,
                                                  illumination_corr=True,
                                                  correction_folder=correction_folder)
cy7_corr_ims, = ia.io_tools.load.correct_fov_image(cy7_filename, 
                                                   bleedthrough_channels, 
                                                   bleed_corr=True, chromatic_corr=False,
                                                   hot_pixel_corr=False, z_shift_corr=True,
                                                   corr_channels=bleedthrough_channels,
                                                   single_im_size=single_im_size,
                                                   num_buffer_frames=num_buffer_frames,
                                                   all_channels=all_colors,
                                                   illumination_corr=True,
                                                   correction_folder=correction_folder)
# Out:
# D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_03.dax
# - correct the whole fov for image: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_03.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# -- loading image from file:D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_03.dax  in 5.128s
# -- correct Z-shifts for channels:['750', '647'] in 9.294s
# -- illumination correction for channels: 750, 647, in 3.109s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 18.266s
# - correct the whole fov for image: D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_03.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_2048_2048.npy
# -- loading image from file:D:\Data\20210905-colorswap_MEF_CTP-08_MERFISH4\H0U1_Cy7\Conv_zscan_03.dax  in 1.125s
# -- correct Z-shifts for channels:['750', '647'] in 9.228s
# -- bleedthrough correction for channels: ['750', '647'] in 9.902s
# -- illumination correction for channels: 750, 647, in 3.089s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 24.141s

# %%
# %matplotlib notebook
# %matplotlib notebook

visual_tools.imshow_mark_3d_v2([cy7_raw_ims[0], cy7_corr_ims[0], cy7_raw_ims[1], cy7_corr_ims[1]])
# Out:
# <img src="data:image/png;base64,..." width="288">
