# %% [markdown]
# # Generate correction profiles for denoised
#
# by Pu Zheng
#
# 2019.06.18

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *

print(os.getpid())
# Out:
# 4776

# %%
reload(ia.get_img_info)
reload(ia.corrections)
reload(ia.visual_tools)
reload(ia.classes)
reload(ia.alignment_tools)
reload(ia.correction_tools.illumination)
# Out:
# <module 'ImageAnalysis3.correction_tools.illumination' from 'E:\\Users\\puzheng\\Documents\\ImageAnalysis3\\correction_tools\\illumination.py'>

# %% [markdown]
# # Data folder

# %%
# master folder for this dataset:
master_folder = r'\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08'
# correction folder
correction_folder=os.path.join(master_folder, 'Corrections')
if not os.path.exists(correction_folder):
    print(f"creating folder: {correction_folder}")
    os.makedirs(correction_folder)

# %% [markdown]
# # Illumination_correction

# %%
#master_folder = r'\\10.245.74.116\Chromatin_NAS_4\20191218_CTP05-chr21_HCT116_6hauxin'
#correction_folder =os.path.join(master_folder, 'Corrections')
folders, fovs = get_img_info.get_folders(master_folder, 'H')
folders = [_fd for _fd in folders if ('Cy' in _fd and '3color' not in _fd) or 'H0R0' in _fd]
print(folders)
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 3
# - Number of field of views: 48
# ['\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H0R0', '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H1R1_Cy7', '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H2R2_Cy5']

# %%
# shared parameters
single_im_size = np.array([40,2048,2048])
all_colors = ['750','647','488','405']
# image and threads
num_images = 45
num_threads = 15

# %% [markdown]
# # Illumination correction

# %%
# %matplotlib inline
reload(ia.correction_tools.illumination)

dapi_folder = folders[0]
illumination_pfs = correction_tools.illumination.Generate_illumination_correction(
                        dapi_folder, 
                        all_colors,
                        all_channels=all_colors,
                        num_threads=num_threads,
                        num_images=num_images,
                        single_im_size=single_im_size,
                        correction_folder=correction_folder,
                        gaussian_filter_size=40,
                        save=True, save_folder=correction_folder,
                        overwrite=False,
                        )
# Out:
# -- directly load:[] illumination profiles for files
# -- start calculating ['750', '647', '488', '405'] illumination profiles
# -- 45 among 49 dax files will be loaded in data_folder: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H0R0
# ++ start multi-processing illumination profile calculateion with 15 threads for 45 images in 726.10s.
# -- saving updated profiles
# --- saving 750 profile into file: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\Corrections\illumination_correction_750_2048x2048.npy
# --- saving 647 profile into file: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\Corrections\illumination_correction_647_2048x2048.npy
# --- saving 488 profile into file: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\Corrections\illumination_correction_488_2048x2048.npy
# --- saving 405 profile into file: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\Corrections\illumination_correction_405_2048x2048.npy
# -- finish generating illumination profiles, time:738.29s

# %% [markdown]
# # Chromatic Abbrevation

# %% [markdown]
# ## chromatic for 750

# %%
cc_folder = folders[-2]
ref_folder = folders[-1]
print(f"chromatic_corr_folder: {cc_folder},\nref_folder:{ref_folder}")
# Out:
# chromatic_corr_folder: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7,
# ref_folder:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H2R2_Cy5

# %%
# %matplotlib inline
reload(correction_tools.chromatic)
chromatic_pfs, chromatic_consts = correction_tools.chromatic.Generate_chromatic_abbrevation(
                                    cc_folder, ref_folder, '750',
                                    num_images=num_images, 
                                    num_threads=num_threads, 
                                    fitting_orders=[0,1,1],
                                    correction_args={'correction_folder':correction_folder,
                                                     'single_im_size': single_im_size,
                                                     'all_channels': all_colors,
                                                     'corr_channels': ['750', '647'],
                                                     },
                                    save_folder=correction_folder,
                                    overwrite_temp=False,
                                    overwrite_profile=True)
# Out:
# -- loading illumination correction profile from file:
# 	 647 illumination_correction_647_2048x2048.npy
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# ++ generating chromatic info for 45 images in 15 threads in 16.327s.
# ++ fitting polynomial orders: [0 1 1]
# -- constants: [0.36797913] with rsquare=0.0
# -- constants: [-1.56583030e-02 -4.94306483e-03 -1.80111165e-03 -1.75646546e-05] with rsquare=0.9412327206071116
# -- constants: [-1.14545099e-01 -9.78315678e-04 -3.13718046e-05 -1.80337538e-03] with rsquare=0.9393615894860733
# ++ saving new profiles into folder: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\Corrections
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### check chromatic abbrevation, 750-647

# %%
ref_filename = os.path.join(ref_folder, fovs[1])
cc_filename = os.path.join(cc_folder, fovs[1])

# %%
# target image, not warpping
raw_ims, corr_funcs, drift = ia.io_tools.load.correct_fov_image(cc_filename, 
    [750, 488], 
    calculate_drift=True,
    ref_filename=ref_ims[-1],
    single_im_size=single_im_size,
    all_channels=all_colors,
    warp_image=False,
    illumination_corr=True,
    chromatic_corr=True,
    bleed_corr=False, 
    correction_folder=correction_folder,
    return_drift=True)
# Out:
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_01.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_40_2048_2048_const.pkl
# 	 647 None
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_01.dax  in 6.369s
# -- removing hot pixels for channels:['750', '488'] in 20.219s
# -- illumination correction for channels: 750, 488, in 4.266s
# -- apply bead_drift calculate for channel: 488
# -- aligning image -> directly use image
# -- directly use ref_image
# --- finish drift in 92.328s
# -- drift: [-0.21 -0.62  4.83]
# -- generate translation function for chromatic correction for channels: ['750'] and drift:[-0.21 -0.62  4.83] in 0.000s
# -- finish correction in 124.418s

# %%
# reference image
ref_ims, = ia.io_tools.load.correct_fov_image(ref_filename, 
    [647, 488], 
    single_im_size=single_im_size,
    all_channels=all_colors,
    warp_image=True,
    illumination_corr=True,
    chromatic_corr=False,
    bleed_corr=False, 
    correction_folder=correction_folder)

# target image, not warpping
raw_ims, corr_funcs, drift = ia.io_tools.load.correct_fov_image(cc_filename, 
    [750, 488], 
    calculate_drift=True,
    ref_filename=ref_ims[-1],
    single_im_size=single_im_size,
    all_channels=all_colors,
    warp_image=False,
    illumination_corr=True,
    chromatic_corr=True,
    bleed_corr=False, 
    correction_folder=correction_folder,
    return_drift=True)

# target image, warppring
corr_ims, = ia.io_tools.load.correct_fov_image(cc_filename, 
     [750, 488], 
     calculate_drift=False,
     drift=drift,
     ref_filename=ref_ims[-1],
     single_im_size=single_im_size,
     all_channels=all_colors,
     warp_image=True,
     illumination_corr=True,
     chromatic_corr=True, 
     bleed_corr=False, 
     correction_folder=correction_folder,
     return_drift=False)
# Out:
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H2R2_Cy5\Conv_zscan_01.dax
# -- loading illumination correction profile from file:
# 	 647 illumination_correction_647_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H2R2_Cy5\Conv_zscan_01.dax  in 5.781s
# -- removing hot pixels for channels:['647', '488'] in 14.484s
# -- illumination correction for channels: 647, 488, in 3.078s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 24.536s
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_01.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 488 illumination_correction_488_2048x2048.npy
# -- loading chromatic_constants correction profile from file:
# 	 750 chromatic_correction_750_647_40_2048_2048_const.pkl
# 	 647 None
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_01.dax  in 5.547s
# -- removing hot pixels for channels:['750', '488'] in 15.266s
# -- illumination correction for channels: 750, 488, in 2.928s
# -- apply bead_drift calculate for channel: 488
# -- aligning image -> directly use image
# -- directly use ref_image
# --- finish drift in 71.852s
# -- drift: [-0.21 -0.62  4.83]
# -- generate translation function for chromatic correction for channels: ['750'] and drift:[-0.21 -0.62  4.83] in 0.000s
# -- finish correction in 96.384s
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_01.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# -- loading chromatic correction profile from file:
# 	 750 chromatic_correction_750_647_40_2048_2048.npy
# 	 647 None
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_01.dax  in 5.702s
# -- removing hot pixels for channels:['750'] in 10.281s
# -- illumination correction for channels: 750, in 2.118s
# -- warp image with chromatic correction for channels: ['750'] and drift:[-0.21 -0.62  4.83] 750, in 143.185s
# -- finish correction in 184.219s

# %%
reload(correction_tools.alignment)
correction_tools.alignment.align_image(corr_ims[-1], ref_ims[-1], use_autocorr=True, 
                                       correction_args={'single_im_size': single_im_size}, detailed_verbose=True)
# Out:
# -- start aligning given source image to given reference image.
# --- use auto correlation to calculate drift.
# --- align image 0 in 4.937s.
# --- drift: [ 0.03 -0.02  0.03]
# --- use auto correlation to calculate drift.
# --- align image 1 in 4.953s.
# --- drift: [-0.12  0.15 -0.03]
# --- use auto correlation to calculate drift.
# --- align image 2 in 5.000s.
# --- drift: [0.02 0.   0.05]
# --- drifts for [0 1 2] pass the thresold, exit cycle.
# array([-0.02333333,  0.04333333,  0.01666667])

# %%
reload(correction_tools.alignment)
correction_tools.alignment.align_image(raw_ims[-1], ref_ims[-1], use_autocorr=False, 
                                       correction_args={'single_im_size': single_im_size}, detailed_verbose=True)
# Out:
# -- start aligning given source image to given reference image.
# --- use beads fitting to calculate drift.
# -- start fitting spots in channel:488, 40 seeded,
# E:\Users\puzheng\anaconda3\lib\site-packages\scipy\optimize\minpack.py:475: RuntimeWarning: Number of calls to function has reached maxfev = 1000.
#   warnings.warn(errors[info][0], RuntimeWarning)
# 40 fitted in 7.406s.
# -- start fitting spots in channel:488, 157 seeded,
# E:\Users\puzheng\Documents\ImageAnalysis3\External\Fitting_v4.py:285: RuntimeWarning: overflow encountered in exp
#   self.f = np.exp(bk)+self.f0
# 157 fitted in 5.656s.
# -- 156 among 157 centers are selected by th=2.0
# -- aligning 40 centers to 156 ref_centers, given drift:[  3. -12.  29.], 0 pairs found, updated_drift:nan
# before check: nan 0
# --- align image 0 in 13.516s.
# --- drift: nan
# --- use beads fitting to calculate drift.
# -- start fitting spots in channel:488,
# E:\Users\puzheng\Documents\ImageAnalysis3\spot_tools\matching.py:207: RuntimeWarning: Mean of empty slice
#   _new_drift = np.nanmean(_paired_tar_cts - _paired_ref_cts, axis=0)
# E:\Users\puzheng\Documents\ImageAnalysis3\correction_tools\alignment.py:678: RuntimeWarning: Mean of empty slice
#   _mean_dft = np.nanmean(_drifts, axis=0)
# 33 seeded, 33 fitted in 5.813s.
# -- start fitting spots in channel:488, 140 seeded, 140 fitted in 5.453s.
# -- 140 among 140 centers are selected by th=2.0
# -- aligning 33 centers to 140 ref_centers, given drift:[  3.  13. 222.], 0 pairs found, updated_drift:nan
# before check: nan 0
# --- align image 1 in 11.719s.
# --- drift: nan
# --- use beads fitting to calculate drift.
# -- start fitting spots in channel:488, 14 seeded, 14 fitted in 5.189s.
# -- start fitting spots in channel:488, 159 seeded, 159 fitted in 5.759s.
# -- 159 among 159 centers are selected by th=2.0
# -- aligning 14 centers to 159 ref_centers, given drift:[3. 0. 0.], 0 pairs found, updated_drift:nan
# before check: nan 0
# --- align image 2 in 11.422s.
# --- drift: nan
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-38-0eb4779496f4> in <module>()
#       1 reload(correction_tools.alignment)
#       2 correction_tools.alignment.align_image(raw_ims[-1], ref_ims[-1], use_autocorr=False,
# ----> 3                                        correction_args={'single_im_size': single_im_size}, detailed_verbose=True)
#
# E:\Users\puzheng\Documents\ImageAnalysis3\correction_tools\alignment.py in align_image(src_im, ref_im, crop_list, use_autocorr, precision_fold, min_good_drifts, drift_diff_th, all_channels, ref_all_channels, drift_channel, correction_args, fitting_args, match_distance_th, verbose, detailed_verbose)
#     678         _mean_dft = np.nanmean(_drifts, axis=0)
#     679         if len(_drifts) >= min_good_drifts:
# --> 680             _dists = np.linalg.norm(_drifts-_mean_dft, axis=1)
#     681             _kept_drift_inds = np.where(_dists <= drift_diff_th)[0]
#     682             if len(_kept_drift_inds) >= min_good_drifts:
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# E:\Users\puzheng\anaconda3\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2559             # special case for speedup
#    2560             s = (x.conj() * x).real
# -> 2561             return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2562         # None of the str-type keywords for ord ('fro', 'nuc')
#    2563         # are valid for vectors
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
reload(correction_tools.alignment)
correction_tools.alignment.align_image(corr_ims[-1], ref_ims[-1], use_autocorr=True, 
                                       correction_args={'single_im_size': single_im_size})
# Out:
# -- start aligning given source image to given reference image.
# --- use auto correlation to calculate drift.
# --- align image 0 in 5.015s.
# --- use auto correlation to calculate drift.
# --- align image 1 in 5.031s.
# --- use auto correlation to calculate drift.
# --- align image 2 in 5.047s.
# array([-0.02333333,  0.04333333,  0.01666667])

# %%
correction_tools.alignment.align_image(corr_ims[-1], ref_ims[-1], use_autocorr=False, 
                                       correction_args={'single_im_size': single_im_size})
# Out:
# -- start aligning given source image to given reference image.
# E:\Users\puzheng\Documents\ImageAnalysis3\External\Fitting_v4.py:285: RuntimeWarning: overflow encountered in exp
#   self.f = np.exp(bk)+self.f0
# before check: [ 0.07955991  0.04270659 -0.00431055] 151
# --- align image 0 in 12.149s.
# before check: [-0.1298588   0.15000343 -0.04635264] 139
# --- align image 1 in 11.930s.
# before check: [0.01503202 0.01641369 0.04315543] 158
# --- align image 2 in 12.366s.
# array([-0.01419497,  0.07237547,  0.01145366])

# %%
# %matplotlib notebook
visual_tools.imshow_mark_3d_v2([corr_ims[-1], ref_ims[-1]])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# %matplotlib notebook
visual_tools.imshow_mark_3d_v2([raw_ims[0], corr_ims[0], ref_ims[0]])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
corr_funcs[0]
# Out:
# <function ImageAnalysis3.correction_tools.chromatic.generate_chromatic_function.<locals>._shift_function>

# %%
reload(ia.io_tools.load)
reload(ia.correction_tools.chromatic)
from ImageAnalysis3.spot_tools.fitting import fit_fov_image
# fitting
int_th = 300

# warpped image
corr_spots = fit_fov_image(corr_ims[0], '750', th_seed=200, normalize_background=False)
# original image
raw_spots = fit_fov_image(raw_ims[0], '750', th_seed=200, normalize_background=False)
# reference
ref_spots = fit_fov_image(ref_ims[0], '647', th_seed=300, normalize_background=False)

corr_spots = corr_spots[corr_spots[:,0] >= int_th]
raw_spots = raw_spots[raw_spots[:,0] >= int_th]
corr_raw_spots = corr_funcs[0](raw_spots)
ref_spots = ref_spots[ref_spots[:,0] >= int_th]
# Out:
# -- start fitting spots in channel:750, 49 seeded,
# E:\Users\puzheng\Documents\ImageAnalysis3\External\Fitting_v4.py:285: RuntimeWarning: overflow encountered in exp
#   self.f = np.exp(bk)+self.f0
# 49 fitted in 252.780s.
# -- start fitting spots in channel:750, 54 seeded, 54 fitted in 256.339s.
# -- start fitting spots in channel:647, 363 seeded, 363 fitted in 250.656s.

# %%
int_th = 500
corr_spots = corr_spots[corr_spots[:,0] >= int_th]
raw_spots = raw_spots[raw_spots[:,0] >= int_th]
corr_raw_spots = corr_funcs[0](raw_spots)
ref_spots = ref_spots[ref_spots[:,0] >= int_th]

# %%
# visualize_all_chromosomes
# %matplotlib notebook
# %matplotlib notebook

## visualize
coord_dict = {'coords':[],
              'class_ids':[],
             }
coord_dict['coords'] += list(np.flipud(_spot[1:4]) for _spot in raw_spots)
coord_dict['class_ids'] += list(0 * np.ones(len(raw_spots),dtype=np.int))

coord_dict['coords'] += list(np.flipud(_spot[1:4]) for _spot in corr_spots)
coord_dict['class_ids'] += list(1 * np.ones(len(corr_spots),dtype=np.int))

coord_dict['coords'] += list(np.flipud(_spot[1:4]) for _spot in ref_spots[ref_spots[:,0] > 1000])
coord_dict['class_ids'] += list(2 * np.ones(len(ref_spots[ref_spots[:,0] > 1000]),dtype=np.int))



fig=plt.figure(figsize=(4,5), dpi=150)    
    
visual_tools.imshow_mark_3d_v2([raw_ims[0], corr_ims[0], ref_ims[0]],
                               fig=fig,
                               given_dic=coord_dict,
                               save_file=None,
                               )
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure(figsize=(6,6),dpi=100)
plt.plot(ref_spots[ref_spots[:,0] > 1000,1], ref_spots[ref_spots[:,0] > 1000,3], 'bx', label='ref')
plt.plot(corr_spots[:,1], corr_spots[:,3], 'r.', label='warp image')
plt.plot(corr_raw_spots[:,1], corr_raw_spots[:,3], 'g.', label='translate spots')
plt.plot(raw_spots[:,1]+drift[1], raw_spots[:,3]+drift[2], 'y.', label='drifted')

plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure(figsize=(6,6),dpi=100)
plt.plot(ref_spots[:,2], ref_spots[:,3], 'bx', label='ref')
plt.plot(corr_spots[:,2], corr_spots[:,3], 'r.', label='warp image')
plt.plot(corr_raw_spots[:,2], corr_raw_spots[:,3], 'g.', label='translate spots')
plt.plot(raw_spots[:,2]+drift[1], raw_spots[:,3]+drift[2], 'y.', label='drifted')

plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from ImageAnalysis3.spot_tools.matching import find_paired_centers, check_paired_centers

# matching
_new_drift, paired_ref_cts, paired_corr_cts = find_paired_centers(ref_spots[:,1:4], corr_spots[:,1:4], drift=drift)
print(_new_drift)
_new_drift, paired_ref_cts, paired_corr_cts = check_paired_centers(paired_ref_cts, paired_corr_cts+drift)
print(_new_drift)
# Out:
# nan
# E:\Users\puzheng\Documents\ImageAnalysis3\spot_tools\matching.py:207: RuntimeWarning: Mean of empty slice
#   _new_drift = np.nanmean(_paired_tar_cts - _paired_ref_cts, axis=0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f059a8dce117> in <module>
#       4 _new_drift, paired_ref_cts, paired_corr_cts = find_paired_centers(ref_spots[:,1:4], corr_spots[:,1:4], drift=drift)
#       5 print(_new_drift)
# ----> 6 _new_drift, paired_ref_cts, paired_corr_cts = check_paired_centers(paired_ref_cts, paired_corr_cts+drift)
#       7 print(_new_drift)
#
# ValueError: operands could not be broadcast together with shapes (0,) (3,)

# %% [markdown]
# ## visualize

# %%
# %matplotlib notebook
visual_tools.imshow_mark_3d_v2([raw_ims[0], corr_ims[0], ref_ims[0]])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# # bleedthrough correction

# %%
from ImageAnalysis3 import _image_size, _correction_folder, _allowed_colors
reload(correction_tools.bleedthrough)
from ImageAnalysis3.correction_tools.bleedthrough import find_bleedthrough_pairs, interploate_bleedthrough_correction_from_channel
import multiprocessing as mp
from ImageAnalysis3.correction_tools.chromatic import generate_polynomial_data


bleedthrough_channels=['750', '647']

bleedthrough_correction_args = {
    'correction_folder': _correction_folder,
    'single_im_size':single_im_size,
    'all_channels':all_colors,
    'corr_channels':['750','647'],
    'bleed_corr':False,
    'illumination_corr':False,
    'chromatic_corr':False,
}

bleedthrough_fitting_args = {'max_num_seeds':1000,
    'th_seed': 300,
    'use_dynamic_th':True,
}
reload(correction_tools.bleedthrough)
# Out:
# <module 'ImageAnalysis3.correction_tools.bleedthrough' from 'E:\\Users\\puzheng\\Documents\\ImageAnalysis3\\correction_tools\\bleedthrough.py'>

# %%
info_dicts
# Out:
# [{'coord': array([  18.055817, 1025.7837  , 1188.0149  ], dtype=float32),
#   'ref_im': array([[[ 354,  319,  411,  381,  342,  384,  333,  386,  331],
#           [ 398,  331,  390,  374,  376,  427,  361,  336,  359],
#           [ 363,  315,  352,  341,  361,  367,  349,  335,  344],
#           [ 322,  318,  297,  305,  332,  374,  329,  336,  311],
#           [ 330,  338,  358,  342,  305,  315,  334,  349,  352],
#           [ 314,  324,  320,  312,  326,  329,  339,  354,  325],
#           [ 365,  305,  338,  320,  316,  320,  335,  353,  335],
#           [ 354,  288,  294,  374,  365,  340,  308,  319,  293],
#           [ 341,  325,  305,  316,  356,  286,  322,  356,  372]],
#
#          [[ 400,  379,  389,  436,  493,  492,  439,  437,  378],
#           [ 395,  434,  376,  485,  582,  622,  577,  426,  383],
#           [ 398,  451,  484,  537,  573,  697,  619,  558,  417],
#           [ 383,  459,  514,  550,  577,  552,  533,  498,  406],
#           [ 395,  484,  486,  506,  505,  476,  494,  420,  380],
#           [ 424,  474,  467,  455,  465,  405,  457,  424,  423],
#           [ 362,  411,  438,  369,  431,  426,  470,  404,  421],
#           [ 375,  379,  448,  438,  450,  464,  470,  425,  348],
#           [ 326,  351,  431,  389,  365,  433,  367,  353,  313]],
#
#          [[ 326,  362,  369,  465,  468,  504,  464,  355,  330],
#           [ 347,  461,  493,  497,  724,  710,  663,  499,  411],
#           [ 445,  556,  571,  699,  828,  812,  721,  536,  481],
#           [ 454,  584,  679,  838,  871,  847,  712,  511,  488],
#           [ 461,  636,  671,  835,  870,  760,  611,  545,  460],
#           [ 418,  567,  644,  722,  726,  645,  561,  467,  407],
#           [ 406,  484,  541,  542,  609,  493,  524,  436,  410],
#           [ 344,  382,  448,  534,  556,  536,  475,  434,  373],
#           [ 321,  381,  423,  437,  438,  441,  466,  382,  296]],
#
#          [[ 266,  289,  338,  370,  416,  400,  390,  283,  244],
#           [ 291,  341,  422,  578,  628,  626,  584,  446,  331],
#           [ 392,  432,  618,  796,  996,  932,  738,  521,  367],
#           [ 461,  555,  823, 1253, 1419, 1285,  913,  499,  359],
#           [ 441,  615, 1003, 1410, 1567, 1422, 1001,  509,  361],
#           [ 403,  571,  848, 1172, 1313, 1188,  795,  468,  368],
#           [ 370,  440,  585,  742,  808,  796,  597,  447,  372],
#           [ 362,  387,  473,  519,  548,  563,  480,  429,  309],
#           [ 287,  360,  417,  425,  432,  380,  408,  327,  284]],
#
#          [[ 253,  264,  285,  337,  311,  373,  360,  330,  246],
#           [ 238,  361,  343,  448,  555,  556,  434,  357,  358],
#           [ 372,  440,  542,  825,  960,  889,  664,  415,  401],
#           [ 444,  577,  838, 1334, 1559, 1374,  845,  487,  379],
#           [ 379,  657, 1080, 1681, 1959, 1648,  986,  515,  340],
#           [ 284,  606,  872, 1394, 1641, 1436,  951,  488,  325],
#           [ 307,  437,  613,  865,  969,  890,  676,  403,  289],
#           [ 291,  319,  363,  487,  536,  537,  460,  324,  303],
#           [ 282,  302,  317,  368,  377,  365,  330,  295,  260]],
#
#          [[ 251,  279,  258,  300,  320,  321,  307,  292,  273],
#           [ 250,  263,  349,  395,  415,  388,  396,  320,  357],
#           [ 322,  445,  640,  611,  763,  720,  534,  419,  402],
#           [ 338,  569,  824, 1143, 1396, 1123,  714,  440,  349],
#           [ 398,  575, 1040, 1480, 1742, 1455,  980,  493,  360],
#           [ 346,  505,  852, 1278, 1574, 1308,  912,  501,  314],
#           [ 263,  385,  544,  849, 1059,  853,  652,  434,  313],
#           [ 261,  280,  391,  487,  551,  487,  466,  326,  281],
#           [ 246,  271,  318,  352,  327,  331,  297,  304,  232]],
#
#          [[ 292,  291,  275,  327,  323,  304,  310,  314,  266],
#           [ 316,  315,  329,  387,  421,  417,  308,  351,  325],
#           [ 352,  417,  451,  523,  622,  610,  482,  400,  332],
#           [ 329,  478,  608,  735,  863,  817,  628,  488,  378],
#           [ 352,  466,  708,  824, 1001,  880,  663,  451,  427],
#           [ 359,  462,  626,  789,  848,  810,  657,  467,  357],
#           [ 307,  369,  471,  585,  653,  558,  516,  375,  348],
#           [ 285,  307,  363,  460,  483,  472,  381,  345,  339],
#           [ 283,  267,  305,  312,  344,  356,  334,  300,  280]],
#
#          [[ 260,  277,  271,  320,  331,  303,  286,  314,  285],
#           [ 264,  314,  352,  367,  370,  359,  371,  305,  305],
#           [ 313,  356,  413,  467,  433,  495,  427,  447,  327],
#           [ 340,  378,  468,  451,  503,  550,  490,  452,  343],
#           [ 354,  426,  521,  541,  548,  593,  490,  479,  394],
#           [ 295,  417,  467,  501,  528,  511,  473,  397,  375],
#           [ 334,  409,  427,  440,  441,  438,  455,  394,  333],
#           [ 303,  325,  400,  410,  363,  361,  387,  338,  296],
#           [ 247,  265,  290,  306,  326,  336,  271,  303,  285]],
#
#          [[ 279,  271,  310,  298,  286,  329,  278,  296,  310],
#           [ 228,  289,  324,  312,  330,  356,  348,  310,  284],
#           [ 261,  289,  351,  367,  387,  375,  429,  351,  336],
#           [ 303,  415,  399,  423,  415,  422,  389,  347,  326],
#           [ 298,  385,  378,  427,  459,  408,  376,  358,  316],
#           [ 297,  350,  355,  409,  450,  371,  392,  357,  357],
#           [ 264,  282,  329,  352,  380,  392,  360,  340,  335],
#           [ 248,  301,  296,  336,  345,  308,  348,  296,  311],
#           [ 232,  261,  277,  293,  263,  307,  276,  274,  280]]],
#         dtype=uint16),
#   'bleed_im': array([[[ 733,  756,  783,  782,  677,  806,  702,  717,  803],
#           [ 742,  769,  776,  688,  795,  795,  767,  756,  726],
#           [ 799,  781,  729,  775,  726,  811,  792,  726,  737],
#           [ 796,  813,  783,  811,  752,  765,  801,  735,  736],
#           [ 760,  745,  801,  763,  794,  779,  758,  723,  773],
#           [ 742,  738,  749,  720,  716,  658,  739,  771,  753],
#           [ 849,  771,  778,  755,  751,  696,  735,  796,  807],
#           [ 754,  734,  727,  742,  772,  745,  755,  772,  759],
#           [ 777,  742,  769,  807,  750,  774,  762,  727,  720]],
#
#          [[ 754,  698,  726,  783,  792,  786,  725,  754,  737],
#           [ 715,  740,  752,  808,  794,  815,  767,  809,  719],
#           [ 791,  790,  763,  799,  846,  815,  796,  751,  765],
#           [ 832,  756,  760,  828,  794,  814,  858,  726,  759],
#           [ 819,  736,  821,  764,  804,  735,  791,  764,  704],
#           [ 804,  751,  835,  758,  732,  845,  778,  678,  814],
#           [ 791,  743,  762,  759,  757,  782,  767,  759,  776],
#           [ 684,  682,  737,  792,  748,  843,  741,  782,  761],
#           [ 709,  671,  794,  764,  765,  746,  697,  722,  735]],
#
#          [[ 701,  775,  743,  784,  734,  774,  824,  710,  735],
#           [ 760,  724,  759,  796,  863,  865,  770,  807,  795],
#           [ 809,  846,  760,  897,  909,  912,  870,  825,  785],
#           [ 715,  769,  847,  884,  866,  871,  881,  741,  807],
#           [ 746,  787,  838,  879,  810,  856,  796,  800,  717],
#           [ 783,  808,  816,  781,  764,  905,  740,  777,  770],
#           [ 749,  757,  743,  768,  819,  853,  771,  766,  761],
#           [ 763,  744,  776,  819,  766,  846,  839,  776,  739],
#           [ 751,  737,  803,  804,  841,  786,  675,  778,  788]],
#
#          [[ 757,  705,  721,  857,  778,  800,  775,  734,  752],
#           [ 697,  778,  751,  800,  840,  882,  796,  787,  728],
#           [ 696,  803,  851,  834,  940,  937,  826,  753,  674],
#           [ 812,  810,  822, 1019, 1046, 1019,  858,  755,  697],
#           [ 804,  879,  905,  992,  962, 1032,  893,  794,  714],
#           [ 717,  851,  844,  891,  971,  948,  830,  765,  801],
#           [ 676,  769,  842,  876,  860,  913,  824,  723,  737],
#           [ 746,  756,  732,  786,  803,  837,  693,  784,  734],
#           [ 694,  773,  746,  759,  753,  738,  753,  751,  728]],
#
#          [[ 714,  689,  713,  807,  685,  757,  671,  690,  758],
#           [ 721,  708,  780,  731,  743,  736,  771,  744,  764],
#           [ 858,  734,  834,  918,  944,  898,  810,  751,  735],
#           [ 746,  829,  954,  987,  987,  963,  935,  792,  745],
#           [ 745,  847,  944,  988, 1100, 1069,  960,  808,  698],
#           [ 762,  801,  888, 1088, 1054,  974,  818,  788,  766],
#           [ 691,  684,  876,  887,  940,  920,  729,  761,  713],
#           [ 760,  753,  754,  774,  851,  751,  731,  783,  676],
#           [ 766,  724,  767,  759,  748,  737,  779,  763,  730]],
#
#          [[ 710,  817,  724,  763,  737,  748,  752,  779,  751],
#           [ 724,  852,  762,  746,  748,  813,  763,  770,  808],
#           [ 680,  748,  834,  834,  853,  867,  671,  772,  761],
#           [ 731,  791,  857,  940,  993,  864,  797,  785,  682],
#           [ 753,  755,  826,  969, 1059,  975,  866,  774,  815],
#           [ 699,  755,  876, 1036,  962,  953,  901,  773,  741],
#           [ 740,  737,  843,  758,  820,  832,  846,  763,  701],
#           [ 731,  761,  717,  795,  771,  706,  781,  731,  733],
#           [ 750,  731,  763,  785,  774,  754,  787,  678,  769]],
#
#          [[ 739,  746,  679,  813,  740,  779,  772,  719,  731],
#           [ 658,  679,  716,  793,  813,  785,  744,  731,  763],
#           [ 748,  778,  839,  776,  772,  760,  810,  754,  755],
#           [ 769,  803,  766,  890,  875,  849,  886,  786,  789],
#           [ 736,  761,  823,  882,  977,  937,  855,  776,  716],
#           [ 743,  810,  774,  895,  928,  841,  817,  768,  833],
#           [ 793,  762,  792,  798,  794,  785,  843,  752,  741],
#           [ 767,  772,  706,  796,  752,  752,  802,  737,  715],
#           [ 720,  727,  775,  746,  727,  786,  803,  721,  756]],
#
#          [[ 724,  753,  733,  726,  688,  754,  759,  767,  701],
#           [ 761,  768,  817,  758,  738,  791,  731,  723,  711],
#           [ 743,  781,  734,  778,  795,  761,  733,  796,  751],
#           [ 683,  687,  753,  775,  835,  729,  769,  755,  710],
#           [ 738,  739,  765,  742,  865,  763,  809,  737,  680],
#           [ 707,  759,  757,  881,  846,  712,  773,  756,  778],
#           [ 685,  722,  716,  812,  822,  717,  729,  769,  831],
#           [ 735,  716,  759,  727,  752,  799,  709,  764,  779],
#           [ 736,  749,  735,  747,  698,  757,  717,  729,  748]],
#
#          [[ 750,  732,  779,  771,  673,  782,  696,  717,  713],
#           [ 778,  733,  718,  742,  712,  771,  701,  703,  737],
#           [ 673,  763,  816,  773,  785,  749,  738,  778,  798],
#           [ 727,  809,  773,  738,  781,  772,  721,  760,  771],
#           [ 741,  713,  690,  783,  724,  742,  762,  808,  787],
#           [ 741,  763,  774,  770,  773,  788,  733,  790,  759],
#           [ 675,  713,  739,  808,  742,  784,  778,  702,  791],
#           [ 706,  650,  698,  829,  770,  739,  768,  786,  660],
#           [ 785,  724,  811,  792,  656,  735,  743,  766,  722]]],
#         dtype=uint16),
#   'rsquare': 0.685237654982664,
#   'slope': 0.22848710133406372,
#   'intercept': 671.0675987501511,
#   'file': '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H1R1_Cy7\\Conv_zscan_01.dax'},
#  {'coord': array([  33.226185, 1679.3699  , 1383.5443  ], dtype=float32),
#   'ref_im': array([[[ 264,  288,  307,  329,  332,  293,  280,  289,  264],
#           [ 294,  313,  314,  323,  340,  328,  313,  313,  297],
#           [ 282,  331,  334,  320,  295,  321,  324,  304,  289],
#           [ 285,  287,  324,  330,  324,  284,  281,  285,  276],
#           [ 283,  265,  290,  338,  326,  275,  300,  285,  280],
#           [ 281,  282,  271,  279,  273,  256,  262,  264,  286],
#           [ 302,  309,  250,  258,  251,  255,  256,  273,  261],
#           [ 277,  268,  265,  289,  282,  270,  276,  266,  249],
#           [ 267,  251,  277,  282,  262,  276,  287,  263,  256]],
#
#          [[ 278,  285,  328,  333,  364,  376,  328,  308,  269],
#           [ 278,  298,  376,  416,  394,  373,  371,  351,  323],
#           [ 310,  361,  395,  439,  440,  406,  363,  347,  329],
#           [ 287,  343,  419,  479,  506,  476,  391,  335,  318],
#           [ 261,  320,  410,  480,  492,  440,  414,  359,  317],
#           [ 274,  310,  356,  408,  443,  417,  349,  314,  303],
#           [ 264,  287,  296,  338,  331,  345,  324,  276,  280],
#           [ 255,  295,  327,  305,  293,  291,  294,  286,  267],
#           [ 270,  284,  316,  294,  292,  292,  291,  287,  262]],
#
#          [[ 261,  270,  332,  363,  365,  354,  330,  328,  264],
#           [ 281,  321,  392,  462,  469,  435,  355,  321,  287],
#           [ 317,  404,  491,  604,  638,  588,  438,  343,  339],
#           [ 322,  423,  569,  748,  847,  777,  565,  391,  349],
#           [ 316,  383,  601,  806,  910,  820,  542,  385,  336],
#           [ 300,  364,  505,  711,  757,  685,  513,  350,  332],
#           [ 269,  315,  395,  486,  524,  486,  396,  293,  255],
#           [ 249,  288,  335,  361,  347,  332,  328,  291,  260],
#           [ 233,  289,  317,  338,  291,  297,  344,  298,  259]],
#
#          [[ 206,  233,  281,  296,  293,  313,  275,  237,  231],
#           [ 243,  277,  359,  444,  483,  413,  324,  293,  245],
#           [ 281,  378,  553,  785,  834,  691,  496,  333,  281],
#           [ 280,  430,  707, 1127, 1313, 1120,  701,  380,  315],
#           [ 297,  410,  792, 1322, 1596, 1346,  761,  407,  320],
#           [ 259,  369,  653, 1113, 1292, 1031,  639,  354,  288],
#           [ 241,  280,  421,  673,  807,  620,  449,  360,  279],
#           [ 237,  258,  308,  330,  403,  374,  330,  300,  241],
#           [ 213,  287,  290,  278,  319,  298,  308,  291,  215]],
#
#          [[ 197,  231,  269,  248,  272,  302,  279,  259,  222],
#           [ 238,  263,  321,  404,  465,  408,  300,  246,  224],
#           [ 250,  330,  506,  802,  927,  735,  449,  290,  249],
#           [ 242,  384,  785, 1327, 1538, 1229,  703,  371,  293],
#           [ 267,  404,  862, 1619, 1916, 1493,  887,  455,  284],
#           [ 246,  372,  752, 1306, 1561, 1331,  821,  439,  293],
#           [ 221,  282,  476,  760,  895,  801,  550,  383,  270],
#           [ 227,  251,  305,  392,  439,  409,  367,  315,  240],
#           [ 226,  261,  264,  292,  324,  336,  375,  317,  247]],
#
#          [[ 216,  240,  290,  298,  329,  315,  284,  297,  255],
#           [ 226,  277,  353,  407,  423,  403,  379,  327,  279],
#           [ 257,  325,  459,  654,  762,  676,  469,  370,  301],
#           [ 315,  439,  676, 1073, 1249,  994,  635,  441,  336],
#           [ 312,  489,  860, 1332, 1557, 1296,  815,  503,  360],
#           [ 288,  390,  770, 1113, 1360, 1305,  791,  481,  351],
#           [ 267,  354,  507,  720,  856,  841,  599,  431,  331],
#           [ 259,  297,  341,  405,  480,  486,  414,  389,  317],
#           [ 243,  267,  328,  363,  379,  385,  391,  353,  311]],
#
#          [[ 250,  289,  320,  319,  357,  375,  327,  318,  289],
#           [ 307,  357,  390,  432,  445,  446,  424,  410,  312],
#           [ 350,  406,  479,  588,  611,  569,  508,  482,  379],
#           [ 381,  494,  585,  760,  795,  688,  618,  522,  407],
#           [ 389,  504,  609,  795,  888,  782,  635,  533,  429],
#           [ 322,  412,  550,  711,  785,  699,  550,  504,  430],
#           [ 305,  415,  442,  567,  604,  552,  523,  419,  371],
#           [ 294,  336,  382,  440,  468,  476,  455,  400,  345],
#           [ 287,  332,  373,  404,  429,  451,  441,  414,  348]],
#
#          [[ 283,  309,  347,  347,  329,  323,  341,  305,  305],
#           [ 353,  382,  370,  385,  414,  400,  374,  366,  323],
#           [ 382,  438,  448,  411,  425,  465,  441,  435,  347],
#           [ 393,  429,  463,  397,  361,  393,  486,  478,  386],
#           [ 383,  399,  392,  347,  312,  338,  408,  444,  426],
#           [ 332,  376,  383,  334,  317,  327,  335,  386,  386],
#           [ 326,  357,  305,  317,  305,  307,  324,  364,  350],
#           [ 296,  309,  298,  301,  284,  331,  344,  323,  308],
#           [ 293,  306,  317,  320,  322,  334,  317,  315,  298]],
#
#          [[ 311,  319,  317,  356,  323,  289,  300,  300,  328],
#           [ 290,  325,  354,  331,  317,  328,  332,  323,  335],
#           [ 310,  319,  355,  360,  357,  365,  340,  317,  308],
#           [ 351,  333,  326,  371,  349,  332,  345,  330,  330],
#           [ 323,  313,  310,  334,  333,  341,  336,  317,  306],
#           [ 287,  294,  306,  302,  308,  290,  301,  313,  287],
#           [ 272,  282,  284,  279,  262,  279,  281,  276,  278],
#           [ 266,  272,  259,  239,  238,  258,  272,  272,  272],
#           [ 255,  260,  244,  231,  273,  271,  266,  274,  262]]],
#         dtype=uint16),
#   'bleed_im': array([[[ 745,  693,  736,  688,  727,  728,  686,  683,  701],
#           [ 749,  748,  699,  682,  724,  742,  655,  748,  739],
#           [ 677,  723,  731,  759,  762,  733,  694,  721,  721],
#           [ 723,  695,  745,  766,  740,  706,  711,  700,  698],
#           [ 722,  715,  755,  687,  705,  756,  772,  739,  698],
#           [ 691,  736,  711,  679,  694,  728,  753,  748,  679],
#           [ 658,  680,  688,  699,  713,  718,  735,  712,  697],
#           [ 671,  700,  723,  728,  701,  742,  759,  712,  706],
#           [ 710,  706,  708,  734,  704,  757,  750,  719,  745]],
#
#          [[ 692,  721,  737,  742,  713,  719,  781,  717,  710],
#           [ 720,  776,  772,  708,  749,  762,  717,  748,  728],
#           [ 734,  797,  791,  753,  824,  795,  690,  768,  766],
#           [ 693,  745,  832,  848,  789,  780,  791,  746,  754],
#           [ 720,  699,  736,  782,  797,  781,  764,  714,  716],
#           [ 702,  700,  695,  701,  766,  768,  721,  713,  664],
#           [ 703,  705,  708,  711,  742,  725,  718,  742,  709],
#           [ 693,  717,  712,  724,  742,  737,  725,  688,  717],
#           [ 681,  717,  746,  734,  751,  751,  723,  673,  696]],
#
#          [[ 757,  739,  735,  781,  757,  706,  739,  714,  685],
#           [ 744,  795,  715,  728,  805,  769,  746,  703,  719],
#           [ 744,  732,  782,  788,  829,  824,  740,  708,  730],
#           [ 690,  717,  782,  881,  852,  818,  767,  743,  754],
#           [ 703,  753,  748,  860,  908,  868,  799,  737,  734],
#           [ 697,  737,  825,  850,  882,  843,  751,  711,  714],
#           [ 707,  722,  756,  769,  792,  777,  714,  691,  704],
#           [ 724,  725,  705,  730,  780,  747,  735,  667,  725],
#           [ 712,  730,  715,  693,  689,  703,  696,  656,  716]],
#
#          [[ 698,  695,  700,  710,  716,  703,  690,  707,  652],
#           [ 727,  753,  689,  753,  721,  693,  712,  731,  710],
#           [ 732,  706,  723,  872,  868,  818,  753,  768,  697],
#           [ 693,  716,  837,  920, 1027,  983,  839,  757,  699],
#           [ 675,  718,  826,  935, 1032, 1006,  867,  753,  703],
#           [ 707,  723,  844,  944,  980,  929,  748,  727,  727],
#           [ 672,  703,  771,  791,  842,  841,  770,  740,  679],
#           [ 737,  725,  711,  714,  762,  763,  758,  731,  679],
#           [ 739,  715,  732,  736,  690,  668,  691,  702,  709]],
#
#          [[ 721,  709,  672,  679,  713,  687,  774,  725,  631],
#           [ 729,  676,  666,  761,  709,  721,  730,  708,  670],
#           [ 687,  674,  718,  795,  851,  866,  769,  718,  709],
#           [ 718,  755,  798,  946, 1054,  964,  804,  728,  705],
#           [ 687,  760,  895, 1075, 1083,  968,  839,  704,  693],
#           [ 690,  732,  824,  968, 1056, 1009,  866,  738,  701],
#           [ 712,  720,  729,  783,  900,  873,  761,  757,  739],
#           [ 708,  693,  687,  725,  764,  780,  722,  706,  701],
#           [ 700,  694,  663,  730,  753,  745,  702,  721,  667]],
#
#          [[ 689,  688,  697,  729,  743,  702,  740,  747,  705],
#           [ 710,  744,  767,  756,  800,  789,  747,  799,  714],
#           [ 709,  743,  780,  770,  802,  838,  797,  736,  725],
#           [ 723,  767,  815,  899,  962,  892,  834,  760,  730],
#           [ 718,  765,  806,  991, 1043,  989,  901,  792,  742],
#           [ 735,  732,  829, 1002,  996,  945,  852,  775,  715],
#           [ 725,  665,  729,  865,  942,  917,  780,  733,  723],
#           [ 736,  678,  693,  768,  800,  754,  748,  743,  738],
#           [ 766,  734,  706,  725,  777,  748,  737,  777,  732]],
#
#          [[ 713,  666,  739,  745,  778,  740,  708,  746,  670],
#           [ 696,  711,  735,  789,  786,  752,  763,  739,  700],
#           [ 733,  755,  793,  820,  759,  803,  787,  711,  739],
#           [ 723,  785,  789,  845,  791,  808,  835,  734,  728],
#           [ 739,  751,  731,  828,  816,  795,  779,  730,  733],
#           [ 742,  761,  743,  743,  910,  843,  722,  779,  793],
#           [ 738,  763,  771,  726,  830,  855,  783,  783,  788],
#           [ 741,  711,  720,  775,  761,  733,  759,  702,  693],
#           [ 731,  716,  711,  724,  759,  737,  735,  741,  699]],
#
#          [[ 762,  751,  755,  723,  764,  762,  720,  676,  715],
#           [ 707,  750,  756,  738,  722,  759,  752,  701,  745],
#           [ 745,  736,  767,  784,  725,  813,  806,  718,  706],
#           [ 737,  739,  755,  702,  682,  722,  745,  707,  721],
#           [ 759,  760,  719,  707,  692,  673,  734,  734,  741],
#           [ 744,  701,  696,  704,  703,  712,  781,  724,  706],
#           [ 711,  716,  720,  756,  738,  693,  737,  758,  738],
#           [ 704,  720,  705,  745,  781,  709,  714,  776,  750],
#           [ 673,  707,  712,  693,  743,  710,  701,  763,  755]],
#
#          [[ 726,  756,  740,  722,  756,  755,  737,  717,  729],
#           [ 753,  765,  714,  767,  781,  736,  761,  742,  733],
#           [ 741,  754,  785,  779,  777,  775,  755,  752,  737],
#           [ 748,  753,  771,  678,  707,  706,  695,  719,  753],
#           [ 761,  772,  727,  732,  720,  738,  711,  726,  703],
#           [ 740,  715,  748,  790,  685,  684,  726,  719,  703],
#           [ 736,  697,  712,  727,  696,  658,  726,  761,  750],
#           [ 681,  730,  710,  705,  748,  719,  708,  745,  733],
#           [ 664,  726,  748,  718,  752,  719,  663,  719,  736]]],
#         dtype=uint16),
#   'rsquare': 0.8034268678524473,
#   'slope': 0.25392355983675785,
#   'intercept': 643.9763178139303,
#   'file': '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H1R1_Cy7\\Conv_zscan_01.dax'},
#  {'coord': array([ 17.87061, 923.307  , 771.3797 ], dtype=float32),
#   'ref_im': array([[[ 331,  345,  346,  332,  323,  307,  346,  371,  374],
#           [ 316,  330,  321,  296,  303,  325,  336,  357,  387],
#           [ 321,  314,  303,  283,  271,  271,  333,  355,  382],
#           [ 328,  341,  304,  287,  278,  302,  345,  361,  366],
#           [ 321,  343,  299,  313,  319,  302,  321,  385,  364],
#           [ 317,  341,  349,  334,  316,  301,  338,  373,  388],
#           [ 334,  360,  369,  382,  344,  335,  361,  343,  353],
#           [ 382,  382,  383,  415,  416,  363,  345,  364,  369],
#           [ 380,  366,  433,  411,  382,  386,  381,  360,  347]],
#
#          [[ 398,  412,  412,  444,  454,  446,  436,  384,  359],
#           [ 407,  416,  416,  404,  416,  422,  421,  432,  455],
#           [ 387,  429,  432,  396,  390,  431,  401,  457,  492],
#           [ 420,  430,  441,  453,  467,  437,  428,  477,  476],
#           [ 413,  460,  428,  421,  453,  467,  478,  453,  466],
#           [ 405,  454,  485,  441,  433,  456,  435,  444,  432],
#           [ 406,  428,  469,  527,  502,  476,  474,  471,  442],
#           [ 434,  454,  506,  550,  550,  538,  440,  413,  429],
#           [ 426,  423,  528,  598,  518,  527,  474,  383,  384]],
#
#          [[ 369,  415,  464,  436,  444,  440,  437,  361,  362],
#           [ 438,  531,  581,  460,  487,  484,  471,  434,  401],
#           [ 511,  544,  542,  564,  628,  617,  495,  455,  455],
#           [ 421,  441,  515,  698,  785,  711,  566,  495,  506],
#           [ 460,  511,  616,  763,  819,  674,  573,  528,  504],
#           [ 452,  474,  518,  665,  789,  672,  525,  472,  469],
#           [ 430,  497,  549,  597,  622,  570,  516,  478,  457],
#           [ 400,  472,  533,  589,  620,  559,  506,  432,  373],
#           [ 409,  443,  477,  565,  600,  524,  487,  401,  362]],
#
#          [[ 370,  391,  377,  331,  339,  347,  340,  316,  308],
#           [ 396,  427,  466,  479,  473,  448,  373,  329,  326],
#           [ 442,  436,  577,  805,  868,  707,  519,  403,  402],
#           [ 411,  490,  776, 1193, 1392, 1123,  694,  407,  378],
#           [ 392,  506,  853, 1379, 1596, 1323,  807,  473,  420],
#           [ 405,  470,  708, 1087, 1252, 1057,  743,  441,  372],
#           [ 334,  422,  584,  705,  826,  745,  570,  389,  340],
#           [ 338,  387,  492,  525,  521,  484,  416,  366,  358],
#           [ 341,  414,  461,  465,  457,  445,  373,  319,  329]],
#
#          [[ 329,  350,  372,  331,  270,  266,  319,  299,  310],
#           [ 405,  401,  381,  406,  456,  426,  334,  299,  298],
#           [ 389,  405,  522,  819,  925,  767,  530,  328,  305],
#           [ 354,  453,  785, 1332, 1535, 1244,  804,  390,  301],
#           [ 343,  478,  952, 1560, 1899, 1556,  884,  435,  346],
#           [ 337,  423,  792, 1320, 1596, 1301,  768,  438,  328],
#           [ 311,  421,  584,  723,  864,  735,  578,  405,  345],
#           [ 329,  357,  365,  433,  479,  453,  410,  311,  289],
#           [ 329,  323,  333,  385,  395,  429,  412,  304,  280]],
#
#          [[ 364,  362,  354,  310,  310,  316,  292,  313,  309],
#           [ 332,  392,  394,  431,  477,  408,  354,  354,  336],
#           [ 344,  372,  485,  679,  779,  723,  537,  399,  374],
#           [ 363,  451,  725, 1081, 1273, 1107,  781,  459,  365],
#           [ 389,  540,  875, 1232, 1500, 1349,  870,  518,  385],
#           [ 350,  474,  686, 1042, 1219, 1081,  803,  443,  361],
#           [ 310,  403,  557,  726,  867,  759,  538,  382,  365],
#           [ 315,  331,  357,  424,  489,  418,  361,  341,  335],
#           [ 308,  310,  306,  370,  375,  353,  326,  314,  294]],
#
#          [[ 322,  312,  379,  373,  313,  317,  339,  329,  325],
#           [ 349,  376,  380,  378,  434,  467,  390,  365,  344],
#           [ 335,  383,  468,  537,  583,  602,  481,  428,  401],
#           [ 342,  405,  542,  677,  748,  759,  666,  471,  415],
#           [ 352,  433,  572,  725,  851,  809,  693,  515,  431],
#           [ 340,  436,  611,  714,  737,  775,  677,  486,  442],
#           [ 323,  411,  499,  553,  607,  592,  482,  432,  405],
#           [ 302,  365,  380,  401,  429,  432,  405,  380,  350],
#           [ 330,  388,  378,  388,  412,  432,  365,  348,  327]],
#
#          [[ 334,  345,  376,  326,  331,  385,  332,  339,  335],
#           [ 357,  366,  361,  376,  423,  426,  368,  365,  339],
#           [ 366,  352,  398,  447,  462,  468,  415,  405,  377],
#           [ 332,  401,  452,  475,  517,  533,  528,  477,  438],
#           [ 315,  450,  460,  472,  534,  539,  547,  478,  434],
#           [ 333,  415,  434,  516,  519,  512,  555,  452,  401],
#           [ 353,  362,  448,  505,  494,  486,  489,  468,  399],
#           [ 317,  352,  392,  426,  443,  457,  408,  369,  358],
#           [ 294,  352,  406,  350,  377,  434,  385,  347,  326]],
#
#          [[ 309,  306,  333,  325,  328,  310,  328,  317,  305],
#           [ 285,  283,  338,  354,  368,  384,  354,  315,  316],
#           [ 268,  293,  320,  329,  356,  410,  394,  366,  392],
#           [ 286,  312,  352,  394,  424,  441,  431,  395,  381],
#           [ 302,  354,  364,  436,  489,  444,  455,  440,  387],
#           [ 331,  350,  364,  428,  492,  462,  450,  436,  412],
#           [ 328,  321,  353,  442,  426,  437,  417,  399,  406],
#           [ 349,  352,  373,  377,  396,  370,  360,  351,  351],
#           [ 360,  369,  356,  346,  370,  335,  300,  339,  338]]],
#         dtype=uint16),
#   'bleed_im': array([[[ 722,  708,  799,  712,  636,  743,  704,  670,  690],
#           [ 691,  734,  695,  700,  708,  669,  682,  717,  698],
#           [ 778,  715,  689,  739,  680,  676,  739,  734,  693],
#           [ 759,  718,  700,  673,  718,  709,  742,  733,  712],
#           [ 718,  726,  745,  690,  662,  715,  739,  749,  770],
#           [ 680,  723,  718,  707,  732,  711,  715,  719,  707],
#           [ 713,  690,  751,  761,  756,  707,  689,  690,  760],
#           [ 726,  727,  695,  735,  759,  722,  712,  718,  765],
#           [ 712,  680,  700,  742,  725,  729,  757,  733,  734]],
#
#          [[ 756,  728,  759,  741,  692,  758,  704,  700,  694],
#           [ 715,  710,  713,  690,  757,  759,  716,  706,  721],
#           [ 693,  743,  712,  780,  703,  685,  779,  717,  759],
#           [ 732,  790,  737,  712,  718,  735,  771,  748,  729],
#           [ 702,  757,  720,  703,  771,  749,  756,  747,  710],
#           [ 760,  762,  687,  743,  723,  734,  765,  713,  704],
#           [ 733,  789,  748,  689,  699,  768,  784,  731,  731],
#           [ 704,  715,  781,  768,  725,  743,  764,  727,  721],
#           [ 717,  754,  739,  790,  707,  719,  755,  760,  743]],
#
#          [[ 713,  713,  744,  764,  730,  756,  735,  739,  750],
#           [ 760,  727,  749,  766,  814,  814,  741,  749,  732],
#           [ 744,  718,  771,  815,  792,  780,  755,  745,  752],
#           [ 681,  789,  775,  805,  774,  749,  744,  777,  777],
#           [ 722,  748,  733,  826,  798,  744,  715,  773,  755],
#           [ 703,  743,  800,  748,  829,  806,  795,  755,  724],
#           [ 770,  791,  796,  786,  731,  735,  773,  768,  734],
#           [ 695,  690,  770,  794,  749,  793,  764,  726,  713],
#           [ 699,  690,  736,  780,  715,  747,  810,  750,  745]],
#
#          [[ 767,  707,  789,  816,  685,  689,  711,  682,  658],
#           [ 703,  745,  766,  760,  748,  763,  774,  719,  709],
#           [ 736,  750,  784,  815,  790,  777,  836,  767,  711],
#           [ 738,  740,  833,  935,  955,  945,  793,  743,  736],
#           [ 712,  744,  827,  965, 1032,  900,  832,  795,  745],
#           [ 719,  717,  848,  907,  956,  904,  751,  737,  759],
#           [ 743,  726,  778,  813,  839,  847,  707,  699,  733],
#           [ 696,  771,  709,  743,  737,  724,  763,  716,  714],
#           [ 711,  760,  757,  740,  735,  760,  754,  686,  685]],
#
#          [[ 761,  737,  723,  736,  680,  673,  719,  704,  692],
#           [ 713,  674,  685,  768,  766,  675,  730,  700,  665],
#           [ 756,  720,  793,  875,  844,  796,  740,  698,  697],
#           [ 720,  746,  918,  995, 1016,  987,  820,  754,  716],
#           [ 748,  728,  837, 1033, 1111, 1038,  807,  755,  774],
#           [ 736,  737,  857,  950,  987,  985,  811,  733,  749],
#           [ 723,  711,  734,  817,  881,  803,  766,  723,  732],
#           [ 726,  694,  723,  723,  734,  733,  729,  721,  748],
#           [ 706,  673,  704,  695,  736,  728,  716,  748,  745]],
#
#          [[ 679,  690,  691,  708,  681,  658,  723,  693,  684],
#           [ 705,  697,  703,  715,  739,  743,  775,  707,  694],
#           [ 735,  754,  760,  802,  819,  832,  743,  771,  746],
#           [ 715,  718,  789,  866,  909,  949,  802,  705,  732],
#           [ 659,  734,  863,  971,  908,  942,  872,  742,  701],
#           [ 723,  718,  763,  856,  864,  851,  814,  742,  671],
#           [ 748,  732,  744,  720,  776,  852,  809,  720,  727],
#           [ 706,  672,  737,  726,  709,  819,  782,  712,  697],
#           [ 756,  661,  710,  750,  745,  777,  731,  665,  676]],
#
#          [[ 672,  703,  719,  756,  735,  731,  655,  711,  747],
#           [ 666,  730,  741,  765,  772,  748,  724,  735,  739],
#           [ 657,  724,  697,  750,  786,  775,  826,  750,  715],
#           [ 711,  736,  724,  791,  857,  858,  765,  748,  737],
#           [ 700,  756,  730,  799,  844,  834,  773,  787,  795],
#           [ 733,  818,  791,  830,  856,  847,  759,  745,  751],
#           [ 718,  774,  758,  759,  770,  794,  800,  775,  731],
#           [ 701,  704,  703,  768,  769,  755,  773,  752,  730],
#           [ 721,  683,  692,  796,  770,  732,  722,  693,  735]],
#
#          [[ 677,  667,  687,  735,  675,  697,  762,  731,  673],
#           [ 690,  732,  694,  646,  735,  767,  683,  690,  723],
#           [ 722,  711,  742,  775,  736,  766,  730,  722,  782],
#           [ 715,  743,  777,  752,  771,  818,  780,  700,  713],
#           [ 676,  727,  761,  724,  801,  774,  764,  719,  706],
#           [ 681,  713,  736,  802,  746,  716,  767,  762,  726],
#           [ 733,  743,  784,  746,  718,  722,  693,  779,  754],
#           [ 707,  731,  744,  766,  735,  768,  706,  745,  729],
#           [ 702,  720,  717,  764,  730,  720,  724,  738,  704]],
#
#          [[ 728,  690,  706,  669,  683,  700,  717,  706,  716],
#           [ 746,  700,  720,  724,  659,  666,  723,  759,  744],
#           [ 701,  697,  743,  750,  779,  733,  724,  743,  717],
#           [ 683,  719,  675,  697,  728,  741,  760,  721,  738],
#           [ 734,  718,  624,  721,  744,  703,  771,  783,  792],
#           [ 699,  719,  701,  696,  761,  738,  750,  772,  757],
#           [ 692,  760,  765,  688,  689,  652,  706,  711,  652],
#           [ 679,  733,  760,  697,  703,  698,  719,  700,  662],
#           [ 652,  721,  709,  670,  692,  743,  736,  710,  688]]],
#         dtype=uint16),
#   'rsquare': 0.7298898666560274,
#   'slope': 0.23852850304124512,
#   'intercept': 633.3826162132549,
#   'file': '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H1R1_Cy7\\Conv_zscan_01.dax'},
#  {'coord': array([  20.717787, 1166.9214  , 1339.4932  ], dtype=float32),
#   'ref_im': array([[[ 287,  309,  300,  288,  277,  293,  273,  266,  278],
#           [ 314,  285,  296,  304,  265,  252,  230,  258,  272],
#           [ 311,  291,  280,  277,  259,  257,  232,  263,  282],
#           [ 285,  294,  266,  264,  228,  210,  257,  266,  258],
#           [ 295,  286,  279,  243,  217,  257,  244,  257,  277],
#           [ 296,  274,  280,  240,  220,  231,  280,  299,  278],
#           [ 258,  256,  270,  261,  258,  268,  251,  264,  272],
#           [ 260,  264,  258,  261,  262,  268,  266,  274,  280],
#           [ 267,  266,  281,  276,  287,  286,  261,  265,  269]],
#
#          [[ 308,  330,  370,  404,  351,  333,  309,  301,  319],
#           [ 333,  399,  395,  368,  393,  351,  366,  366,  342],
#           [ 362,  421,  410,  393,  363,  337,  360,  363,  366],
#           [ 384,  429,  389,  354,  363,  358,  389,  399,  395],
#           [ 380,  357,  335,  337,  319,  363,  360,  369,  380],
#           [ 362,  341,  336,  339,  352,  311,  326,  359,  353],
#           [ 354,  332,  357,  378,  324,  338,  354,  355,  358],
#           [ 294,  327,  373,  372,  366,  357,  340,  298,  278],
#           [ 310,  320,  353,  349,  351,  362,  338,  290,  276]],
#
#          [[ 305,  372,  396,  411,  399,  366,  338,  335,  347],
#           [ 405,  446,  451,  461,  452,  408,  375,  353,  349],
#           [ 380,  433,  507,  530,  589,  545,  456,  398,  378],
#           [ 434,  479,  559,  674,  698,  624,  522,  445,  438],
#           [ 406,  479,  570,  670,  774,  736,  512,  429,  414],
#           [ 384,  414,  532,  600,  659,  611,  443,  377,  374],
#           [ 331,  368,  438,  454,  466,  502,  452,  352,  340],
#           [ 271,  372,  400,  429,  501,  448,  403,  292,  243],
#           [ 274,  332,  374,  391,  381,  417,  360,  277,  274]],
#
#          [[ 259,  290,  297,  298,  316,  270,  262,  269,  264],
#           [ 303,  319,  392,  436,  422,  378,  320,  293,  286],
#           [ 293,  347,  518,  662,  814,  737,  473,  348,  343],
#           [ 319,  450,  712, 1099, 1318, 1069,  698,  433,  379],
#           [ 338,  463,  828, 1312, 1509, 1215,  810,  465,  364],
#           [ 321,  437,  659, 1031, 1199,  960,  653,  407,  363],
#           [ 273,  347,  537,  680,  725,  638,  494,  343,  309],
#           [ 257,  299,  365,  440,  483,  507,  397,  291,  292],
#           [ 235,  266,  316,  356,  356,  342,  310,  246,  221]],
#
#          [[ 243,  240,  263,  301,  297,  259,  212,  206,  210],
#           [ 225,  239,  324,  398,  417,  377,  309,  253,  235],
#           [ 279,  317,  515,  705,  819,  729,  472,  342,  311],
#           [ 269,  430,  737, 1182, 1466, 1220,  757,  382,  322],
#           [ 273,  480,  940, 1493, 1779, 1435,  862,  473,  391],
#           [ 258,  414,  772, 1220, 1447, 1197,  757,  394,  327],
#           [ 222,  310,  520,  793,  865,  739,  560,  338,  291],
#           [ 255,  265,  338,  427,  459,  456,  395,  320,  292],
#           [ 218,  235,  277,  309,  316,  325,  308,  268,  265]],
#
#          [[ 265,  257,  258,  264,  282,  275,  248,  259,  253],
#           [ 274,  309,  327,  374,  417,  368,  330,  289,  270],
#           [ 277,  295,  456,  674,  780,  693,  490,  327,  274],
#           [ 316,  421,  647,  964, 1166, 1056,  703,  393,  328],
#           [ 301,  465,  814, 1225, 1401, 1242,  835,  434,  361],
#           [ 257,  383,  722, 1016, 1171, 1084,  708,  401,  345],
#           [ 242,  310,  501,  693,  759,  720,  561,  373,  338],
#           [ 216,  261,  339,  407,  473,  489,  397,  353,  355],
#           [ 220,  221,  277,  345,  317,  360,  370,  300,  298]],
#
#          [[ 268,  292,  324,  327,  343,  351,  309,  284,  288],
#           [ 285,  342,  362,  388,  418,  399,  374,  337,  320],
#           [ 341,  368,  412,  521,  567,  502,  429,  355,  316],
#           [ 350,  401,  531,  624,  685,  677,  535,  406,  381],
#           [ 337,  405,  515,  728,  814,  726,  589,  435,  397],
#           [ 286,  352,  474,  624,  684,  676,  525,  358,  342],
#           [ 278,  343,  445,  508,  537,  513,  458,  395,  370],
#           [ 236,  263,  341,  376,  412,  454,  405,  363,  362],
#           [ 245,  233,  268,  313,  297,  372,  399,  353,  359]],
#
#          [[ 288,  278,  284,  330,  366,  352,  315,  273,  269],
#           [ 315,  302,  326,  333,  394,  425,  412,  355,  319],
#           [ 366,  371,  370,  378,  397,  429,  457,  375,  335],
#           [ 377,  362,  342,  417,  411,  417,  406,  378,  374],
#           [ 332,  355,  375,  392,  397,  395,  422,  394,  365],
#           [ 245,  335,  379,  391,  418,  400,  366,  343,  338],
#           [ 245,  326,  381,  381,  357,  370,  410,  310,  274],
#           [ 257,  289,  301,  321,  341,  349,  361,  358,  341],
#           [ 253,  263,  268,  296,  329,  339,  368,  359,  342]],
#
#          [[ 244,  236,  234,  279,  313,  351,  356,  310,  303],
#           [ 254,  262,  263,  286,  393,  411,  386,  316,  282],
#           [ 251,  279,  287,  312,  339,  362,  375,  330,  320],
#           [ 272,  271,  311,  321,  329,  352,  295,  284,  291],
#           [ 272,  283,  309,  304,  340,  341,  303,  292,  279],
#           [ 266,  279,  331,  331,  326,  303,  281,  281,  267],
#           [ 223,  254,  276,  297,  289,  303,  294,  266,  277],
#           [ 229,  238,  252,  265,  291,  293,  259,  266,  272],
#           [ 220,  229,  256,  257,  267,  277,  278,  278,  273]]],
#         dtype=uint16),
#   'bleed_im': array([[[ 738,  763,  702,  716,  748,  747,  747,  730,  739],
#           [ 756,  756,  705,  694,  729,  729,  752,  768,  776],
#           [ 727,  705,  740,  736,  701,  715,  693,  759,  780],
#           [ 789,  778,  771,  740,  655,  718,  740,  728,  743],
#           [ 725,  724,  711,  703,  699,  745,  739,  721,  749],
#           [ 737,  750,  717,  779,  745,  680,  744,  785,  795],
#           [ 724,  748,  729,  729,  754,  680,  677,  711,  703],
#           [ 695,  723,  681,  716,  721,  729,  722,  707,  722],
#           [ 742,  744,  799,  740,  706,  764,  730,  724,  750]],
#
#          [[ 731,  757,  770,  772,  777,  790,  728,  718,  757],
#           [ 772,  734,  735,  766,  737,  758,  737,  771,  802],
#           [ 797,  816,  784,  730,  686,  691,  753,  810,  819],
#           [ 835,  778,  782,  783,  755,  774,  791,  748,  759],
#           [ 849,  775,  784,  793,  765,  752,  747,  770,  790],
#           [ 803,  770,  758,  773,  788,  697,  777,  767,  721],
#           [ 788,  801,  792,  791,  765,  737,  727,  762,  780],
#           [ 767,  711,  727,  742,  751,  769,  792,  757,  720],
#           [ 718,  748,  785,  742,  777,  749,  804,  724,  664]],
#
#          [[ 749,  743,  771,  804,  712,  738,  726,  731,  779],
#           [ 786,  719,  786,  807,  772,  772,  773,  737,  742],
#           [ 831,  821,  765,  811,  738,  748,  792,  752,  747],
#           [ 801,  723,  792,  916,  928,  843,  814,  797,  767],
#           [ 852,  759,  831,  891,  917,  943,  848,  840,  853],
#           [ 808,  753,  797,  876,  789,  736,  771,  751,  740],
#           [ 753,  775,  790,  813,  776,  788,  820,  752,  719],
#           [ 738,  724,  699,  699,  759,  775,  782,  742,  695],
#           [ 741,  744,  671,  775,  818,  731,  761,  726,  702]],
#
#          [[ 753,  742,  744,  719,  733,  713,  728,  723,  689],
#           [ 778,  751,  743,  795,  824,  772,  704,  687,  692],
#           [ 792,  776,  765,  836,  898,  874,  782,  793,  828],
#           [ 766,  793,  861, 1002, 1034,  917,  848,  780,  730],
#           [ 830,  777,  824,  976, 1054, 1001,  934,  810,  777],
#           [ 760,  799,  833,  878,  909,  873,  821,  761,  759],
#           [ 769,  748,  743,  801,  865,  845,  833,  770,  735],
#           [ 733,  715,  795,  766,  765,  773,  770,  749,  715],
#           [ 732,  751,  745,  782,  810,  766,  714,  690,  688]],
#
#          [[ 701,  731,  720,  684,  709,  694,  648,  690,  702],
#           [ 811,  817,  795,  768,  794,  731,  709,  682,  631],
#           [ 801,  816,  903,  867,  870,  904,  806,  732,  712],
#           [ 754,  779,  895,  987, 1025,  932,  831,  748,  725],
#           [ 730,  784,  888, 1073, 1109,  990,  902,  756,  729],
#           [ 784,  762,  876,  986, 1053,  977,  787,  731,  760],
#           [ 788,  751,  865,  911,  890,  840,  816,  778,  761],
#           [ 730,  695,  755,  757,  739,  754,  753,  701,  679],
#           [ 729,  738,  754,  717,  718,  749,  735,  709,  697]],
#
#          [[ 751,  770,  781,  753,  729,  773,  686,  673,  699],
#           [ 763,  761,  817,  820,  784,  796,  721,  713,  744],
#           [ 746,  787,  771,  822,  801,  817,  749,  685,  721],
#           [ 773,  806,  885,  898,  871,  960,  841,  727,  743],
#           [ 760,  761,  891, 1011, 1006,  953,  851,  768,  776],
#           [ 734,  784,  881,  983,  954,  944,  837,  778,  812],
#           [ 739,  726,  790,  849,  853,  815,  741,  761,  773],
#           [ 673,  675,  734,  729,  785,  802,  746,  758,  760],
#           [ 691,  775,  713,  712,  745,  756,  755,  692,  671]],
#
#          [[ 772,  795,  758,  735,  725,  728,  777,  745,  706],
#           [ 703,  728,  795,  812,  804,  794,  763,  775,  806],
#           [ 762,  788,  783,  797,  773,  791,  712,  753,  810],
#           [ 762,  757,  787,  824,  831,  847,  766,  725,  728],
#           [ 728,  717,  789,  830,  853,  807,  828,  787,  747],
#           [ 732,  775,  839,  839,  859,  793,  783,  799,  769],
#           [ 736,  741,  747,  751,  774,  774,  812,  751,  694],
#           [ 693,  752,  729,  713,  784,  782,  760,  729,  731],
#           [ 757,  729,  719,  744,  764,  733,  753,  774,  775]],
#
#          [[ 776,  745,  724,  764,  792,  792,  779,  749,  723],
#           [ 710,  750,  756,  810,  808,  744,  789,  818,  807],
#           [ 736,  740,  788,  744,  740,  750,  758,  753,  716],
#           [ 756,  731,  730,  726,  695,  784,  805,  738,  745],
#           [ 784,  762,  749,  778,  767,  692,  735,  761,  742],
#           [ 742,  735,  721,  647,  779,  763,  760,  709,  649],
#           [ 745,  717,  748,  737,  692,  724,  774,  719,  699],
#           [ 696,  741,  732,  703,  738,  752,  713,  682,  685],
#           [ 812,  701,  712,  773,  759,  716,  747,  743,  718]],
#
#          [[ 727,  745,  734,  732,  726,  776,  764,  760,  791],
#           [ 736,  718,  702,  753,  826,  764,  774,  743,  697],
#           [ 821,  717,  693,  753,  811,  776,  769,  753,  731],
#           [ 764,  770,  776,  785,  724,  676,  774,  737,  709],
#           [ 664,  752,  779,  780,  761,  710,  766,  763,  742],
#           [ 705,  708,  726,  723,  791,  749,  754,  715,  656],
#           [ 734,  744,  752,  772,  774,  735,  685,  703,  723],
#           [ 747,  722,  762,  759,  719,  732,  728,  689,  688],
#           [ 688,  679,  724,  736,  751,  734,  719,  676,  636]]],
#         dtype=uint16),
#   'rsquare': 0.7119682331019757,
#   'slope': 0.2548961541881525,
#   'intercept': 663.9190038829975,
#   'file': '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H1R1_Cy7\\Conv_zscan_01.dax'},
#  {'coord': array([  23.572086 ,    2.4984934, 1091.8286   ], dtype=float32),
#   'ref_im': array([[[ 228,  218,  206,  201,  199,  226,  224,  279,  256],
#           [ 228,  218,  206,  201,  199,  226,  224,  279,  256],
#           [ 247,  228,  204,  201,  201,  218,  221,  275,  264],
#           [ 255,  246,  227,  205,  192,  215,  244,  266,  289],
#           [ 240,  240,  227,  217,  186,  235,  265,  270,  338],
#           [ 265,  240,  232,  219,  210,  278,  255,  275,  333],
#           [ 284,  237,  256,  257,  254,  267,  291,  292,  279],
#           [ 299,  287,  286,  300,  327,  353,  326,  301,  285],
#           [ 299,  308,  302,  303,  347,  412,  328,  299,  290]],
#
#          [[ 359,  350,  287,  250,  301,  270,  315,  343,  303],
#           [ 359,  350,  287,  250,  301,  270,  315,  343,  303],
#           [ 354,  368,  306,  265,  330,  301,  328,  351,  333],
#           [ 358,  381,  362,  312,  335,  361,  376,  353,  411],
#           [ 368,  339,  357,  343,  354,  418,  420,  378,  407],
#           [ 358,  363,  400,  412,  440,  420,  429,  439,  374],
#           [ 347,  330,  388,  443,  442,  436,  434,  421,  337],
#           [ 322,  344,  404,  432,  487,  455,  419,  366,  307],
#           [ 316,  376,  439,  435,  504,  430,  403,  357,  299]],
#
#          [[ 395,  390,  374,  316,  343,  340,  402,  352,  305],
#           [ 395,  390,  374,  316,  343,  340,  402,  352,  305],
#           [ 401,  405,  399,  416,  418,  397,  416,  387,  346],
#           [ 408,  427,  484,  631,  652,  585,  520,  419,  428],
#           [ 382,  445,  544,  711,  782,  649,  539,  438,  378],
#           [ 366,  421,  546,  744,  778,  650,  553,  461,  324],
#           [ 327,  382,  510,  590,  646,  633,  527,  421,  350],
#           [ 260,  352,  450,  485,  512,  481,  423,  389,  299],
#           [ 248,  332,  427,  474,  478,  420,  417,  370,  257]],
#
#          [[ 309,  384,  400,  495,  553,  539,  487,  379,  285],
#           [ 309,  384,  400,  495,  553,  539,  487,  379,  285],
#           [ 350,  412,  462,  623,  712,  625,  501,  437,  305],
#           [ 386,  460,  689, 1091, 1286, 1062,  665,  483,  321],
#           [ 341,  459,  840, 1308, 1495, 1198,  709,  444,  302],
#           [ 302,  472,  761, 1158, 1277,  970,  607,  414,  278],
#           [ 261,  379,  598,  809,  854,  696,  491,  342,  289],
#           [ 248,  288,  410,  479,  473,  422,  342,  303,  260],
#           [ 235,  284,  336,  401,  395,  369,  322,  281,  227]],
#
#          [[ 282,  328,  377,  545,  777,  750,  545,  362,  288],
#           [ 282,  328,  377,  545,  777,  750,  545,  362,  288],
#           [ 297,  342,  457,  696,  967,  892,  638,  413,  282],
#           [ 305,  417,  789, 1318, 1605, 1403,  846,  466,  290],
#           [ 282,  459,  960, 1565, 1777, 1464,  813,  431,  258],
#           [ 252,  461,  855, 1366, 1516, 1069,  638,  368,  236],
#           [ 227,  354,  565,  836,  922,  642,  391,  260,  220],
#           [ 237,  228,  294,  353,  382,  334,  261,  218,  207],
#           [ 237,  220,  245,  293,  297,  268,  242,  203,  224]],
#
#          [[ 280,  313,  368,  473,  594,  621,  521,  377,  315],
#           [ 280,  313,  368,  473,  594,  621,  521,  377,  315],
#           [ 281,  315,  399,  589,  728,  738,  629,  406,  327],
#           [ 299,  383,  632,  975, 1180, 1131,  853,  466,  328],
#           [ 281,  421,  783, 1156, 1341, 1169,  837,  478,  314],
#           [ 244,  383,  696, 1059, 1197,  970,  698,  433,  279],
#           [ 248,  340,  476,  699,  800,  700,  475,  344,  244],
# ...
#           [255, 251, 295, 314, 317, 280, 294, 249, 208],
#           [245, 282, 311, 378, 361, 351, 316, 269, 261],
#           [259, 253, 309, 356, 399, 355, 306, 295, 286],
#           [232, 244, 290, 324, 329, 348, 299, 270, 268],
#           [211, 230, 261, 257, 300, 296, 302, 283, 270],
#           [210, 213, 229, 237, 268, 254, 253, 268, 252],
#           [208, 220, 213, 250, 238, 256, 247, 254, 240]],
#
#          [[227, 205, 217, 221, 238, 224, 232, 222, 214],
#           [227, 243, 248, 225, 245, 247, 235, 247, 236],
#           [208, 264, 280, 241, 239, 240, 225, 228, 220],
#           [241, 264, 265, 266, 234, 270, 251, 221, 226],
#           [258, 251, 262, 241, 252, 279, 250, 243, 226],
#           [235, 234, 234, 242, 241, 258, 263, 256, 271],
#           [210, 217, 233, 236, 232, 244, 305, 274, 301],
#           [198, 221, 233, 215, 218, 230, 270, 279, 292],
#           [199, 230, 227, 216, 221, 241, 265, 283, 297]],
#
#          [[239, 183, 196, 205, 215, 211, 225, 223, 227],
#           [236, 221, 220, 204, 212, 223, 208, 219, 225],
#           [208, 236, 244, 213, 225, 252, 209, 212, 217],
#           [237, 208, 229, 205, 232, 259, 220, 229, 226],
#           [238, 213, 228, 233, 229, 245, 212, 238, 239],
#           [205, 232, 204, 245, 232, 256, 250, 265, 303],
#           [211, 219, 228, 236, 225, 260, 289, 289, 310],
#           [215, 200, 237, 226, 223, 243, 270, 267, 277],
#           [205, 203, 232, 220, 230, 248, 262, 266, 283]]], dtype=uint16),
#   'bleed_im': array([[[693, 664, 726, 684, 681, 735, 743, 711, 719],
#           [687, 701, 722, 700, 679, 671, 692, 665, 666],
#           [693, 732, 698, 659, 660, 687, 686, 681, 691],
#           [649, 695, 670, 659, 700, 711, 762, 680, 712],
#           [720, 734, 693, 723, 743, 757, 780, 741, 715],
#           [748, 758, 720, 677, 714, 696, 688, 707, 760],
#           [716, 729, 731, 670, 712, 713, 716, 673, 748],
#           [725, 694, 727, 747, 726, 740, 702, 732, 746],
#           [696, 683, 736, 738, 724, 721, 652, 762, 770]],
#
#          [[677, 750, 735, 644, 686, 714, 692, 687, 674],
#           [678, 774, 738, 716, 739, 714, 714, 679, 689],
#           [762, 760, 718, 742, 757, 729, 699, 706, 676],
#           [753, 676, 657, 715, 752, 699, 691, 746, 686],
#           [741, 720, 645, 681, 728, 703, 695, 697, 693],
#           [718, 715, 765, 684, 665, 715, 672, 655, 666],
#           [683, 703, 722, 677, 691, 712, 730, 733, 722],
#           [687, 731, 703, 721, 691, 778, 765, 762, 760],
#           [685, 751, 737, 734, 657, 807, 762, 758, 745]],
#
#          [[651, 700, 718, 738, 712, 746, 684, 749, 719],
#           [621, 749, 676, 709, 712, 749, 702, 677, 749],
#           [717, 679, 719, 663, 761, 722, 735, 705, 739],
#           [721, 685, 714, 765, 730, 703, 679, 767, 694],
#           [713, 738, 740, 776, 707, 714, 697, 738, 727],
#           [764, 664, 756, 730, 731, 710, 694, 773, 718],
#           [698, 660, 736, 710, 735, 709, 735, 806, 719],
#           [681, 712, 700, 694, 760, 719, 784, 830, 753],
#           [725, 736, 679, 694, 769, 713, 784, 836, 744]],
#
#          [[718, 698, 759, 676, 709, 715, 679, 714, 758],
#           [708, 715, 735, 725, 754, 727, 688, 689, 695],
#           [691, 684, 721, 697, 778, 743, 709, 734, 669],
#           [723, 667, 717, 740, 724, 687, 706, 714, 649],
#           [747, 672, 780, 780, 777, 756, 661, 702, 707],
#           [755, 693, 701, 800, 799, 722, 709, 723, 705],
#           [677, 641, 731, 718, 768, 683, 728, 782, 712],
#           [681, 652, 726, 719, 706, 727, 753, 776, 728],
#           [711, 670, 677, 757, 673, 710, 773, 737, 703]],
#
#          [[743, 699, 740, 723, 712, 664, 699, 727, 653],
#           [710, 736, 702, 752, 751, 686, 677, 712, 662],
#           [625, 702, 736, 771, 744, 667, 666, 702, 684],
#           [744, 698, 780, 758, 794, 726, 675, 701, 683],
#           [720, 713, 727, 740, 804, 820, 701, 710, 692],
#           [680, 679, 684, 732, 771, 779, 758, 700, 709],
#           [698, 702, 688, 700, 701, 714, 765, 710, 714],
#           [706, 665, 675, 697, 634, 692, 692, 737, 715],
#           [720, 672, 691, 705, 643, 676, 656, 721, 726]],
#
#          [[692, 727, 754, 733, 673, 783, 776, 716, 755],
#           [626, 684, 730, 724, 670, 754, 696, 667, 681],
#           [653, 754, 713, 737, 764, 689, 720, 674, 671],
#           [724, 760, 766, 763, 801, 756, 702, 711, 700],
#           [670, 723, 691, 755, 817, 792, 770, 708, 698],
#           [674, 736, 740, 731, 786, 691, 800, 714, 719],
#           [718, 700, 750, 678, 739, 722, 740, 697, 734],
#           [716, 716, 693, 652, 699, 721, 724, 696, 691],
#           [714, 740, 701, 662, 677, 695, 711, 694, 675]],
#
#          [[699, 711, 671, 713, 693, 773, 713, 725, 768],
#           [694, 696, 745, 744, 683, 691, 715, 732, 704],
#           [716, 713, 749, 731, 759, 668, 720, 704, 659],
#           [772, 744, 725, 723, 740, 705, 718, 695, 691],
#           [731, 715, 728, 721, 692, 706, 703, 732, 716],
#           [752, 741, 740, 703, 718, 745, 699, 770, 719],
#           [731, 703, 715, 688, 738, 721, 737, 702, 696],
#           [724, 707, 707, 690, 723, 756, 684, 693, 695],
#           [739, 715, 719, 712, 717, 775, 642, 729, 714]],
#
#          [[717, 665, 685, 708, 653, 718, 692, 680, 672],
#           [720, 696, 691, 719, 723, 690, 728, 631, 684],
#           [689, 706, 715, 703, 761, 684, 689, 680, 780],
#           [699, 724, 697, 690, 727, 721, 707, 657, 714],
#           [720, 731, 667, 713, 721, 778, 730, 675, 671],
#           [745, 729, 732, 704, 696, 714, 697, 737, 735],
#           [728, 734, 711, 711, 720, 674, 697, 723, 765],
#           [681, 701, 719, 743, 738, 710, 699, 722, 743],
#           [693, 685, 753, 744, 723, 710, 703, 742, 724]],
#
#          [[704, 713, 728, 655, 684, 690, 732, 704, 716],
#           [698, 692, 717, 655, 681, 709, 712, 625, 676],
#           [718, 663, 743, 734, 694, 745, 677, 683, 724],
#           [729, 693, 660, 710, 699, 693, 735, 663, 707],
#           [741, 776, 620, 695, 711, 664, 753, 691, 671],
#           [688, 695, 738, 677, 697, 687, 690, 757, 745],
#           [657, 618, 728, 678, 696, 707, 689, 751, 805],
#           [722, 713, 687, 727, 755, 687, 726, 691, 749],
#           [740, 750, 704, 730, 744, 681, 761, 681, 710]]], dtype=uint16),
#   'rsquare': 0.20872962626167169,
#   'slope': 0.21752709670534506,
#   'intercept': 654.7029109776186,
#   'file': '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H1R1_Cy7\\Conv_zscan_01.dax'},
#  {'coord': array([  20.3957, 1841.0798,  736.6051], dtype=float32),
#   'ref_im': array([[[268, 256, 246, 258, 282, 268, 272, 281, 269],
#           [248, 252, 263, 253, 250, 270, 251, 258, 263],
#           [273, 271, 229, 223, 249, 230, 264, 283, 257],
#           [271, 259, 255, 238, 225, 214, 262, 285, 244],
#           [257, 257, 263, 254, 246, 247, 240, 233, 274],
#           [274, 268, 250, 235, 266, 267, 259, 248, 258],
#           [257, 249, 248, 288, 259, 269, 241, 235, 258],
#           [253, 243, 256, 268, 245, 260, 252, 246, 250],
#           [251, 222, 231, 260, 273, 255, 254, 249, 253]],
#
#          [[255, 295, 316, 317, 364, 327, 277, 303, 249],
#           [285, 282, 276, 314, 328, 332, 316, 280, 282],
#           [293, 333, 358, 325, 329, 321, 308, 330, 300],
#           [304, 289, 318, 319, 344, 330, 297, 297, 280],
#           [280, 271, 293, 321, 331, 327, 267, 269, 285],
#           [293, 328, 310, 293, 318, 338, 300, 280, 266],
#           [267, 296, 302, 311, 314, 301, 285, 282, 252],
#           [299, 292, 258, 323, 317, 275, 277, 288, 254],
#           [296, 306, 290, 296, 270, 277, 283, 252, 238]],
#
#          [[270, 294, 326, 354, 346, 346, 278, 255, 246],
#           [284, 311, 317, 429, 447, 376, 338, 298, 246],
#           [270, 314, 412, 475, 505, 453, 367, 306, 256],
#           [293, 308, 348, 449, 486, 416, 347, 298, 273],
#           [281, 338, 342, 394, 412, 389, 335, 282, 260],
#           [287, 333, 321, 324, 380, 376, 330, 300, 250],
#           [281, 299, 358, 350, 378, 363, 295, 285, 258],
#           [299, 331, 321, 356, 353, 314, 288, 268, 246],
#           [266, 341, 359, 322, 321, 330, 274, 253, 225]],
#
#          [[243, 247, 291, 365, 365, 323, 293, 238, 216],
#           [249, 263, 344, 465, 507, 435, 344, 265, 223],
#           [239, 266, 381, 515, 625, 569, 380, 303, 256],
#           [258, 291, 351, 551, 609, 488, 404, 294, 225],
#           [273, 318, 382, 491, 522, 490, 378, 289, 244],
#           [262, 322, 380, 488, 526, 437, 338, 278, 236],
#           [284, 328, 395, 466, 478, 422, 322, 264, 270],
#           [254, 343, 387, 427, 472, 382, 293, 263, 246],
#           [269, 315, 371, 415, 400, 355, 286, 230, 220]],
#
#          [[217, 232, 282, 331, 386, 333, 303, 278, 220],
#           [227, 245, 330, 410, 471, 459, 341, 254, 231],
#           [210, 240, 371, 500, 538, 537, 392, 268, 230],
#           [197, 245, 355, 530, 600, 526, 403, 280, 206],
#           [251, 263, 355, 501, 599, 509, 349, 275, 248],
#           [239, 295, 413, 503, 542, 475, 356, 235, 223],
#           [236, 326, 442, 529, 574, 462, 330, 277, 235],
#           [254, 291, 404, 499, 518, 428, 330, 251, 228],
#           [250, 272, 394, 463, 404, 330, 277, 230, 213]],
#
#          [[223, 248, 294, 324, 371, 360, 309, 311, 235],
#           [243, 256, 296, 370, 406, 421, 332, 288, 282],
#           [237, 262, 366, 451, 453, 441, 384, 292, 243],
#           [212, 240, 316, 437, 507, 454, 377, 312, 239],
#           [225, 259, 316, 446, 517, 455, 360, 272, 226],
#           [217, 258, 384, 440, 481, 484, 379, 272, 237],
#           [241, 273, 412, 472, 500, 453, 341, 294, 221],
#           [247, 280, 381, 475, 496, 437, 359, 265, 210],
#           [223, 279, 325, 426, 408, 330, 304, 252, 236]],
#
#          [[217, 245, 307, 330, 366, 373, 302, 287, 237],
#           [224, 246, 281, 333, 344, 394, 360, 308, 283],
#           [242, 284, 323, 358, 395, 423, 373, 326, 310],
#           [232, 264, 290, 358, 404, 390, 358, 312, 299],
#           [221, 263, 302, 351, 379, 407, 348, 293, 255],
#           [219, 254, 338, 422, 439, 416, 372, 322, 248],
#           [234, 268, 336, 428, 441, 402, 343, 301, 246],
#           [213, 277, 362, 393, 412, 370, 296, 268, 237],
#           [226, 253, 293, 353, 366, 298, 267, 253, 226]],
#
#          [[220, 237, 278, 326, 352, 338, 326, 299, 274],
#           [223, 250, 261, 297, 342, 392, 377, 323, 280],
#           [232, 274, 279, 323, 371, 392, 365, 321, 299],
#           [229, 254, 270, 297, 334, 357, 336, 269, 275],
#           [222, 261, 256, 278, 327, 317, 303, 297, 277],
#           [228, 242, 270, 329, 328, 320, 296, 294, 251],
#           [221, 250, 278, 309, 309, 316, 309, 276, 253],
#           [219, 253, 294, 287, 313, 303, 276, 255, 248],
#           [218, 247, 275, 271, 279, 262, 247, 247, 219]],
#
#          [[215, 210, 281, 318, 341, 314, 339, 353, 302],
#           [226, 244, 234, 275, 332, 360, 365, 344, 265],
#           [218, 247, 253, 325, 350, 375, 350, 315, 285],
#           [229, 248, 263, 302, 335, 362, 346, 297, 278],
#           [216, 251, 233, 262, 306, 283, 298, 281, 268],
#           [224, 232, 276, 291, 285, 308, 304, 272, 241],
#           [220, 240, 280, 281, 255, 305, 282, 258, 251],
#           [200, 242, 245, 249, 293, 291, 292, 265, 239],
#           [214, 239, 244, 276, 265, 245, 255, 244, 214]]], dtype=uint16),
#   'bleed_im': array([[[594, 590, 616, 618, 620, 610, 685, 678, 639],
#           [661, 674, 617, 659, 657, 635, 671, 639, 643],
#           [644, 691, 625, 614, 654, 679, 698, 675, 632],
#           [670, 622, 629, 678, 630, 622, 643, 661, 644],
#           [592, 660, 669, 628, 612, 633, 655, 645, 651],
#           [675, 699, 599, 640, 681, 618, 572, 620, 630],
#           [672, 647, 605, 674, 647, 627, 670, 612, 608],
#           [637, 635, 630, 604, 576, 609, 672, 640, 659],
#           [642, 630, 645, 639, 619, 659, 641, 636, 658]],
#
#          [[626, 635, 669, 637, 662, 641, 687, 647, 608],
#           [667, 696, 642, 640, 663, 609, 654, 664, 624],
#           [673, 687, 626, 652, 686, 676, 651, 608, 622],
#           [648, 655, 621, 703, 645, 665, 686, 631, 637],
#           [631, 672, 607, 628, 699, 695, 647, 644, 654],
#           [609, 646, 676, 646, 657, 678, 659, 654, 633],
#           [654, 646, 660, 639, 680, 677, 651, 659, 659],
#           [627, 642, 657, 664, 638, 618, 680, 634, 609],
#           [677, 646, 659, 633, 594, 601, 625, 655, 651]],
#
#          [[608, 631, 659, 692, 665, 656, 622, 593, 636],
#           [641, 664, 693, 633, 657, 688, 700, 652, 639],
#           [628, 655, 650, 703, 715, 669, 668, 609, 653],
#           [681, 687, 706, 761, 676, 646, 694, 671, 649],
#           [660, 627, 663, 700, 698, 670, 670, 676, 630],
#           [619, 647, 686, 684, 660, 691, 705, 640, 647],
#           [636, 648, 731, 698, 683, 675, 711, 652, 642],
#           [647, 706, 672, 644, 672, 664, 654, 681, 647],
#           [663, 705, 708, 662, 653, 652, 682, 723, 634]],
#
#          [[600, 668, 662, 648, 635, 657, 633, 603, 606],
#           [628, 664, 636, 690, 740, 707, 647, 627, 646],
#           [652, 617, 631, 714, 757, 719, 652, 613, 617],
#           [668, 682, 701, 699, 734, 733, 686, 645, 625],
#           [671, 658, 730, 728, 682, 661, 639, 652, 584],
#           [660, 692, 712, 718, 709, 685, 632, 654, 645],
#           [626, 628, 713, 725, 655, 635, 706, 623, 598],
#           [641, 659, 653, 699, 701, 640, 658, 678, 659],
#           [673, 710, 677, 672, 659, 638, 709, 662, 626]],
#
#          [[606, 607, 679, 621, 703, 678, 666, 664, 581],
#           [595, 597, 652, 712, 697, 673, 686, 684, 645],
#           [671, 602, 666, 732, 726, 723, 689, 670, 660],
#           [701, 694, 720, 708, 731, 651, 663, 644, 610],
#           [674, 660, 652, 717, 777, 716, 643, 640, 614],
#           [682, 672, 701, 719, 741, 684, 584, 639, 650],
#           [649, 614, 677, 729, 707, 644, 677, 648, 647],
#           [646, 643, 679, 736, 740, 663, 596, 645, 583],
#           [638, 632, 666, 716, 640, 624, 653, 606, 623]],
#
#          [[645, 610, 645, 650, 715, 756, 665, 633, 640],
#           [625, 680, 699, 676, 676, 666, 708, 699, 631],
#           [628, 603, 653, 716, 665, 660, 713, 650, 700],
#           [685, 691, 621, 691, 747, 659, 635, 607, 596],
#           [647, 663, 638, 717, 731, 692, 669, 674, 642],
#           [647, 621, 663, 677, 735, 725, 623, 594, 641],
#           [630, 596, 635, 711, 704, 667, 657, 629, 667],
#           [670, 640, 670, 702, 713, 670, 661, 639, 615],
#           [605, 619, 623, 688, 685, 662, 658, 631, 612]],
#
#          [[649, 662, 691, 652, 668, 695, 631, 649, 675],
#           [649, 656, 648, 671, 688, 669, 667, 630, 673],
#           [655, 656, 641, 650, 693, 668, 655, 631, 629],
#           [667, 640, 612, 658, 693, 705, 656, 654, 630],
#           [672, 660, 595, 670, 670, 666, 669, 671, 623],
#           [620, 614, 636, 690, 709, 679, 654, 669, 637],
#           [640, 668, 631, 648, 692, 681, 630, 631, 604],
#           [643, 615, 659, 653, 673, 693, 717, 674, 651],
#           [638, 621, 582, 642, 654, 676, 669, 645, 614]],
#
#          [[608, 610, 683, 668, 652, 660, 642, 677, 665],
#           [649, 602, 634, 666, 673, 650, 671, 652, 671],
#           [688, 676, 626, 645, 646, 663, 682, 641, 645],
#           [649, 673, 647, 664, 672, 694, 659, 679, 695],
#           [637, 621, 647, 691, 679, 638, 650, 690, 633],
#           [585, 640, 670, 649, 637, 636, 638, 687, 636],
#           [625, 684, 629, 616, 667, 693, 631, 626, 682],
#           [659, 648, 623, 629, 686, 653, 623, 679, 632],
#           [659, 668, 651, 633, 667, 685, 662, 609, 665]],
#
#          [[602, 624, 671, 688, 669, 690, 623, 719, 669],
#           [648, 636, 625, 626, 651, 633, 691, 681, 662],
#           [676, 670, 606, 639, 678, 650, 695, 713, 699],
#           [631, 692, 628, 650, 661, 644, 639, 691, 629],
#           [588, 632, 713, 710, 663, 645, 646, 692, 648],
#           [594, 644, 663, 652, 642, 608, 644, 659, 604],
#           [597, 640, 648, 617, 657, 693, 638, 635, 725],
#           [674, 672, 621, 627, 677, 625, 587, 628, 616],
#           [642, 691, 651, 660, 688, 672, 659, 585, 657]]], dtype=uint16),
#   'rsquare': 0.3204154369275565,
#   'slope': 0.24585824920459998,
#   'intercept': 580.1950471744499,
#   'file': '\\\\10.245.74.158\\Chromatin_NAS_4\\20210501-colorswap_MEF_CTP-08\\H1R1_Cy7\\Conv_zscan_01.dax'}]

# %%
num_kept = 0
for _dict in info_dicts:
    if correction_tools.bleedthrough.check_bleedthrough_info(_dict, _rsq_th=0.75):
        num_kept += 1
print(num_kept)
# Out:
# 109

# %%
reload(correction_tools.bleedthrough)
# Out:
# <module 'ImageAnalysis3.correction_tools.bleedthrough' from 'E:\\Users\\puzheng\\Documents\\ImageAnalysis3\\correction_tools\\bleedthrough.py'>

# %%
# load info
info_dicts = []
for _fov in fovs:
    temp_basename = f"bleedthrough_{_fov.split(os.extsep)[0]}_ref_750_to_647.pkl"
    if os.path.isfile(os.path.join(folders[1], temp_basename)):
        temp_dicts = pickle.load(open(os.path.join(folders[1], temp_basename), 'rb'))
        info_dicts.extend(temp_dicts)

# %%
(np.array(np.shape(_dict['ref_im']))-1)/2-1
# Out:
# array([3., 3., 3.])

# %%
xp, slopes, intercepts = [], [], []

for _dict in info_dicts:
    _max_inds = np.array(np.unravel_index(np.argmax(_dict['ref_im']), np.shape(_dict['ref_im'])))
    _im_ct_inds = (np.array(np.shape(_dict['ref_im']))-1)/2
    
    #if (_max_inds >= _im_ct_inds-0.5).all() and (_max_inds <= _im_ct_inds+0.5).all():
    if correction_tools.bleedthrough.check_bleedthrough_info(_dict, _rsq_th=0.75, _center_radius=0.5):
        xp.append(_dict['coord'][1])
        slopes.append(_dict['slope'])
        intercepts.append(_dict['intercept'])
    else:
        if _dict['slope'] > 10:
            print(os.path.basename(_dict['file']), _dict['rsquare'], _dict['slope'])

# %%
plt.figure()
plt.plot(xp, slopes, '.')
plt.show()

# %%
xp, slopes, intercepts = [], [], []
vis_ref_ims = []
vis_bld_ims = []
for _dict in info_dicts:
    if _dict['rsquare'] > 0.75:

        if _dict['slope'] <50:
            xp.append(_dict['coord'][0])
            slopes.append(_dict['slope'])
            intercepts.append(_dict['intercept'])
            vis_ref_ims.append(_dict['ref_im'])
            vis_bld_ims.append(_dict['bleed_im'])
        else:
            if _dict['intercept'] < 0:
                print(_dict['file'])
plt.figure()
plt.plot(xp, intercepts, '.')
plt.show()

# %%
# %matplotlib notebook
visual_tools.imshow_mark_3d_v2(vis_bld_ims)
# Out:
# <img src="data:image/png;base64,..." width="288">

# %%
from sklearn.linear_model import LinearRegression

# %%
# ?LinearRegression

# %%
reg_model = LinearRegression(fit_intercept=False)

# %%
x = np.arange(10)
y = 1+ 2*x

# %%
reg_model = LinearRegression(fit_intercept=False)
reg_model.fit(x[:,np.newaxis],y)
# Out:
# LinearRegression(fit_intercept=False)

# %%
reg_model.score(x[:,np.newaxis],y)
# Out:
# 0.9912280701754386

# %%
for _dict in info_dicts:
    reg_model = LinearRegression(fit_intercept=False)
    _x, _y = np.ravel(_dict['ref_im']), np.ravel(_dict['bleed_im'])
    reg_model.fit(_x[:,np.newaxis], _y)
    _rsq = reg_model.score(np.ravel(_dict['ref_im'])[:,np.newaxis], )
    print(reg_model.coef_, _dict['slope'], _rsq, _dict['rsquare'])
# Out:
# [1.34299016] 0.22848710133406372 -20.067433781669994 0.685237654982664
# [1.45058718] 0.25392355983675785 -22.59621688308017 0.8034268678524473
# [1.36481026] 0.23852850304124512 -18.83487224391229 0.7298898666560274
# [1.55525505] 0.2548961541881525 -22.85948556239519 0.7119682331019757
# [1.24108987] 0.23853979046847387 -15.880270108613622 0.7313935889175727
# [1.49387446] 0.33413002342370535 -11.311511195651976 0.8282577223931153
# [1.62411546] 0.3230895255069643 -15.599854648301793 0.7907936980702739
# [1.74845308] 0.22693518033682722 -31.490669918564777 0.5972547759594999
# [1.66105505] 0.21924575577973027 -25.563178000303317 0.5174979654648437
# [1.31668486] 0.21345617164122505 -20.817454370916902 0.676025435124026
# [2.0942429] 0.2616458637458767 -33.94727663133064 0.5745240091072381
# [1.84853583] 0.4686105393511824 -6.45982464800173 0.7402474736298252
# [1.7634053] 0.21490843567724838 -23.618488423279697 0.4096492463718783
# [2.15275069] 0.2375570295798655 -29.123721380647314 0.38831410366572294
# [2.06116334] 0.3709441840299939 -14.504592549314788 0.6282611339220692
# [1.86339884] 0.2282734673236636 -31.189606294324776 0.5266131279637638
# [1.87936549] 0.23114228409110116 -20.22459533325586 0.3682653902279792
# [1.95369701] 0.23160506325523383 -16.12246399139828 0.27677032462645546
# [2.27834861] 0.2115116680732832 -29.896205071669282 0.28696369770644026
# [2.10145435] 0.2197840466438774 -18.38048488659768 0.2349169258295044
# [2.33493533] 0.21210248070573892 -26.131263009797294 0.24506393947634886
# [1.90209769] 0.23009827422591486 -11.455938580894022 0.21063031378813035
# [1.85520493] 0.2483914323365038 -14.543387913784342 0.33180650544468115
# [2.74161765] 0.24272256715881893 -25.73475005225684 0.22505335053069586
# [2.39960822] 0.24027684054397155 -28.816838560571885 0.33711074202342084
# [2.32197258] 0.252680241453735 -13.304220771258416 0.18851288559232204
# [1.96927677] 0.22424616586811663 -15.811895093099064 0.25302004228411523
# [2.88543364] 0.24501518590617805 -26.447659305893414 0.21045621450294116
# [2.19308672] 0.22480368797749065 -19.759744468980617 0.24337405507492516
# [2.4365222] 0.22155651896343942 -24.504983549425152 0.2329230178403977
# [2.46885448] 0.21752709670534506 -23.695556057995898 0.20872962626167169
# [2.00692837] 0.24585824920459998 -17.110311662749325 0.3204154369275565

# %%
# %matplotlib inline
reload(correction_tools.bleedthrough)
bleed_pf = correction_tools.bleedthrough.Generate_bleedthrough_correction(
            folders[1:3],
            rsq_th=0.75,
            intensity_th=300,
            corr_channels=bleedthrough_channels,
            correction_args=bleedthrough_correction_args,
            fitting_order=1,
            fitting_args=bleedthrough_fitting_args,
            interpolate_args={'check_params':{'outlier_sigma':3.}, 'min_num_spots':50},
            num_images=num_images, 
            num_threads=num_threads,
            save_folder=correction_folder,
            overwrite_profile=True,
            overwrite_temp=False,
            )
# Out:
# + generating bleedthrough profiles.
# ++ generating bleedthrough info for 45 images in 15 threads in 4.522s.
# - check 64 bleedthrough pairs.
# - start iteration with outlier_sigma=3.00, keep_percentage=0.95
# -- iter: 1, kept in this round: 0.969, total: 0.969 in 0.078s
# - 62 pairs passed.
# -- 62 spots are used to generate profiles from 750 to 647
# [ 3.33537878e-01 -1.68054273e-03 -1.49116093e-05 -1.03100191e-05] 0.147279911618581
# [ 5.66693182e+02  3.39356253e-01 -5.54172716e-04  4.77301416e-02] 0.36800522104798206
# -- saving bleedthrough temp profile from channel: 750 to channel: 647.
# -- not enough spots (4) from 647 to 750
# -- generating inverse matrix.
# -- saving to file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\Corrections\bleedthrough_correction_750_647_2048_2048.npy

# %% [markdown]
# ### Check bleedthorugh for cy7

# %%
from ImageAnalysis3.io_tools.load import correct_fov_image
from ImageAnalysis3.io_tools.crop import crop_neighboring_area

# %%
cy7_filename = os.path.join(folders[1], fovs[3])
print(cy7_filename)
# Out:
# \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax

# %%
reload(ia.io_tools.load)
cy7_filename = os.path.join(folders[1], fovs[3])

cy7_raw_ims, = ia.io_tools.load.correct_fov_image(cy7_filename, 
                                                  bleedthrough_channels, 
                                                  bleed_corr=False, chromatic_corr=False,
                                                  corr_channels=bleedthrough_channels,
                                                  single_im_size=single_im_size,
                                                  all_channels=all_colors,
                                                  illumination_corr=True,
                                                  correction_folder=correction_folder)
cy7_corr_ims, = ia.io_tools.load.correct_fov_image(cy7_filename, 
                                                   bleedthrough_channels, 
                                                   bleed_corr=True, chromatic_corr=False, 
                                                   corr_channels=bleedthrough_channels,
                                                   single_im_size=single_im_size,
                                                   all_channels=all_colors,
                                                   illumination_corr=True,
                                                   correction_folder=correction_folder)
# Out:
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax  in 6.422s
# -- removing hot pixels for channels:['750', '647'] in 20.297s
# -- illumination correction for channels: 750, 647, in 4.375s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 32.552s
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_2048_2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax  in 5.864s
# -- removing hot pixels for channels:['750', '647'] in 20.515s
# -- bleedthrough correction for channels: ['750', '647'] in 11.251s
# -- illumination correction for channels: 750, 647, in 4.282s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 44.103s

# %%
# %matplotlib notebook
# %matplotlib notebook

visual_tools.imshow_mark_3d_v2([cy7_raw_ims[0], cy7_corr_ims[0], cy7_raw_ims[1], cy7_corr_ims[1]])
# Out:
# <img src="data:image/png;base64,..." width="544">

# %% [markdown]
# ## Check bleedthrough for cy5

# %%
reload(ia.io_tools.load)
cy5_filename = os.path.join(folders[1], fovs[3])

cy5_raw_ims, = ia.io_tools.load.correct_fov_image(cy5_filename, 
                                                  bleedthrough_channels, 
                                                  bleed_corr=False, chromatic_corr=False,
                                                  corr_channels=bleedthrough_channels,
                                                  single_im_size=single_im_size,
                                                  all_channels=all_colors,
                                                  illumination_corr=True,
                                                  correction_folder=correction_folder)
cy5_corr_ims, = ia.io_tools.load.correct_fov_image(cy5_filename, 
                                                   bleedthrough_channels, 
                                                   bleed_corr=True, chromatic_corr=False, 
                                                   corr_channels=bleedthrough_channels,
                                                   single_im_size=single_im_size,
                                                   all_channels=all_colors,
                                                   illumination_corr=True,
                                                   correction_folder=correction_folder)
# Out:
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax  in 6.018s
# -- removing hot pixels for channels:['750', '647'] in 20.203s
# -- illumination correction for channels: 750, 647, in 4.424s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 31.907s
# - correct the whole fov for image: \\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax
# -- loading illumination correction profile from file:
# 	 750 illumination_correction_750_2048x2048.npy
# 	 647 illumination_correction_647_2048x2048.npy
# -- loading bleedthrough correction profile from file:bleedthrough_correction_750_647_2048_2048.npy
# -- loading image from file:\\10.245.74.158\Chromatin_NAS_4\20210501-colorswap_MEF_CTP-08\H1R1_Cy7\Conv_zscan_03.dax  in 5.678s
# -- removing hot pixels for channels:['750', '647'] in 20.430s
# -- bleedthrough correction for channels: ['750', '647'] in 10.969s
# -- illumination correction for channels: 750, 647, in 4.186s
# -- warp image with drift:[0. 0. 0.] in 0.000s
# -- finish correction in 43.136s

# %%
# %matplotlib notebook
# %matplotlib notebook

visual_tools.imshow_mark_3d_v2([cy5_raw_ims[0], cy5_raw_ims[1], cy5_corr_ims[1], cy5_corr_ims[0]])
# Out:
# <img src="data:image/png;base64,..." width="288">
