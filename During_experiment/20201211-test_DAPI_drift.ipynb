# %%
# %run "E:\Users\puzheng\Documents\Startup_py3.py"
sys.path.append(r"E:\Users\puzheng\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())
# Out:
# 29160

# %%
ref_im_folder = r'U:\20201211-NO_Acr_ctp08_P_brain_exp2\H0R0'
im_folder = r'\\STORM6-pc\STORM6-FLASHDrive\Shiwei\20201211-NO_Acr_ctp08_P_brain_exp2\H1R1'

# %%
ref_im_folder = r'U:\20201211-NO_Acr_ctp08_P_brain_exp2\H0R0'
im_folder = r'\\STORM6-pc\STORM6-FLASHDrive\Shiwei\20201211-NO_Acr_ctp08_P_brain_exp2\H1R1'

# %%
im_basenames = [_fl for _fl in os.listdir(ref_im_folder) if _fl.split(os.extsep)[-1]=='dax']

# %%
channels = ['750','647','561','405']
single_im_size = [50,2048,2048]
correction_folder = r'\\10.245.74.158\Chromatin_NAS_0\Corrections\20201204-Corrections_3color_50'
ref_ims, = io_tools.load.correct_fov_image(os.path.join(ref_im_folder, im_basenames[0]),
                                [561,405], single_im_size=single_im_size,
                                all_channels=channels, 
                                          correction_folder=correction_folder,
                                drift_channel='561')

ims, = io_tools.load.correct_fov_image(os.path.join(im_folder, im_basenames[0]),
                                    [561,405], single_im_size=single_im_size,
                                    all_channels=channels, 
                                    correction_folder=correction_folder,
                                    drift_channel='561')
# Out:
# 'Conv_zscan_00.dax'

# %%
visual_tools.imshow_mark_3d_v2([ref_ims[0][0],ims[0][0]])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
bead_drift = correction_tools.alignment.cross_correlation_align_single_image(ref_ims[0][0], ims[0][0], single_im_size=single_im_size)

dapi_drift = correction_tools.alignment.cross_correlation_align_single_image(ref_ims[0][1], ims[0][1], single_im_size=single_im_size)
# Out:
# -- aligning image -> directly use image
# -- directly use ref_image
# array([ 0.03, -1.62,  2.37])

# %%
# Out:
# -- aligning image -> directly use image
# -- directly use ref_image
# array([ 0.36, -1.65,  3.76])
