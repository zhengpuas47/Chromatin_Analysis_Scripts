# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\Documents")

# %%
import ImageAnalysis3 as ia
reload(ia.get_img_info)
# Out:
# <module 'ImageAnalysis3.get_img_info' from '..\\..\\..\\Documents\\ImageAnalysis3\\get_img_info.py'>

# %%
folders, fovs = ia.get_img_info.get_folders(r'\\10.245.74.158\Chromatin_NAS_5\20210717-P_brain_MO4_MERFISH')
input_filename = os.path.join(folders[13], fovs[65])
print(input_filename)
im = ImageAnalysis3.visual_tools.batch_load_dax(input_filename)
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 19
# - Number of field of views: 101

# %%
# %matplotlib notebook
cy7_im, cy5_im = im[0::3], im[1::3]
ImageAnalysis3.visual_tools.imshow_mark_3d_v2([cy7_im, cy5_im])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
folders, fovs = ia.get_img_info.get_folders(r'\\10.245.74.158\Chromatin_NAS_5\20210719-Thymus_Aire_Ck5_smIntron')
input_filename = os.path.join(folders[0], fovs[2])
print(input_filename)
im = ImageAnalysis3.visual_tools.batch_load_dax(input_filename)
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 2
# - Number of field of views: 10
# \\10.245.74.158\Chromatin_NAS_5\20210719-Thymus_Aire_Ck5_smIntron\H0R0\Conv_zscan_02.dax

# %%
# %matplotlib notebook
cy7_im, cy5_im = im[0::4], im[1::4]
ImageAnalysis3.visual_tools.imshow_mark_3d_v2([cy7_im, cy5_im])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
folders, fovs = ia.get_img_info.get_folders(r'\\10.245.74.158\Chromatin_NAS_5\20210719-Thymus_Aire_Ck5_smIntron')
input_filename = os.path.join(folders[3], fovs[2])
print(input_filename)
im = ImageAnalysis3.visual_tools.batch_load_dax(input_filename)
# Out:
# Get Folder Names: (ia.get_img_info.get_folders)
# - Number of folders: 4
# - Number of field of views: 10
# \\10.245.74.158\Chromatin_NAS_5\20210719-Thymus_Aire_Ck5_smIntron\H2P1_new\Conv_zscan_02.dax

# %%
# %matplotlib notebook
cy7_im2, cy5_im2 = im[0::3], im[1::3]
ImageAnalysis3.visual_tools.imshow_mark_3d_v2([cy7_im, cy7_im2, cy5_im, cy5_im2])
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">
