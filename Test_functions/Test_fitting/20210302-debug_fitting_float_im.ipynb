# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"C:\Users\puzheng\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())
# Out:
# 25028

# %%
# load image
im_filename = os.path.join(r"C:\Users\puzheng\Documents", 'im.npy')
im = np.load(im_filename)

# %%
im.shape
# Out:
# (32, 2048, 2048)

# %%
# visualize
# %matplotlib notebook
# %matplotlib notebook
visual_tools.imshow_mark_3d_v2([im[1:-1, :500,:500]])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
# test fitting
spots = spot_tools.fitting.fit_fov_image(im[1:-1], None, th_seed=500, use_dynamic_th=False)
# Out:
# -- start fitting spots in channel:None, 0 seeded,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-be7a275de8d6> in <module>
#       1 # test fitting
# ----> 2 spots = spot_tools.fitting.fit_fov_image(im[1:-1], None, th_seed=500, use_dynamic_th=False)
#
# ~\Documents\ImageAnalysis3\spot_tools\fitting.py in fit_fov_image(im, channel, seeds, max_num_seeds, th_seed, th_seed_per, use_percentile, use_dynamic_th, dynamic_niters, min_dynamic_seeds, remove_hot_pixel, seeding_kwargs, fit_radius, normalize_backgroud, normalize_local, background_args, fitting_args, verbose)
#     197     )
#     198     # fit
# --> 199     _fitter.firstfit()
#     200     # check
#     201     _fitter.repeatfit()
#
# ~\Documents\ImageAnalysis3\External\Fitting_v4.py in firstfit(self)
#     593                     self.centers_fit.append([np.nan]*3)
#     594
# ...

# %%
reload(spot_tools.fitting)
spot_tools.fitting.get_seeds(im[1:-1, :500,:500], th_seed=100, 
                             verbose=True)
# Out:
# -- start seeding image, th=100.00->100.00, found 420 seeds in 1.81s
# array([[ 22., 263., 266.],
#        [ 16., 262., 261.],
#        [ 17., 215., 272.],
#        ...,
#        [ 13., 321., 273.],
#        [ 15., 205., 275.],
#        [ 21., 497., 457.]])

# %%
visual_tools.imshow_mark_3d_v2([max_im, min_im])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
im.dtype
# Out:
# dtype('float64')

# %%
plt.figure()
plt.hist(np.ravel(im), 30, range=(0,3000))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
