# %% [markdown]
# col0 - 750 (first frame)...
#
# Q - RNA
#
# R - DNA
#
# A(b) - Ab (647)

# %%
bb_info_dict = {'B': 'H98R65,B__col0',
 'B_rep1': 'H99R90,B__col0',
 'B_rep2': 'H110B,R80__col1',
 'Q1': 'H1Q1,Q2,Q3__col0',
 'Q10': 'H4Q10,Q11,Q12__col0',
 'Q11': 'H4Q10,Q11,Q12__col1',
 'Q12': 'H4Q10,Q11,Q12__col2',
 'Q13': 'H5Q13,Q14,Q15__col0',
 'Q14': 'H5Q13,Q14,Q15__col1',
 'Q15': 'H5Q13,Q14,Q15__col2',
 'Q16': 'H6Q16,Q17,Q18__col0',
 'Q17': 'H6Q16,Q17,Q18__col1',
 'Q18': 'H6Q16,Q17,Q18__col2',
 'Q19': 'H7Q19,Q20,Q21__col0',
 'Q2': 'H1Q1,Q2,Q3__col1',
 'Q20': 'H7Q19,Q20,Q21__col1',
 'Q21': 'H7Q19,Q20,Q21__col2',
 'Q22': 'H8Q22,Q23,Q24_rep__col0',
 'Q22_rep1': 'H8Q22,Q23,Q24__col0',
 'Q23': 'H8Q22,Q23,Q24_rep__col1',
 'Q23_rep1': 'H8Q22,Q23,Q24__col1',
 'Q24': 'H8Q22,Q23,Q24_rep__col2',
 'Q24_rep1': 'H8Q22,Q23,Q24__col2',
 'Q25': 'H9Q25,Q26,Q27__col0',
 'Q26': 'H9Q25,Q26,Q27__col1',
 'Q27': 'H9Q25,Q26,Q27__col2',
 'Q28': 'H10Q28,Q29,Q30__col0',
 'Q29': 'H10Q28,Q29,Q30__col1',
 'Q3': 'H1Q1,Q2,Q3__col2',
 'Q30': 'H10Q28,Q29,Q30__col2',
 'Q31': 'H11Q31,Q32,Q33__col0',
 'Q32': 'H11Q31,Q32,Q33__col1',
 'Q33': 'H11Q31,Q32,Q33__col2',
 'Q34': 'H12Q34,Q35,Q36__col0',
 'Q35': 'H12Q34,Q35,Q36__col1',
 'Q36': 'H12Q34,Q35,Q36__col2',
 'Q37': 'H13Q37,Q38,Q39__col0',
 'Q38': 'H13Q37,Q38,Q39__col1',
 'Q39': 'H13Q37,Q38,Q39__col2',
 'Q4': 'H2Q4,Q5,Q6__col0',
 'Q40': 'H14Q40,Q41,Q42__col0',
 'Q40_rep1': 'H14Q40,Q41,Q42_rep__col0',
 'Q41': 'H14Q40,Q41,Q42__col1',
 'Q41_rep1': 'H14Q40,Q41,Q42_rep__col1',
 'Q42': 'H14Q40,Q41,Q42__col2',
 'Q42_rep1': 'H14Q40,Q41,Q42_rep__col2',
 'Q43': 'H15Q43,Q44,Q45__col0',
 'Q44': 'H15Q43,Q44,Q45__col1',
 'Q45': 'H15Q43,Q44,Q45__col2',
 'Q46': 'H16Q46,Q47,Q48__col0',
 'Q47': 'H16Q46,Q47,Q48__col1',
 'Q48': 'H16Q46,Q47,Q48__col2',
 'Q49': 'H17Q49,Q50,Q51__col0',
 'Q5': 'H2Q4,Q5,Q6__col1',
 'Q50': 'H17Q49,Q50,Q51__col1',
 'Q51': 'H17Q49,Q50,Q51__col2',
 'Q52': 'H18Q52,Q53,Q54__col0',
 'Q53': 'H18Q52,Q53,Q54__col1',
 'Q54': 'H18Q52,Q53,Q54__col2',
 'Q6': 'H2Q4,Q5,Q6__col2',
 'Q7': 'H3Q7,Q8,Q9__col0',
 'Q8': 'H3Q7,Q8,Q9__col1',
 'Q9': 'H3Q7,Q8,Q9__col2',
 'R1': 'H58R1,R26__col1',
 'R10': 'H67R10,R35__col1',
 'R100': 'H109R75,R100__col0',
 'R11': 'H68R11,R36__col1',
 'R12': 'H69R12,R37__col1',
 'R13': 'H70R13,R38__col1',
 'R14': 'H71R14,R39__col0',
 'R15': 'H72R15,R40__col1',
 'R16': 'H73R16,R41__col1',
 'R17': 'H75R17,R42__col1',
 'R18': 'H76R18,R43__col1',
 'R19': 'H77R19,R44__col1',
 'R2': 'H59R2,R27__col1',
 'R20': 'H78R20,R45__col1',
 'R21': 'H79R21,R46__col0',
 'R22': 'H80R22,R47__col1',
 'R23': 'H81R23,R48__col1',
 'R24': 'H82R24,R49__col1',
 'R25': 'H83R25,R50__col1',
 'R26': 'H58R1,R26__col0',
 'R27': 'H59R2,R27__col0',
 'R28': 'H60R3,R28__col1',
 'R29': 'H61R4,R29__col1',
 'R3': 'H60R3,R28__col0',
 'R30': 'H62R5,R30__col0',
 'R31': 'H63R6,R31__col0',
 'R32': 'H64R7,R32__col0',
 'R33': 'H65R8,R33__col1',
 'R34': 'H66R9,R34__col0',
 'R35': 'H67R10,R35__col0',
 'R36': 'H68R11,R36__col0',
 'R37': 'H69R12,R37__col0',
 'R38': 'H70R13,R38__col0',
 'R39': 'H71R14,R39__col1',
 'R3_rep1': 'H112R3,R5__col1',
 'R4': 'H61R4,R29__col0',
 'R40': 'H72R15,R40__col0',
 'R41': 'H73R16,R41__col0',
 'R42': 'H75R17,R42__col0',
 'R43': 'H76R18,R43__col0',
 'R44': 'H77R19,R44__col0',
 'R45': 'H78R20,R45__col0',
 'R46': 'H79R21,R46__col1',
 'R47': 'H80R22,R47__col0',
 'R48': 'H81R23,R48__col0',
 'R49': 'H82R24,R49__col0',
 'R5': 'H62R5,R30__col1',
 'R50': 'H83R25,R50__col0',
 'R51': 'H84R51,R76__col1',
 'R52': 'H85R52,R77__col1',
 'R53': 'H86R53,R78__col1',
 'R54': 'H87R54,R79__col1',
 'R55': 'H88R55,R80__col1',
 'R56': 'H89R56,R81__col1',
 'R57': 'H90R57,R82__col1',
 'R58': 'H91R58,R83__col1',
 'R59': 'H92R59,R84__col1',
 'R5_rep1': 'H112R3,R5__col0',
 'R6': 'H63R6,R31__col1',
 'R60': 'H93R60,R85__col1',
 'R61': 'H94R61,R86__col1',
 'R62': 'H95R62,R87__col1',
 'R63': 'H96R63,R88__col1',
 'R64': 'H97R64,R89__col1',
 'R65': 'H98R65,B__col1',
 'R66': 'H100R66,R91__col1',
 'R67': 'H101R67,R92__col0',
 'R68': 'H102R68,R93__col1',
 'R69': 'H103R69,R94__col1',
 'R7': 'H64R7,R32__col1',
 'R70': 'H104R70,R95__col1',
 'R71': 'H105R71,R96__col1',
 'R72': 'H106R72,R97__col0',
 'R73': 'H107R73,R98__col1',
 'R74': 'H108R74,R99__col1',
 'R75': 'H109R75,R100__col1',
 'R76': 'H84R51,R76__col0',
 'R77': 'H85R52,R77__col0',
 'R78': 'H86R53,R78__col0',
 'R79': 'H87R54,R79__col0',
 'R8': 'H65R8,R33__col0',
 'R80': 'H88R55,R80__col0',
 'R80_rep1': 'H110B,R80__col0',
 'R81': 'H89R56,R81__col0',
 'R82': 'H90R57,R82__col0',
 'R83': 'H91R58,R83__col0',
 'R84': 'H92R59,R84__col0',
 'R85': 'H93R60,R85__col0',
 'R86': 'H94R61,R86__col0',
 'R87': 'H95R62,R87__col0',
 'R88': 'H96R63,R88__col0',
 'R89': 'H97R64,R89__col0',
 'R9': 'H66R9,R34__col1',
 'R90': 'H99R90,B__col1',
 'R91': 'H100R66,R91__col0',
 'R92': 'H101R67,R92__col1',
 'R93': 'H102R68,R93__col0',
 'R94': 'H103R69,R94__col0',
 'R95': 'H104R70,R95__col0',
 'R96': 'H105R71,R96__col0',
 'R97': 'H106R72,R97__col1',
 'R98': 'H107R73,R98__col0',
 'R99': 'H108R74,R99__col0',
 'U1': 'H113U1,U6__col1',
 'U10': 'H113U5,U10__col0',
 'U2': 'H113U2,U7__col1',
 'U3': 'H113U3,U8__col1',
 'U4': 'H113U4,U9__col1',
 'U5': 'H113U5,U10__col1',
 'U6': 'H113U1,U6__col0',
 'U7': 'H113U2,U7__col0',
 'U8': 'H113U3,U8__col0',
 'U9': 'H113U4,U9__col0'}

# %%
color_usage_dict = {}
for _k, _v in bb_info_dict.items():
    _reg_name = _k.lower()
    if _reg_name[0] == 'q':
        _reg_name = 'm' + _reg_name[1:] # merfish rna
    if _reg_name[0] == 'r':
        _reg_name = 'c' + _reg_name[1:] # combo dna
    _fd = _v.split('__col')[0]
    _ch = int(_v.split('__col')[1])
    print(_reg_name, _fd, _ch)
    # append
    if _fd not in color_usage_dict:
        color_usage_dict[_fd] = {}
    if _ch not in color_usage_dict[_fd]:
        color_usage_dict[_fd][_ch] = _reg_name
# Out:
# b H98R65,B 0
# b_rep1 H99R90,B 0
# b_rep2 H110B,R80 1
# m1 H1Q1,Q2,Q3 0
# m10 H4Q10,Q11,Q12 0
# m11 H4Q10,Q11,Q12 1
# m12 H4Q10,Q11,Q12 2
# m13 H5Q13,Q14,Q15 0
# m14 H5Q13,Q14,Q15 1
# m15 H5Q13,Q14,Q15 2
# m16 H6Q16,Q17,Q18 0
# m17 H6Q16,Q17,Q18 1
# m18 H6Q16,Q17,Q18 2
# m19 H7Q19,Q20,Q21 0
# m2 H1Q1,Q2,Q3 1
# m20 H7Q19,Q20,Q21 1
# m21 H7Q19,Q20,Q21 2
# m22 H8Q22,Q23,Q24_rep 0
# m22_rep1 H8Q22,Q23,Q24 0
# m23 H8Q22,Q23,Q24_rep 1
# m23_rep1 H8Q22,Q23,Q24 1
# m24 H8Q22,Q23,Q24_rep 2
# m24_rep1 H8Q22,Q23,Q24 2
# m25 H9Q25,Q26,Q27 0
# m26 H9Q25,Q26,Q27 1
# m27 H9Q25,Q26,Q27 2
# m28 H10Q28,Q29,Q30 0
# m29 H10Q28,Q29,Q30 1
# m3 H1Q1,Q2,Q3 2
# m30 H10Q28,Q29,Q30 2
# m31 H11Q31,Q32,Q33 0
# m32 H11Q31,Q32,Q33 1
# m33 H11Q31,Q32,Q33 2
# m34 H12Q34,Q35,Q36 0
# m35 H12Q34,Q35,Q36 1
# m36 H12Q34,Q35,Q36 2
# m37 H13Q37,Q38,Q39 0
# m38 H13Q37,Q38,Q39 1
# m39 H13Q37,Q38,Q39 2
# m4 H2Q4,Q5,Q6 0
# m40 H14Q40,Q41,Q42 0
# m40_rep1 H14Q40,Q41,Q42_rep 0
# m41 H14Q40,Q41,Q42 1
# ...

# %%
# append reference rounds
color_usage_dict['H0B,B'] = {}
color_usage_dict['H20B,B'] = {}

# %%
import os
import csv
import re

# %%
save_folder = r'\\10.245.74.218\Raw_data\Bogdan\7_27_2019_IMR90RNA\Pu_Analysis'
all_channels = ['750', '647', '561', '488', '405',]

lines = []

with open(os.path.join(save_folder, 'Color_Usage.tsv'), 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter='\t', 
                           quotechar='|', quoting=csv.QUOTE_MINIMAL)
    # write header
    _header = ['Hyb']+all_channels
    csvwriter.writerow(_header)
    lines.append(_header)

    for _fd in sorted(color_usage_dict, key=lambda _v:int( re.split(r'^H([0-9]+)[RQBU](.*)', _v)[1] ) ):
        _line  = [_fd]
        for _i in range(len(all_channels)-2):
            if _i in color_usage_dict[_fd]:
                _line.append(color_usage_dict[_fd][_i])
            else:
                _line.append('null')
        _line.append('beads')
        # append dapi for ref rounds
        if _fd == 'H0B,B' or _fd == 'H20B,B':
            _line.append('DAPI')
        # write row of this info
        csvwriter.writerow(_line)
        lines.append(_line)

# %%
for _line in lines:
    print(_line)
# Out:
# ['Hyb', '750', '647', '561', '488', '405']
# ['H0B,B', 'null', 'null', 'null', 'beads', 'DAPI']
# ['H1Q1,Q2,Q3', 'm1', 'm2', 'm3', 'beads']
# ['H2Q4,Q5,Q6', 'm4', 'm5', 'm6', 'beads']
# ['H3Q7,Q8,Q9', 'm7', 'm8', 'm9', 'beads']
# ['H4Q10,Q11,Q12', 'm10', 'm11', 'm12', 'beads']
# ['H5Q13,Q14,Q15', 'm13', 'm14', 'm15', 'beads']
# ['H6Q16,Q17,Q18', 'm16', 'm17', 'm18', 'beads']
# ['H7Q19,Q20,Q21', 'm19', 'm20', 'm21', 'beads']
# ['H8Q22,Q23,Q24_rep', 'm22', 'm23', 'm24', 'beads']
# ['H8Q22,Q23,Q24', 'm22_rep1', 'm23_rep1', 'm24_rep1', 'beads']
# ['H9Q25,Q26,Q27', 'm25', 'm26', 'm27', 'beads']
# ['H10Q28,Q29,Q30', 'm28', 'm29', 'm30', 'beads']
# ['H11Q31,Q32,Q33', 'm31', 'm32', 'm33', 'beads']
# ['H12Q34,Q35,Q36', 'm34', 'm35', 'm36', 'beads']
# ['H13Q37,Q38,Q39', 'm37', 'm38', 'm39', 'beads']
# ['H14Q40,Q41,Q42', 'm40', 'm41', 'm42', 'beads']
# ['H14Q40,Q41,Q42_rep', 'm40_rep1', 'm41_rep1', 'm42_rep1', 'beads']
# ['H15Q43,Q44,Q45', 'm43', 'm44', 'm45', 'beads']
# ...
