# %% [markdown]
# # Design CTP-14 human genome DNA-MERFISH library
#
# by Pu Zheng
#
# 2022.10.14

# %% [markdown]
# # Table of contents
#
#
# > 0. [Minimum required packages and settings](#0)
# >>
# >> 0.1: [import required packages](#0.1)
# >
# > 1. [Extract region sequences](#1)

# %% [markdown]
# <a id='0'></a>
# # 0 Minimum required packages and settings

# %% [markdown]
# <a id='0.1'></a>
# ## 0.1 load required packages

# %%
# %run "..\..\Startup_py3.py"
sys.path.append(r"..\..\..\..\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())

# library design specific tools
from ImageAnalysis3.library_tools import LibraryDesigner as ld
from ImageAnalysis3.library_tools import LibraryTools as lt
# biopython imports
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Blast.Applications import NcbiblastnCommandline
from Bio.Blast import NCBIXML
# Out:
# 18804

# %% [markdown]
# <a id='1'></a>
# # 1 Extract region sequences

# %%
## Some folders
# human genome
reference_folder = r'\\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\Genomes\human\hg38'
genome_folder = os.path.join(reference_folder, 'Genome')
# Library directories
pool_folder = r'\\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain'
if not os.path.exists(pool_folder):
    print(f"Create pool_folder: {pool_folder}")
    os.makedirs(pool_folder)
else:
    print(f"Use pool_folder: {pool_folder}")
# Out:
# Use pool_folder: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain

# %%
resolution = 0
flanking = 10000
# folder for sub-pool
library_folder = os.path.join(pool_folder, f'human_brain_promoter_enhancer')
if not os.path.exists(library_folder):
    print(f"create library folder: {library_folder}")
    os.makedirs(library_folder)
# folder for fasta sequences
sequence_folder = os.path.join(library_folder, 'sequences_enhancers')
if not os.path.exists(sequence_folder):
    print(f"create sequence folder: {sequence_folder}")
    os.makedirs(sequence_folder)
# folder to save result probes
report_folder = os.path.join(library_folder, 'reports')
if not os.path.exists(report_folder):
    print(f"create report folder: {report_folder}")
    os.makedirs(report_folder)
    
print(f"-- library_folder: {library_folder}")
print(f"-- sequence_folder: {sequence_folder}")
print(f"-- report_folder: {report_folder}")
# Out:
# -- library_folder: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer
# -- sequence_folder: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers
# -- report_folder: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\reports

# %% [markdown]
# <a id='1.1'></a>
# ## 1.1 select regions

# %% [markdown]
# ### Load selected SEs

# %%
import os
import pandas as pd
se_df_filename = os.path.join(library_folder, 'hM1_selected_final_cell_type_SE.csv')

se_df = pd.read_csv(se_df_filename).rename(columns={'Unnamed: 0':'region_name'})

# %%
se_df
# Out:
#                  region_name Imaged_mSE liftover_th  \
# 0       chr1_1430239_1442070        NaN         0.7
# 1       chr1_6634488_6683694        NaN         0.1
# 2       chr1_8620665_8687442        NaN         0.3
# 3       chr1_9345782_9411449        NaN         0.3
# 4       chr1_9593339_9630197        NaN         0.3
# ..                       ...        ...         ...
# 563  chr22_41957901_41979895        NaN         0.4
# 564  chr22_44316829_44352293        NaN         0.5
# 565  chr22_44571858_44599820        NaN         0.1
# 566  chr22_44928982_44981587        NaN         0.1
# 567  chr22_49767361_49811691        NaN         0.2
#
#     covering_hSE_100kb_center_to_liftover human_cell_type  \
# 0                                     NaN      Endo; VLMC
# 1                                     NaN      Vip; Pvalb
# 2                                     NaN           Pvalb
# 3                                     NaN           Oligo
# 4                                     NaN            VLMC
# ..                                    ...             ...
# 563                                   NaN           Astro
# 564                                   NaN      Pvalb; Sst
# 565                                   NaN           Pvalb
# 566                                   NaN           Lamp5
# 567                                   NaN      L6_IT_Car3
#
#          mouse_cell_type shared_cell_type  chr  merged_START  merged_STOP  \
# 0    Astro; L5_IT; Oligo             None    1       1430239      1442070
# 1         Sncg; Sst; Vip              Vip    1       6634488      6683694
# 2              Sncg; Vip             None    1       8620665      8687442
# 3        MicroPVM; Oligo            Oligo    1       9345782      9411449
# 4                  L6_CT             None    1       9593339      9630197
# ..                   ...              ...  ...           ...          ...
# 563         L5_6_NP; L6b             None   22      41957901     41979895
# 564    L5_IT; L6_IT; Vip             None   22      44316829     44352293
# 565            Sncg; Sst             None   22      44571858     44599820
# 566                Astro             None   22      44928982     44981587
# 567             L6b; Sst             None   22      49767361     49811691
#
#     merged_initial_index merged_enhancerRank  merged_enhancerNUMBER  \
# 0            [445, 7840]           [61, 154]                    2.0
# 1           [7535, 6686]          [234, 480]                    2.0
# 2                 [6593]               [387]                    1.0
# 3                 [5612]                [44]                    1.0
# 4                 [7833]               [147]                    1.0
# ..                   ...                 ...                    ...
# 563                [308]               [309]                    1.0
# 564         [6466, 7263]          [260, 286]                    2.0
# 565               [6662]               [456]                    1.0
# 566               [5019]               [264]                    1.0
# 567               [3755]               [436]                    1.0
#
#                  score  ave_score  merged_SIZE  \
# 0    [1.      0.92258]   0.961290        11831
# 1    [1.      0.78053]   0.890265        49206
# 2                 [1.]   1.000000        66777
# 3                 [1.]   1.000000        65667
# 4                 [1.]   1.000000        36858
# ..                 ...        ...          ...
# 563               [1.]   1.000000        21994
# 564  [1.      0.67962]   0.839810        35464
# 565               [1.]   1.000000        27962
# 566               [1.]   1.000000        52605
# 567               [1.]   1.000000        44330
#
#                   adjacent_mSE_10kb_center_to_liftover  \
# 0    chr4_155769707_155791654; chr4_155769885_15579...
# 1    chr4_151945203_151981828; chr4_151948574_15198...
# 2    chr4_150371536_150427020; chr4_150396749_15047...
# 3    chr4_149838364_149945586; chr4_149838647_14992...
# 4                             chr4_149710643_149734099
# ..                                                 ...
# 563   chr15_82266345_82293772; chr15_82266528_82293896
# 564  chr15_84399265_84451297; chr15_84407942_844511...
# 565   chr15_84588255_84640251; chr15_84610040_84631963
# 566                            chr15_84800208_84854291
# 567   chr15_88650962_88717686; chr15_88677548_88724924
#
#                                     liftover_loci_name  \
# 0    chr4_155768303_155781615; chr4_155768889_15578...
# 1    chr4_151948895_151981697; chr4_151959619_15198...
# 2                             chr4_150385599_150434896
# 3                             chr4_149872176_149914498
# 4                             chr4_149713698_149734072
# ..                                                 ...
# 563                            chr15_82259794_82277947
# 564   chr15_84433762_84462296; chr15_84433796_84453370
# 565                            chr15_84600041_84614158
# 566                            chr15_84812906_84832338
# 567                            chr15_88687008_88718600
#
#                    merged_mSE
# 0    chr4_155769707_155792098
# 1    chr4_151945203_151981909
# 2    chr4_150371536_150473957
# 3    chr4_149838364_149945586
# 4    chr4_149710643_149734099
# ..                        ...
# 563   chr15_82266345_82293896
# 564   chr15_84399265_84451297
# 565   chr15_84588255_84640251
# 566   chr15_84800208_84854291
# 567   chr15_88650962_88724924
#
# [568 rows x 19 columns]

# %%
len([_r for _r in se_df['Imaged_mSE'] if isinstance(_r, str)])
# Out:
# 86

# %%
np.nan
# Out:
# nan

# %%
np.isnan(se_df['Imaged_mSE'].values.astype(np.float64))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_18804\2865698748.py in <module>
# ----> 1 np.isnan(se_df['Imaged_mSE'].values.astype(np.float64))
#
# ValueError: could not convert string to float: 'chr4_131791450_131800142'

# %% [markdown]
# ### Convert into region_dicts

# %%
import re

region_dicts = []

for _i, _row in se_df.iterrows():
    
#for _i, _n in se_df[''].items():
    _match = re.match(r'chr(?P<chr>[0-9XY]+)_(?P<start>[0-9]+)_(?P<end>[0-9]+)', _row['region_name'])
    # assemble dict
    if _match:
        _dict = {
            'Chr': _match.groupdict()['chr'],
            'Start': int(_match.groupdict()['start']),
            'End': int(_match.groupdict()['end']),
            'Name': f"hSE-{_i}",
            'Gene': f'hSE-{_i}',
            'Region': f"{_match.groupdict()['chr']}:{int(_match.groupdict()['start'])}-{int(_match.groupdict()['end'])}",
            'Strand': '+',
        }
        if np.isfinite(_row['merged_enhancerNUMBER']):
            _dict['Name'] = _dict['Name'] + f"_mergeNum_{int(_row['merged_enhancerNUMBER'])}" 
        if np.isfinite(_row['merged_SIZE']):
            _dict['Name'] = _dict['Name'] + f"_mergeSize_{int(_row['merged_SIZE'])}" 
        
        # append
        region_dicts.append(_dict)

# %%
print(len(region_dicts))
print(region_dicts[0])
# Out:
# 568
# {'Chr': '1', 'Start': 1430239, 'End': 1442070, 'Name': 'hSE-0_mergeNum_2_mergeSize_11831', 'Gene': 'hSE-0', 'Region': '1:1430239-1442070', 'Strand': '+'}

# %%
# save region dict
se_dicts_filename = os.path.join(library_folder, 'enhancer_region_dicts.pkl')
overwrite = False

if not os.path.exists(se_dicts_filename) or overwrite:
    print(f"Saving to file: {se_dicts_filename}")
    pickle.dump(region_dicts, open(se_dicts_filename, 'wb'))
else:
    print(f"File: {se_dicts_filename} already exists, skip.")
# Out:
# File: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\enhancer_region_dicts.pkl already exists, skip.

# %% [markdown]
# ## Load specific sequences

# %%
reload(library_tools.references)
reload(library_tools.sequences)

# prepare sequence reader
reload(ia.library_tools.sequences)
seq_rd = ia.library_tools.sequences.sequence_reader(genome_folder)
seq_rd.load_ref_sequences() # load genomic sequences

# %%
# load tss sequences
for _tss_d in region_dicts:
    seq_rd.find_sequence_for_region(_tss_d)
print(len(seq_rd.seq_dict))

seq_rd.save_sequences(sequence_folder)
# Out:
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 1.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 2.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 3.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 4.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 5.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 6.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 7.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 8.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 9.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 10.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 11.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 12.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 13.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 14.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 15.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 16.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 17.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 18.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 19.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 20.
# -- searching among 1 references
# -- a match found in record: 21.
# -- searching among 1 references
# -- a match found in record: 21.
# -- searching among 1 references
# -- a match found in record: 21.
# -- searching among 1 references
# -- a match found in record: 21.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# -- searching among 1 references
# -- a match found in record: 22.
# 568
# -- saving sequences into folder: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-0_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-1_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-2_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-3_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-4_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-5_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-6_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-7_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-8_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-9_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-10_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-11_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-12_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-13_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-14_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-15_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-16_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-17_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-18_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-19_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-20_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-21_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-22_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-23_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-24_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-25_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-26_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-27_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-28_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-29_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-30_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-31_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-32_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-33_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-34_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-35_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-36_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-37_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-38_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-39_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-40_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-41_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-42_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-43_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-44_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-45_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-46_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-47_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-48_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-49_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-50_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-51_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-52_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-53_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-54_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-55_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-56_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-57_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-58_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-59_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-60_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-61_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-62_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-63_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-64_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-65_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-66_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-67_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-68_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-69_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-70_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-71_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-72_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-73_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-74_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-75_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-76_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-77_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-78_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-79_reg_0.fasta
# ...
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-460_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-461_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-462_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-463_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-464_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-465_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-466_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-467_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-468_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-469_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-470_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-471_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-472_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-473_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-474_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-475_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-476_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-477_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-478_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-479_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-480_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-481_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-482_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-483_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-484_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-485_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-486_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-487_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-488_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-489_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-490_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-491_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-492_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-493_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-494_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-495_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-496_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-497_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-498_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-499_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-500_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-501_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-502_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-503_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-504_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-505_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-506_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-507_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-508_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-509_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-510_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-511_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-512_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-513_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-514_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-515_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-516_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-517_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-518_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-519_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-520_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-521_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-522_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-523_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-524_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-525_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-526_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-527_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-528_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-529_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-530_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-531_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-532_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-533_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-534_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-535_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-536_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-537_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-538_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-539_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-540_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-541_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-542_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-543_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-544_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-545_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-546_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-547_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-548_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-549_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-550_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-551_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-552_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-553_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-554_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-555_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-556_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-557_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-558_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-559_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-560_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-561_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-562_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-563_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-564_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-565_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-566_reg_0.fasta
# -- save to file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences\hSE-567_reg_0.fasta

# %% [markdown]
# <a id='2'></a>
# # 2. Design probe targeting sequences by probe_designer
#
# run probe_designer, remeber to clear the memory usage because each table should take ~32GB

# %% [markdown]
# <a id='2.1'></a>
# ## 2.1 Construct count table with all the 17-mers in the genome
#
# Only do this if you don't have pre-built 17-mer
#
# However you can do almost the same thing for your own library during quality check
#
# This library requires hg38 genome

# %%
overwrite_table = False

# %% [markdown]
# ### construct map for whole genome

# %%
from ImageAnalysis3 import library_tools

# %%
reload(library_tools.design)
 
genome_table_file = os.path.join(reference_folder, 'hg38_genome_17w.npy')

if not os.path.exists(genome_table_file) or overwrite_table:
    # genome
    _genome_filenames = [os.path.join(genome_folder, _fl) 
         for _fl in os.listdir(genome_folder) 
         if _fl.split(os.extsep)[-1]=='fasta' or _fl.split(os.extsep)[-1]=='fa']
    print(len(_genome_filenames))

    ct = library_tools.design.countTable(word=17,save_file=genome_table_file, 
                       sparse=False)
    ct.verbose=True

    ct.read(_genome_filenames) # read sequences from fasta files

    ct.consume_loaded(num_threads=24) # convert sequences into integers

    ct.complete(verbose=True)

    ct.save()

    # clear RAM if contructed countable 
    del(ct)
else:
    print(f"reference table: {genome_table_file} already exist, skip.")
# Out:
# reference table: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\Genomes\human\hg38\hg38_genome_17w.npy already exist, skip.

# %% [markdown]
# ### construct map for transcriptome

# %%
from tqdm import tqdm
# transcriptome
transcriptome_folder = os.path.join(reference_folder, 'Transcriptome')

transcriptome_table_file = os.path.join(reference_folder, 'hg38_transcriptome_17w.npy')

if not os.path.exists(transcriptome_table_file) or overwrite_table:
    # transcriptome
    _transcriptome_filenames = [os.path.join(transcriptome_folder, _fl) 
         for _fl in os.listdir(transcriptome_folder) 
         if _fl.split(os.extsep)[-1]=='fasta' or _fl.split(os.extsep)[-1]=='fa']
    print(len(_transcriptome_filenames))
    
    ct = library_tools.design.countTable(word=17,save_file=transcriptome_table_file, 
                       sparse=False)
    ct.verbose=True

    ct.read(_transcriptome_filenames) # read sequences from fasta files

    ct.consume_loaded(num_threads=24) # convert sequences into integers

    ct.complete(verbose=True)

    ct.save()
    
    # clear RAM if contructed countable 
    del(ct)
else:
    print(f"reference table: {transcriptome_table_file} already exist, skip.")
# Out:
# reference table: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\Genomes\human\hg38\hg38_transcriptome_17w.npy already exist, skip.

# %% [markdown]
# ### construct map for repeats from RepBase

# %%
from tqdm import tqdm
# repeat
repeat_folder = r'\\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\Genomes\Repbase'

repeat_table_file = os.path.join(reference_folder, 'Repbase_v2603_repeat_17w.npy')

if not os.path.exists(repeat_table_file) or overwrite_table:
    # repeat
    _repeat_filenames = [os.path.join(repeat_folder, _fl) 
         for _fl in os.listdir(repeat_folder) 
         if _fl.split(os.extsep)[-1]=='fasta' or _fl.split(os.extsep)[-1]=='fa']
    print(len(_repeat_filenames))
    
    ct = library_tools.design.countTable(word=17,save_file=repeat_table_file, 
                       sparse=False)
    ct.verbose=True

    ct.read(_repeat_filenames) # read sequences from fasta files

    ct.consume_loaded(num_threads=24) # convert sequences into integers

    ct.complete(verbose=True)

    ct.save()
    
    # clear RAM if contructed countable 
    del(ct)
else:
    print(f"reference table: {repeat_table_file} already exist, skip.")
# Out:
# reference table: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\Genomes\human\hg38\Repbase_v2603_repeat_17w.npy already exist, skip.

# %% [markdown]
# <a id='2.2'></a>
# ## 2.2 Design probes

# %%
from ImageAnalysis3 import library_tools
# requires pre_defined genome_folder and library_folder
# Indices
genome_index = os.path.join(reference_folder, 'hg38_genome_17w.npy')
transcriptome_index = os.path.join(reference_folder, 'hg38_transcriptome_17w.npy') 
repeat_index = os.path.join(reference_folder, 'Repbase_v2603_repeat_17w.npy')
#ref_merfish_index = os.path.join(reference_folder, 'M1_meng_MERFISH_17w.npy') # merfish designed by Meng
# get input files 
input_files = glob.glob(os.path.join(sequence_folder, '*.fasta'))
input_files = sorted(input_files, key=lambda f:int(os.path.basename(f).split('_reg')[0].split('-')[1]))
print(f"{len(input_files)} regions loaded to design probes.")

if not os.path.exists(report_folder):
    os.makedirs(report_folder)
    
# filename to save probe reports
probe_savefile = os.path.join(report_folder, f'hSE_probes.pbr')
print(probe_savefile)
# Out:
# 568 regions loaded to design probes.
# \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\reports\hSE_probes.pbr

# %%
input_files
# Out:
# ['\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-0_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-1_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-2_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-3_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-4_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-5_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-6_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-7_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-8_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-9_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-10_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-11_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-12_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-13_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-14_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-15_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-16_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-17_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-18_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-19_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-20_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-21_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-22_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-23_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-24_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-25_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-26_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-27_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-28_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-29_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-30_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-31_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-32_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-33_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-34_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-35_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-36_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-37_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-38_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-39_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-40_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-41_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-42_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-43_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-44_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-45_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-46_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-47_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-48_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-49_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-50_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-51_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-52_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-53_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-54_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-55_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-56_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-57_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-58_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-59_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-60_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-61_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-62_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-63_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-64_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-65_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-66_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-67_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-68_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-69_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-70_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-71_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-72_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-73_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-74_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-75_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-76_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-77_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-78_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-79_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-80_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-81_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-82_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-83_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-84_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-85_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-86_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-87_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-88_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-89_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-90_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-91_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-92_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-93_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-94_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-95_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-96_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-97_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-98_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-99_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-100_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-101_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-102_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-103_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-104_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-105_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-106_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-107_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-108_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-109_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-110_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-111_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-112_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-113_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-114_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-115_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-116_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-117_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-118_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-119_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-120_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-121_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-122_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-123_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-124_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-125_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-126_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-127_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-128_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-129_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-130_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-131_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-132_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-133_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-134_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-135_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-136_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-137_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-138_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-139_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-140_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-141_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-142_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-143_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-144_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-145_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-146_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-147_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-148_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-149_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-150_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-151_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-152_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-153_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-154_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-155_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-156_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-157_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-158_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-159_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-160_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-161_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-162_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-163_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-164_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-165_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-166_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-167_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-168_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-169_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-170_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-171_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-172_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-173_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-174_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-175_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-176_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-177_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-178_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-179_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-180_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-181_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-182_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-183_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-184_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-185_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-186_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-187_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-188_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-189_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-190_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-191_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-192_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-193_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-194_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-195_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-196_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-197_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-198_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-199_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-200_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-201_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-202_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-203_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-204_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-205_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-206_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-207_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-208_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-209_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-210_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-211_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-212_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-213_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-214_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-215_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-216_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-217_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-218_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-219_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-220_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-221_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-222_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-223_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-224_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-225_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-226_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-227_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-228_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-229_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-230_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-231_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-232_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-233_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-234_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-235_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-236_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-237_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-238_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-239_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-240_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-241_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-242_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-243_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-244_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-245_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-246_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-247_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-248_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-249_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-250_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-251_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-252_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-253_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-254_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-255_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-256_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-257_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-258_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-259_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-260_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-261_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-262_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-263_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-264_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-265_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-266_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-267_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-268_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-269_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-270_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-271_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-272_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-273_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-274_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-275_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-276_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-277_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-278_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-279_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-280_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-281_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-282_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-283_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-284_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-285_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-286_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-287_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-288_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-289_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-290_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-291_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-292_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-293_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-294_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-295_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-296_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-297_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-298_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-299_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-300_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-301_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-302_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-303_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-304_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-305_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-306_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-307_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-308_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-309_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-310_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-311_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-312_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-313_reg_0.fasta',
# ...
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-464_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-465_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-466_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-467_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-468_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-469_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-470_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-471_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-472_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-473_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-474_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-475_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-476_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-477_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-478_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-479_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-480_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-481_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-482_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-483_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-484_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-485_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-486_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-487_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-488_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-489_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-490_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-491_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-492_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-493_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-494_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-495_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-496_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-497_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-498_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-499_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-500_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-501_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-502_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-503_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-504_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-505_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-506_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-507_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-508_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-509_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-510_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-511_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-512_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-513_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-514_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-515_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-516_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-517_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-518_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-519_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-520_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-521_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-522_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-523_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-524_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-525_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-526_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-527_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-528_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-529_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-530_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-531_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-532_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-533_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-534_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-535_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-536_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-537_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-538_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-539_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-540_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-541_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-542_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-543_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-544_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-545_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-546_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-547_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-548_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-549_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-550_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-551_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-552_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-553_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-554_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-555_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-556_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-557_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-558_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-559_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-560_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-561_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-562_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-563_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-564_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-565_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-566_reg_0.fasta',
#  '\\\\10.245.74.212\\Chromatin_NAS_2\\Chromatin_Libraries\\CTP-14_human_brain\\human_brain_promoter_enhancer\\sequences_enhancers\\hSE-567_reg_0.fasta']

# %% [markdown]
# ### create pb_designer class

# %%
reload(library_tools)
reload(library_tools.design)

pb_designer = library_tools.design.pb_reports_class(
    sequence_dic={'file':input_files,
                  'rev_com':True, # design two strands
                  'two_stranded':True},
    map_dic={'genome':{'file':genome_index,'rev_com':False,'two_stranded':True},
             'transcriptome':{'file':transcriptome_index,'rev_com':True,'two_stranded':False},
             'rep_genome':{'file':repeat_index,'rev_com':False,'two_stranded':True},
             'self_sequences':{'file':input_files,'force_list':True,'rev_com':False,'two_stranded':True},
             #'ref_merfish':{'file':ref_merfish_index,'rev_com':False,'two_stranded':True},
             },
        save_file=probe_savefile,
    params_dic={'word_size':17,'pb_len':42,'buffer_len':2,'max_count':2**16-1,
                'check_on_go': False, # whether automatically check probes
                'auto': False, # whether automatically convert reference maps
               },
    check_dic={('genome','self_sequences'): 25,
               'rep_genome': 0,
               'transcriptome': 25, # 14
               #'ref_merfish': 14,
               'gc':[0.25,0.75],'tm': 37+0.62*50+5,
               }
    )
print(pb_designer)
pb_designer.load_from_file(load_probes_only=True)
# Out:
# Probe designer derived from Bogdan Bintu:
# https://github.com/BogdanBintu/ChromatinImaging/blob/master/LibraryDesign/LibraryDesigner.py
# by Pu Zheng, 2020.11
#
# Major changes:
#     1. allow design of two strands
#     2. separate reverse_complement (rev_com) and from two strands (two_stranded) as
#     two different inputs for map_dic and sequence_dic
#     3. replace 'local_genome' with 'self_sequences' to be more explicit, and only
#     exclude the counts for the corresponding self_sequence within each input.
#
# Key information:
#     - number of input_sequence(s): 568
#     - save_file location: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\reports\hSE_probes.pbr
#
# - Fail to load from savefile: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\reports\hSE_probes.pbr, file doesn't exist.
# False

# %% [markdown]
# ### calculate probe reports

# %%
# %%time
pb_designer.computeOTmaps() # load the tables 
pb_designer.compute_pb_report() # design candidate probes
# Out:
# -- setting attribute: map_genome
# --- finish map_genome in 119.473s.
# -- setting attribute: map_transcriptome
# --- finish map_transcriptome in 144.201s.
# -- setting attribute: map_rep_genome
# --- finish map_rep_genome in 143.362s.
# Time(s): 407.0357446670532
# - Designing targeting sequence for 568 regions
# -- designing region: 1:1430239-1442070_strand_+_gene_hSE-0 -- region: 0, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-0_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.279s.
# - Designed 23582 candidate probes in 8.738s.
# -- designing region: 1:6634488-6683694_strand_+_gene_hSE-1 -- region: 1, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-1_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.303s.
# - Designed 98332 candidate probes in 41.693s.
# -- designing region: 1:8620665-8687442_strand_+_gene_hSE-2 -- region: 2, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-2_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 1.114s.
# - Designed 133474 candidate probes in 54.657s.
# -- designing region: 1:9345782-9411449_strand_+_gene_hSE-3 -- region: 3, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-3_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.420s.
# - Designed 131254 candidate probes in 41.102s.
# -- designing region: 1:9593339-9630197_strand_+_gene_hSE-4 -- region: 4, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-4_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.345s.
# - Designed 73636 candidate probes in 21.138s.
# -- designing region: 1:11784919-11803898_strand_+_gene_hSE-5 -- region: 5, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-5_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.234s.
# - Designed 37878 candidate probes in 10.462s.
# -- designing region: 1:13712764-13767099_strand_+_gene_hSE-6 -- region: 6, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-6_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.351s.
# - Designed 108590 candidate probes in 34.106s.
# -- designing region: 1:15304714-15342680_strand_+_gene_hSE-7 -- region: 7, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-7_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.303s.
# - Designed 75852 candidate probes in 20.317s.
# -- designing region: 1:19376017-19455255_strand_+_gene_hSE-8 -- region: 8, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-8_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.371s.
# - Designed 158396 candidate probes in 41.580s.
# -- designing region: 1:20682311-20712550_strand_+_gene_hSE-9 -- region: 9, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-9_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.258s.
# - Designed 60398 candidate probes in 16.253s.
# -- designing region: 1:21638668-21674028_strand_+_gene_hSE-10 -- region: 10, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-10_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.283s.
# - Designed 70640 candidate probes in 18.875s.
# -- designing region: 1:22799957-22855040_strand_+_gene_hSE-11 -- region: 11, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-11_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.325s.
# - Designed 110086 candidate probes in 29.075s.
# -- designing region: 1:23539736-23581634_strand_+_gene_hSE-12 -- region: 12, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-12_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.295s.
# - Designed 83716 candidate probes in 22.272s.
# -- designing region: 1:24688503-24736373_strand_+_gene_hSE-13 -- region: 13, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-13_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.294s.
# - Designed 95660 candidate probes in 25.235s.
# -- designing region: 1:27858017-27892069_strand_+_gene_hSE-14 -- region: 14, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-14_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.277s.
# - Designed 68024 candidate probes in 18.185s.
# -- designing region: 1:29256947-29342815_strand_+_gene_hSE-15 -- region: 15, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-15_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.414s.
# - Designed 171656 candidate probes in 44.986s.
# -- designing region: 1:30085753-30111941_strand_+_gene_hSE-16 -- region: 16, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-16_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.252s.
# - Designed 52296 candidate probes in 14.167s.
# -- designing region: 1:32972754-33026496_strand_+_gene_hSE-17 -- region: 17, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-17_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.326s.
# - Designed 107404 candidate probes in 28.255s.
# -- designing region: 1:33364069-33410626_strand_+_gene_hSE-18 -- region: 18, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-18_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.300s.
# - Designed 93034 candidate probes in 24.637s.
# -- designing region: 1:33942513-33985735_strand_+_gene_hSE-19 -- region: 19, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-19_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.305s.
# - Designed 86364 candidate probes in 22.964s.
# -- designing region: 1:36160823-36200646_strand_+_gene_hSE-20 -- region: 20, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-20_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.302s.
# - Designed 79566 candidate probes in 21.148s.
# -- designing region: 1:40383030-40405268_strand_+_gene_hSE-21 -- region: 21, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-21_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.260s.
# - Designed 44396 candidate probes in 12.122s.
# -- designing region: 1:42924178-42932394_strand_+_gene_hSE-22 -- region: 22, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-22_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.215s.
# - Designed 16352 candidate probes in 4.867s.
# -- designing region: 1:43271997-43295887_strand_+_gene_hSE-23 -- region: 23, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-23_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.256s.
# - Designed 47700 candidate probes in 12.948s.
# -- designing region: 1:47211730-47239911_strand_+_gene_hSE-24 -- region: 24, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-24_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.268s.
# - Designed 56282 candidate probes in 15.230s.
# -- designing region: 1:74463706-74546503_strand_+_gene_hSE-25 -- region: 25, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-25_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.436s.
# - Designed 165514 candidate probes in 43.524s.
# -- designing region: 1:83889722-83950902_strand_+_gene_hSE-26 -- region: 26, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-26_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.370s.
# - Designed 122280 candidate probes in 32.330s.
# -- designing region: 1:84344166-84387321_strand_+_gene_hSE-27 -- region: 27, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-27_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.320s.
# - Designed 86230 candidate probes in 23.035s.
# -- designing region: 1:84753497-84785597_strand_+_gene_hSE-28 -- region: 28, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-28_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.290s.
# - Designed 64120 candidate probes in 17.277s.
# -- designing region: 1:87938009-87981108_strand_+_gene_hSE-29 -- region: 29, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-29_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.323s.
# - Designed 86118 candidate probes in 29.440s.
# -- designing region: 1:93595674-93641187_strand_+_gene_hSE-30 -- region: 30, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-30_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.337s.
# - Designed 90946 candidate probes in 24.261s.
# -- designing region: 1:108804549-108852967_strand_+_gene_hSE-31 -- region: 31, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-31_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.355s.
# - Designed 96756 candidate probes in 25.772s.
# -- designing region: 1:111471042-111516564_strand_+_gene_hSE-32 -- region: 32, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-32_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.326s.
# - Designed 90964 candidate probes in 24.459s.
# -- designing region: 1:113239232-113299463_strand_+_gene_hSE-33 -- region: 33, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-33_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.379s.
# - Designed 120382 candidate probes in 31.839s.
# -- designing region: 1:116458014-116485677_strand_+_gene_hSE-34 -- region: 34, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-34_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.271s.
# - Designed 55246 candidate probes in 14.984s.
# -- designing region: 1:119581001-119631839_strand_+_gene_hSE-35 -- region: 35, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-35_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.340s.
# - Designed 101596 candidate probes in 26.981s.
# -- designing region: 1:150159530-150187849_strand_+_gene_hSE-36 -- region: 36, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-36_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.276s.
# - Designed 56558 candidate probes in 15.319s.
# -- designing region: 1:155069705-155094754_strand_+_gene_hSE-37 -- region: 37, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-37_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.265s.
# - Designed 50018 candidate probes in 13.525s.
# -- designing region: 1:155961029-155989716_strand_+_gene_hSE-38 -- region: 38, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-38_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.270s.
# - Designed 57294 candidate probes in 15.476s.
# -- designing region: 1:156122739-156147282_strand_+_gene_hSE-39 -- region: 39, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-39_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.254s.
# - Designed 49006 candidate probes in 13.323s.
# -- designing region: 1:159181407-159219417_strand_+_gene_hSE-40 -- region: 40, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-40_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.329s.
# - Designed 75940 candidate probes in 20.298s.
# -- designing region: 1:162180487-162254771_strand_+_gene_hSE-41 -- region: 41, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-41_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.539s.
# - Designed 148488 candidate probes in 39.252s.
# -- designing region: 1:162877908-162950638_strand_+_gene_hSE-42 -- region: 42, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-42_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.407s.
# - Designed 145380 candidate probes in 38.253s.
# -- designing region: 1:166057386-166096188_strand_+_gene_hSE-43 -- region: 43, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-43_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.320s.
# - Designed 77524 candidate probes in 20.764s.
# -- designing region: 1:167600121-167663464_strand_+_gene_hSE-44 -- region: 44, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-44_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.375s.
# - Designed 126606 candidate probes in 33.484s.
# -- designing region: 1:168360565-168403520_strand_+_gene_hSE-45 -- region: 45, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-45_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.318s.
# - Designed 85830 candidate probes in 22.890s.
# -- designing region: 1:169081022-169110120_strand_+_gene_hSE-46 -- region: 46, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-46_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.273s.
# - Designed 58116 candidate probes in 15.755s.
# -- designing region: 1:182114177-182144615_strand_+_gene_hSE-47 -- region: 47, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-47_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.283s.
# - Designed 60796 candidate probes in 16.397s.
# -- designing region: 1:182651253-182684870_strand_+_gene_hSE-48 -- region: 48, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-48_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.294s.
# - Designed 67154 candidate probes in 18.018s.
# -- designing region: 1:202101074-202135594_strand_+_gene_hSE-49 -- region: 49, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-49_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.279s.
# - Designed 68960 candidate probes in 18.486s.
# -- designing region: 1:209850354-209886516_strand_+_gene_hSE-50 -- region: 50, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-50_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.292s.
# - Designed 72244 candidate probes in 19.361s.
# -- designing region: 1:211731778-211757085_strand_+_gene_hSE-51 -- region: 51, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-51_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.270s.
# - Designed 50534 candidate probes in 13.746s.
# -- designing region: 1:212450290-212515259_strand_+_gene_hSE-52 -- region: 52, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-52_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.380s.
# - Designed 129858 candidate probes in 34.412s.
# -- designing region: 1:213996599-214037834_strand_+_gene_hSE-53 -- region: 53, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-53_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.308s.
# - Designed 82390 candidate probes in 29.627s.
# -- designing region: 1:214303536-214372510_strand_+_gene_hSE-54 -- region: 54, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-54_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.368s.
# - Designed 137868 candidate probes in 36.239s.
# -- designing region: 1:223749018-223812070_strand_+_gene_hSE-55 -- region: 55, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-55_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.353s.
# - Designed 126024 candidate probes in 33.249s.
# -- designing region: 1:225845735-225880437_strand_+_gene_hSE-56 -- region: 56, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-56_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.280s.
# - Designed 69324 candidate probes in 18.630s.
# -- designing region: 1:229364081-229417075_strand_+_gene_hSE-57 -- region: 57, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-57_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.329s.
# - Designed 105908 candidate probes in 28.044s.
# -- designing region: 1:230797884-230859532_strand_+_gene_hSE-58 -- region: 58, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-58_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.361s.
# - Designed 123216 candidate probes in 41.115s.
# -- designing region: 1:231683651-231757238_strand_+_gene_hSE-59 -- region: 59, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-59_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.360s.
# - Designed 147094 candidate probes in 38.653s.
# -- designing region: 1:233627407-233674330_strand_+_gene_hSE-60 -- region: 60, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-60_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.327s.
# - Designed 93766 candidate probes in 24.924s.
# -- designing region: 1:234067937-234124233_strand_+_gene_hSE-61 -- region: 61, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-61_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.351s.
# - Designed 112512 candidate probes in 29.820s.
# -- designing region: 1:236673262-236734560_strand_+_gene_hSE-62 -- region: 62, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-62_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.356s.
# - Designed 122516 candidate probes in 32.976s.
# -- designing region: 1:237170162-237235604_strand_+_gene_hSE-63 -- region: 63, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-63_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.366s.
# - Designed 130804 candidate probes in 34.422s.
# -- designing region: 1:240985018-241034779_strand_+_gene_hSE-64 -- region: 64, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-64_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.332s.
# - Designed 99442 candidate probes in 26.399s.
# -- designing region: 1:248850425-248874090_strand_+_gene_hSE-65 -- region: 65, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-65_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.254s.
# - Designed 47250 candidate probes in 12.920s.
# -- designing region: 2:2285196-2326618_strand_+_gene_hSE-66 -- region: 66, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-66_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.314s.
# - Designed 82764 candidate probes in 22.041s.
# -- designing region: 2:17892542-17940538_strand_+_gene_hSE-67 -- region: 67, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-67_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.342s.
# - Designed 95912 candidate probes in 25.505s.
# -- designing region: 2:25895563-25957062_strand_+_gene_hSE-68 -- region: 68, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-68_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.344s.
# - Designed 122918 candidate probes in 32.375s.
# -- designing region: 2:28389910-28423879_strand_+_gene_hSE-69 -- region: 69, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-69_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.294s.
# - Designed 67858 candidate probes in 18.267s.
# -- designing region: 2:30115178-30158156_strand_+_gene_hSE-70 -- region: 70, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-70_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.321s.
# - Designed 85876 candidate probes in 22.882s.
# -- designing region: 2:40435529-40489838_strand_+_gene_hSE-71 -- region: 71, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-71_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.357s.
# - Designed 108538 candidate probes in 28.791s.
# -- designing region: 2:55111810-55139043_strand_+_gene_hSE-72 -- region: 72, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-72_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.269s.
# - Designed 54386 candidate probes in 14.795s.
# -- designing region: 2:65351295-65415355_strand_+_gene_hSE-73 -- region: 73, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-73_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.384s.
# - Designed 128040 candidate probes in 33.865s.
# -- designing region: 2:68679255-68752177_strand_+_gene_hSE-74 -- region: 74, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-74_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.422s.
# - Designed 145764 candidate probes in 38.417s.
# -- designing region: 2:70132418-70142985_strand_+_gene_hSE-75 -- region: 75, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-75_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.217s.
# - Designed 21054 candidate probes in 6.184s.
# -- designing region: 2:70679166-70734203_strand_+_gene_hSE-76 -- region: 76, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-76_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.369s.
# - Designed 109994 candidate probes in 29.155s.
# -- designing region: 2:72127833-72150745_strand_+_gene_hSE-77 -- region: 77, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-77_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.284s.
# - Designed 45744 candidate probes in 12.603s.
# -- designing region: 2:74806927-74876578_strand_+_gene_hSE-78 -- region: 78, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-78_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.396s.
# - Designed 139222 candidate probes in 36.664s.
# -- designing region: 2:85993858-86055654_strand_+_gene_hSE-79 -- region: 79, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-79_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.388s.
# - Designed 123512 candidate probes in 32.705s.
# -- designing region: 2:95301818-95323825_strand_+_gene_hSE-80 -- region: 80, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-80_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.258s.
# - Designed 43934 candidate probes in 12.111s.
# -- designing region: 2:98455476-98519608_strand_+_gene_hSE-81 -- region: 81, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-81_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.384s.
# - Designed 128184 candidate probes in 33.856s.
# -- designing region: 2:101734463-101831718_strand_+_gene_hSE-82 -- region: 82, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-82_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.504s.
# - Designed 194430 candidate probes in 51.074s.
# -- designing region: 2:104825985-104845399_strand_+_gene_hSE-83 -- region: 83, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-83_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.241s.
# - Designed 38748 candidate probes in 10.771s.
# -- designing region: 2:111347565-111407472_strand_+_gene_hSE-84 -- region: 84, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-84_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.359s.
# - Designed 119734 candidate probes in 31.641s.
# -- designing region: 2:128299141-128322199_strand_+_gene_hSE-85 -- region: 85, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-85_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.250s.
# - Designed 46036 candidate probes in 12.613s.
# -- designing region: 2:135157923-135196307_strand_+_gene_hSE-86 -- region: 86, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-86_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.312s.
# - Designed 76688 candidate probes in 20.449s.
# -- designing region: 2:158619217-158676750_strand_+_gene_hSE-87 -- region: 87, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-87_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.354s.
# - Designed 114986 candidate probes in 30.446s.
# -- designing region: 2:161217490-161250781_strand_+_gene_hSE-88 -- region: 88, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-88_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.300s.
# - Designed 66502 candidate probes in 18.277s.
# -- designing region: 2:162146510-162203239_strand_+_gene_hSE-89 -- region: 89, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-89_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 2.125s.
# - Designed 113378 candidate probes in 36.199s.
# -- designing region: 2:168118569-168183848_strand_+_gene_hSE-90 -- region: 90, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-90_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.388s.
# - Designed 130478 candidate probes in 34.367s.
# -- designing region: 2:170190614-170242013_strand_+_gene_hSE-91 -- region: 91, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-91_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.322s.
# - Designed 102718 candidate probes in 38.388s.
# -- designing region: 2:170803888-170822682_strand_+_gene_hSE-92 -- region: 92, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-92_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.230s.
# - Designed 37508 candidate probes in 10.379s.
# -- designing region: 2:172667041-172743591_strand_+_gene_hSE-93 -- region: 93, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-93_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.382s.
# - Designed 153020 candidate probes in 40.156s.
# -- designing region: 2:216004762-216045454_strand_+_gene_hSE-94 -- region: 94, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-94_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.301s.
# - Designed 81304 candidate probes in 21.699s.
# -- designing region: 2:216682392-216711300_strand_+_gene_hSE-95 -- region: 95, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-95_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.267s.
# - Designed 57736 candidate probes in 15.611s.
# -- designing region: 2:219261532-219299142_strand_+_gene_hSE-96 -- region: 96, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-96_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.294s.
# - Designed 75140 candidate probes in 20.090s.
# -- designing region: 2:219506346-219530597_strand_+_gene_hSE-97 -- region: 97, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-97_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.257s.
# - Designed 48422 candidate probes in 13.233s.
# -- designing region: 2:219642387-219690095_strand_+_gene_hSE-98 -- region: 98, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-98_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.325s.
# - Designed 95336 candidate probes in 25.383s.
# -- designing region: 2:229633545-229675837_strand_+_gene_hSE-99 -- region: 99, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-99_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.310s.
# - Designed 84504 candidate probes in 22.569s.
# -- designing region: 2:232303321-232335665_strand_+_gene_hSE-100 -- region: 100, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-100_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.278s.
# - Designed 64608 candidate probes in 17.449s.
# -- designing region: 3:229810-285643_strand_+_gene_hSE-101 -- region: 101, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-101_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.348s.
# - Designed 111586 candidate probes in 29.546s.
# -- designing region: 3:11183206-11212608_strand_+_gene_hSE-102 -- region: 102, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-102_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.272s.
# - Designed 58724 candidate probes in 15.939s.
# -- designing region: 3:16439998-16496611_strand_+_gene_hSE-103 -- region: 103, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-103_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.350s.
# - Designed 113146 candidate probes in 29.995s.
# -- designing region: 3:18369517-18408885_strand_+_gene_hSE-104 -- region: 104, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-104_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.306s.
# - Designed 78656 candidate probes in 21.052s.
# -- designing region: 3:30629143-30668635_strand_+_gene_hSE-105 -- region: 105, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-105_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.303s.
# - Designed 78904 candidate probes in 21.118s.
# -- designing region: 3:37529575-37558895_strand_+_gene_hSE-106 -- region: 106, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-106_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.273s.
# - Designed 58560 candidate probes in 15.898s.
# -- designing region: 3:39177787-39268066_strand_+_gene_hSE-107 -- region: 107, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-107_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.468s.
# - Designed 180478 candidate probes in 47.476s.
# -- designing region: 3:40143076-40202975_strand_+_gene_hSE-108 -- region: 108, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-108_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.370s.
# - Designed 119718 candidate probes in 31.755s.
# -- designing region: 3:42419688-42459881_strand_+_gene_hSE-109 -- region: 109, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-109_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.309s.
# - Designed 80306 candidate probes in 21.545s.
# -- designing region: 3:42712818-42763438_strand_+_gene_hSE-110 -- region: 110, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-110_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.336s.
# - Designed 101160 candidate probes in 26.956s.
# -- designing region: 3:50243183-50260429_strand_+_gene_hSE-111 -- region: 111, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-111_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.232s.
# - Designed 34412 candidate probes in 9.593s.
# -- designing region: 3:50408362-50475060_strand_+_gene_hSE-112 -- region: 112, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-112_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.413s.
# - Designed 133316 candidate probes in 35.180s.
# -- designing region: 3:50623107-50649902_strand_+_gene_hSE-113 -- region: 113, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-113_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.265s.
# - Designed 53510 candidate probes in 14.569s.
# -- designing region: 3:51681373-51705022_strand_+_gene_hSE-114 -- region: 114, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-114_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.260s.
# - Designed 47218 candidate probes in 12.957s.
# -- designing region: 3:52468183-52498525_strand_+_gene_hSE-115 -- region: 115, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-115_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.279s.
# - Designed 60604 candidate probes in 16.379s.
# -- designing region: 3:53153934-53176878_strand_+_gene_hSE-116 -- region: 116, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-116_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.252s.
# - Designed 45808 candidate probes in 12.535s.
# -- designing region: 3:53989310-54046045_strand_+_gene_hSE-117 -- region: 117, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-117_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.353s.
# - Designed 113390 candidate probes in 30.067s.
# -- designing region: 3:56073355-56153695_strand_+_gene_hSE-118 -- region: 118, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-118_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.450s.
# - Designed 160600 candidate probes in 42.349s.
# -- designing region: 3:61874703-61937952_strand_+_gene_hSE-119 -- region: 119, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-119_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.354s.
# - Designed 126418 candidate probes in 33.442s.
# -- designing region: 3:63324550-63371885_strand_+_gene_hSE-120 -- region: 120, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-120_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.321s.
# - Designed 94590 candidate probes in 25.193s.
# -- designing region: 3:64116478-64181338_strand_+_gene_hSE-121 -- region: 121, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-121_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.375s.
# - Designed 129640 candidate probes in 34.249s.
# -- designing region: 3:65381472-65427232_strand_+_gene_hSE-122 -- region: 122, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-122_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.326s.
# - Designed 91440 candidate probes in 24.380s.
# -- designing region: 3:113241829-113290175_strand_+_gene_hSE-123 -- region: 123, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-123_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.332s.
# - Designed 96612 candidate probes in 26.918s.
# ...
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.337s.
# - Designed 95830 candidate probes in 25.432s.
# -- designing region: 20:10311323-10352964_strand_+_gene_hSE-528 -- region: 528, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-528_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.318s.
# - Designed 83202 candidate probes in 25.131s.
# -- designing region: 20:16241799-16297292_strand_+_gene_hSE-529 -- region: 529, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-529_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.357s.
# - Designed 110906 candidate probes in 32.061s.
# -- designing region: 20:19961140-19993999_strand_+_gene_hSE-530 -- region: 530, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-530_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.288s.
# - Designed 65638 candidate probes in 20.640s.
# -- designing region: 20:21505148-21530281_strand_+_gene_hSE-531 -- region: 531, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-531_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.260s.
# - Designed 50186 candidate probes in 13.638s.
# -- designing region: 20:31661589-31699620_strand_+_gene_hSE-532 -- region: 532, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-532_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.303s.
# - Designed 75982 candidate probes in 20.319s.
# -- designing region: 20:33415919-33476076_strand_+_gene_hSE-533 -- region: 533, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-533_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.351s.
# - Designed 120234 candidate probes in 38.512s.
# -- designing region: 20:33819468-33871657_strand_+_gene_hSE-534 -- region: 534, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-534_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.356s.
# - Designed 104298 candidate probes in 27.758s.
# -- designing region: 20:37823836-37864837_strand_+_gene_hSE-535 -- region: 535, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-535_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.318s.
# - Designed 81922 candidate probes in 22.026s.
# -- designing region: 20:41631734-41671044_strand_+_gene_hSE-536 -- region: 536, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-536_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.312s.
# - Designed 78540 candidate probes in 21.102s.
# -- designing region: 20:44594716-44642895_strand_+_gene_hSE-537 -- region: 537, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-537_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.336s.
# - Designed 96278 candidate probes in 25.686s.
# -- designing region: 20:44763069-44806416_strand_+_gene_hSE-538 -- region: 538, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-538_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.326s.
# - Designed 86614 candidate probes in 23.254s.
# -- designing region: 20:45962258-46014521_strand_+_gene_hSE-539 -- region: 539, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-539_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.342s.
# - Designed 104446 candidate probes in 27.777s.
# -- designing region: 20:46559688-46588481_strand_+_gene_hSE-540 -- region: 540, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-540_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.278s.
# - Designed 57506 candidate probes in 15.643s.
# -- designing region: 20:51668504-51757755_strand_+_gene_hSE-541 -- region: 541, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-541_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.458s.
# - Designed 178422 candidate probes in 46.914s.
# -- designing region: 20:53608390-53661187_strand_+_gene_hSE-542 -- region: 542, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-542_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.330s.
# - Designed 105514 candidate probes in 28.022s.
# -- designing region: 20:57648277-57684109_strand_+_gene_hSE-543 -- region: 543, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-543_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.303s.
# - Designed 71584 candidate probes in 19.363s.
# -- designing region: 20:59560512-59645271_strand_+_gene_hSE-544 -- region: 544, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-544_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.473s.
# - Designed 169438 candidate probes in 44.735s.
# -- designing region: 20:61619691-61664938_strand_+_gene_hSE-545 -- region: 545, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-545_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.341s.
# - Designed 90414 candidate probes in 24.253s.
# -- designing region: 20:62210388-62235513_strand_+_gene_hSE-546 -- region: 546, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-546_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.263s.
# - Designed 50170 candidate probes in 13.714s.
# -- designing region: 21:26127925-26173760_strand_+_gene_hSE-547 -- region: 547, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-547_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.325s.
# - Designed 91590 candidate probes in 24.392s.
# -- designing region: 21:33008810-33064965_strand_+_gene_hSE-548 -- region: 548, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-548_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.364s.
# - Designed 112230 candidate probes in 29.805s.
# -- designing region: 21:33359387-33394726_strand_+_gene_hSE-549 -- region: 549, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-549_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.287s.
# - Designed 70598 candidate probes in 18.967s.
# -- designing region: 21:45104328-45161413_strand_+_gene_hSE-550 -- region: 550, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-550_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.370s.
# - Designed 114090 candidate probes in 30.377s.
# -- designing region: 22:18810242-18833000_strand_+_gene_hSE-551 -- region: 551, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-551_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.254s.
# - Designed 45436 candidate probes in 12.492s.
# -- designing region: 22:21743448-21775567_strand_+_gene_hSE-552 -- region: 552, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-552_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.282s.
# - Designed 64158 candidate probes in 17.239s.
# -- designing region: 22:23814940-23849939_strand_+_gene_hSE-553 -- region: 553, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-553_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.302s.
# - Designed 69918 candidate probes in 18.797s.
# -- designing region: 22:25680920-25726737_strand_+_gene_hSE-554 -- region: 554, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-554_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.322s.
# - Designed 91554 candidate probes in 24.385s.
# -- designing region: 22:27270723-27332254_strand_+_gene_hSE-555 -- region: 555, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-555_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.367s.
# - Designed 122982 candidate probes in 32.501s.
# -- designing region: 22:27642125-27686973_strand_+_gene_hSE-556 -- region: 556, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-556_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.323s.
# - Designed 89616 candidate probes in 23.867s.
# -- designing region: 22:28009271-28052211_strand_+_gene_hSE-557 -- region: 557, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-557_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.328s.
# - Designed 85800 candidate probes in 22.910s.
# -- designing region: 22:28943224-29023880_strand_+_gene_hSE-558 -- region: 558, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-558_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.457s.
# - Designed 161232 candidate probes in 42.338s.
# -- designing region: 22:30856108-30891077_strand_+_gene_hSE-559 -- region: 559, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-559_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.293s.
# - Designed 69858 candidate probes in 22.119s.
# -- designing region: 22:33471967-33536400_strand_+_gene_hSE-560 -- region: 560, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-560_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.402s.
# - Designed 128786 candidate probes in 33.943s.
# -- designing region: 22:33656962-33708838_strand_+_gene_hSE-561 -- region: 561, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-561_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.355s.
# - Designed 103672 candidate probes in 27.632s.
# -- designing region: 22:38763990-38812092_strand_+_gene_hSE-562 -- region: 562, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-562_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.338s.
# - Designed 96124 candidate probes in 28.464s.
# -- designing region: 22:41957901-41979895_strand_+_gene_hSE-563 -- region: 563, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-563_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.246s.
# - Designed 43908 candidate probes in 14.355s.
# -- designing region: 22:44316829-44352293_strand_+_gene_hSE-564 -- region: 564, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-564_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.753s.
# - Designed 70848 candidate probes in 20.429s.
# -- designing region: 22:44571858-44599820_strand_+_gene_hSE-565 -- region: 565, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-565_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.260s.
# - Designed 55844 candidate probes in 15.086s.
# -- designing region: 22:44928982-44981587_strand_+_gene_hSE-566 -- region: 566, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-566_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.351s.
# - Designed 105130 candidate probes in 27.931s.
# -- designing region: 22:49767361-49811691_strand_+_gene_hSE-567 -- region: 567, input file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\sequences_enhancers\hSE-567_reg_0.fasta
# -- setting attribute: map_self_sequences
# - Mapping no. of seqs: 1
# --- finish map_self_sequences in 0.317s.
# - Designed 88580 candidate probes in 75.957s.
# - Save reports into file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\reports\hSE_probes.pbr
# Wall time: 4h 30min 41s

# %% [markdown]
# ### check probes

# %%
pbs, pb_scores = pb_designer.check_probes()
# Out:
# -- check region:0 1:1430239-1442070_strand_+_gene_hSE-0, 23582 candidate probes
# --- 8209 probes passed check_dic selection.
# finish in 1.090s, 162 probes kept.
# -- check region:1 1:6634488-6683694_strand_+_gene_hSE-1, 94514 candidate probes
# --- 29539 probes passed check_dic selection.
# finish in 4.170s, 464 probes kept.
# -- check region:2 1:8620665-8687442_strand_+_gene_hSE-2, 130980 candidate probes
# --- 28534 probes passed check_dic selection.
# finish in 4.682s, 538 probes kept.
# -- check region:3 1:9345782-9411449_strand_+_gene_hSE-3, 127244 candidate probes
# --- 49545 probes passed check_dic selection.
# finish in 4.533s, 716 probes kept.
# -- check region:4 1:9593339-9630197_strand_+_gene_hSE-4, 70700 candidate probes
# --- 25324 probes passed check_dic selection.
# finish in 2.254s, 411 probes kept.
# -- check region:5 1:11784919-11803898_strand_+_gene_hSE-5, 37194 candidate probes
# --- 12984 probes passed check_dic selection.
# finish in 1.196s, 211 probes kept.
# -- check region:6 1:13712764-13767099_strand_+_gene_hSE-6, 106434 candidate probes
# --- 31424 probes passed check_dic selection.
# finish in 3.034s, 561 probes kept.
# -- check region:7 1:15304714-15342680_strand_+_gene_hSE-7, 74408 candidate probes
# --- 21373 probes passed check_dic selection.
# finish in 2.149s, 373 probes kept.
# -- check region:8 1:19376017-19455255_strand_+_gene_hSE-8, 156142 candidate probes
# --- 66160 probes passed check_dic selection.
# finish in 5.337s, 938 probes kept.
# -- check region:9 1:20682311-20712550_strand_+_gene_hSE-9, 58494 candidate probes
# --- 19745 probes passed check_dic selection.
# finish in 1.809s, 316 probes kept.
# -- check region:10 1:21638668-21674028_strand_+_gene_hSE-10, 69864 candidate probes
# --- 28187 probes passed check_dic selection.
# finish in 2.321s, 437 probes kept.
# -- check region:11 1:22799957-22855040_strand_+_gene_hSE-11, 108900 candidate probes
# --- 44812 probes passed check_dic selection.
# finish in 3.713s, 671 probes kept.
# -- check region:12 1:23539736-23581634_strand_+_gene_hSE-12, 80436 candidate probes
# --- 24515 probes passed check_dic selection.
# finish in 2.358s, 422 probes kept.
# -- check region:13 1:24688503-24736373_strand_+_gene_hSE-13, 89846 candidate probes
# --- 20270 probes passed check_dic selection.
# finish in 2.358s, 330 probes kept.
# -- check region:14 1:27858017-27892069_strand_+_gene_hSE-14, 64594 candidate probes
# --- 18343 probes passed check_dic selection.
# finish in 1.840s, 317 probes kept.
# -- check region:15 1:29256947-29342815_strand_+_gene_hSE-15, 168146 candidate probes
# --- 51933 probes passed check_dic selection.
# finish in 4.955s, 889 probes kept.
# -- check region:16 1:30085753-30111941_strand_+_gene_hSE-16, 52056 candidate probes
# --- 20869 probes passed check_dic selection.
# finish in 1.728s, 337 probes kept.
# -- check region:17 1:32972754-33026496_strand_+_gene_hSE-17, 101712 candidate probes
# --- 29246 probes passed check_dic selection.
# finish in 2.884s, 511 probes kept.
# -- check region:18 1:33364069-33410626_strand_+_gene_hSE-18, 91512 candidate probes
# --- 31533 probes passed check_dic selection.
# finish in 2.817s, 509 probes kept.
# -- check region:19 1:33942513-33985735_strand_+_gene_hSE-19, 86002 candidate probes
# --- 37281 probes passed check_dic selection.
# finish in 2.970s, 564 probes kept.
# -- check region:20 1:36160823-36200646_strand_+_gene_hSE-20, 75218 candidate probes
# --- 18174 probes passed check_dic selection.
# finish in 2.036s, 320 probes kept.
# -- check region:21 1:40383030-40405268_strand_+_gene_hSE-21, 43600 candidate probes
# --- 11800 probes passed check_dic selection.
# finish in 1.232s, 195 probes kept.
# -- check region:22 1:42924178-42932394_strand_+_gene_hSE-22, 16344 candidate probes
# --- 6594 probes passed check_dic selection.
# finish in 0.563s, 123 probes kept.
# -- check region:23 1:43271997-43295887_strand_+_gene_hSE-23, 46506 candidate probes
# --- 18568 probes passed check_dic selection.
# finish in 1.562s, 284 probes kept.
# -- check region:24 1:47211730-47239911_strand_+_gene_hSE-24, 55924 candidate probes
# --- 20880 probes passed check_dic selection.
# finish in 1.841s, 355 probes kept.
# -- check region:25 1:74463706-74546503_strand_+_gene_hSE-25, 161658 candidate probes
# --- 44927 probes passed check_dic selection.
# finish in 4.517s, 829 probes kept.
# -- check region:26 1:83889722-83950902_strand_+_gene_hSE-26, 119592 candidate probes
# --- 23574 probes passed check_dic selection.
# finish in 2.921s, 512 probes kept.
# -- check region:27 1:84344166-84387321_strand_+_gene_hSE-27, 85802 candidate probes
# --- 28676 probes passed check_dic selection.
# finish in 2.611s, 518 probes kept.
# -- check region:28 1:84753497-84785597_strand_+_gene_hSE-28, 63910 candidate probes
# --- 26988 probes passed check_dic selection.
# finish in 2.171s, 388 probes kept.
# -- check region:29 1:87938009-87981108_strand_+_gene_hSE-29, 85782 candidate probes
# --- 27158 probes passed check_dic selection.
# finish in 2.530s, 470 probes kept.
# -- check region:30 1:93595674-93641187_strand_+_gene_hSE-30, 89620 candidate probes
# --- 36973 probes passed check_dic selection.
# finish in 3.064s, 549 probes kept.
# -- check region:31 1:108804549-108852967_strand_+_gene_hSE-31, 94034 candidate probes
# --- 25834 probes passed check_dic selection.
# finish in 2.626s, 448 probes kept.
# -- check region:32 1:111471042-111516564_strand_+_gene_hSE-32, 89740 candidate probes
# --- 30835 probes passed check_dic selection.
# finish in 2.762s, 523 probes kept.
# -- check region:33 1:113239232-113299463_strand_+_gene_hSE-33, 118004 candidate probes
# --- 36946 probes passed check_dic selection.
# finish in 3.488s, 638 probes kept.
# -- check region:34 1:116458014-116485677_strand_+_gene_hSE-34, 54954 candidate probes
# --- 21159 probes passed check_dic selection.
# finish in 1.794s, 336 probes kept.
# -- check region:35 1:119581001-119631839_strand_+_gene_hSE-35, 98578 candidate probes
# --- 23092 probes passed check_dic selection.
# finish in 2.623s, 498 probes kept.
# -- check region:36 1:150159530-150187849_strand_+_gene_hSE-36, 54572 candidate probes
# --- 14753 probes passed check_dic selection.
# finish in 1.529s, 251 probes kept.
# -- check region:37 1:155069705-155094754_strand_+_gene_hSE-37, 49284 candidate probes
# --- 23668 probes passed check_dic selection.
# finish in 1.815s, 329 probes kept.
# -- check region:38 1:155961029-155989716_strand_+_gene_hSE-38, 55414 candidate probes
# --- 18597 probes passed check_dic selection.
# finish in 1.716s, 321 probes kept.
# -- check region:39 1:156122739-156147282_strand_+_gene_hSE-39, 47254 candidate probes
# --- 14365 probes passed check_dic selection.
# finish in 1.402s, 260 probes kept.
# -- check region:40 1:159181407-159219417_strand_+_gene_hSE-40, 75508 candidate probes
# --- 28572 probes passed check_dic selection.
# finish in 2.493s, 497 probes kept.
# -- check region:41 1:162180487-162254771_strand_+_gene_hSE-41, 147746 candidate probes
# --- 53134 probes passed check_dic selection.
# finish in 4.626s, 836 probes kept.
# -- check region:42 1:162877908-162950638_strand_+_gene_hSE-42, 142852 candidate probes
# --- 43578 probes passed check_dic selection.
# finish in 4.164s, 724 probes kept.
# -- check region:43 1:166057386-166096188_strand_+_gene_hSE-43, 77088 candidate probes
# --- 29223 probes passed check_dic selection.
# finish in 2.525s, 481 probes kept.
# -- check region:44 1:167600121-167663464_strand_+_gene_hSE-44, 123906 candidate probes
# --- 40001 probes passed check_dic selection.
# finish in 3.714s, 650 probes kept.
# -- check region:45 1:168360565-168403520_strand_+_gene_hSE-45, 85420 candidate probes
# --- 28612 probes passed check_dic selection.
# finish in 2.626s, 497 probes kept.
# -- check region:46 1:169081022-169110120_strand_+_gene_hSE-46, 58046 candidate probes
# --- 23571 probes passed check_dic selection.
# finish in 1.914s, 363 probes kept.
# -- check region:47 1:182114177-182144615_strand_+_gene_hSE-47, 59938 candidate probes
# --- 21252 probes passed check_dic selection.
# finish in 1.869s, 325 probes kept.
# -- check region:48 1:182651253-182684870_strand_+_gene_hSE-48, 66986 candidate probes
# --- 24597 probes passed check_dic selection.
# finish in 2.132s, 415 probes kept.
# -- check region:49 1:202101074-202135594_strand_+_gene_hSE-49, 66300 candidate probes
# --- 19845 probes passed check_dic selection.
# finish in 1.965s, 351 probes kept.
# -- check region:50 1:209850354-209886516_strand_+_gene_hSE-50, 71486 candidate probes
# --- 21225 probes passed check_dic selection.
# finish in 2.063s, 384 probes kept.
# -- check region:51 1:211731778-211757085_strand_+_gene_hSE-51, 49820 candidate probes
# --- 13514 probes passed check_dic selection.
# finish in 1.403s, 262 probes kept.
# -- check region:52 1:212450290-212515259_strand_+_gene_hSE-52, 127216 candidate probes
# --- 47372 probes passed check_dic selection.
# finish in 4.105s, 724 probes kept.
# -- check region:53 1:213996599-214037834_strand_+_gene_hSE-53, 82036 candidate probes
# --- 28832 probes passed check_dic selection.
# finish in 2.540s, 492 probes kept.
# -- check region:54 1:214303536-214372510_strand_+_gene_hSE-54, 135640 candidate probes
# --- 44917 probes passed check_dic selection.
# finish in 4.116s, 768 probes kept.
# -- check region:55 1:223749018-223812070_strand_+_gene_hSE-55, 121690 candidate probes
# --- 32310 probes passed check_dic selection.
# finish in 3.355s, 603 probes kept.
# -- check region:56 1:225845735-225880437_strand_+_gene_hSE-56, 67854 candidate probes
# --- 23925 probes passed check_dic selection.
# finish in 2.126s, 400 probes kept.
# -- check region:57 1:229364081-229417075_strand_+_gene_hSE-57, 102916 candidate probes
# --- 30059 probes passed check_dic selection.
# finish in 2.944s, 463 probes kept.
# -- check region:58 1:230797884-230859532_strand_+_gene_hSE-58, 121236 candidate probes
# --- 40622 probes passed check_dic selection.
# finish in 3.647s, 628 probes kept.
# -- check region:59 1:231683651-231757238_strand_+_gene_hSE-59, 145210 candidate probes
# --- 39496 probes passed check_dic selection.
# finish in 4.014s, 693 probes kept.
# -- check region:60 1:233627407-233674330_strand_+_gene_hSE-60, 92236 candidate probes
# --- 30278 probes passed check_dic selection.
# finish in 2.759s, 496 probes kept.
# -- check region:61 1:234067937-234124233_strand_+_gene_hSE-61, 109291 candidate probes
# --- 32780 probes passed check_dic selection.
# finish in 3.140s, 544 probes kept.
# -- check region:62 1:236673262-236734560_strand_+_gene_hSE-62, 117254 candidate probes
# --- 33063 probes passed check_dic selection.
# finish in 3.267s, 575 probes kept.
# -- check region:63 1:237170162-237235604_strand_+_gene_hSE-63, 128170 candidate probes
# --- 31450 probes passed check_dic selection.
# finish in 3.400s, 559 probes kept.
# -- check region:64 1:240985018-241034779_strand_+_gene_hSE-64, 97290 candidate probes
# --- 20023 probes passed check_dic selection.
# finish in 2.418s, 385 probes kept.
# -- check region:65 1:248850425-248874090_strand_+_gene_hSE-65, 46528 candidate probes
# --- 14800 probes passed check_dic selection.
# finish in 1.413s, 247 probes kept.
# -- check region:66 2:2285196-2326618_strand_+_gene_hSE-66, 82324 candidate probes
# --- 29063 probes passed check_dic selection.
# finish in 2.583s, 475 probes kept.
# -- check region:67 2:17892542-17940538_strand_+_gene_hSE-67, 91744 candidate probes
# --- 22640 probes passed check_dic selection.
# finish in 2.457s, 400 probes kept.
# -- check region:68 2:25895563-25957062_strand_+_gene_hSE-68, 113230 candidate probes
# --- 18614 probes passed check_dic selection.
# finish in 2.683s, 345 probes kept.
# -- check region:69 2:28389910-28423879_strand_+_gene_hSE-69, 67316 candidate probes
# --- 28276 probes passed check_dic selection.
# finish in 2.319s, 429 probes kept.
# -- check region:70 2:30115178-30158156_strand_+_gene_hSE-70, 83966 candidate probes
# --- 21372 probes passed check_dic selection.
# finish in 2.266s, 389 probes kept.
# -- check region:71 2:40435529-40489838_strand_+_gene_hSE-71, 106872 candidate probes
# --- 28594 probes passed check_dic selection.
# finish in 2.908s, 511 probes kept.
# -- check region:72 2:55111810-55139043_strand_+_gene_hSE-72, 53216 candidate probes
# --- 14494 probes passed check_dic selection.
# finish in 1.496s, 229 probes kept.
# -- check region:73 2:65351295-65415355_strand_+_gene_hSE-73, 124874 candidate probes
# --- 43934 probes passed check_dic selection.
# finish in 3.890s, 677 probes kept.
# -- check region:74 2:68679255-68752177_strand_+_gene_hSE-74, 143314 candidate probes
# --- 41203 probes passed check_dic selection.
# finish in 4.069s, 703 probes kept.
# -- check region:75 2:70132418-70142985_strand_+_gene_hSE-75, 20300 candidate probes
# --- 6278 probes passed check_dic selection.
# finish in 0.607s, 96 probes kept.
# -- check region:76 2:70679166-70734203_strand_+_gene_hSE-76, 108794 candidate probes
# --- 42411 probes passed check_dic selection.
# finish in 3.575s, 645 probes kept.
# -- check region:77 2:72127833-72150745_strand_+_gene_hSE-77, 45744 candidate probes
# --- 22303 probes passed check_dic selection.
# finish in 1.711s, 330 probes kept.
# -- check region:78 2:74806927-74876578_strand_+_gene_hSE-78, 135706 candidate probes
# --- 48255 probes passed check_dic selection.
# finish in 4.248s, 755 probes kept.
# -- check region:79 2:85993858-86055654_strand_+_gene_hSE-79, 121644 candidate probes
# --- 46676 probes passed check_dic selection.
# finish in 3.981s, 719 probes kept.
# -- check region:80 2:95301818-95323825_strand_+_gene_hSE-80, 43828 candidate probes
# --- 18945 probes passed check_dic selection.
# finish in 1.557s, 295 probes kept.
# -- check region:81 2:98455476-98519608_strand_+_gene_hSE-81, 126966 candidate probes
# --- 49585 probes passed check_dic selection.
# finish in 4.167s, 753 probes kept.
# -- check region:82 2:101734463-101831718_strand_+_gene_hSE-82, 188426 candidate probes
# --- 63156 probes passed check_dic selection.
# finish in 5.717s, 1020 probes kept.
# -- check region:83 2:104825985-104845399_strand_+_gene_hSE-83, 38370 candidate probes
# --- 12714 probes passed check_dic selection.
# finish in 1.156s, 199 probes kept.
# -- check region:84 2:111347565-111407472_strand_+_gene_hSE-84, 118996 candidate probes
# --- 3649 probes passed check_dic selection.
# finish in 2.615s, 119 probes kept.
# -- check region:85 2:128299141-128322199_strand_+_gene_hSE-85, 46036 candidate probes
# --- 24016 probes passed check_dic selection.
# finish in 1.792s, 341 probes kept.
# -- check region:86 2:135157923-135196307_strand_+_gene_hSE-86, 73952 candidate probes
# --- 15992 probes passed check_dic selection.
# finish in 1.889s, 291 probes kept.
# -- check region:87 2:158619217-158676750_strand_+_gene_hSE-87, 114282 candidate probes
# --- 34301 probes passed check_dic selection.
# finish in 3.297s, 600 probes kept.
# -- check region:88 2:161217490-161250781_strand_+_gene_hSE-88, 66050 candidate probes
# --- 13953 probes passed check_dic selection.
# finish in 1.637s, 290 probes kept.
# -- check region:89 2:162146510-162203239_strand_+_gene_hSE-89, 112906 candidate probes
# --- 28828 probes passed check_dic selection.
# finish in 3.012s, 564 probes kept.
# -- check region:90 2:168118569-168183848_strand_+_gene_hSE-90, 129098 candidate probes
# --- 40899 probes passed check_dic selection.
# finish in 3.757s, 707 probes kept.
# -- check region:91 2:170190614-170242013_strand_+_gene_hSE-91, 101562 candidate probes
# --- 27821 probes passed check_dic selection.
# finish in 2.803s, 481 probes kept.
# -- check region:92 2:170803888-170822682_strand_+_gene_hSE-92, 37426 candidate probes
# --- 14817 probes passed check_dic selection.
# finish in 1.220s, 215 probes kept.
# -- check region:93 2:172667041-172743591_strand_+_gene_hSE-93, 150380 candidate probes
# --- 33104 probes passed check_dic selection.
# finish in 3.829s, 643 probes kept.
# -- check region:94 2:216004762-216045454_strand_+_gene_hSE-94, 77930 candidate probes
# --- 22803 probes passed check_dic selection.
# finish in 2.220s, 376 probes kept.
# -- check region:95 2:216682392-216711300_strand_+_gene_hSE-95, 56906 candidate probes
# --- 22339 probes passed check_dic selection.
# finish in 1.856s, 336 probes kept.
# -- check region:96 2:219261532-219299142_strand_+_gene_hSE-96, 73504 candidate probes
# --- 22456 probes passed check_dic selection.
# finish in 2.170s, 434 probes kept.
# -- check region:97 2:219506346-219530597_strand_+_gene_hSE-97, 48104 candidate probes
# --- 20006 probes passed check_dic selection.
# finish in 1.637s, 317 probes kept.
# -- check region:98 2:219642387-219690095_strand_+_gene_hSE-98, 93316 candidate probes
# --- 27115 probes passed check_dic selection.
# finish in 2.684s, 462 probes kept.
# -- check region:99 2:229633545-229675837_strand_+_gene_hSE-99, 83104 candidate probes
# --- 28974 probes passed check_dic selection.
# finish in 2.559s, 453 probes kept.
# -- check region:100 2:232303321-232335665_strand_+_gene_hSE-100, 64270 candidate probes
# --- 21483 probes passed check_dic selection.
# finish in 1.973s, 348 probes kept.
# -- check region:101 3:229810-285643_strand_+_gene_hSE-101, 109460 candidate probes
# --- 27651 probes passed check_dic selection.
# finish in 2.927s, 495 probes kept.
# -- check region:102 3:11183206-11212608_strand_+_gene_hSE-102, 57668 candidate probes
# --- 18935 probes passed check_dic selection.
# finish in 1.752s, 303 probes kept.
# -- check region:103 3:16439998-16496611_strand_+_gene_hSE-103, 112668 candidate probes
# --- 35828 probes passed check_dic selection.
# finish in 3.346s, 609 probes kept.
# -- check region:104 3:18369517-18408885_strand_+_gene_hSE-104, 78260 candidate probes
# --- 19638 probes passed check_dic selection.
# finish in 2.082s, 395 probes kept.
# -- check region:105 3:30629143-30668635_strand_+_gene_hSE-105, 78202 candidate probes
# --- 25440 probes passed check_dic selection.
# finish in 2.331s, 424 probes kept.
# -- check region:106 3:37529575-37558895_strand_+_gene_hSE-106, 58158 candidate probes
# --- 25025 probes passed check_dic selection.
# finish in 2.027s, 376 probes kept.
# -- check region:107 3:39177787-39268066_strand_+_gene_hSE-107, 175828 candidate probes
# --- 54978 probes passed check_dic selection.
# finish in 5.228s, 960 probes kept.
# -- check region:108 3:40143076-40202975_strand_+_gene_hSE-108, 112834 candidate probes
# --- 36631 probes passed check_dic selection.
# finish in 3.388s, 617 probes kept.
# -- check region:109 3:42419688-42459881_strand_+_gene_hSE-109, 78796 candidate probes
# --- 23415 probes passed check_dic selection.
# finish in 2.293s, 379 probes kept.
# -- check region:110 3:42712818-42763438_strand_+_gene_hSE-110, 97904 candidate probes
# --- 28243 probes passed check_dic selection.
# finish in 2.800s, 478 probes kept.
# -- check region:111 3:50243183-50260429_strand_+_gene_hSE-111, 33090 candidate probes
# --- 12705 probes passed check_dic selection.
# finish in 1.132s, 211 probes kept.
# -- check region:112 3:50408362-50475060_strand_+_gene_hSE-112, 132004 candidate probes
# --- 63411 probes passed check_dic selection.
# finish in 4.863s, 920 probes kept.
# -- check region:113 3:50623107-50649902_strand_+_gene_hSE-113, 52958 candidate probes
# --- 23291 probes passed check_dic selection.
# finish in 1.890s, 340 probes kept.
# -- check region:114 3:51681373-51705022_strand_+_gene_hSE-114, 46780 candidate probes
# --- 18522 probes passed check_dic selection.
# finish in 1.562s, 304 probes kept.
# -- check region:115 3:52468183-52498525_strand_+_gene_hSE-115, 59650 candidate probes
# --- 24148 probes passed check_dic selection.
# finish in 2.017s, 390 probes kept.
# -- check region:116 3:53153934-53176878_strand_+_gene_hSE-116, 45750 candidate probes
# --- 20718 probes passed check_dic selection.
# finish in 1.646s, 307 probes kept.
# -- check region:117 3:53989310-54046045_strand_+_gene_hSE-117, 111978 candidate probes
# --- 37571 probes passed check_dic selection.
# finish in 3.407s, 587 probes kept.
# -- check region:118 3:56073355-56153695_strand_+_gene_hSE-118, 159296 candidate probes
# --- 43102 probes passed check_dic selection.
# finish in 4.385s, 789 probes kept.
# -- check region:119 3:61874703-61937952_strand_+_gene_hSE-119, 125172 candidate probes
# --- 35790 probes passed check_dic selection.
# finish in 3.534s, 629 probes kept.
# -- check region:120 3:63324550-63371885_strand_+_gene_hSE-120, 93186 candidate probes
# --- 23255 probes passed check_dic selection.
# finish in 2.500s, 434 probes kept.
# -- check region:121 3:64116478-64181338_strand_+_gene_hSE-121, 128556 candidate probes
# --- 40962 probes passed check_dic selection.
# finish in 3.824s, 694 probes kept.
# -- check region:122 3:65381472-65427232_strand_+_gene_hSE-122, 90974 candidate probes
# --- 30737 probes passed check_dic selection.
# finish in 2.778s, 544 probes kept.
# -- check region:123 3:113241829-113290175_strand_+_gene_hSE-123, 96566 candidate probes
# --- 36735 probes passed check_dic selection.
# finish in 3.148s, 623 probes kept.
# -- check region:124 3:114394427-114428168_strand_+_gene_hSE-124, 67122 candidate probes
# --- 24007 probes passed check_dic selection.
# finish in 2.094s, 391 probes kept.
# -- check region:125 3:115990333-116051531_strand_+_gene_hSE-125, 121586 candidate probes
# --- 36000 probes passed check_dic selection.
# finish in 3.471s, 623 probes kept.
# -- check region:126 3:120641608-120689253_strand_+_gene_hSE-126, 94242 candidate probes
# --- 24890 probes passed check_dic selection.
# finish in 2.595s, 452 probes kept.
# -- check region:127 3:123402800-123444475_strand_+_gene_hSE-127, 82220 candidate probes
# --- 33695 probes passed check_dic selection.
# finish in 2.738s, 503 probes kept.
# -- check region:128 3:125766201-125799003_strand_+_gene_hSE-128, 43902 candidate probes
# --- 20 probes passed check_dic selection.
# finish in 0.762s, 2 probes kept.
# -- check region:129 3:125953579-125990748_strand_+_gene_hSE-129, 73884 candidate probes
# --- 12610 probes passed check_dic selection.
# finish in 1.759s, 278 probes kept.
# -- check region:130 3:126246072-126301515_strand_+_gene_hSE-130, 109404 candidate probes
# --- 32332 probes passed check_dic selection.
# finish in 3.130s, 504 probes kept.
# -- check region:131 3:133362559-133423952_strand_+_gene_hSE-131, 122026 candidate probes
# --- 43852 probes passed check_dic selection.
# finish in 3.887s, 751 probes kept.
# -- check region:132 3:151346283-151399373_strand_+_gene_hSE-132, 104782 candidate probes
# --- 24783 probes passed check_dic selection.
# finish in 2.731s, 494 probes kept.
# -- check region:133 3:156381375-156417831_strand_+_gene_hSE-133, 71616 candidate probes
# --- 22624 probes passed check_dic selection.
# finish in 2.113s, 384 probes kept.
# -- check region:134 3:171113627-171174242_strand_+_gene_hSE-134, 117076 candidate probes
# --- 39742 probes passed check_dic selection.
# finish in 3.552s, 662 probes kept.
# -- check region:135 3:171282065-171352074_strand_+_gene_hSE-135, 137358 candidate probes
# --- 39477 probes passed check_dic selection.
# finish in 3.877s, 685 probes kept.
# -- check region:136 3:177676941-177726382_strand_+_gene_hSE-136, 97070 candidate probes
# --- 25816 probes passed check_dic selection.
# finish in 2.702s, 469 probes kept.
# -- check region:137 3:182238089-182260005_strand_+_gene_hSE-137, 43180 candidate probes
# --- 12211 probes passed check_dic selection.
# finish in 1.224s, 211 probes kept.
# -- check region:138 3:183793909-183823106_strand_+_gene_hSE-138, 56190 candidate probes
# --- 17376 probes passed check_dic selection.
# finish in 1.688s, 302 probes kept.
# -- check region:139 3:184658335-184697613_strand_+_gene_hSE-139, 75522 candidate probes
# --- 33351 probes passed check_dic selection.
# finish in 2.637s, 461 probes kept.
# -- check region:140 3:186298694-186350017_strand_+_gene_hSE-140, 99797 candidate probes
# --- 28987 probes passed check_dic selection.
# finish in 2.860s, 482 probes kept.
# -- check region:141 3:186967625-187029778_strand_+_gene_hSE-141, 120778 candidate probes
# --- 35871 probes passed check_dic selection.
# finish in 3.485s, 586 probes kept.
# -- check region:142 3:192566715-192620921_strand_+_gene_hSE-142, 107536 candidate probes
# --- 26606 probes passed check_dic selection.
# finish in 2.865s, 483 probes kept.
# -- check region:143 3:195839395-195873780_strand_+_gene_hSE-143, 65676 candidate probes
# --- 21817 probes passed check_dic selection.
# finish in 1.990s, 348 probes kept.
# -- check region:144 3:196163976-196253985_strand_+_gene_hSE-144, 169762 candidate probes
# --- 47941 probes passed check_dic selection.
# finish in 4.856s, 807 probes kept.
# -- check region:145 3:197487536-197526172_strand_+_gene_hSE-145, 74762 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 1.321s, 0 probes kept.
# -- check region:146 4:1746169-1810274_strand_+_gene_hSE-146, 127062 candidate probes
# --- 54770 probes passed check_dic selection.
# finish in 4.327s, 856 probes kept.
# -- check region:147 4:5812681-5858484_strand_+_gene_hSE-147, 90054 candidate probes
# --- 34567 probes passed check_dic selection.
# finish in 2.947s, 534 probes kept.
# -- check region:148 4:16775674-16795226_strand_+_gene_hSE-148, 38718 candidate probes
# --- 14189 probes passed check_dic selection.
# finish in 1.235s, 225 probes kept.
# -- check region:149 4:24084159-24122236_strand_+_gene_hSE-149, 75654 candidate probes
# --- 26315 probes passed check_dic selection.
# finish in 2.340s, 425 probes kept.
# -- check region:150 4:24360696-24405801_strand_+_gene_hSE-150, 87844 candidate probes
# --- 23893 probes passed check_dic selection.
# finish in 2.433s, 403 probes kept.
# -- check region:151 4:41619002-41661905_strand_+_gene_hSE-151, 85338 candidate probes
# --- 26072 probes passed check_dic selection.
# finish in 2.492s, 476 probes kept.
# -- check region:152 4:82698339-82793740_strand_+_gene_hSE-152, 186138 candidate probes
# --- 56894 probes passed check_dic selection.
# finish in 5.466s, 937 probes kept.
# -- check region:153 4:86279377-86344472_strand_+_gene_hSE-153, 127308 candidate probes
# --- 26167 probes passed check_dic selection.
# finish in 3.172s, 533 probes kept.
# -- check region:154 4:87030818-87079602_strand_+_gene_hSE-154, 95982 candidate probes
# --- 28132 probes passed check_dic selection.
# finish in 2.746s, 482 probes kept.
# -- check region:155 4:87514660-87559831_strand_+_gene_hSE-155, 87640 candidate probes
# --- 20260 probes passed check_dic selection.
# finish in 2.286s, 386 probes kept.
# -- check region:156 4:95156174-95233120_strand_+_gene_hSE-156, 145002 candidate probes
# --- 42817 probes passed check_dic selection.
# finish in 4.185s, 762 probes kept.
# -- check region:157 4:102583911-102629999_strand_+_gene_hSE-157, 90364 candidate probes
# --- 27276 probes passed check_dic selection.
# finish in 2.610s, 468 probes kept.
# -- check region:158 4:107639908-107693977_strand_+_gene_hSE-158, 104446 candidate probes
# --- 26545 probes passed check_dic selection.
# finish in 2.815s, 479 probes kept.
# -- check region:159 4:121759398-121795320_strand_+_gene_hSE-159, 71420 candidate probes
# --- 18394 probes passed check_dic selection.
# finish in 1.941s, 338 probes kept.
# -- check region:160 4:139934471-139989771_strand_+_gene_hSE-160, 107572 candidate probes
# --- 32671 probes passed check_dic selection.
# finish in 3.115s, 546 probes kept.
# -- check region:161 4:152247566-152317674_strand_+_gene_hSE-161, 139080 candidate probes
# --- 44561 probes passed check_dic selection.
# finish in 4.150s, 740 probes kept.
# -- check region:162 4:153193472-153250108_strand_+_gene_hSE-162, 111356 candidate probes
# --- 32310 probes passed check_dic selection.
# finish in 3.153s, 531 probes kept.
# -- check region:163 4:153488652-153538904_strand_+_gene_hSE-163, 97802 candidate probes
# --- 27843 probes passed check_dic selection.
# finish in 2.741s, 461 probes kept.
# -- check region:164 4:159345300-159432795_strand_+_gene_hSE-164, 170424 candidate probes
# --- 36076 probes passed check_dic selection.
# finish in 4.369s, 714 probes kept.
# -- check region:165 4:175872119-175928832_strand_+_gene_hSE-165, 111726 candidate probes
# --- 20231 probes passed check_dic selection.
# finish in 2.661s, 424 probes kept.
# -- check region:166 4:185710686-185748717_strand_+_gene_hSE-166, 75258 candidate probes
# --- 29269 probes passed check_dic selection.
# finish in 2.433s, 452 probes kept.
# -- check region:167 4:186689363-186727075_strand_+_gene_hSE-167, 74084 candidate probes
# --- 25380 probes passed check_dic selection.
# finish in 2.251s, 419 probes kept.
# -- check region:168 5:1477224-1518269_strand_+_gene_hSE-168, 80572 candidate probes
# --- 9656 probes passed check_dic selection.
# finish in 1.786s, 129 probes kept.
# -- check region:169 5:6455521-6517487_strand_+_gene_hSE-169, 122190 candidate probes
# --- 47802 probes passed check_dic selection.
# finish in 4.003s, 718 probes kept.
# -- check region:170 5:6753713-6821319_strand_+_gene_hSE-170, 133094 candidate probes
# --- 49791 probes passed check_dic selection.
# finish in 4.251s, 737 probes kept.
# -- check region:171 5:11372849-11422769_strand_+_gene_hSE-171, 98946 candidate probes
# --- 28082 probes passed check_dic selection.
# finish in 2.782s, 496 probes kept.
# -- check region:172 5:14574047-14608593_strand_+_gene_hSE-172, 68650 candidate probes
# --- 20648 probes passed check_dic selection.
# finish in 1.985s, 343 probes kept.
# -- check region:173 5:36655119-36701776_strand_+_gene_hSE-173, 92414 candidate probes
# --- 31164 probes passed check_dic selection.
# finish in 2.815s, 517 probes kept.
# -- check region:174 5:58665977-58718694_strand_+_gene_hSE-174, 103186 candidate probes
# --- 22894 probes passed check_dic selection.
# finish in 2.630s, 446 probes kept.
# -- check region:175 5:61603463-61635762_strand_+_gene_hSE-175, 63584 candidate probes
# --- 24067 probes passed check_dic selection.
# finish in 2.054s, 362 probes kept.
# -- check region:176 5:65791562-65832174_strand_+_gene_hSE-176, 80064 candidate probes
# --- 15934 probes passed check_dic selection.
# finish in 1.990s, 343 probes kept.
# -- check region:177 5:66608766-66669231_strand_+_gene_hSE-177, 119896 candidate probes
# --- 33152 probes passed check_dic selection.
# finish in 3.371s, 601 probes kept.
# -- check region:178 5:67156891-67221910_strand_+_gene_hSE-178, 126712 candidate probes
# --- 38224 probes passed check_dic selection.
# finish in 3.736s, 693 probes kept.
# -- check region:179 5:68707924-68784475_strand_+_gene_hSE-179, 150502 candidate probes
# --- 50770 probes passed check_dic selection.
# finish in 4.616s, 816 probes kept.
# -- check region:180 5:72226206-72308738_strand_+_gene_hSE-180, 162876 candidate probes
# --- 36915 probes passed check_dic selection.
# finish in 4.189s, 727 probes kept.
# -- check region:181 5:72624922-72671791_strand_+_gene_hSE-181, 91302 candidate probes
# --- 31652 probes passed check_dic selection.
# finish in 2.818s, 507 probes kept.
# -- check region:182 5:73902661-73977502_strand_+_gene_hSE-182, 147698 candidate probes
# --- 43281 probes passed check_dic selection.
# finish in 4.224s, 779 probes kept.
# -- check region:183 5:78467765-78554497_strand_+_gene_hSE-183, 172194 candidate probes
# --- 62430 probes passed check_dic selection.
# finish in 5.431s, 992 probes kept.
# -- check region:184 5:80172125-80239413_strand_+_gene_hSE-184, 129675 candidate probes
# --- 31467 probes passed check_dic selection.
# finish in 3.454s, 550 probes kept.
# -- check region:185 5:89253742-89321146_strand_+_gene_hSE-185, 132920 candidate probes
# --- 37064 probes passed check_dic selection.
# finish in 3.689s, 657 probes kept.
# -- check region:186 5:95834579-95900837_strand_+_gene_hSE-186, 130642 candidate probes
# --- 40314 probes passed check_dic selection.
# finish in 3.841s, 681 probes kept.
# -- check region:187 5:109711524-109754085_strand_+_gene_hSE-187, 81380 candidate probes
# --- 15283 probes passed check_dic selection.
# finish in 1.962s, 313 probes kept.
# -- check region:188 5:114370909-114419049_strand_+_gene_hSE-188, 95172 candidate probes
# --- 24856 probes passed check_dic selection.
# finish in 2.584s, 455 probes kept.
# -- check region:189 5:116378276-116464706_strand_+_gene_hSE-189, 172194 candidate probes
# --- 62422 probes passed check_dic selection.
# finish in 5.433s, 1004 probes kept.
# -- check region:190 5:124620729-124678056_strand_+_gene_hSE-190, 113802 candidate probes
# --- 36728 probes passed check_dic selection.
# finish in 3.405s, 643 probes kept.
# -- check region:191 5:126824999-126878072_strand_+_gene_hSE-191, 102990 candidate probes
# --- 28124 probes passed check_dic selection.
# finish in 2.869s, 466 probes kept.
# -- check region:192 5:131999493-132009444_strand_+_gene_hSE-192, 19650 candidate probes
# --- 10424 probes passed check_dic selection.
# finish in 0.773s, 142 probes kept.
# -- check region:193 5:132753549-132822095_strand_+_gene_hSE-193, 133992 candidate probes
# --- 43760 probes passed check_dic selection.
# finish in 4.023s, 735 probes kept.
# -- check region:194 5:134547480-134603508_strand_+_gene_hSE-194, 107652 candidate probes
# --- 36780 probes passed check_dic selection.
# finish in 3.346s, 598 probes kept.
# -- check region:195 5:134925222-134925722_strand_+_gene_hSE-195, 920 candidate probes
# --- 82 probes passed check_dic selection.
# finish in 0.023s, 5 probes kept.
# -- check region:196 5:135623789-135671007_strand_+_gene_hSE-196, 94280 candidate probes
# --- 36165 probes passed check_dic selection.
# finish in 3.084s, 576 probes kept.
# -- check region:197 5:140341565-140373327_strand_+_gene_hSE-197, 62622 candidate probes
# --- 22062 probes passed check_dic selection.
# finish in 1.972s, 380 probes kept.
# -- check region:198 5:140569758-140612578_strand_+_gene_hSE-198, 82166 candidate probes
# --- 13747 probes passed check_dic selection.
# finish in 1.946s, 276 probes kept.
# -- check region:199 5:140977023-141017732_strand_+_gene_hSE-199, 79236 candidate probes
# --- 23249 probes passed check_dic selection.
# finish in 2.274s, 410 probes kept.
# -- check region:200 5:149777851-149840046_strand_+_gene_hSE-200, 121350 candidate probes
# --- 51067 probes passed check_dic selection.
# finish in 4.150s, 751 probes kept.
# -- check region:201 5:159504835-159577432_strand_+_gene_hSE-201, 143325 candidate probes
# --- 48533 probes passed check_dic selection.
# finish in 4.383s, 824 probes kept.
# -- check region:202 5:159928360-159972308_strand_+_gene_hSE-202, 86562 candidate probes
# --- 24651 probes passed check_dic selection.
# finish in 2.460s, 430 probes kept.
# -- check region:203 5:160479986-160537501_strand_+_gene_hSE-203, 112998 candidate probes
# --- 32252 probes passed check_dic selection.
# finish in 3.212s, 580 probes kept.
# -- check region:204 5:161366128-161423146_strand_+_gene_hSE-204, 113666 candidate probes
# --- 27640 probes passed check_dic selection.
# finish in 2.990s, 513 probes kept.
# -- check region:205 5:172399346-172446323_strand_+_gene_hSE-205, 92742 candidate probes
# --- 35276 probes passed check_dic selection.
# finish in 3.007s, 511 probes kept.
# -- check region:206 5:174053843-174122148_strand_+_gene_hSE-206, 134228 candidate probes
# --- 49149 probes passed check_dic selection.
# finish in 4.254s, 783 probes kept.
# -- check region:207 5:180160829-180180373_strand_+_gene_hSE-207, 37618 candidate probes
# --- 12179 probes passed check_dic selection.
# finish in 1.147s, 200 probes kept.
# -- check region:208 6:11202800-11223748_strand_+_gene_hSE-208, 41242 candidate probes
# --- 16470 probes passed check_dic selection.
# finish in 1.368s, 255 probes kept.
# -- check region:209 6:12748963-12812006_strand_+_gene_hSE-209, 124518 candidate probes
# --- 36409 probes passed check_dic selection.
# finish in 3.535s, 622 probes kept.
# -- check region:210 6:14091413-14149329_strand_+_gene_hSE-210, 113444 candidate probes
# --- 40950 probes passed check_dic selection.
# finish in 3.564s, 643 probes kept.
# -- check region:211 6:15479623-15521933_strand_+_gene_hSE-211, 84150 candidate probes
# --- 40277 probes passed check_dic selection.
# finish in 3.088s, 585 probes kept.
# -- check region:212 6:16803350-16838304_strand_+_gene_hSE-212, 68696 candidate probes
# --- 20318 probes passed check_dic selection.
# finish in 1.977s, 343 probes kept.
# -- check region:213 6:16985781-17046339_strand_+_gene_hSE-213, 119482 candidate probes
# --- 28579 probes passed check_dic selection.
# finish in 3.179s, 535 probes kept.
# -- check region:214 6:17432209-17507249_strand_+_gene_hSE-214, 144812 candidate probes
# --- 38048 probes passed check_dic selection.
# finish in 3.974s, 657 probes kept.
# -- check region:215 6:26299376-26328048_strand_+_gene_hSE-215, 56138 candidate probes
# --- 14517 probes passed check_dic selection.
# finish in 1.536s, 255 probes kept.
# -- check region:216 6:35713408-35732508_strand_+_gene_hSE-216, 36966 candidate probes
# --- 14980 probes passed check_dic selection.
# finish in 1.236s, 232 probes kept.
# -- check region:217 6:38134579-38180620_strand_+_gene_hSE-217, 91100 candidate probes
# --- 37219 probes passed check_dic selection.
# finish in 3.085s, 598 probes kept.
# -- check region:218 6:39816832-39865715_strand_+_gene_hSE-218, 96644 candidate probes
# --- 38195 probes passed check_dic selection.
# finish in 3.215s, 604 probes kept.
# -- check region:219 6:41676420-41723865_strand_+_gene_hSE-219, 93226 candidate probes
# --- 35461 probes passed check_dic selection.
# finish in 3.014s, 571 probes kept.
# -- check region:220 6:46199402-46252074_strand_+_gene_hSE-220, 99702 candidate probes
# --- 26170 probes passed check_dic selection.
# finish in 2.760s, 485 probes kept.
# -- check region:221 6:47236110-47294034_strand_+_gene_hSE-221, 112938 candidate probes
# --- 32156 probes passed check_dic selection.
# finish in 3.197s, 559 probes kept.
# -- check region:222 6:54073977-54118521_strand_+_gene_hSE-222, 88406 candidate probes
# --- 21981 probes passed check_dic selection.
# finish in 2.355s, 416 probes kept.
# -- check region:223 6:88549780-88596088_strand_+_gene_hSE-223, 92300 candidate probes
# --- 30453 probes passed check_dic selection.
# finish in 2.802s, 491 probes kept.
# -- check region:224 6:90149271-90194810_strand_+_gene_hSE-224, 87526 candidate probes
# --- 23633 probes passed check_dic selection.
# finish in 2.422s, 406 probes kept.
# -- check region:225 6:98824429-98846049_strand_+_gene_hSE-225, 43160 candidate probes
# --- 17802 probes passed check_dic selection.
# finish in 1.454s, 285 probes kept.
# -- check region:226 6:105785323-105910294_strand_+_gene_hSE-226, 243808 candidate probes
# --- 79523 probes passed check_dic selection.
# finish in 7.353s, 1266 probes kept.
# -- check region:227 6:110528012-110557654_strand_+_gene_hSE-227, 59002 candidate probes
# --- 17830 probes passed check_dic selection.
# finish in 1.713s, 295 probes kept.
# -- check region:228 6:133961793-134021658_strand_+_gene_hSE-228, 118280 candidate probes
# --- 25842 probes passed check_dic selection.
# finish in 3.010s, 502 probes kept.
# -- check region:229 6:136316932-136383731_strand_+_gene_hSE-229, 132086 candidate probes
# --- 33062 probes passed check_dic selection.
# finish in 3.542s, 626 probes kept.
# -- check region:230 6:137224767-137314634_strand_+_gene_hSE-230, 178120 candidate probes
# --- 43646 probes passed check_dic selection.
# finish in 4.741s, 792 probes kept.
# -- check region:231 6:148494844-148544860_strand_+_gene_hSE-231, 98512 candidate probes
# --- 35421 probes passed check_dic selection.
# finish in 3.093s, 580 probes kept.
# -- check region:232 6:155224006-155258231_strand_+_gene_hSE-232, 67194 candidate probes
# --- 22976 probes passed check_dic selection.
# finish in 2.079s, 363 probes kept.
# -- check region:233 6:157861732-157912801_strand_+_gene_hSE-233, 100206 candidate probes
# --- 26965 probes passed check_dic selection.
# finish in 2.774s, 475 probes kept.
# -- check region:234 6:161393814-161486857_strand_+_gene_hSE-234, 181946 candidate probes
# --- 63663 probes passed check_dic selection.
# finish in 5.635s, 961 probes kept.
# -- check region:235 6:163522807-163565597_strand_+_gene_hSE-235, 84376 candidate probes
# --- 17472 probes passed check_dic selection.
# finish in 2.105s, 349 probes kept.
# -- check region:236 6:167895708-167946464_strand_+_gene_hSE-236, 98792 candidate probes
# --- 29127 probes passed check_dic selection.
# finish in 2.822s, 506 probes kept.
# -- check region:237 6:170286501-170298238_strand_+_gene_hSE-237, 23394 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 0.382s, 0 probes kept.
# -- check region:238 7:650194-708334_strand_+_gene_hSE-238, 109467 candidate probes
# --- 39023 probes passed check_dic selection.
# finish in 3.426s, 575 probes kept.
# -- check region:239 7:1446047-1474426_strand_+_gene_hSE-239, 56252 candidate probes
# --- 22732 probes passed check_dic selection.
# finish in 1.891s, 369 probes kept.
# -- check region:240 7:2444422-2469254_strand_+_gene_hSE-240, 47258 candidate probes
# --- 9660 probes passed check_dic selection.
# finish in 1.215s, 170 probes kept.
# -- check region:241 7:6393259-6442405_strand_+_gene_hSE-241, 92814 candidate probes
# --- 25316 probes passed check_dic selection.
# finish in 2.623s, 419 probes kept.
# -- check region:242 7:16766600-16801496_strand_+_gene_hSE-242, 67542 candidate probes
# --- 14493 probes passed check_dic selection.
# finish in 1.705s, 285 probes kept.
# -- check region:243 7:27983649-28037674_strand_+_gene_hSE-243, 103936 candidate probes
# --- 32057 probes passed check_dic selection.
# finish in 3.051s, 507 probes kept.
# -- check region:244 7:28695478-28760016_strand_+_gene_hSE-244, 126492 candidate probes
# --- 39920 probes passed check_dic selection.
# finish in 3.719s, 679 probes kept.
# -- check region:245 7:28949736-28987026_strand_+_gene_hSE-245, 74100 candidate probes
# --- 25085 probes passed check_dic selection.
# finish in 2.259s, 423 probes kept.
# -- check region:246 7:30142157-30249789_strand_+_gene_hSE-246, 213370 candidate probes
# --- 70861 probes passed check_dic selection.
# finish in 6.505s, 1156 probes kept.
# -- check region:247 7:47300651-47336634_strand_+_gene_hSE-247, 70870 candidate probes
# --- 28715 probes passed check_dic selection.
# finish in 2.349s, 410 probes kept.
# -- check region:248 7:73699309-73726146_strand_+_gene_hSE-248, 51830 candidate probes
# --- 15863 probes passed check_dic selection.
# finish in 1.545s, 270 probes kept.
# -- check region:249 7:75925652-75989623_strand_+_gene_hSE-249, 122434 candidate probes
# --- 37250 probes passed check_dic selection.
# finish in 3.588s, 567 probes kept.
# -- check region:250 7:78124134-78176575_strand_+_gene_hSE-250, 103872 candidate probes
# --- 34604 probes passed check_dic selection.
# finish in 3.141s, 578 probes kept.
# -- check region:251 7:86747661-86798481_strand_+_gene_hSE-251, 100884 candidate probes
# --- 28018 probes passed check_dic selection.
# finish in 2.806s, 517 probes kept.
# -- check region:252 7:90994075-91042574_strand_+_gene_hSE-252, 95728 candidate probes
# --- 26360 probes passed check_dic selection.
# finish in 2.636s, 472 probes kept.
# -- check region:253 7:99092884-99137847_strand_+_gene_hSE-253, 88726 candidate probes
# --- 20105 probes passed check_dic selection.
# finish in 2.285s, 374 probes kept.
# -- check region:254 7:101162798-101192924_strand_+_gene_hSE-254, 57994 candidate probes
# --- 17535 probes passed check_dic selection.
# finish in 1.710s, 301 probes kept.
# -- check region:255 7:104963731-105003758_strand_+_gene_hSE-255, 78212 candidate probes
# --- 20320 probes passed check_dic selection.
# finish in 2.128s, 349 probes kept.
# -- check region:256 7:130982106-131040936_strand_+_gene_hSE-256, 114684 candidate probes
# --- 34772 probes passed check_dic selection.
# finish in 3.345s, 580 probes kept.
# -- check region:257 7:131179959-131265717_strand_+_gene_hSE-257, 166076 candidate probes
# --- 38941 probes passed check_dic selection.
# finish in 4.367s, 669 probes kept.
# -- check region:258 7:131497257-131545211_strand_+_gene_hSE-258, 93966 candidate probes
# --- 31462 probes passed check_dic selection.
# finish in 2.909s, 507 probes kept.
# -- check region:259 7:132711164-132750972_strand_+_gene_hSE-259, 78600 candidate probes
# --- 24662 probes passed check_dic selection.
# finish in 2.336s, 425 probes kept.
# -- check region:260 7:137265427-137328841_strand_+_gene_hSE-260, 125584 candidate probes
# --- 30792 probes passed check_dic selection.
# finish in 3.326s, 567 probes kept.
# -- check region:261 7:138907796-138971523_strand_+_gene_hSE-261, 123344 candidate probes
# --- 37365 probes passed check_dic selection.
# finish in 3.624s, 617 probes kept.
# -- check region:262 7:139634067-139669918_strand_+_gene_hSE-262, 69864 candidate probes
# --- 28299 probes passed check_dic selection.
# finish in 2.330s, 401 probes kept.
# -- check region:263 7:150962876-150989026_strand_+_gene_hSE-263, 51832 candidate probes
# --- 21447 probes passed check_dic selection.
# finish in 1.764s, 318 probes kept.
# -- check region:264 8:756590-806322_strand_+_gene_hSE-264, 94040 candidate probes
# --- 658 probes passed check_dic selection.
# finish in 1.667s, 21 probes kept.
# -- check region:265 8:1062006-1128511_strand_+_gene_hSE-265, 127918 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 2.216s, 0 probes kept.
# -- check region:266 8:7091733-7126984_strand_+_gene_hSE-266, 52394 candidate probes
# --- 735 probes passed check_dic selection.
# finish in 0.943s, 41 probes kept.
# -- check region:267 8:17602572-17628929_strand_+_gene_hSE-267, 51152 candidate probes
# --- 15238 probes passed check_dic selection.
# finish in 1.485s, 238 probes kept.
# -- check region:268 8:22379370-22430704_strand_+_gene_hSE-268, 98684 candidate probes
# --- 28296 probes passed check_dic selection.
# finish in 2.821s, 451 probes kept.
# -- check region:269 8:22755975-22811265_strand_+_gene_hSE-269, 108698 candidate probes
# --- 43308 probes passed check_dic selection.
# finish in 3.615s, 652 probes kept.
# -- check region:270 8:22974019-23003219_strand_+_gene_hSE-270, 57096 candidate probes
# --- 18985 probes passed check_dic selection.
# finish in 1.725s, 300 probes kept.
# -- check region:271 8:28577689-28638791_strand_+_gene_hSE-271, 117504 candidate probes
# --- 28462 probes passed check_dic selection.
# finish in 3.145s, 462 probes kept.
# -- check region:272 8:40828972-40893521_strand_+_gene_hSE-272, 126768 candidate probes
# --- 48530 probes passed check_dic selection.
# finish in 4.146s, 730 probes kept.
# -- check region:273 8:55353505-55387663_strand_+_gene_hSE-273, 67530 candidate probes
# --- 22233 probes passed check_dic selection.
# finish in 2.049s, 356 probes kept.
# -- check region:274 8:58030675-58098999_strand_+_gene_hSE-274, 134716 candidate probes
# --- 38404 probes passed check_dic selection.
# finish in 3.805s, 640 probes kept.
# -- check region:275 8:60982736-61038209_strand_+_gene_hSE-275, 108730 candidate probes
# --- 40907 probes passed check_dic selection.
# finish in 3.483s, 635 probes kept.
# -- check region:276 8:66498459-66561132_strand_+_gene_hSE-276, 123640 candidate probes
# --- 36129 probes passed check_dic selection.
# finish in 3.576s, 591 probes kept.
# -- check region:277 8:93802636-93881940_strand_+_gene_hSE-277, 154636 candidate probes
# --- 30597 probes passed check_dic selection.
# finish in 3.835s, 611 probes kept.
# -- check region:278 8:117529291-117602950_strand_+_gene_hSE-278, 145652 candidate probes
# --- 41970 probes passed check_dic selection.
# finish in 4.121s, 724 probes kept.
# -- check region:279 8:117819305-117892637_strand_+_gene_hSE-279, 143744 candidate probes
# --- 42363 probes passed check_dic selection.
# finish in 4.113s, 711 probes kept.
# -- check region:280 8:122804992-122895957_strand_+_gene_hSE-280, 178320 candidate probes
# --- 62058 probes passed check_dic selection.
# finish in 5.543s, 991 probes kept.
# -- check region:281 8:124592927-124625028_strand_+_gene_hSE-281, 63146 candidate probes
# --- 26792 probes passed check_dic selection.
# finish in 2.159s, 385 probes kept.
# -- check region:282 8:125592510-125644931_strand_+_gene_hSE-282, 103808 candidate probes
# --- 37620 probes passed check_dic selection.
# finish in 3.297s, 608 probes kept.
# -- check region:283 8:129953414-129995549_strand_+_gene_hSE-283, 80364 candidate probes
# --- 22498 probes passed check_dic selection.
# finish in 2.268s, 357 probes kept.
# -- check region:284 8:132987736-133044477_strand_+_gene_hSE-284, 112872 candidate probes
# --- 41563 probes passed check_dic selection.
# finish in 3.610s, 669 probes kept.
# -- check region:285 8:133518552-133555672_strand_+_gene_hSE-285, 72686 candidate probes
# --- 26865 probes passed check_dic selection.
# finish in 2.316s, 402 probes kept.
# -- check region:286 8:134531678-134582535_strand_+_gene_hSE-286, 100820 candidate probes
# --- 34950 probes passed check_dic selection.
# finish in 3.104s, 580 probes kept.
# -- check region:287 8:135169030-135251947_strand_+_gene_hSE-287, 164220 candidate probes
# --- 52357 probes passed check_dic selection.
# finish in 4.885s, 843 probes kept.
# -- check region:288 8:135644093-135692133_strand_+_gene_hSE-288, 95218 candidate probes
# ...
# -- check region:472 16:86640283-86681116_strand_+_gene_hSE-472, 80458 candidate probes
# --- 29985 probes passed check_dic selection.
# finish in 2.603s, 462 probes kept.
# -- check region:473 16:87675218-87704276_strand_+_gene_hSE-473, 57144 candidate probes
# --- 23622 probes passed check_dic selection.
# finish in 1.975s, 386 probes kept.
# -- check region:474 16:88332165-88393529_strand_+_gene_hSE-474, 121164 candidate probes
# --- 55039 probes passed check_dic selection.
# finish in 4.294s, 773 probes kept.
# -- check region:475 17:1571174-1593869_strand_+_gene_hSE-475, 44240 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 0.779s, 0 probes kept.
# -- check region:476 17:1730255-1797245_strand_+_gene_hSE-476, 124190 candidate probes
# --- 14240 probes passed check_dic selection.
# finish in 2.742s, 255 probes kept.
# -- check region:477 17:3502429-3535925_strand_+_gene_hSE-477, 65142 candidate probes
# --- 19444 probes passed check_dic selection.
# finish in 1.900s, 332 probes kept.
# -- check region:478 17:4509868-4541828_strand_+_gene_hSE-478, 63004 candidate probes
# --- 23529 probes passed check_dic selection.
# finish in 2.054s, 396 probes kept.
# -- check region:479 17:4856864-4889505_strand_+_gene_hSE-479, 62116 candidate probes
# --- 16733 probes passed check_dic selection.
# finish in 1.743s, 269 probes kept.
# -- check region:480 17:7191452-7214844_strand_+_gene_hSE-480, 45886 candidate probes
# --- 15548 probes passed check_dic selection.
# finish in 1.421s, 267 probes kept.
# -- check region:481 17:8456615-8481575_strand_+_gene_hSE-481, 49372 candidate probes
# --- 19535 probes passed check_dic selection.
# finish in 1.653s, 328 probes kept.
# -- check region:482 17:8658777-8710289_strand_+_gene_hSE-482, 100386 candidate probes
# --- 28317 probes passed check_dic selection.
# finish in 2.866s, 452 probes kept.
# -- check region:483 17:30933793-30968911_strand_+_gene_hSE-483, 67756 candidate probes
# --- 12652 probes passed check_dic selection.
# finish in 1.672s, 235 probes kept.
# -- check region:484 17:33079134-33128151_strand_+_gene_hSE-484, 97538 candidate probes
# --- 37932 probes passed check_dic selection.
# finish in 3.198s, 588 probes kept.
# -- check region:485 17:40515665-40557340_strand_+_gene_hSE-485, 82358 candidate probes
# --- 30009 probes passed check_dic selection.
# finish in 2.634s, 475 probes kept.
# -- check region:486 17:41959643-41976660_strand_+_gene_hSE-486, 33370 candidate probes
# --- 11863 probes passed check_dic selection.
# finish in 1.069s, 207 probes kept.
# -- check region:487 17:42517419-42555063_strand_+_gene_hSE-487, 72392 candidate probes
# --- 15569 probes passed check_dic selection.
# finish in 1.890s, 315 probes kept.
# -- check region:488 17:46002380-46052395_strand_+_gene_hSE-488, 98368 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 1.710s, 0 probes kept.
# -- check region:489 17:46260101-46287260_strand_+_gene_hSE-489, 52970 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 0.906s, 0 probes kept.
# -- check region:490 17:46752471-46797923_strand_+_gene_hSE-490, 89372 candidate probes
# --- 88 probes passed check_dic selection.
# finish in 1.554s, 4 probes kept.
# -- check region:491 17:46942528-46968778_strand_+_gene_hSE-491, 50638 candidate probes
# --- 16421 probes passed check_dic selection.
# finish in 1.533s, 262 probes kept.
# -- check region:492 17:57091164-57131937_strand_+_gene_hSE-492, 80150 candidate probes
# --- 29562 probes passed check_dic selection.
# finish in 2.597s, 472 probes kept.
# -- check region:493 17:62703766-62757832_strand_+_gene_hSE-493, 106406 candidate probes
# --- 34506 probes passed check_dic selection.
# finish in 3.218s, 529 probes kept.
# -- check region:494 17:66938552-66999946_strand_+_gene_hSE-494, 120907 candidate probes
# --- 49740 probes passed check_dic selection.
# finish in 4.107s, 746 probes kept.
# -- check region:495 17:72501923-72540722_strand_+_gene_hSE-495, 76084 candidate probes
# --- 28812 probes passed check_dic selection.
# finish in 2.449s, 424 probes kept.
# -- check region:496 17:75468170-75507384_strand_+_gene_hSE-496, 76856 candidate probes
# --- 28684 probes passed check_dic selection.
# finish in 2.511s, 476 probes kept.
# -- check region:497 17:75674907-75705147_strand_+_gene_hSE-497, 59206 candidate probes
# --- 20467 probes passed check_dic selection.
# finish in 1.838s, 344 probes kept.
# -- check region:498 17:76138008-76197157_strand_+_gene_hSE-498, 116248 candidate probes
# --- 36425 probes passed check_dic selection.
# finish in 3.477s, 610 probes kept.
# -- check region:499 17:79286361-79323144_strand_+_gene_hSE-499, 72900 candidate probes
# --- 32379 probes passed check_dic selection.
# finish in 2.555s, 459 probes kept.
# -- check region:500 17:80426810-80469269_strand_+_gene_hSE-500, 84072 candidate probes
# --- 34444 probes passed check_dic selection.
# finish in 2.832s, 545 probes kept.
# -- check region:501 18:24176687-24229049_strand_+_gene_hSE-501, 103176 candidate probes
# --- 26541 probes passed check_dic selection.
# finish in 2.801s, 454 probes kept.
# -- check region:502 18:26883139-26920125_strand_+_gene_hSE-502, 73608 candidate probes
# --- 12426 probes passed check_dic selection.
# finish in 1.753s, 297 probes kept.
# -- check region:503 18:35095852-35156068_strand_+_gene_hSE-503, 119676 candidate probes
# --- 34634 probes passed check_dic selection.
# finish in 3.417s, 585 probes kept.
# -- check region:504 18:36482970-36572666_strand_+_gene_hSE-504, 177364 candidate probes
# --- 59336 probes passed check_dic selection.
# finish in 5.380s, 927 probes kept.
# -- check region:505 18:50429142-50478724_strand_+_gene_hSE-505, 98860 candidate probes
# --- 834 probes passed check_dic selection.
# finish in 1.737s, 29 probes kept.
# -- check region:506 18:55371554-55415715_strand_+_gene_hSE-506, 87940 candidate probes
# --- 26392 probes passed check_dic selection.
# finish in 2.529s, 452 probes kept.
# -- check region:507 18:75220811-75258016_strand_+_gene_hSE-507, 74026 candidate probes
# --- 29776 probes passed check_dic selection.
# finish in 2.440s, 451 probes kept.
# -- check region:508 18:78974104-79001521_strand_+_gene_hSE-508, 54754 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 0.891s, 0 probes kept.
# -- check region:509 18:79217945-79261920_strand_+_gene_hSE-509, 86001 candidate probes
# --- 27462 probes passed check_dic selection.
# finish in 2.560s, 442 probes kept.
# -- check region:510 18:79899182-79944630_strand_+_gene_hSE-510, 86742 candidate probes
# --- 33277 probes passed check_dic selection.
# finish in 2.821s, 528 probes kept.
# -- check region:511 19:601971-624241_strand_+_gene_hSE-511, 42766 candidate probes
# --- 14838 probes passed check_dic selection.
# finish in 1.283s, 248 probes kept.
# -- check region:512 19:1851820-1860488_strand_+_gene_hSE-512, 17256 candidate probes
# --- 6999 probes passed check_dic selection.
# finish in 0.575s, 112 probes kept.
# -- check region:513 19:12757504-12783011_strand_+_gene_hSE-513, 48714 candidate probes
# --- 13733 probes passed check_dic selection.
# finish in 1.387s, 228 probes kept.
# -- check region:514 19:13429027-13461991_strand_+_gene_hSE-514, 64508 candidate probes
# --- 13877 probes passed check_dic selection.
# finish in 1.668s, 251 probes kept.
# -- check region:515 19:13847545-13866828_strand_+_gene_hSE-515, 37166 candidate probes
# --- 9877 probes passed check_dic selection.
# finish in 1.017s, 151 probes kept.
# -- check region:516 19:19519357-19541606_strand_+_gene_hSE-516, 43802 candidate probes
# --- 13884 probes passed check_dic selection.
# finish in 1.305s, 233 probes kept.
# -- check region:517 19:29844355-29890340_strand_+_gene_hSE-517, 90408 candidate probes
# --- 25051 probes passed check_dic selection.
# finish in 2.534s, 403 probes kept.
# -- check region:518 19:33235228-33298833_strand_+_gene_hSE-518, 126160 candidate probes
# --- 50171 probes passed check_dic selection.
# finish in 4.200s, 735 probes kept.
# -- check region:519 19:33406742-33434496_strand_+_gene_hSE-519, 55234 candidate probes
# --- 24094 probes passed check_dic selection.
# finish in 1.914s, 347 probes kept.
# -- check region:520 19:40420885-40434283_strand_+_gene_hSE-520, 26002 candidate probes
# --- 5127 probes passed check_dic selection.
# finish in 0.654s, 103 probes kept.
# -- check region:521 19:40539010-40571140_strand_+_gene_hSE-521, 62376 candidate probes
# --- 14085 probes passed check_dic selection.
# finish in 1.633s, 246 probes kept.
# -- check region:522 19:49127845-49152146_strand_+_gene_hSE-522, 47678 candidate probes
# --- 16314 probes passed check_dic selection.
# finish in 1.481s, 269 probes kept.
# -- check region:523 19:50300704-50325990_strand_+_gene_hSE-523, 49926 candidate probes
# --- 14919 probes passed check_dic selection.
# finish in 1.465s, 278 probes kept.
# -- check region:524 19:50524832-50556995_strand_+_gene_hSE-524, 62608 candidate probes
# --- 20727 probes passed check_dic selection.
# finish in 1.906s, 317 probes kept.
# -- check region:525 20:1273305-1305041_strand_+_gene_hSE-525, 61452 candidate probes
# --- 24735 probes passed check_dic selection.
# finish in 2.044s, 382 probes kept.
# -- check region:526 20:5135148-5177583_strand_+_gene_hSE-526, 83844 candidate probes
# --- 25314 probes passed check_dic selection.
# finish in 2.431s, 411 probes kept.
# -- check region:527 20:9682911-9730866_strand_+_gene_hSE-527, 94914 candidate probes
# --- 24054 probes passed check_dic selection.
# finish in 2.558s, 431 probes kept.
# -- check region:528 20:10311323-10352964_strand_+_gene_hSE-528, 82944 candidate probes
# --- 21806 probes passed check_dic selection.
# finish in 2.283s, 409 probes kept.
# -- check region:529 20:16241799-16297292_strand_+_gene_hSE-529, 109442 candidate probes
# --- 40016 probes passed check_dic selection.
# finish in 3.473s, 638 probes kept.
# -- check region:530 20:19961140-19993999_strand_+_gene_hSE-530, 65228 candidate probes
# --- 22055 probes passed check_dic selection.
# finish in 2.005s, 363 probes kept.
# -- check region:531 20:21505148-21530281_strand_+_gene_hSE-531, 50186 candidate probes
# --- 25676 probes passed check_dic selection.
# finish in 1.907s, 346 probes kept.
# -- check region:532 20:31661589-31699620_strand_+_gene_hSE-532, 74730 candidate probes
# --- 20915 probes passed check_dic selection.
# finish in 2.120s, 347 probes kept.
# -- check region:533 20:33415919-33476076_strand_+_gene_hSE-533, 115766 candidate probes
# --- 21743 probes passed check_dic selection.
# finish in 2.865s, 364 probes kept.
# -- check region:534 20:33819468-33871657_strand_+_gene_hSE-534, 103414 candidate probes
# --- 37452 probes passed check_dic selection.
# finish in 3.287s, 594 probes kept.
# -- check region:535 20:37823836-37864837_strand_+_gene_hSE-535, 81648 candidate probes
# --- 32582 probes passed check_dic selection.
# finish in 2.704s, 498 probes kept.
# -- check region:536 20:41631734-41671044_strand_+_gene_hSE-536, 77964 candidate probes
# --- 24430 probes passed check_dic selection.
# finish in 2.294s, 397 probes kept.
# -- check region:537 20:44594716-44642895_strand_+_gene_hSE-537, 95338 candidate probes
# --- 34555 probes passed check_dic selection.
# finish in 3.042s, 541 probes kept.
# -- check region:538 20:44763069-44806416_strand_+_gene_hSE-538, 86364 candidate probes
# --- 31303 probes passed check_dic selection.
# finish in 2.754s, 500 probes kept.
# -- check region:539 20:45962258-46014521_strand_+_gene_hSE-539, 103246 candidate probes
# --- 27696 probes passed check_dic selection.
# finish in 2.914s, 474 probes kept.
# -- check region:540 20:46559688-46588481_strand_+_gene_hSE-540, 57366 candidate probes
# --- 17836 probes passed check_dic selection.
# finish in 1.697s, 303 probes kept.
# -- check region:541 20:51668504-51757755_strand_+_gene_hSE-541, 175346 candidate probes
# --- 40736 probes passed check_dic selection.
# finish in 4.647s, 700 probes kept.
# -- check region:542 20:53608390-53661187_strand_+_gene_hSE-542, 103384 candidate probes
# --- 17894 probes passed check_dic selection.
# finish in 2.462s, 316 probes kept.
# -- check region:543 20:57648277-57684109_strand_+_gene_hSE-543, 71400 candidate probes
# --- 37877 probes passed check_dic selection.
# finish in 2.839s, 534 probes kept.
# -- check region:544 20:59560512-59645271_strand_+_gene_hSE-544, 169072 candidate probes
# --- 68197 probes passed check_dic selection.
# finish in 5.620s, 1035 probes kept.
# -- check region:545 20:61619691-61664938_strand_+_gene_hSE-545, 89010 candidate probes
# --- 44220 probes passed check_dic selection.
# finish in 3.330s, 603 probes kept.
# -- check region:546 20:62210388-62235513_strand_+_gene_hSE-546, 49464 candidate probes
# --- 20137 probes passed check_dic selection.
# finish in 1.684s, 327 probes kept.
# -- check region:547 21:26127925-26173760_strand_+_gene_hSE-547, 90956 candidate probes
# --- 21104 probes passed check_dic selection.
# finish in 2.360s, 391 probes kept.
# -- check region:548 21:33008810-33064965_strand_+_gene_hSE-548, 111538 candidate probes
# --- 48041 probes passed check_dic selection.
# finish in 3.875s, 712 probes kept.
# -- check region:549 21:33359387-33394726_strand_+_gene_hSE-549, 69408 candidate probes
# --- 15908 probes passed check_dic selection.
# finish in 1.820s, 274 probes kept.
# -- check region:550 21:45104328-45161413_strand_+_gene_hSE-550, 113180 candidate probes
# --- 43352 probes passed check_dic selection.
# finish in 3.671s, 644 probes kept.
# -- check region:551 22:18810242-18833000_strand_+_gene_hSE-551, 45412 candidate probes
# --- 20 probes passed check_dic selection.
# finish in 0.794s, 3 probes kept.
# -- check region:552 22:21743448-21775567_strand_+_gene_hSE-552, 63326 candidate probes
# --- 16020 probes passed check_dic selection.
# finish in 1.741s, 300 probes kept.
# -- check region:553 22:23814940-23849939_strand_+_gene_hSE-553, 69456 candidate probes
# --- 0 probes passed check_dic selection.
# finish in 1.237s, 0 probes kept.
# -- check region:554 22:25680920-25726737_strand_+_gene_hSE-554, 91238 candidate probes
# --- 25695 probes passed check_dic selection.
# finish in 2.574s, 447 probes kept.
# -- check region:555 22:27270723-27332254_strand_+_gene_hSE-555, 122676 candidate probes
# --- 47241 probes passed check_dic selection.
# finish in 3.994s, 743 probes kept.
# -- check region:556 22:27642125-27686973_strand_+_gene_hSE-556, 89144 candidate probes
# --- 31449 probes passed check_dic selection.
# finish in 2.791s, 475 probes kept.
# -- check region:557 22:28009271-28052211_strand_+_gene_hSE-557, 85220 candidate probes
# --- 33022 probes passed check_dic selection.
# finish in 2.842s, 475 probes kept.
# -- check region:558 22:28943224-29023880_strand_+_gene_hSE-558, 160476 candidate probes
# --- 47788 probes passed check_dic selection.
# finish in 4.648s, 778 probes kept.
# -- check region:559 22:30856108-30891077_strand_+_gene_hSE-559, 69630 candidate probes
# --- 30424 probes passed check_dic selection.
# finish in 2.440s, 434 probes kept.
# -- check region:560 22:33471967-33536400_strand_+_gene_hSE-560, 128200 candidate probes
# --- 44249 probes passed check_dic selection.
# finish in 3.973s, 674 probes kept.
# -- check region:561 22:33656962-33708838_strand_+_gene_hSE-561, 103556 candidate probes
# --- 36633 probes passed check_dic selection.
# finish in 3.231s, 576 probes kept.
# -- check region:562 22:38763990-38812092_strand_+_gene_hSE-562, 95260 candidate probes
# --- 31623 probes passed check_dic selection.
# finish in 2.908s, 479 probes kept.
# -- check region:563 22:41957901-41979895_strand_+_gene_hSE-563, 43814 candidate probes
# --- 14625 probes passed check_dic selection.
# finish in 1.327s, 222 probes kept.
# -- check region:564 22:44316829-44352293_strand_+_gene_hSE-564, 70762 candidate probes
# --- 31049 probes passed check_dic selection.
# finish in 2.441s, 452 probes kept.
# -- check region:565 22:44571858-44599820_strand_+_gene_hSE-565, 55758 candidate probes
# --- 24198 probes passed check_dic selection.
# finish in 1.950s, 351 probes kept.
# -- check region:566 22:44928982-44981587_strand_+_gene_hSE-566, 105080 candidate probes
# --- 43643 probes passed check_dic selection.
# finish in 3.607s, 649 probes kept.
# -- check region:567 22:49767361-49811691_strand_+_gene_hSE-567, 86818 candidate probes
# --- 39789 probes passed check_dic selection.
# finish in 3.122s, 569 probes kept.

# %% [markdown]
# ### save probes

# %%
overwrite_savefile = True 
if not os.path.exists(pb_designer.save_file) or overwrite_savefile:
    #pb_designer.plots()
    #pb_designer.save_csv()
    pb_designer.save_to_file()
print(f"-- number of probes kept: {len(pb_designer.kept_probes)}")
# Out:
# - Save reports into file: \\10.245.74.212\Chromatin_NAS_2\Chromatin_Libraries\CTP-14_human_brain\human_brain_promoter_enhancer\reports\hSE_probes.pbr
# -- number of probes kept: 265626

# %%
del(pb_designer)
